# %% [markdown]
# # **Swin Transformer pretrained**

# %%
import os
import pandas as pd
from PIL import Image
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torch.nn.functional as F
import torchvision.models as models
import numpy as np
import timm
import torch
import torch.nn.functional as F
import numpy as np
from torcheval.metrics import MulticlassAccuracy, MulticlassPrecision, MulticlassRecall, MulticlassF1Score, MulticlassAUROC, MulticlassAUPRC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import matthews_corrcoef
import random


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)  # For CPU
    torch.cuda.manual_seed(seed)  # For GPU (if used)
    torch.cuda.manual_seed_all(seed)  # For all GPUs
    torch.backends.cudnn.deterministic = True  # Ensure deterministic behavior
    torch.backends.cudnn.benchmark = False


def calculate_metrics(predicted, probabilities, labels, num_classes):
    # Initialize Torcheval metrics
    accuracy_metric = MulticlassAccuracy(num_classes=num_classes, average="macro")
    precision_metric = MulticlassPrecision(num_classes=num_classes, average="macro")
    recall_metric = MulticlassRecall(num_classes=num_classes, average="macro")
    f1_score_metric = MulticlassF1Score(num_classes=num_classes, average="macro")
    auc_metric = MulticlassAUROC(num_classes=num_classes, average="macro")
    aupr_metric = MulticlassAUPRC(num_classes=num_classes, average="macro")

    # Update metrics with predictions
    accuracy_metric.update(predicted, labels)
    precision_metric.update(predicted, labels)
    recall_metric.update(predicted, labels)
    f1_score_metric.update(predicted, labels)
    auc_metric.update(probabilities, labels)
    aupr_metric.update(probabilities, labels)

    # Compute metrics
    accuracy = accuracy_metric.compute()
    precision = precision_metric.compute()
    recall = recall_metric.compute()
    f1_score = f1_score_metric.compute()
    auc = auc_metric.compute()
    aupr = aupr_metric.compute()

    # Specificity calculation
    conf_matrix = confusion_matrix(labels.cpu().numpy(), predicted.cpu().numpy(), labels=range(num_classes))
    specificity_per_class = []

    for i in range(num_classes):
        TP = conf_matrix[i, i]
        FP = conf_matrix[:, i].sum() - TP
        FN = conf_matrix[i, :].sum() - TP
        TN = conf_matrix.sum() - (TP + FP + FN)

        specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
        specificity_per_class.append(specificity)

    macro_specificity = np.mean(specificity_per_class)

    # MCC calculation for multi-class classification
    mcc_per_class = []
    for i in range(num_classes):
        # Treat each class as the positive class and others as negative
        binary_pred = (predicted == i).int()
        binary_labels = (labels == i).int()
        mcc = matthews_corrcoef(binary_labels.cpu().numpy(), binary_pred.cpu().numpy())
        mcc_per_class.append(mcc)

    macro_mcc = np.mean(mcc_per_class)

    # Print all metrics
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1_score:.4f}")
    print(f"AUC: {auc:.4f}")
    print(f"AUPR: {aupr:.4f}")
    print(f"Specificity per class: {specificity_per_class}")
    print(f"Macro-average Specificity: {macro_specificity:.4f}")
    print(f"MCC per class: {mcc_per_class}")
    print(f"Macro-average MCC: {macro_mcc:.4f}")

    f1_score_metric_micro = MulticlassF1Score(num_classes=num_classes, average="micro")
    f1_score_metric_micro.update(predicted, labels)
    f1_score_micro = f1_score_metric_micro.compute()
    print(f"F1 Score (micro): {f1_score_micro:.4f}")

    f1_score_metric_weighted = MulticlassF1Score(num_classes=num_classes, average="weighted")
    f1_score_metric_weighted.update(predicted, labels)
    f1_score_weighted = f1_score_metric_weighted.compute()
    print(f"F1 Score (weighted): {f1_score_weighted:.4f}")


    # Return metrics as a dictionary
    return {
        "accuracy": "{:.4f}".format(accuracy.item()),
        "precision": "{:.4f}".format(precision.item()),
        "recall": "{:.4f}".format(recall.item()),
        "f1_score": "{:.4f}".format(f1_score.item()),
        "auc": "{:.4f}".format(auc.item()),
        "aupr": "{:.4f}".format(aupr.item()),
        "macro_specificity": "{:.4f}".format(macro_specificity.item()),
        "macro_mcc": "{:.4f}".format(macro_mcc.item())
    }


class ImageDataset(Dataset):
    def __init__(self, images, features, labels, transform=None):
        self.images = images
        self.features = features
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        feature = self.features[idx]
        label = self.labels[idx]
        return image, feature, label


# Image transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

set_seed(42)

dataset_path = "baldder_tissue_classification"

train_df = pd.read_csv("train_df.csv")
val_df = pd.read_csv("val_df.csv")

train_images = []
train_labels = []
for idx, row in train_df.iterrows():
    image_path = os.path.join(dataset_path, row[1], row[0])
    image = Image.open(image_path)
    image = transform(image)
    train_images.append(image)
    train_labels.append(row['encoded_label'])

loaded_images = np.load("top_images.npy")
loaded_labels = np.load("top_labels.npy")
print(len(train_images))
for i in range(len(loaded_images)):
    image = loaded_images[i]
    label = loaded_labels[i]

    # Denormalize the image
    image = (image * np.array([0.229, 0.224, 0.225])[:, None, None]) + np.array([0.485, 0.456, 0.406])[:, None, None]
    image = (image * 255).astype(np.uint8)  # Convert to integer type for PIL compatibility

    # Convert NumPy array to PIL image
    image = Image.fromarray(image.transpose(1, 2, 0))  # H x W x C format

    # Apply transformations
    image = transform(image)

    # Convert back to PyTorch tensor (if required)
    image = torch.tensor(image, dtype=torch.float32)
    train_images.append(image)
    train_labels.append(label)

print(len(train_images))

val_images = []
val_labels = []
for idx, row in val_df.iterrows():
    image_path = os.path.join(dataset_path, row[1], row[0])
    image = Image.open(image_path)
    image = transform(image)
    val_images.append(image)
    val_labels.append(row['encoded_label'])

print(len(val_images))

train_features = np.load("features_RFE.npy")[:-val_df.shape[0]]
augmented_features = np.load("features_top_images_RFE.npy")
train_features = np.concatenate((train_features, augmented_features), axis=0)
val_features = np.load("features_RFE.npy")[-val_df.shape[0]:]

print(train_features.shape)
print(val_features.shape)

# Create DataLoaders
train_dataset = ImageDataset(train_images, train_features, train_labels, transform=transform)
val_dataset = ImageDataset(val_images, val_features, val_labels, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)


# Define the CNN model
class SimpleCNN(nn.Module):
    def __init__(self, num_classes):
        super(SimpleCNN, self).__init__()
        self.block = timm.create_model('swin_base_patch4_window7_224.ms_in22k_ft_in1k', pretrained=True)
        # self.block.head = nn.Linear(self.block.num_features, 1000)

        self.fc1 = nn.Linear(1000, 512)
        self.bn1 = nn.BatchNorm1d(512)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(0.2)
        self.fc2 = nn.Linear(512, 256)
        self.bn2 = nn.BatchNorm1d(256)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(0.2)

        self.fc_ann1 = nn.Linear(512, 256)
        self.bn_ann1 = nn.BatchNorm1d(256)
        self.relu_ann1 = nn.ReLU()
        self.dropout_ann1 = nn.Dropout(0.2)
        self.fc_ann2 = nn.Linear(256, 128)
        self.bn_ann2 = nn.BatchNorm1d(128)
        self.relu_ann2 = nn.ReLU()
        self.dropout_ann2 = nn.Dropout(0.2)

        self.fc_comb = nn.Linear(384, 256)
        self.bn_comb = nn.BatchNorm1d(256)
        self.relu_comb = nn.ReLU()
        self.dropout_comb = nn.Dropout(0.2)

        self.fc3 = nn.Linear(256, 128)
        self.bn3 = nn.BatchNorm1d(128)
        self.relu3 = nn.ReLU()
        self.dropout3 = nn.Dropout(0.2)
        self.fc4 = nn.Linear(128, num_classes)

        self.relu = nn.ReLU()


    def forward(self, x, features):
        features = features.float()
        x = self.block(x)
        # print(x.shape)
        x = x.view(-1, 1000)  # Flatten
        x = self.dropout1(self.relu1(self.bn1(self.fc1(x))))
        x = self.dropout2(self.relu2(self.bn2(self.fc2(x))))

        features = self.dropout_ann1(self.relu_ann1(self.bn_ann1(self.fc_ann1(features))))
        features = self.dropout_ann2(self.relu_ann2(self.bn_ann2(self.fc_ann2(features))))

        x = torch.cat((x, features), dim=1)
        x = self.dropout_comb(self.relu_comb(self.bn_comb(self.fc_comb(x))))

        x = self.dropout3(self.relu3(self.bn3(self.fc3(x))))
        x = self.fc4(x)
        return x


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")
# Instantiate model, loss function, and optimizer
num_classes = 4
model = SimpleCNN(num_classes)
model = model.to(device)
criterion = nn.CrossEntropyLoss().to(device)

optimizer = optim.Adam(model.parameters(), lr=0.0001)

# Training loop
num_epochs = 50
all_metrics = []

best_f1 = -100
best_epoch = 0
best_metric = 0
with open('Results/swin_base_patch4_window7_224_pretrained.csv', 'w') as f:
    f.write("Epoch,Train Loss,Val Loss,Accuracy,Precision,Recall,F1 Score,AUC,AUPR,Specificity,MCC\n")
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for images, features, labels in train_loader:
            images, features, labels = images.to(device), features.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images, features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * images.size(0)

        train_loss = running_loss / len(train_loader.dataset)
        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {train_loss:.4f}")

        # Validation loop
        model.eval()
        running_loss = 0.0
        with torch.no_grad():
            y_pred = []
            y_true = []
            y_proba = []
            for images, features, labels in val_loader:
                images, features, labels = images.to(device), features.to(device), labels.to(device)

                outputs = model(images, features)
                loss = criterion(outputs, labels)

                running_loss += loss.item() * images.size(0)

                # Apply softmax to get probabilities
                probabilities = F.softmax(outputs, dim=1)

                # Get the predicted class and corresponding probability
                proba, predicted = torch.max(probabilities, 1)

                # Store results
                y_pred.extend(predicted.cpu().tolist())
                y_true.extend(labels.cpu().tolist())
                y_proba.extend(probabilities.cpu().tolist())

            val_loss = running_loss / len(val_loader.dataset)
            print(f"Epoch {epoch+1}/{num_epochs}, Loss: {val_loss:.4f}")
            # Convert lists to tensors
            y_pred = torch.tensor(y_pred)
            y_true = torch.tensor(y_true)
            y_proba = torch.tensor(y_proba)

            metrics = calculate_metrics(y_pred, y_proba, y_true, num_classes)
            all_metrics.append(metrics)

            if best_f1 < float(metrics["f1_score"]):
                best_f1 = float(metrics["f1_score"])
                best_epoch = epoch+1
                best_metric = metrics
            print('---------------------------------------------------------------------------------------------------')

            f.write(f"{epoch+1},{train_loss},{val_loss},{metrics['accuracy']},{metrics['precision']},{metrics['recall']},{metrics['f1_score']},{metrics['auc']},{metrics['aupr']},{metrics['macro_specificity']},{metrics['macro_mcc']}\n")
            f.flush()
    print("Training and validating complete")
# Out:
# <ipython-input-7-ebc52e334170>:155: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   image_path = os.path.join(dataset_path, row[1], row[0])
# 1262
# <ipython-input-7-ebc52e334170>:179: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   image = torch.tensor(image, dtype=torch.float32)
# 1762
# <ipython-input-7-ebc52e334170>:188: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   image_path = os.path.join(dataset_path, row[1], row[0])
# 316
# (1762, 512)
# (316, 512)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Epoch 1/50, Loss: 1.0234
# Epoch 1/50, Loss: 0.7297
# Accuracy: 0.6266
# Precision: 0.7177
# Recall: 0.6266
# F1 Score: 0.6278
# AUC: 0.9193
# AUPR: 0.7503
# Specificity per class: [0.8362068965517241, 0.8391959798994975, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9160
# MCC per class: [0.5059248958578667, 0.7879623642614569, 0.8219586442409945, 0.18124266959083374]
# Macro-average MCC: 0.5743
# F1 Score (micro): 0.7690
# F1 Score (weighted): 0.7500
# ---------------------------------------------------------------------------------------------------
# Epoch 2/50, Loss: 0.9549
# Epoch 2/50, Loss: 0.6845
# Accuracy: 0.6649
# Precision: 0.7315
# Recall: 0.6649
# F1 Score: 0.6681
# AUC: 0.9124
# AUPR: 0.7611
# Specificity per class: [0.7413793103448276, 0.9447236180904522, 0.9955555555555555, 0.9828767123287672]
# Macro-average Specificity: 0.9161
# MCC per class: [0.5866148796725079, 0.6563418101663109, 0.8994303870852426, 0.2893656919124181]
# Macro-average MCC: 0.6079
# F1 Score (micro): 0.7563
# F1 Score (weighted): 0.7540
# ---------------------------------------------------------------------------------------------------
# Epoch 3/50, Loss: 0.7555
# Epoch 3/50, Loss: 0.5270
# Accuracy: 0.7387
# Precision: 0.8966
# Recall: 0.7387
# F1 Score: 0.7548
# AUC: 0.9640
# AUPR: 0.8945
# Specificity per class: [0.7801724137931034, 0.9849246231155779, 1.0, 1.0]
# Macro-average Specificity: 0.9413
# MCC per class: [0.6867648986963164, 0.7859794061529034, 0.9461635504451551, 0.5249955051947106]
# Macro-average MCC: 0.7360
# F1 Score (micro): 0.8291
# F1 Score (weighted): 0.8265
# ---------------------------------------------------------------------------------------------------
# Epoch 4/50, Loss: 0.5730
# Epoch 4/50, Loss: 0.3655
# Accuracy: 0.8322
# Precision: 0.9357
# Recall: 0.8322
# F1 Score: 0.8577
# AUC: 0.9813
# AUPR: 0.9257
# Specificity per class: [0.9267241379310345, 0.964824120603015, 0.9911111111111112, 1.0]
# Macro-average Specificity: 0.9707
# MCC per class: [0.8420085581822808, 0.9049950607739552, 0.9691330891330892, 0.6624181566108]
# Macro-average MCC: 0.8446
# F1 Score (micro): 0.9177
# F1 Score (weighted): 0.9125
# ---------------------------------------------------------------------------------------------------
# Epoch 5/50, Loss: 0.5571
# Epoch 5/50, Loss: 0.3863
# Accuracy: 0.7875
# Precision: 0.9091
# Recall: 0.7875
# F1 Score: 0.8108
# AUC: 0.9803
# AUPR: 0.9233
# Specificity per class: [0.8922413793103449, 0.9447236180904522, 0.9911111111111112, 1.0]
# Macro-average Specificity: 0.9570
# MCC per class: [0.7643210457796498, 0.8296210929895484, 0.9691330891330892, 0.5972248524885476]
# Macro-average MCC: 0.7901
# F1 Score (micro): 0.8797
# F1 Score (weighted): 0.8733
# ---------------------------------------------------------------------------------------------------
# Epoch 6/50, Loss: 0.4692
# Epoch 6/50, Loss: 0.3074
# Accuracy: 0.8489
# Precision: 0.9331
# Recall: 0.8489
# F1 Score: 0.8712
# AUC: 0.9900
# AUPR: 0.9522
# Specificity per class: [0.9137931034482759, 0.9899497487437185, 0.9777777777777777, 1.0]
# Macro-average Specificity: 0.9704
# MCC per class: [0.8409276971582241, 0.8988061414620218, 0.9547410841058538, 0.7224971973786625]
# Macro-average MCC: 0.8542
# F1 Score (micro): 0.9146
# F1 Score (weighted): 0.9118
# ---------------------------------------------------------------------------------------------------
# Epoch 7/50, Loss: 0.4441
# Epoch 7/50, Loss: 0.2958
# Accuracy: 0.8880
# Precision: 0.9484
# Recall: 0.8880
# F1 Score: 0.9072
# AUC: 0.9888
# AUPR: 0.9473
# Specificity per class: [0.9181034482758621, 0.9949748743718593, 0.9955555555555555, 1.0]
# Macro-average Specificity: 0.9772
# MCC per class: [0.8562490274339389, 0.9126866390039042, 0.9923377950662305, 0.8055363982396382]
# Macro-average MCC: 0.8917
# F1 Score (micro): 0.9335
# F1 Score (weighted): 0.9331
# ---------------------------------------------------------------------------------------------------
# Epoch 8/50, Loss: 0.3708
# Epoch 8/50, Loss: 0.2172
# Accuracy: 0.9049
# Precision: 0.9341
# Recall: 0.9049
# F1 Score: 0.9155
# AUC: 0.9963
# AUPR: 0.9804
# Specificity per class: [0.9482758620689655, 1.0, 0.9866666666666667, 0.9931506849315068]
# Macro-average Specificity: 0.9820
# MCC per class: [0.9021394970306476, 0.9397532094515858, 0.9773317271860865, 0.7817354424163053]
# Macro-average MCC: 0.9002
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9453
# ---------------------------------------------------------------------------------------------------
# Epoch 9/50, Loss: 0.3123
# Epoch 9/50, Loss: 0.2210
# Accuracy: 0.8950
# Precision: 0.9249
# Recall: 0.8950
# F1 Score: 0.9038
# AUC: 0.9971
# AUPR: 0.9786
# Specificity per class: [0.9181034482758621, 1.0, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9767
# MCC per class: [0.8653002714427839, 0.9003820048251676, 0.9923377950662305, 0.7817354424163053]
# Macro-average MCC: 0.8849
# F1 Score (micro): 0.9304
# F1 Score (weighted): 0.9302
# ---------------------------------------------------------------------------------------------------
# Epoch 10/50, Loss: 0.2622
# Epoch 10/50, Loss: 0.1758
# Accuracy: 0.8988
# Precision: 0.9303
# Recall: 0.8988
# F1 Score: 0.9102
# AUC: 0.9979
# AUPR: 0.9850
# Specificity per class: [0.9353448275862069, 0.9949748743718593, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9798
# MCC per class: [0.881964418149203, 0.939250105582329, 0.9690466897894506, 0.7817354424163053]
# Macro-average MCC: 0.8930
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9397
# ---------------------------------------------------------------------------------------------------
# Epoch 11/50, Loss: 0.2255
# Epoch 11/50, Loss: 0.2858
# Accuracy: 0.8781
# Precision: 0.8825
# Recall: 0.8781
# F1 Score: 0.8743
# AUC: 0.9964
# AUPR: 0.9806
# Specificity per class: [0.9267241379310345, 1.0, 0.9466666666666667, 0.9863013698630136]
# Macro-average Specificity: 0.9649
# MCC per class: [0.859969113749979, 0.8358022036135844, 0.9145356223410569, 0.7664214473484227]
# Macro-average MCC: 0.8442
# F1 Score (micro): 0.8956
# F1 Score (weighted): 0.8938
# ---------------------------------------------------------------------------------------------------
# Epoch 12/50, Loss: 0.4827
# Epoch 12/50, Loss: 0.3316
# Accuracy: 0.8884
# Precision: 0.8326
# Recall: 0.8884
# F1 Score: 0.8369
# AUC: 0.9900
# AUPR: 0.9488
# Specificity per class: [0.9568965517241379, 0.9899497487437185, 1.0, 0.910958904109589]
# Macro-average Specificity: 0.9645
# MCC per class: [0.9073772042004405, 0.8921716075923306, 0.84647998770768, 0.6108617489875351]
# Macro-average MCC: 0.8142
# F1 Score (micro): 0.8797
# F1 Score (weighted): 0.8901
# ---------------------------------------------------------------------------------------------------
# Epoch 13/50, Loss: 0.4558
# Epoch 13/50, Loss: 0.2603
# Accuracy: 0.9301
# Precision: 0.9188
# Recall: 0.9301
# F1 Score: 0.9227
# AUC: 0.9921
# AUPR: 0.9714
# Specificity per class: [0.9396551724137931, 0.9899497487437185, 1.0, 0.9863013698630136]
# Macro-average Specificity: 0.9790
# MCC per class: [0.8797493707395952, 0.8921716075923306, 0.9922876771341849, 0.8453483040258218]
# Macro-average MCC: 0.9024
# F1 Score (micro): 0.9367
# F1 Score (weighted): 0.9372
# ---------------------------------------------------------------------------------------------------
# Epoch 14/50, Loss: 0.3947
# Epoch 14/50, Loss: 0.3148
# Accuracy: 0.8622
# Precision: 0.8623
# Recall: 0.8622
# F1 Score: 0.8527
# AUC: 0.9917
# AUPR: 0.9629
# Specificity per class: [0.8620689655172413, 0.9949748743718593, 0.9955555555555555, 0.9794520547945206]
# Macro-average Specificity: 0.9580
# MCC per class: [0.7806196899817874, 0.7956081216384681, 0.9690466897894506, 0.7294520547945206]
# Macro-average MCC: 0.8187
# F1 Score (micro): 0.8734
# F1 Score (weighted): 0.8745
# ---------------------------------------------------------------------------------------------------
# Epoch 15/50, Loss: 0.3456
# Epoch 15/50, Loss: 0.2492
# Accuracy: 0.9054
# Precision: 0.8936
# Recall: 0.9054
# F1 Score: 0.8973
# AUC: 0.9924
# AUPR: 0.9714
# Specificity per class: [0.9310344827586207, 0.9798994974874372, 0.9911111111111112, 0.9828767123287672]
# Macro-average Specificity: 0.9712
# MCC per class: [0.8575394188165092, 0.8509795986543359, 0.9691330891330892, 0.801092163523476]
# Macro-average MCC: 0.8697
# F1 Score (micro): 0.9146
# F1 Score (weighted): 0.9148
# ---------------------------------------------------------------------------------------------------
# Epoch 16/50, Loss: 0.2955
# Epoch 16/50, Loss: 0.2059
# Accuracy: 0.9497
# Precision: 0.9211
# Recall: 0.9497
# F1 Score: 0.9330
# AUC: 0.9945
# AUPR: 0.9777
# Specificity per class: [0.9525862068965517, 0.9899497487437185, 1.0, 0.9828767123287672]
# Macro-average Specificity: 0.9814
# MCC per class: [0.9003285737788081, 0.9054549279550154, 0.9768873266890564, 0.8774216391143502]
# Macro-average MCC: 0.9150
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9437
# ---------------------------------------------------------------------------------------------------
# Epoch 17/50, Loss: 0.2494
# Epoch 17/50, Loss: 0.2158
# Accuracy: 0.9377
# Precision: 0.8867
# Recall: 0.9377
# F1 Score: 0.9059
# AUC: 0.9943
# AUPR: 0.9800
# Specificity per class: [0.9482758620689655, 0.9798994974874372, 0.9866666666666667, 0.9726027397260274]
# Macro-average Specificity: 0.9719
# MCC per class: [0.8758405569800997, 0.8310102051300107, 0.9615706499287768, 0.8540796536591423]
# Macro-average MCC: 0.8806
# F1 Score (micro): 0.9146
# F1 Score (weighted): 0.9145
# ---------------------------------------------------------------------------------------------------
# Epoch 18/50, Loss: 0.2345
# Epoch 18/50, Loss: 0.1827
# Accuracy: 0.9401
# Precision: 0.9158
# Recall: 0.9401
# F1 Score: 0.9265
# AUC: 0.9957
# AUPR: 0.9853
# Specificity per class: [0.9568965517241379, 0.9698492462311558, 0.9911111111111112, 0.9863013698630136]
# Macro-average Specificity: 0.9760
# MCC per class: [0.8900299226224551, 0.8568492412252594, 0.9691330891330892, 0.8952207487823]
# Macro-average MCC: 0.9028
# F1 Score (micro): 0.9304
# F1 Score (weighted): 0.9303
# ---------------------------------------------------------------------------------------------------
# Epoch 19/50, Loss: 0.1966
# Epoch 19/50, Loss: 0.2068
# Accuracy: 0.9217
# Precision: 0.9205
# Recall: 0.9217
# F1 Score: 0.9203
# AUC: 0.9937
# AUPR: 0.9797
# Specificity per class: [0.9439655172413793, 0.9698492462311558, 1.0, 0.9897260273972602]
# Macro-average Specificity: 0.9759
# MCC per class: [0.8688916865617802, 0.8909856897472449, 0.9615145720873706, 0.8647260273972602]
# Macro-average MCC: 0.8965
# F1 Score (micro): 0.9304
# F1 Score (weighted): 0.9311
# ---------------------------------------------------------------------------------------------------
# Epoch 20/50, Loss: 0.1661
# Epoch 20/50, Loss: 0.1806
# Accuracy: 0.9373
# Precision: 0.9246
# Recall: 0.9373
# F1 Score: 0.9300
# AUC: 0.9962
# AUPR: 0.9862
# Specificity per class: [0.9612068965517241, 0.9849246231155779, 0.9777777777777777, 0.9897260273972602]
# Macro-average Specificity: 0.9784
# MCC per class: [0.8972759311048011, 0.8849256439201393, 0.9627314536524979, 0.8896044445281678]
# Macro-average MCC: 0.9086
# F1 Score (micro): 0.9367
# F1 Score (weighted): 0.9363
# ---------------------------------------------------------------------------------------------------
# Epoch 21/50, Loss: 0.1549
# Epoch 21/50, Loss: 0.2017
# Accuracy: 0.9220
# Precision: 0.8981
# Recall: 0.9220
# F1 Score: 0.9069
# AUC: 0.9945
# AUPR: 0.9815
# Specificity per class: [0.9267241379310345, 0.9748743718592965, 1.0, 0.9828767123287672]
# Macro-average Specificity: 0.9711
# MCC per class: [0.8509907844378062, 0.8302961063315345, 0.9845836908536074, 0.852488157148583]
# Macro-average MCC: 0.8796
# F1 Score (micro): 0.9146
# F1 Score (weighted): 0.9149
# ---------------------------------------------------------------------------------------------------
# Epoch 22/50, Loss: 0.1437
# Epoch 22/50, Loss: 0.1511
# Accuracy: 0.9517
# Precision: 0.9345
# Recall: 0.9517
# F1 Score: 0.9424
# AUC: 0.9963
# AUPR: 0.9911
# Specificity per class: [0.9698275862068966, 0.9748743718592965, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9814
# MCC per class: [0.9206073369943373, 0.8910182431431822, 0.9691330891330892, 0.9140014911483973]
# Macro-average MCC: 0.9237
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9462
# ---------------------------------------------------------------------------------------------------
# Epoch 23/50, Loss: 0.1240
# Epoch 23/50, Loss: 0.1643
# Accuracy: 0.9505
# Precision: 0.9101
# Recall: 0.9505
# F1 Score: 0.9270
# AUC: 0.9964
# AUPR: 0.9877
# Specificity per class: [0.9698275862068966, 0.9748743718592965, 0.9866666666666667, 0.9794520547945206]
# Macro-average Specificity: 0.9777
# MCC per class: [0.9120851963967855, 0.8639094426589815, 0.9615706499287768, 0.8851901738245949]
# Macro-average MCC: 0.9057
# F1 Score (micro): 0.9335
# F1 Score (weighted): 0.9335
# ---------------------------------------------------------------------------------------------------
# Epoch 24/50, Loss: 0.1226
# Epoch 24/50, Loss: 0.1920
# Accuracy: 0.9360
# Precision: 0.8942
# Recall: 0.9360
# F1 Score: 0.9096
# AUC: 0.9963
# AUPR: 0.9842
# Specificity per class: [0.9439655172413793, 0.9949748743718593, 0.9822222222222222, 0.976027397260274]
# Macro-average Specificity: 0.9743
# MCC per class: [0.8865171778142027, 0.8537465402871464, 0.9620442890220036, 0.8444384117429264]
# Macro-average MCC: 0.8867
# F1 Score (micro): 0.9209
# F1 Score (weighted): 0.9206
# ---------------------------------------------------------------------------------------------------
# Epoch 25/50, Loss: 0.1028
# Epoch 25/50, Loss: 0.1665
# Accuracy: 0.9446
# Precision: 0.9118
# Recall: 0.9446
# F1 Score: 0.9256
# AUC: 0.9961
# AUPR: 0.9874
# Specificity per class: [0.9612068965517241, 0.9748743718592965, 1.0, 0.9794520547945206]
# Macro-average Specificity: 0.9789
# MCC per class: [0.9059017880597403, 0.8774366592188979, 0.9768873266890564, 0.8605191922093021]
# Macro-average MCC: 0.9052
# F1 Score (micro): 0.9367
# F1 Score (weighted): 0.9373
# ---------------------------------------------------------------------------------------------------
# Epoch 26/50, Loss: 0.1101
# Epoch 26/50, Loss: 0.1371
# Accuracy: 0.9597
# Precision: 0.9298
# Recall: 0.9597
# F1 Score: 0.9430
# AUC: 0.9975
# AUPR: 0.9910
# Specificity per class: [0.978448275862069, 0.9798994974874372, 0.9822222222222222, 0.9863013698630136]
# Macro-average Specificity: 0.9817
# MCC per class: [0.9273382946495989, 0.8912236406874062, 0.9620442890220036, 0.9194569996298345]
# Macro-average MCC: 0.9250
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9460
# ---------------------------------------------------------------------------------------------------
# Epoch 27/50, Loss: 0.1059
# Epoch 27/50, Loss: 0.1719
# Accuracy: 0.9528
# Precision: 0.9141
# Recall: 0.9528
# F1 Score: 0.9297
# AUC: 0.9962
# AUPR: 0.9885
# Specificity per class: [0.9568965517241379, 0.9899497487437185, 0.9822222222222222, 0.9828767123287672]
# Macro-average Specificity: 0.9780
# MCC per class: [0.9073772042004405, 0.8657642388851019, 0.9620442890220036, 0.9018953432650142]
# Macro-average MCC: 0.9093
# F1 Score (micro): 0.9335
# F1 Score (weighted): 0.9330
# ---------------------------------------------------------------------------------------------------
# Epoch 28/50, Loss: 0.1012
# Epoch 28/50, Loss: 0.1832
# Accuracy: 0.9499
# Precision: 0.9193
# Recall: 0.9499
# F1 Score: 0.9313
# AUC: 0.9962
# AUPR: 0.9878
# Specificity per class: [0.9482758620689655, 0.9899497487437185, 1.0, 0.9828767123287672]
# Macro-average Specificity: 0.9803
# MCC per class: [0.9109014103130726, 0.8789429484359373, 0.9845836908536074, 0.8774216391143502]
# Macro-average MCC: 0.9130
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9400
# ---------------------------------------------------------------------------------------------------
# Epoch 29/50, Loss: 0.0928
# Epoch 29/50, Loss: 0.1453
# Accuracy: 0.9570
# Precision: 0.9273
# Recall: 0.9570
# F1 Score: 0.9405
# AUC: 0.9968
# AUPR: 0.9902
# Specificity per class: [0.9741379310344828, 0.9748743718592965, 0.9866666666666667, 0.9863013698630136]
# Macro-average Specificity: 0.9805
# MCC per class: [0.9196546412641213, 0.8842203413542737, 0.9615706499287768, 0.9194569996298345]
# Macro-average MCC: 0.9212
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9429
# ---------------------------------------------------------------------------------------------------
# Epoch 30/50, Loss: 0.0818
# Epoch 30/50, Loss: 0.1723
# Accuracy: 0.9350
# Precision: 0.9093
# Recall: 0.9350
# F1 Score: 0.9189
# AUC: 0.9965
# AUPR: 0.9867
# Specificity per class: [0.9439655172413793, 0.9949748743718593, 0.9866666666666667, 0.9828767123287672]
# Macro-average Specificity: 0.9771
# MCC per class: [0.895325390526334, 0.8732831003040421, 0.9694477535121453, 0.852488157148583]
# Macro-average MCC: 0.8976
# F1 Score (micro): 0.9304
# F1 Score (weighted): 0.9302
# ---------------------------------------------------------------------------------------------------
# Epoch 31/50, Loss: 0.0693
# Epoch 31/50, Loss: 0.1322
# Accuracy: 0.9506
# Precision: 0.9475
# Recall: 0.9506
# F1 Score: 0.9486
# AUC: 0.9973
# AUPR: 0.9916
# Specificity per class: [0.9655172413793104, 0.9849246231155779, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9848
# MCC per class: [0.9217736534970257, 0.9252324391444847, 0.9768030891848316, 0.9098173515981736]
# Macro-average MCC: 0.9334
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9558
# ---------------------------------------------------------------------------------------------------
# Epoch 32/50, Loss: 0.0660
# Epoch 32/50, Loss: 0.1615
# Accuracy: 0.9497
# Precision: 0.9180
# Recall: 0.9497
# F1 Score: 0.9308
# AUC: 0.9971
# AUPR: 0.9892
# Specificity per class: [0.9568965517241379, 0.9949748743718593, 0.9866666666666667, 0.9828767123287672]
# Macro-average Specificity: 0.9804
# MCC per class: [0.9160470173873222, 0.886364825126441, 0.9694477535121453, 0.8774216391143502]
# Macro-average MCC: 0.9123
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9397
# ---------------------------------------------------------------------------------------------------
# Epoch 33/50, Loss: 0.0717
# Epoch 33/50, Loss: 0.1294
# Accuracy: 0.9562
# Precision: 0.9729
# Recall: 0.9562
# F1 Score: 0.9640
# AUC: 0.9969
# AUPR: 0.9924
# Specificity per class: [0.978448275862069, 0.9698492462311558, 1.0, 1.0]
# Macro-average Specificity: 0.9871
# MCC per class: [0.9357496161555404, 0.9324627709882455, 0.9845836908536074, 0.9541649956911371]
# Macro-average MCC: 0.9517
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9653
# ---------------------------------------------------------------------------------------------------
# Epoch 34/50, Loss: 0.0697
# Epoch 34/50, Loss: 0.1384
# Accuracy: 0.9442
# Precision: 0.9396
# Recall: 0.9442
# F1 Score: 0.9411
# AUC: 0.9975
# AUPR: 0.9920
# Specificity per class: [0.9568965517241379, 0.9849246231155779, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9815
# MCC per class: [0.9073772042004405, 0.9050106221559147, 0.9691330891330892, 0.9098173515981736]
# Macro-average MCC: 0.9228
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9463
# ---------------------------------------------------------------------------------------------------
# Epoch 35/50, Loss: 0.0663
# Epoch 35/50, Loss: 0.1629
# Accuracy: 0.9418
# Precision: 0.9219
# Recall: 0.9418
# F1 Score: 0.9296
# AUC: 0.9976
# AUPR: 0.9940
# Specificity per class: [0.9396551724137931, 0.9849246231155779, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9764
# MCC per class: [0.8797493707395952, 0.8649612735451366, 0.9691330891330892, 0.9140014911483973]
# Macro-average MCC: 0.9070
# F1 Score (micro): 0.9304
# F1 Score (weighted): 0.9303
# ---------------------------------------------------------------------------------------------------
# Epoch 36/50, Loss: 0.0651
# Epoch 36/50, Loss: 0.1302
# Accuracy: 0.9544
# Precision: 0.9427
# Recall: 0.9544
# F1 Score: 0.9480
# AUC: 0.9977
# AUPR: 0.9924
# Specificity per class: [0.9741379310344828, 0.9849246231155779, 0.9777777777777777, 0.9931506849315068]
# Macro-average Specificity: 0.9825
# MCC per class: [0.9281223053474523, 0.9050106221559147, 0.9547410841058538, 0.9338605850305136]
# Macro-average MCC: 0.9304
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9491
# ---------------------------------------------------------------------------------------------------
# Epoch 37/50, Loss: 0.0616
# Epoch 37/50, Loss: 0.1282
# Accuracy: 0.9555
# Precision: 0.9434
# Recall: 0.9555
# F1 Score: 0.9483
# AUC: 0.9975
# AUPR: 0.9927
# Specificity per class: [0.9568965517241379, 0.9849246231155779, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9826
# MCC per class: [0.9160470173873222, 0.8983012253384226, 0.9768030891848316, 0.9338605850305136]
# Macro-average MCC: 0.9313
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9494
# ---------------------------------------------------------------------------------------------------
# Epoch 38/50, Loss: 0.0735
# Epoch 38/50, Loss: 0.1392
# Accuracy: 0.9554
# Precision: 0.9294
# Recall: 0.9554
# F1 Score: 0.9408
# AUC: 0.9974
# AUPR: 0.9932
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 0.9733333333333334, 0.9897260273972602]
# Macro-average Specificity: 0.9795
# MCC per class: [0.9120851963967855, 0.8849256439201393, 0.9475354926457952, 0.937953340416017]
# Macro-average MCC: 0.9206
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9394
# ---------------------------------------------------------------------------------------------------
# Epoch 39/50, Loss: 0.0498
# Epoch 39/50, Loss: 0.1253
# Accuracy: 0.9619
# Precision: 0.9411
# Recall: 0.9619
# F1 Score: 0.9506
# AUC: 0.9975
# AUPR: 0.9938
# Specificity per class: [0.9827586206896551, 0.9748743718592965, 0.9866666666666667, 0.9897260273972602]
# Macro-average Specificity: 0.9835
# MCC per class: [0.9267845820012487, 0.9183645700774931, 0.9536996336996337, 0.937953340416017]
# Macro-average MCC: 0.9342
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9526
# ---------------------------------------------------------------------------------------------------
# Epoch 40/50, Loss: 0.0531
# Epoch 40/50, Loss: 0.1432
# Accuracy: 0.9567
# Precision: 0.9271
# Recall: 0.9567
# F1 Score: 0.9401
# AUC: 0.9973
# AUPR: 0.9930
# Specificity per class: [0.978448275862069, 0.9798994974874372, 0.9777777777777777, 0.9863013698630136]
# Macro-average Specificity: 0.9806
# MCC per class: [0.9189244663382594, 0.8912236406874062, 0.9547410841058538, 0.9194569996298345]
# Macro-average MCC: 0.9211
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9428
# ---------------------------------------------------------------------------------------------------
# Epoch 41/50, Loss: 0.0627
# Epoch 41/50, Loss: 0.1113
# Accuracy: 0.9504
# Precision: 0.9412
# Recall: 0.9504
# F1 Score: 0.9456
# AUC: 0.9982
# AUPR: 0.9941
# Specificity per class: [0.978448275862069, 0.9798994974874372, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9848
# MCC per class: [0.9357496161555404, 0.9183327324319255, 0.9769542224975036, 0.8896044445281678]
# Macro-average MCC: 0.9302
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9557
# ---------------------------------------------------------------------------------------------------
# Epoch 42/50, Loss: 0.0559
# Epoch 42/50, Loss: 0.1187
# Accuracy: 0.9663
# Precision: 0.9436
# Recall: 0.9663
# F1 Score: 0.9540
# AUC: 0.9978
# AUPR: 0.9945
# Specificity per class: [0.9870689655172413, 0.9798994974874372, 0.9822222222222222, 0.9897260273972602]
# Macro-average Specificity: 0.9847
# MCC per class: [0.9513546798029556, 0.911531715115916, 0.9541128438605541, 0.937953340416017]
# Macro-average MCC: 0.9387
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9556
# ---------------------------------------------------------------------------------------------------
# Epoch 43/50, Loss: 0.0545
# Epoch 43/50, Loss: 0.1443
# Accuracy: 0.9495
# Precision: 0.9255
# Recall: 0.9495
# F1 Score: 0.9361
# AUC: 0.9974
# AUPR: 0.9903
# Specificity per class: [0.9612068965517241, 0.9849246231155779, 0.9911111111111112, 0.9863013698630136]
# Macro-average Specificity: 0.9809
# MCC per class: [0.9059017880597403, 0.8983012253384226, 0.9691330891330892, 0.8952207487823]
# Macro-average MCC: 0.9171
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9432
# ---------------------------------------------------------------------------------------------------
# Epoch 44/50, Loss: 0.0553
# Epoch 44/50, Loss: 0.1079
# Accuracy: 0.9642
# Precision: 0.9635
# Recall: 0.9642
# F1 Score: 0.9639
# AUC: 0.9977
# AUPR: 0.9946
# Specificity per class: [0.978448275862069, 0.9798994974874372, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9876
# MCC per class: [0.9273382946495989, 0.9388393513815171, 0.9845665445665446, 0.9549086757990868]
# Macro-average MCC: 0.9514
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9652
# ---------------------------------------------------------------------------------------------------
# Epoch 45/50, Loss: 0.0440
# Epoch 45/50, Loss: 0.1188
# Accuracy: 0.9717
# Precision: 0.9517
# Recall: 0.9717
# F1 Score: 0.9608
# AUC: 0.9976
# AUPR: 0.9944
# Specificity per class: [0.9870689655172413, 0.9798994974874372, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9881
# MCC per class: [0.9347680119556898, 0.9388393513815171, 0.9845665445665446, 0.937953340416017]
# Macro-average MCC: 0.9490
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9653
# ---------------------------------------------------------------------------------------------------
# Epoch 46/50, Loss: 0.0417
# Epoch 46/50, Loss: 0.1370
# Accuracy: 0.9563
# Precision: 0.9194
# Recall: 0.9563
# F1 Score: 0.9349
# AUC: 0.9975
# AUPR: 0.9930
# Specificity per class: [0.9741379310344828, 0.9849246231155779, 0.9777777777777777, 0.9828767123287672]
# Macro-average Specificity: 0.9799
# MCC per class: [0.9281223053474523, 0.8782582567558712, 0.9547410841058538, 0.9018953432650142]
# Macro-average MCC: 0.9158
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9395
# ---------------------------------------------------------------------------------------------------
# Epoch 47/50, Loss: 0.0391
# Epoch 47/50, Loss: 0.1305
# Accuracy: 0.9501
# Precision: 0.9311
# Recall: 0.9501
# F1 Score: 0.9395
# AUC: 0.9977
# AUPR: 0.9936
# Specificity per class: [0.9612068965517241, 0.9849246231155779, 0.9866666666666667, 0.9897260273972602]
# Macro-average Specificity: 0.9806
# MCC per class: [0.9059017880597403, 0.8916064328563374, 0.9694477535121453, 0.9140014911483973]
# Macro-average MCC: 0.9202
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9429
# ---------------------------------------------------------------------------------------------------
# Epoch 48/50, Loss: 0.0390
# Epoch 48/50, Loss: 0.1258
# Accuracy: 0.9559
# Precision: 0.9395
# Recall: 0.9559
# F1 Score: 0.9472
# AUC: 0.9978
# AUPR: 0.9937
# Specificity per class: [0.9741379310344828, 0.9798994974874372, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9837
# MCC per class: [0.9281223053474523, 0.911531715115916, 0.9691330891330892, 0.9140014911483973]
# Macro-average MCC: 0.9307
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9526
# ---------------------------------------------------------------------------------------------------
# Epoch 49/50, Loss: 0.0429
# Epoch 49/50, Loss: 0.1228
# Accuracy: 0.9634
# Precision: 0.9311
# Recall: 0.9634
# F1 Score: 0.9450
# AUC: 0.9979
# AUPR: 0.9943
# Specificity per class: [0.9913793103448276, 0.9798994974874372, 0.9822222222222222, 0.9828767123287672]
# Macro-average Specificity: 0.9841
# MCC per class: [0.9511093868051034, 0.911531715115916, 0.9541128438605541, 0.9018953432650142]
# Macro-average MCC: 0.9297
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9528
# ---------------------------------------------------------------------------------------------------
# Epoch 50/50, Loss: 0.0427
# Epoch 50/50, Loss: 0.1381
# Accuracy: 0.9563
# Precision: 0.9294
# Recall: 0.9563
# F1 Score: 0.9411
# AUC: 0.9977
# AUPR: 0.9938
# Specificity per class: [0.9655172413793104, 0.9849246231155779, 0.9777777777777777, 0.9897260273972602]
# Macro-average Specificity: 0.9795
# MCC per class: [0.9132015205357783, 0.8782582567558712, 0.9547410841058538, 0.937953340416017]
# Macro-average MCC: 0.9210
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9393
# ---------------------------------------------------------------------------------------------------
# Training and validating complete

# %% [markdown]
# # Inception v3 pretrained

# %%
import os
import pandas as pd
from PIL import Image
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torch.nn.functional as F
import torchvision.models as models
import numpy as np
import timm
import torch
import torch.nn.functional as F
import numpy as np
from torcheval.metrics import MulticlassAccuracy, MulticlassPrecision, MulticlassRecall, MulticlassF1Score, MulticlassAUROC, MulticlassAUPRC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import matthews_corrcoef
import random


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)  # For CPU
    torch.cuda.manual_seed(seed)  # For GPU (if used)
    torch.cuda.manual_seed_all(seed)  # For all GPUs
    torch.backends.cudnn.deterministic = True  # Ensure deterministic behavior
    torch.backends.cudnn.benchmark = False


def calculate_metrics(predicted, probabilities, labels, num_classes):
    # Initialize Torcheval metrics
    accuracy_metric = MulticlassAccuracy(num_classes=num_classes, average="macro")
    precision_metric = MulticlassPrecision(num_classes=num_classes, average="macro")
    recall_metric = MulticlassRecall(num_classes=num_classes, average="macro")
    f1_score_metric = MulticlassF1Score(num_classes=num_classes, average="macro")
    auc_metric = MulticlassAUROC(num_classes=num_classes, average="macro")
    aupr_metric = MulticlassAUPRC(num_classes=num_classes, average="macro")

    # Update metrics with predictions
    accuracy_metric.update(predicted, labels)
    precision_metric.update(predicted, labels)
    recall_metric.update(predicted, labels)
    f1_score_metric.update(predicted, labels)
    auc_metric.update(probabilities, labels)
    aupr_metric.update(probabilities, labels)

    # Compute metrics
    accuracy = accuracy_metric.compute()
    precision = precision_metric.compute()
    recall = recall_metric.compute()
    f1_score = f1_score_metric.compute()
    auc = auc_metric.compute()
    aupr = aupr_metric.compute()

    # Specificity calculation
    conf_matrix = confusion_matrix(labels.cpu().numpy(), predicted.cpu().numpy(), labels=range(num_classes))
    specificity_per_class = []

    for i in range(num_classes):
        TP = conf_matrix[i, i]
        FP = conf_matrix[:, i].sum() - TP
        FN = conf_matrix[i, :].sum() - TP
        TN = conf_matrix.sum() - (TP + FP + FN)

        specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
        specificity_per_class.append(specificity)

    macro_specificity = np.mean(specificity_per_class)

    # MCC calculation for multi-class classification
    mcc_per_class = []
    for i in range(num_classes):
        # Treat each class as the positive class and others as negative
        binary_pred = (predicted == i).int()
        binary_labels = (labels == i).int()
        mcc = matthews_corrcoef(binary_labels.cpu().numpy(), binary_pred.cpu().numpy())
        mcc_per_class.append(mcc)

    macro_mcc = np.mean(mcc_per_class)

    # Print all metrics
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1_score:.4f}")
    print(f"AUC: {auc:.4f}")
    print(f"AUPR: {aupr:.4f}")
    print(f"Specificity per class: {specificity_per_class}")
    print(f"Macro-average Specificity: {macro_specificity:.4f}")
    print(f"MCC per class: {mcc_per_class}")
    print(f"Macro-average MCC: {macro_mcc:.4f}")

    f1_score_metric_micro = MulticlassF1Score(num_classes=num_classes, average="micro")
    f1_score_metric_micro.update(predicted, labels)
    f1_score_micro = f1_score_metric_micro.compute()
    print(f"F1 Score (micro): {f1_score_micro:.4f}")

    f1_score_metric_weighted = MulticlassF1Score(num_classes=num_classes, average="weighted")
    f1_score_metric_weighted.update(predicted, labels)
    f1_score_weighted = f1_score_metric_weighted.compute()
    print(f"F1 Score (weighted): {f1_score_weighted:.4f}")


    # Return metrics as a dictionary
    return {
        "accuracy": "{:.4f}".format(accuracy.item()),
        "precision": "{:.4f}".format(precision.item()),
        "recall": "{:.4f}".format(recall.item()),
        "f1_score": "{:.4f}".format(f1_score.item()),
        "auc": "{:.4f}".format(auc.item()),
        "aupr": "{:.4f}".format(aupr.item()),
        "macro_specificity": "{:.4f}".format(macro_specificity.item()),
        "macro_mcc": "{:.4f}".format(macro_mcc.item())
    }


class ImageDataset(Dataset):
    def __init__(self, images, features, labels, transform=None):
        self.images = images
        self.features = features
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        feature = self.features[idx]
        label = self.labels[idx]
        return image, feature, label


# Image transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

set_seed(42)

dataset_path = "baldder_tissue_classification"

train_df = pd.read_csv("train_df.csv")
val_df = pd.read_csv("val_df.csv")

train_images = []
train_labels = []
for idx, row in train_df.iterrows():
    image_path = os.path.join(dataset_path, row[1], row[0])
    image = Image.open(image_path)
    image = transform(image)
    train_images.append(image)
    train_labels.append(row['encoded_label'])

loaded_images = np.load("top_images.npy")
loaded_labels = np.load("top_labels.npy")
print(len(train_images))
for i in range(len(loaded_images)):
    image = loaded_images[i]
    label = loaded_labels[i]

    # Denormalize the image
    image = (image * np.array([0.229, 0.224, 0.225])[:, None, None]) + np.array([0.485, 0.456, 0.406])[:, None, None]
    image = (image * 255).astype(np.uint8)  # Convert to integer type for PIL compatibility

    # Convert NumPy array to PIL image
    image = Image.fromarray(image.transpose(1, 2, 0))  # H x W x C format

    # Apply transformations
    image = transform(image)

    # Convert back to PyTorch tensor (if required)
    image = torch.tensor(image, dtype=torch.float32)
    train_images.append(image)
    train_labels.append(label)

print(len(train_images))

val_images = []
val_labels = []
for idx, row in val_df.iterrows():
    image_path = os.path.join(dataset_path, row[1], row[0])
    image = Image.open(image_path)
    image = transform(image)
    val_images.append(image)
    val_labels.append(row['encoded_label'])

print(len(val_images))

train_features = np.load("features_RFE.npy")[:-val_df.shape[0]]
augmented_features = np.load("features_top_images_RFE.npy")
train_features = np.concatenate((train_features, augmented_features), axis=0)
val_features = np.load("features_RFE.npy")[-val_df.shape[0]:]

print(train_features.shape)
print(val_features.shape)

# Create DataLoaders
train_dataset = ImageDataset(train_images, train_features, train_labels, transform=transform)
val_dataset = ImageDataset(val_images, val_features, val_labels, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)


# Define the CNN model
class SimpleCNN(nn.Module):
    def __init__(self, num_classes):
        super(SimpleCNN, self).__init__()
        self.block = timm.create_model('inception_v3.tv_in1k', pretrained=True)
        # self.block.head = nn.Linear(self.block.num_features, 1000)

        self.fc1 = nn.Linear(1000, 512)
        self.bn1 = nn.BatchNorm1d(512)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(0.2)
        self.fc2 = nn.Linear(512, 256)
        self.bn2 = nn.BatchNorm1d(256)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(0.2)

        self.fc_ann1 = nn.Linear(512, 256)
        self.bn_ann1 = nn.BatchNorm1d(256)
        self.relu_ann1 = nn.ReLU()
        self.dropout_ann1 = nn.Dropout(0.2)
        self.fc_ann2 = nn.Linear(256, 128)
        self.bn_ann2 = nn.BatchNorm1d(128)
        self.relu_ann2 = nn.ReLU()
        self.dropout_ann2 = nn.Dropout(0.2)

        self.fc_comb = nn.Linear(384, 256)
        self.bn_comb = nn.BatchNorm1d(256)
        self.relu_comb = nn.ReLU()
        self.dropout_comb = nn.Dropout(0.2)

        self.fc3 = nn.Linear(256, 128)
        self.bn3 = nn.BatchNorm1d(128)
        self.relu3 = nn.ReLU()
        self.dropout3 = nn.Dropout(0.2)
        self.fc4 = nn.Linear(128, num_classes)

        self.relu = nn.ReLU()


    def forward(self, x, features):
        features = features.float()
        x = self.block(x)
        # print(x.shape)
        x = x.view(-1, 1000)  # Flatten
        x = self.dropout1(self.relu1(self.bn1(self.fc1(x))))
        x = self.dropout2(self.relu2(self.bn2(self.fc2(x))))

        features = self.dropout_ann1(self.relu_ann1(self.bn_ann1(self.fc_ann1(features))))
        features = self.dropout_ann2(self.relu_ann2(self.bn_ann2(self.fc_ann2(features))))

        x = torch.cat((x, features), dim=1)
        x = self.dropout_comb(self.relu_comb(self.bn_comb(self.fc_comb(x))))

        x = self.dropout3(self.relu3(self.bn3(self.fc3(x))))
        x = self.fc4(x)
        return x


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")
# Instantiate model, loss function, and optimizer
num_classes = 4
model = SimpleCNN(num_classes)
model = model.to(device)
criterion = nn.CrossEntropyLoss().to(device)

optimizer = optim.Adam(model.parameters(), lr=0.0001)

# Training loop
num_epochs = 50
all_metrics = []

best_f1 = -100
best_epoch = 0
best_metric = 0
with open('Results/inception_v3_pretrained.csv', 'w') as f:
    f.write("Epoch,Train Loss,Val Loss,Accuracy,Precision,Recall,F1 Score,AUC,AUPR,Specificity,MCC\n")
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for images, features, labels in train_loader:
            images, features, labels = images.to(device), features.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images, features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * images.size(0)

        train_loss = running_loss / len(train_loader.dataset)
        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {train_loss:.4f}")

        # Validation loop
        model.eval()
        running_loss = 0.0
        with torch.no_grad():
            y_pred = []
            y_true = []
            y_proba = []
            for images, features, labels in val_loader:
                images, features, labels = images.to(device), features.to(device), labels.to(device)

                outputs = model(images, features)
                loss = criterion(outputs, labels)

                running_loss += loss.item() * images.size(0)

                # Apply softmax to get probabilities
                probabilities = F.softmax(outputs, dim=1)

                # Get the predicted class and corresponding probability
                proba, predicted = torch.max(probabilities, 1)

                # Store results
                y_pred.extend(predicted.cpu().tolist())
                y_true.extend(labels.cpu().tolist())
                y_proba.extend(probabilities.cpu().tolist())

            val_loss = running_loss / len(val_loader.dataset)
            print(f"Epoch {epoch+1}/{num_epochs}, Loss: {val_loss:.4f}")
            # Convert lists to tensors
            y_pred = torch.tensor(y_pred)
            y_true = torch.tensor(y_true)
            y_proba = torch.tensor(y_proba)

            metrics = calculate_metrics(y_pred, y_proba, y_true, num_classes)
            all_metrics.append(metrics)

            if best_f1 < float(metrics["f1_score"]):
                best_f1 = float(metrics["f1_score"])
                best_epoch = epoch+1
                best_metric = metrics
            print('---------------------------------------------------------------------------------------------------')

            f.write(f"{epoch+1},{train_loss},{val_loss},{metrics['accuracy']},{metrics['precision']},{metrics['recall']},{metrics['f1_score']},{metrics['auc']},{metrics['aupr']},{metrics['macro_specificity']},{metrics['macro_mcc']}\n")
            f.flush()
    print("Training and validating complete")
# Out:
# <ipython-input-12-1143e10287fd>:155: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   image_path = os.path.join(dataset_path, row[1], row[0])
# 1262
# <ipython-input-12-1143e10287fd>:179: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   image = torch.tensor(image, dtype=torch.float32)
# 1762
# <ipython-input-12-1143e10287fd>:188: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   image_path = os.path.join(dataset_path, row[1], row[0])
# 316
# (1762, 512)
# (316, 512)
# model.safetensors:   0%|          | 0.00/95.5M [00:00<?, ?B/s]
# Epoch 1/50, Loss: 1.1622
# Epoch 1/50, Loss: 0.6979
# Accuracy: 0.7953
# Precision: 0.8196
# Recall: 0.7953
# F1 Score: 0.8042
# AUC: 0.9674
# AUPR: 0.8698
# Specificity per class: [0.9612068965517241, 0.8944723618090452, 0.9777777777777777, 0.9726027397260274]
# Macro-average Specificity: 0.9515
# MCC per class: [0.7312652394852064, 0.833055200914143, 0.930803504791323, 0.5469745005202838]
# Macro-average MCC: 0.7605
# F1 Score (micro): 0.8639
# F1 Score (weighted): 0.8600
# ---------------------------------------------------------------------------------------------------
# Epoch 2/50, Loss: 0.7544
# Epoch 2/50, Loss: 0.5043
# Accuracy: 0.7648
# Precision: 0.8746
# Recall: 0.7648
# F1 Score: 0.7698
# AUC: 0.9690
# AUPR: 0.8778
# Specificity per class: [0.9224137931034483, 0.9899497487437185, 0.9377777777777778, 0.9965753424657534]
# Macro-average Specificity: 0.9617
# MCC per class: [0.8445252492384426, 0.9054549279550154, 0.8931165071612532, 0.3977415127859719]
# Macro-average MCC: 0.7602
# F1 Score (micro): 0.8892
# F1 Score (weighted): 0.8736
# ---------------------------------------------------------------------------------------------------
# Epoch 3/50, Loss: 0.5778
# Epoch 3/50, Loss: 0.4289
# Accuracy: 0.8020
# Precision: 0.9347
# Recall: 0.8020
# F1 Score: 0.8182
# AUC: 0.9855
# AUPR: 0.9263
# Specificity per class: [0.9525862068965517, 0.9849246231155779, 0.9466666666666667, 1.0]
# Macro-average Specificity: 0.9710
# MCC per class: [0.9003285737788081, 0.9320062537742658, 0.9145356223410569, 0.5249955051947106]
# Macro-average MCC: 0.8180
# F1 Score (micro): 0.9177
# F1 Score (weighted): 0.9049
# ---------------------------------------------------------------------------------------------------
# Epoch 4/50, Loss: 0.4368
# Epoch 4/50, Loss: 0.3529
# Accuracy: 0.8567
# Precision: 0.9502
# Recall: 0.8567
# F1 Score: 0.8806
# AUC: 0.9926
# AUPR: 0.9588
# Specificity per class: [0.9267241379310345, 0.9949748743718593, 0.9911111111111112, 1.0]
# Macro-average Specificity: 0.9782
# MCC per class: [0.877918485504302, 0.9526338872016222, 0.9691330891330892, 0.6930102148559839]
# Macro-average MCC: 0.8732
# F1 Score (micro): 0.9367
# F1 Score (weighted): 0.9326
# ---------------------------------------------------------------------------------------------------
# Epoch 5/50, Loss: 0.3739
# Epoch 5/50, Loss: 0.3111
# Accuracy: 0.8586
# Precision: 0.9136
# Recall: 0.8586
# F1 Score: 0.8746
# AUC: 0.9930
# AUPR: 0.9565
# Specificity per class: [0.9310344827586207, 0.9949748743718593, 0.9822222222222222, 0.9931506849315068]
# Macro-average Specificity: 0.9753
# MCC per class: [0.8843466319929314, 0.9259358814138647, 0.9541128438605541, 0.6663058991386845]
# Macro-average MCC: 0.8577
# F1 Score (micro): 0.9272
# F1 Score (weighted): 0.9241
# ---------------------------------------------------------------------------------------------------
# Epoch 6/50, Loss: 0.4809
# Epoch 6/50, Loss: 0.3932
# Accuracy: 0.8404
# Precision: 0.8499
# Recall: 0.8404
# F1 Score: 0.8418
# AUC: 0.9810
# AUPR: 0.9087
# Specificity per class: [0.9137931034482759, 0.9748743718592965, 0.9733333333333334, 0.9794520547945206]
# Macro-average Specificity: 0.9604
# MCC per class: [0.81363752021537, 0.8302961063315345, 0.9314694126938377, 0.6428923374594678]
# Macro-average MCC: 0.8046
# F1 Score (micro): 0.8829
# F1 Score (weighted): 0.8821
# ---------------------------------------------------------------------------------------------------
# Epoch 7/50, Loss: 0.4837
# Epoch 7/50, Loss: 0.3462
# Accuracy: 0.8588
# Precision: 0.8752
# Recall: 0.8588
# F1 Score: 0.8648
# AUC: 0.9843
# AUPR: 0.9226
# Specificity per class: [0.9181034482758621, 0.9698492462311558, 0.9955555555555555, 0.9828767123287672]
# Macro-average Specificity: 0.9666
# MCC per class: [0.8109468369138241, 0.8841302670587785, 0.9458123186103883, 0.6908512559290599]
# Macro-average MCC: 0.8329
# F1 Score (micro): 0.9019
# F1 Score (weighted): 0.9025
# ---------------------------------------------------------------------------------------------------
# Epoch 8/50, Loss: 0.4443
# Epoch 8/50, Loss: 0.2909
# Accuracy: 0.8905
# Precision: 0.8785
# Recall: 0.8905
# F1 Score: 0.8832
# AUC: 0.9907
# AUPR: 0.9485
# Specificity per class: [0.9439655172413793, 0.9698492462311558, 0.9911111111111112, 0.976027397260274]
# Macro-average Specificity: 0.9702
# MCC per class: [0.8688916865617802, 0.8841302670587785, 0.922316465008429, 0.7401155963844639]
# Macro-average MCC: 0.8539
# F1 Score (micro): 0.9114
# F1 Score (weighted): 0.9124
# ---------------------------------------------------------------------------------------------------
# Epoch 9/50, Loss: 0.3569
# Epoch 9/50, Loss: 0.3047
# Accuracy: 0.9027
# Precision: 0.8966
# Recall: 0.9027
# F1 Score: 0.8984
# AUC: 0.9905
# AUPR: 0.9520
# Specificity per class: [0.9439655172413793, 0.9798994974874372, 1.0, 0.9794520547945206]
# Macro-average Specificity: 0.9758
# MCC per class: [0.87770630245283, 0.9183327324319255, 0.9461635504451551, 0.7568360230211301]
# Macro-average MCC: 0.8748
# F1 Score (micro): 0.9272
# F1 Score (weighted): 0.9282
# ---------------------------------------------------------------------------------------------------
# Epoch 10/50, Loss: 0.3077
# Epoch 10/50, Loss: 0.2560
# Accuracy: 0.8951
# Precision: 0.9122
# Recall: 0.8951
# F1 Score: 0.9003
# AUC: 0.9935
# AUPR: 0.9554
# Specificity per class: [0.9224137931034483, 0.9899497487437185, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9744
# MCC per class: [0.8625573425685678, 0.9054549279550154, 0.9535520638570569, 0.7867690928682439]
# Macro-average MCC: 0.8771
# F1 Score (micro): 0.9241
# F1 Score (weighted): 0.9247
# ---------------------------------------------------------------------------------------------------
# Epoch 11/50, Loss: 0.2701
# Epoch 11/50, Loss: 0.2173
# Accuracy: 0.9249
# Precision: 0.9213
# Recall: 0.9249
# F1 Score: 0.9226
# AUC: 0.9949
# AUPR: 0.9642
# Specificity per class: [0.9612068965517241, 0.9849246231155779, 0.9911111111111112, 0.9863013698630136]
# Macro-average Specificity: 0.9809
# MCC per class: [0.9145246423032853, 0.918475629152568, 0.9613185012354785, 0.819634703196347]
# Macro-average MCC: 0.9035
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9432
# ---------------------------------------------------------------------------------------------------
# Epoch 12/50, Loss: 0.2637
# Epoch 12/50, Loss: 0.2136
# Accuracy: 0.9094
# Precision: 0.9060
# Recall: 0.9094
# F1 Score: 0.9069
# AUC: 0.9939
# AUPR: 0.9576
# Specificity per class: [0.9482758620689655, 0.9849246231155779, 0.9955555555555555, 0.9828767123287672]
# Macro-average Specificity: 0.9779
# MCC per class: [0.8846101301702942, 0.9117352234683014, 0.9690466897894506, 0.7745433789954338]
# Macro-average MCC: 0.8850
# F1 Score (micro): 0.9335
# F1 Score (weighted): 0.9340
# ---------------------------------------------------------------------------------------------------
# Epoch 13/50, Loss: 0.2408
# Epoch 13/50, Loss: 0.1970
# Accuracy: 0.9483
# Precision: 0.9363
# Recall: 0.9483
# F1 Score: 0.9419
# AUC: 0.9947
# AUPR: 0.9723
# Specificity per class: [0.9870689655172413, 0.9748743718592965, 0.9911111111111112, 0.9863013698630136]
# Macro-average Specificity: 0.9848
# MCC per class: [0.9430620346419998, 0.9321393291242538, 0.9613185012354785, 0.870530017457414]
# Macro-average MCC: 0.9268
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9560
# ---------------------------------------------------------------------------------------------------
# Epoch 14/50, Loss: 0.2065
# Epoch 14/50, Loss: 0.1812
# Accuracy: 0.9268
# Precision: 0.9179
# Recall: 0.9268
# F1 Score: 0.9220
# AUC: 0.9956
# AUPR: 0.9682
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 0.9911111111111112, 0.9828767123287672]
# Macro-average Specificity: 0.9822
# MCC per class: [0.9206073369943373, 0.9252324391444847, 0.9691330891330892, 0.801092163523476]
# Macro-average MCC: 0.9040
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9465
# ---------------------------------------------------------------------------------------------------
# Epoch 15/50, Loss: 0.1787
# Epoch 15/50, Loss: 0.1815
# Accuracy: 0.9456
# Precision: 0.9334
# Recall: 0.9456
# F1 Score: 0.9390
# AUC: 0.9944
# AUPR: 0.9654
# Specificity per class: [0.9741379310344828, 0.9748743718592965, 1.0, 0.9863013698630136]
# Macro-average Specificity: 0.9838
# MCC per class: [0.9196546412641213, 0.9321393291242538, 0.96919786333672, 0.870530017457414]
# Macro-average MCC: 0.9229
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9530
# ---------------------------------------------------------------------------------------------------
# Epoch 16/50, Loss: 0.2239
# Epoch 16/50, Loss: 0.1710
# Accuracy: 0.9489
# Precision: 0.9207
# Recall: 0.9489
# F1 Score: 0.9329
# AUC: 0.9970
# AUPR: 0.9820
# Specificity per class: [0.9612068965517241, 0.9849246231155779, 0.9955555555555555, 0.9828767123287672]
# Macro-average Specificity: 0.9811
# MCC per class: [0.9059017880597403, 0.9050106221559147, 0.9690466897894506, 0.8774216391143502]
# Macro-average MCC: 0.9143
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9436
# ---------------------------------------------------------------------------------------------------
# Epoch 17/50, Loss: 0.2035
# Epoch 17/50, Loss: 0.1438
# Accuracy: 0.9585
# Precision: 0.9466
# Recall: 0.9585
# F1 Score: 0.9520
# AUC: 0.9975
# AUPR: 0.9870
# Specificity per class: [0.9956896551724138, 0.9748743718592965, 0.9822222222222222, 0.9897260273972602]
# Macro-average Specificity: 0.9856
# MCC per class: [0.9511202607580309, 0.9321393291242538, 0.9541128438605541, 0.9140014911483973]
# Macro-average MCC: 0.9378
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9590
# ---------------------------------------------------------------------------------------------------
# Epoch 18/50, Loss: 0.1830
# Epoch 18/50, Loss: 0.1621
# Accuracy: 0.9530
# Precision: 0.9271
# Recall: 0.9530
# F1 Score: 0.9386
# AUC: 0.9959
# AUPR: 0.9848
# Specificity per class: [0.9827586206896551, 0.9949748743718593, 0.9911111111111112, 0.9794520547945206]
# Macro-average Specificity: 0.9871
# MCC per class: [0.960196523248786, 0.9459330151619536, 0.9613185012354785, 0.8353862785988658]
# Macro-average MCC: 0.9257
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9596
# ---------------------------------------------------------------------------------------------------
# Epoch 19/50, Loss: 0.1793
# Epoch 19/50, Loss: 0.1673
# Accuracy: 0.9331
# Precision: 0.9093
# Recall: 0.9331
# F1 Score: 0.9190
# AUC: 0.9937
# AUPR: 0.9763
# Specificity per class: [0.9612068965517241, 1.0, 0.9822222222222222, 0.9794520547945206]
# Macro-average Specificity: 0.9807
# MCC per class: [0.923145527810611, 0.9069062982175389, 0.9620442890220036, 0.8097555655148659]
# Macro-average MCC: 0.9005
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9401
# ---------------------------------------------------------------------------------------------------
# Epoch 20/50, Loss: 0.1612
# Epoch 20/50, Loss: 0.1522
# Accuracy: 0.9521
# Precision: 0.9399
# Recall: 0.9521
# F1 Score: 0.9451
# AUC: 0.9942
# AUPR: 0.9840
# Specificity per class: [0.9698275862068966, 1.0, 0.9822222222222222, 0.9897260273972602]
# Macro-average Specificity: 0.9854
# MCC per class: [0.937645518934311, 0.9331519181523712, 0.9620442890220036, 0.8896044445281678]
# Macro-average MCC: 0.9306
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9557
# ---------------------------------------------------------------------------------------------------
# Epoch 21/50, Loss: 0.2243
# Epoch 21/50, Loss: 0.1753
# Accuracy: 0.9385
# Precision: 0.9283
# Recall: 0.9385
# F1 Score: 0.9322
# AUC: 0.9904
# AUPR: 0.9777
# Specificity per class: [0.9568965517241379, 0.9949748743718593, 0.9955555555555555, 0.9863013698630136]
# Macro-average Specificity: 0.9834
# MCC per class: [0.9247156569570832, 0.9325845850929314, 0.9612965996570492, 0.8453483040258218]
# Macro-average MCC: 0.9160
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9498
# ---------------------------------------------------------------------------------------------------
# Epoch 22/50, Loss: 0.1522
# Epoch 22/50, Loss: 0.1658
# Accuracy: 0.9404
# Precision: 0.9348
# Recall: 0.9404
# F1 Score: 0.9358
# AUC: 0.9919
# AUPR: 0.9756
# Specificity per class: [0.9482758620689655, 1.0, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9834
# MCC per class: [0.9109014103130726, 0.9199983092652494, 0.9845665445665446, 0.8647260273972602]
# Macro-average MCC: 0.9200
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9496
# ---------------------------------------------------------------------------------------------------
# Epoch 23/50, Loss: 0.1470
# Epoch 23/50, Loss: 0.1673
# Accuracy: 0.9435
# Precision: 0.9239
# Recall: 0.9435
# F1 Score: 0.9319
# AUC: 0.9957
# AUPR: 0.9827
# Specificity per class: [0.9655172413793104, 1.0, 0.9733333333333334, 0.9863013698630136]
# Macro-average Specificity: 0.9813
# MCC per class: [0.9303440963742202, 0.9069062982175389, 0.9475354926457952, 0.870530017457414]
# Macro-average MCC: 0.9138
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9429
# ---------------------------------------------------------------------------------------------------
# Epoch 24/50, Loss: 0.1760
# Epoch 24/50, Loss: 0.1853
# Accuracy: 0.9320
# Precision: 0.9083
# Recall: 0.9320
# F1 Score: 0.9185
# AUC: 0.9925
# AUPR: 0.9718
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 0.9955555555555555, 0.976027397260274]
# Macro-average Specificity: 0.9816
# MCC per class: [0.9291271099667554, 0.9252324391444847, 0.9535520638570569, 0.7933509180833815]
# Macro-average MCC: 0.9003
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9441
# ---------------------------------------------------------------------------------------------------
# Epoch 25/50, Loss: 0.1470
# Epoch 25/50, Loss: 0.1707
# Accuracy: 0.9377
# Precision: 0.9177
# Recall: 0.9377
# F1 Score: 0.9264
# AUC: 0.9925
# AUPR: 0.9744
# Specificity per class: [0.9698275862068966, 0.9899497487437185, 0.9955555555555555, 0.9794520547945206]
# Macro-average Specificity: 0.9837
# MCC per class: [0.937645518934311, 0.9322043221572608, 0.9612965996570492, 0.8097555655148659]
# Macro-average MCC: 0.9102
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9501
# ---------------------------------------------------------------------------------------------------
# Epoch 26/50, Loss: 0.1367
# Epoch 26/50, Loss: 0.1710
# Accuracy: 0.9307
# Precision: 0.9179
# Recall: 0.9307
# F1 Score: 0.9239
# AUC: 0.9923
# AUPR: 0.9732
# Specificity per class: [0.9741379310344828, 0.9748743718592965, 0.9911111111111112, 0.9828767123287672]
# Macro-average Specificity: 0.9808
# MCC per class: [0.911184000211381, 0.9183645700774931, 0.9613185012354785, 0.8270585437664306]
# Macro-average MCC: 0.9045
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9434
# ---------------------------------------------------------------------------------------------------
# Epoch 27/50, Loss: 0.1136
# Epoch 27/50, Loss: 0.1668
# Accuracy: 0.9417
# Precision: 0.9303
# Recall: 0.9417
# F1 Score: 0.9351
# AUC: 0.9929
# AUPR: 0.9727
# Specificity per class: [0.9655172413793104, 0.9949748743718593, 0.9911111111111112, 0.9863013698630136]
# Macro-average Specificity: 0.9845
# MCC per class: [0.9303440963742202, 0.9259358814138647, 0.9769542224975036, 0.8453483040258218]
# Macro-average MCC: 0.9196
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9527
# ---------------------------------------------------------------------------------------------------
# Epoch 28/50, Loss: 0.1230
# Epoch 28/50, Loss: 0.1819
# Accuracy: 0.9466
# Precision: 0.9290
# Recall: 0.9466
# F1 Score: 0.9367
# AUC: 0.9910
# AUPR: 0.9726
# Specificity per class: [0.9655172413793104, 0.9949748743718593, 0.9866666666666667, 0.9863013698630136]
# Macro-average Specificity: 0.9834
# MCC per class: [0.9303440963742202, 0.9259358814138647, 0.9536996336996337, 0.870530017457414]
# Macro-average MCC: 0.9201
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9496
# ---------------------------------------------------------------------------------------------------
# Epoch 29/50, Loss: 0.1132
# Epoch 29/50, Loss: 0.1519
# Accuracy: 0.9536
# Precision: 0.9369
# Recall: 0.9536
# F1 Score: 0.9445
# AUC: 0.9952
# AUPR: 0.9788
# Specificity per class: [0.9741379310344828, 0.9949748743718593, 0.9911111111111112, 0.9863013698630136]
# Macro-average Specificity: 0.9866
# MCC per class: [0.9450526993977326, 0.939250105582329, 0.9691330891330892, 0.870530017457414]
# Macro-average MCC: 0.9310
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9591
# ---------------------------------------------------------------------------------------------------
# Epoch 30/50, Loss: 0.0936
# Epoch 30/50, Loss: 0.1995
# Accuracy: 0.9187
# Precision: 0.9066
# Recall: 0.9187
# F1 Score: 0.9097
# AUC: 0.9889
# AUPR: 0.9732
# Specificity per class: [0.9353448275862069, 1.0, 0.9911111111111112, 0.9828767123287672]
# Macro-average Specificity: 0.9773
# MCC per class: [0.8908568427730515, 0.8938714459008406, 0.9691330891330892, 0.801092163523476]
# Macro-average MCC: 0.8887
# F1 Score (micro): 0.9304
# F1 Score (weighted): 0.9308
# ---------------------------------------------------------------------------------------------------
# Epoch 31/50, Loss: 0.0866
# Epoch 31/50, Loss: 0.1284
# Accuracy: 0.9534
# Precision: 0.9370
# Recall: 0.9534
# F1 Score: 0.9445
# AUC: 0.9972
# AUPR: 0.9861
# Specificity per class: [0.9827586206896551, 0.9949748743718593, 0.9822222222222222, 0.9863013698630136]
# Macro-average Specificity: 0.9866
# MCC per class: [0.9518445910469595, 0.939250105582329, 0.9620442890220036, 0.870530017457414]
# Macro-average MCC: 0.9309
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9590
# ---------------------------------------------------------------------------------------------------
# Epoch 32/50, Loss: 0.0888
# Epoch 32/50, Loss: 0.1444
# Accuracy: 0.9478
# Precision: 0.9236
# Recall: 0.9478
# F1 Score: 0.9339
# AUC: 0.9951
# AUPR: 0.9798
# Specificity per class: [0.9698275862068966, 1.0, 0.9822222222222222, 0.9828767123287672]
# Macro-average Specificity: 0.9837
# MCC per class: [0.937645518934311, 0.9199983092652494, 0.9620442890220036, 0.852488157148583]
# Macro-average MCC: 0.9180
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9496
# ---------------------------------------------------------------------------------------------------
# Epoch 33/50, Loss: 0.0927
# Epoch 33/50, Loss: 0.1449
# Accuracy: 0.9563
# Precision: 0.9299
# Recall: 0.9563
# F1 Score: 0.9416
# AUC: 0.9936
# AUPR: 0.9778
# Specificity per class: [0.9827586206896551, 0.9949748743718593, 0.9955555555555555, 0.9794520547945206]
# Macro-average Specificity: 0.9882
# MCC per class: [0.960196523248786, 0.939250105582329, 0.9845665445665446, 0.8353862785988658]
# Macro-average MCC: 0.9298
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9627
# ---------------------------------------------------------------------------------------------------
# Epoch 34/50, Loss: 0.0827
# Epoch 34/50, Loss: 0.1281
# Accuracy: 0.9517
# Precision: 0.9435
# Recall: 0.9517
# F1 Score: 0.9474
# AUC: 0.9968
# AUPR: 0.9859
# Specificity per class: [0.9827586206896551, 0.9849246231155779, 0.9866666666666667, 0.9897260273972602]
# Macro-average Specificity: 0.9860
# MCC per class: [0.9351395730706076, 0.9387976740971787, 0.9694477535121453, 0.8896044445281678]
# Macro-average MCC: 0.9332
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9589
# ---------------------------------------------------------------------------------------------------
# Epoch 35/50, Loss: 0.0633
# Epoch 35/50, Loss: 0.1259
# Accuracy: 0.9555
# Precision: 0.9400
# Recall: 0.9555
# F1 Score: 0.9472
# AUC: 0.9958
# AUPR: 0.9824
# Specificity per class: [0.978448275862069, 0.9899497487437185, 0.9955555555555555, 0.9863013698630136]
# Macro-average Specificity: 0.9876
# MCC per class: [0.9441594142981191, 0.9389331631730534, 0.9845665445665446, 0.870530017457414]
# Macro-average MCC: 0.9345
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9623
# ---------------------------------------------------------------------------------------------------
# Epoch 36/50, Loss: 0.0865
# Epoch 36/50, Loss: 0.1227
# Accuracy: 0.9594
# Precision: 0.9580
# Recall: 0.9594
# F1 Score: 0.9584
# AUC: 0.9947
# AUPR: 0.9812
# Specificity per class: [0.9741379310344828, 0.9899497487437185, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9893
# MCC per class: [0.9450526993977326, 0.9592286682907512, 0.9768873266890564, 0.9098173515981736]
# Macro-average MCC: 0.9477
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9685
# ---------------------------------------------------------------------------------------------------
# Epoch 37/50, Loss: 0.0612
# Epoch 37/50, Loss: 0.1155
# Accuracy: 0.9598
# Precision: 0.9512
# Recall: 0.9598
# F1 Score: 0.9553
# AUC: 0.9975
# AUPR: 0.9888
# Specificity per class: [0.9827586206896551, 0.9899497487437185, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9895
# MCC per class: [0.9518445910469595, 0.9524447467356325, 0.9845665445665446, 0.8896044445281678]
# Macro-average MCC: 0.9446
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9685
# ---------------------------------------------------------------------------------------------------
# Epoch 38/50, Loss: 0.0708
# Epoch 38/50, Loss: 0.1072
# Accuracy: 0.9598
# Precision: 0.9512
# Recall: 0.9598
# F1 Score: 0.9553
# AUC: 0.9971
# AUPR: 0.9870
# Specificity per class: [0.9827586206896551, 0.9899497487437185, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9895
# MCC per class: [0.9518445910469595, 0.9524447467356325, 0.9845665445665446, 0.8896044445281678]
# Macro-average MCC: 0.9446
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9685
# ---------------------------------------------------------------------------------------------------
# Epoch 39/50, Loss: 0.0660
# Epoch 39/50, Loss: 0.1130
# Accuracy: 0.9598
# Precision: 0.9512
# Recall: 0.9598
# F1 Score: 0.9553
# AUC: 0.9972
# AUPR: 0.9869
# Specificity per class: [0.9827586206896551, 0.9899497487437185, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9895
# MCC per class: [0.9518445910469595, 0.9524447467356325, 0.9845665445665446, 0.8896044445281678]
# Macro-average MCC: 0.9446
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9685
# ---------------------------------------------------------------------------------------------------
# Epoch 40/50, Loss: 0.0651
# Epoch 40/50, Loss: 0.1258
# Accuracy: 0.9606
# Precision: 0.9508
# Recall: 0.9606
# F1 Score: 0.9554
# AUC: 0.9959
# AUPR: 0.9812
# Specificity per class: [0.9827586206896551, 0.9949748743718593, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9896
# MCC per class: [0.960196523248786, 0.9526338872016222, 0.9769542224975036, 0.8896044445281678]
# Macro-average MCC: 0.9448
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9684
# ---------------------------------------------------------------------------------------------------
# Epoch 41/50, Loss: 0.0605
# Epoch 41/50, Loss: 0.1376
# Accuracy: 0.9491
# Precision: 0.9317
# Recall: 0.9491
# F1 Score: 0.9395
# AUC: 0.9965
# AUPR: 0.9831
# Specificity per class: [0.978448275862069, 0.9949748743718593, 0.9777777777777777, 0.9863013698630136]
# Macro-average Specificity: 0.9844
# MCC per class: [0.9441594142981191, 0.9259358814138647, 0.9547410841058538, 0.870530017457414]
# Macro-average MCC: 0.9238
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9526
# ---------------------------------------------------------------------------------------------------
# Epoch 42/50, Loss: 0.0546
# Epoch 42/50, Loss: 0.1166
# Accuracy: 0.9628
# Precision: 0.9535
# Recall: 0.9628
# F1 Score: 0.9579
# AUC: 0.9970
# AUPR: 0.9846
# Specificity per class: [0.9827586206896551, 0.9949748743718593, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9908
# MCC per class: [0.960196523248786, 0.9593532964589464, 0.9845665445665446, 0.8896044445281678]
# Macro-average MCC: 0.9484
# F1 Score (micro): 0.9715
# F1 Score (weighted): 0.9717
# ---------------------------------------------------------------------------------------------------
# Epoch 43/50, Loss: 0.0578
# Epoch 43/50, Loss: 0.1544
# Accuracy: 0.9485
# Precision: 0.9317
# Recall: 0.9485
# F1 Score: 0.9391
# AUC: 0.9953
# AUPR: 0.9815
# Specificity per class: [0.9612068965517241, 0.9949748743718593, 0.9955555555555555, 0.9863013698630136]
# Macro-average Specificity: 0.9845
# MCC per class: [0.9145246423032853, 0.9325845850929314, 0.9768030891848316, 0.870530017457414]
# Macro-average MCC: 0.9236
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9530
# ---------------------------------------------------------------------------------------------------
# Epoch 44/50, Loss: 0.0607
# Epoch 44/50, Loss: 0.1345
# Accuracy: 0.9557
# Precision: 0.9455
# Recall: 0.9557
# F1 Score: 0.9501
# AUC: 0.9954
# AUPR: 0.9833
# Specificity per class: [0.9698275862068966, 0.9949748743718593, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9875
# MCC per class: [0.937645518934311, 0.9459330151619536, 0.9768030891848316, 0.8896044445281678]
# Macro-average MCC: 0.9375
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9623
# ---------------------------------------------------------------------------------------------------
# Epoch 45/50, Loss: 0.0631
# Epoch 45/50, Loss: 0.1527
# Accuracy: 0.9521
# Precision: 0.9343
# Recall: 0.9521
# F1 Score: 0.9422
# AUC: 0.9957
# AUPR: 0.9807
# Specificity per class: [0.9698275862068966, 0.9949748743718593, 0.9911111111111112, 0.9863013698630136]
# Macro-average Specificity: 0.9856
# MCC per class: [0.937645518934311, 0.9259358814138647, 0.9769542224975036, 0.870530017457414]
# Macro-average MCC: 0.9278
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9558
# ---------------------------------------------------------------------------------------------------
# Epoch 46/50, Loss: 0.0485
# Epoch 46/50, Loss: 0.1304
# Accuracy: 0.9563
# Precision: 0.9454
# Recall: 0.9563
# F1 Score: 0.9504
# AUC: 0.9944
# AUPR: 0.9775
# Specificity per class: [0.9741379310344828, 0.9949748743718593, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9875
# MCC per class: [0.9450526993977326, 0.939250105582329, 0.9769542224975036, 0.8896044445281678]
# Macro-average MCC: 0.9377
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9621
# ---------------------------------------------------------------------------------------------------
# Epoch 47/50, Loss: 0.0428
# Epoch 47/50, Loss: 0.1048
# Accuracy: 0.9525
# Precision: 0.9367
# Recall: 0.9525
# F1 Score: 0.9440
# AUC: 0.9983
# AUPR: 0.9931
# Specificity per class: [0.978448275862069, 0.9949748743718593, 0.9866666666666667, 0.9863013698630136]
# Macro-average Specificity: 0.9866
# MCC per class: [0.9357496161555404, 0.9459330151619536, 0.9694477535121453, 0.870530017457414]
# Macro-average MCC: 0.9304
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9591
# ---------------------------------------------------------------------------------------------------
# Epoch 48/50, Loss: 0.0418
# Epoch 48/50, Loss: 0.1046
# Accuracy: 0.9551
# Precision: 0.9529
# Recall: 0.9551
# F1 Score: 0.9538
# AUC: 0.9980
# AUPR: 0.9912
# Specificity per class: [0.9741379310344828, 0.9849246231155779, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9869
# MCC per class: [0.9450526993977326, 0.9387976740971787, 0.9690466897894506, 0.9098173515981736]
# Macro-average MCC: 0.9407
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9621
# ---------------------------------------------------------------------------------------------------
# Epoch 49/50, Loss: 0.0416
# Epoch 49/50, Loss: 0.1335
# Accuracy: 0.9499
# Precision: 0.9262
# Recall: 0.9499
# F1 Score: 0.9365
# AUC: 0.9973
# AUPR: 0.9873
# Specificity per class: [0.9741379310344828, 1.0, 0.9822222222222222, 0.9828767123287672]
# Macro-average Specificity: 0.9848
# MCC per class: [0.9450526993977326, 0.9265671365457867, 0.9620442890220036, 0.852488157148583]
# Macro-average MCC: 0.9215
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9528
# ---------------------------------------------------------------------------------------------------
# Epoch 50/50, Loss: 0.0438
# Epoch 50/50, Loss: 0.1289
# Accuracy: 0.9563
# Precision: 0.9396
# Recall: 0.9563
# F1 Score: 0.9473
# AUC: 0.9963
# AUPR: 0.9839
# Specificity per class: [0.978448275862069, 0.9949748743718593, 0.9911111111111112, 0.9863013698630136]
# Macro-average Specificity: 0.9877
# MCC per class: [0.9525686552200252, 0.939250105582329, 0.9769542224975036, 0.870530017457414]
# Macro-average MCC: 0.9348
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9622
# ---------------------------------------------------------------------------------------------------
# Training and validating complete

# %% [markdown]
# # resnet50 pretrained

# %%
import os
import pandas as pd
from PIL import Image
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torch.nn.functional as F
import torchvision.models as models
import numpy as np
import timm
import torch
import torch.nn.functional as F
import numpy as np
from torcheval.metrics import MulticlassAccuracy, MulticlassPrecision, MulticlassRecall, MulticlassF1Score, MulticlassAUROC, MulticlassAUPRC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import matthews_corrcoef
import random


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)  # For CPU
    torch.cuda.manual_seed(seed)  # For GPU (if used)
    torch.cuda.manual_seed_all(seed)  # For all GPUs
    torch.backends.cudnn.deterministic = True  # Ensure deterministic behavior
    torch.backends.cudnn.benchmark = False


def calculate_metrics(predicted, probabilities, labels, num_classes):
    # Initialize Torcheval metrics
    accuracy_metric = MulticlassAccuracy(num_classes=num_classes, average="macro")
    precision_metric = MulticlassPrecision(num_classes=num_classes, average="macro")
    recall_metric = MulticlassRecall(num_classes=num_classes, average="macro")
    f1_score_metric = MulticlassF1Score(num_classes=num_classes, average="macro")
    auc_metric = MulticlassAUROC(num_classes=num_classes, average="macro")
    aupr_metric = MulticlassAUPRC(num_classes=num_classes, average="macro")

    # Update metrics with predictions
    accuracy_metric.update(predicted, labels)
    precision_metric.update(predicted, labels)
    recall_metric.update(predicted, labels)
    f1_score_metric.update(predicted, labels)
    auc_metric.update(probabilities, labels)
    aupr_metric.update(probabilities, labels)

    # Compute metrics
    accuracy = accuracy_metric.compute()
    precision = precision_metric.compute()
    recall = recall_metric.compute()
    f1_score = f1_score_metric.compute()
    auc = auc_metric.compute()
    aupr = aupr_metric.compute()

    # Specificity calculation
    conf_matrix = confusion_matrix(labels.cpu().numpy(), predicted.cpu().numpy(), labels=range(num_classes))
    specificity_per_class = []

    for i in range(num_classes):
        TP = conf_matrix[i, i]
        FP = conf_matrix[:, i].sum() - TP
        FN = conf_matrix[i, :].sum() - TP
        TN = conf_matrix.sum() - (TP + FP + FN)

        specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
        specificity_per_class.append(specificity)

    macro_specificity = np.mean(specificity_per_class)

    # MCC calculation for multi-class classification
    mcc_per_class = []
    for i in range(num_classes):
        # Treat each class as the positive class and others as negative
        binary_pred = (predicted == i).int()
        binary_labels = (labels == i).int()
        mcc = matthews_corrcoef(binary_labels.cpu().numpy(), binary_pred.cpu().numpy())
        mcc_per_class.append(mcc)

    macro_mcc = np.mean(mcc_per_class)

    # Print all metrics
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1_score:.4f}")
    print(f"AUC: {auc:.4f}")
    print(f"AUPR: {aupr:.4f}")
    print(f"Specificity per class: {specificity_per_class}")
    print(f"Macro-average Specificity: {macro_specificity:.4f}")
    print(f"MCC per class: {mcc_per_class}")
    print(f"Macro-average MCC: {macro_mcc:.4f}")

    f1_score_metric_micro = MulticlassF1Score(num_classes=num_classes, average="micro")
    f1_score_metric_micro.update(predicted, labels)
    f1_score_micro = f1_score_metric_micro.compute()
    print(f"F1 Score (micro): {f1_score_micro:.4f}")

    f1_score_metric_weighted = MulticlassF1Score(num_classes=num_classes, average="weighted")
    f1_score_metric_weighted.update(predicted, labels)
    f1_score_weighted = f1_score_metric_weighted.compute()
    print(f"F1 Score (weighted): {f1_score_weighted:.4f}")


    # Return metrics as a dictionary
    return {
        "accuracy": "{:.4f}".format(accuracy.item()),
        "precision": "{:.4f}".format(precision.item()),
        "recall": "{:.4f}".format(recall.item()),
        "f1_score": "{:.4f}".format(f1_score.item()),
        "auc": "{:.4f}".format(auc.item()),
        "aupr": "{:.4f}".format(aupr.item()),
        "macro_specificity": "{:.4f}".format(macro_specificity.item()),
        "macro_mcc": "{:.4f}".format(macro_mcc.item())
    }


class ImageDataset(Dataset):
    def __init__(self, images, features, labels, transform=None):
        self.images = images
        self.features = features
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        feature = self.features[idx]
        label = self.labels[idx]
        return image, feature, label


# Image transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

set_seed(42)

dataset_path = "baldder_tissue_classification"

train_df = pd.read_csv("train_df.csv")
val_df = pd.read_csv("val_df.csv")

train_images = []
train_labels = []
for idx, row in train_df.iterrows():
    image_path = os.path.join(dataset_path, row[1], row[0])
    image = Image.open(image_path)
    image = transform(image)
    train_images.append(image)
    train_labels.append(row['encoded_label'])

loaded_images = np.load("top_images.npy")
loaded_labels = np.load("top_labels.npy")
print(len(train_images))
for i in range(len(loaded_images)):
    image = loaded_images[i]
    label = loaded_labels[i]

    # Denormalize the image
    image = (image * np.array([0.229, 0.224, 0.225])[:, None, None]) + np.array([0.485, 0.456, 0.406])[:, None, None]
    image = (image * 255).astype(np.uint8)  # Convert to integer type for PIL compatibility

    # Convert NumPy array to PIL image
    image = Image.fromarray(image.transpose(1, 2, 0))  # H x W x C format

    # Apply transformations
    image = transform(image)

    # Convert back to PyTorch tensor (if required)
    image = torch.tensor(image, dtype=torch.float32)
    train_images.append(image)
    train_labels.append(label)

print(len(train_images))

val_images = []
val_labels = []
for idx, row in val_df.iterrows():
    image_path = os.path.join(dataset_path, row[1], row[0])
    image = Image.open(image_path)
    image = transform(image)
    val_images.append(image)
    val_labels.append(row['encoded_label'])

print(len(val_images))

train_features = np.load("features_RFE.npy")[:-val_df.shape[0]]
augmented_features = np.load("features_top_images_RFE.npy")
train_features = np.concatenate((train_features, augmented_features), axis=0)
val_features = np.load("features_RFE.npy")[-val_df.shape[0]:]

print(train_features.shape)
print(val_features.shape)

# Create DataLoaders
train_dataset = ImageDataset(train_images, train_features, train_labels, transform=transform)
val_dataset = ImageDataset(val_images, val_features, val_labels, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)


# Define the CNN model
class SimpleCNN(nn.Module):
    def __init__(self, num_classes):
        super(SimpleCNN, self).__init__()
        self.block = timm.create_model('resnet50.a1_in1k', pretrained=True)
        # self.block.head = nn.Linear(self.block.num_features, 1000)

        self.fc1 = nn.Linear(1000, 512)
        self.bn1 = nn.BatchNorm1d(512)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(0.2)
        self.fc2 = nn.Linear(512, 256)
        self.bn2 = nn.BatchNorm1d(256)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(0.2)

        self.fc_ann1 = nn.Linear(512, 256)
        self.bn_ann1 = nn.BatchNorm1d(256)
        self.relu_ann1 = nn.ReLU()
        self.dropout_ann1 = nn.Dropout(0.2)
        self.fc_ann2 = nn.Linear(256, 128)
        self.bn_ann2 = nn.BatchNorm1d(128)
        self.relu_ann2 = nn.ReLU()
        self.dropout_ann2 = nn.Dropout(0.2)

        self.fc_comb = nn.Linear(384, 256)
        self.bn_comb = nn.BatchNorm1d(256)
        self.relu_comb = nn.ReLU()
        self.dropout_comb = nn.Dropout(0.2)

        self.fc3 = nn.Linear(256, 128)
        self.bn3 = nn.BatchNorm1d(128)
        self.relu3 = nn.ReLU()
        self.dropout3 = nn.Dropout(0.2)
        self.fc4 = nn.Linear(128, num_classes)

        self.relu = nn.ReLU()


    def forward(self, x, features):
        features = features.float()
        x = self.block(x)
        # print(x.shape)
        x = x.view(-1, 1000)  # Flatten
        x = self.dropout1(self.relu1(self.bn1(self.fc1(x))))
        x = self.dropout2(self.relu2(self.bn2(self.fc2(x))))

        features = self.dropout_ann1(self.relu_ann1(self.bn_ann1(self.fc_ann1(features))))
        features = self.dropout_ann2(self.relu_ann2(self.bn_ann2(self.fc_ann2(features))))

        x = torch.cat((x, features), dim=1)
        x = self.dropout_comb(self.relu_comb(self.bn_comb(self.fc_comb(x))))

        x = self.dropout3(self.relu3(self.bn3(self.fc3(x))))
        x = self.fc4(x)
        return x


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")
# Instantiate model, loss function, and optimizer
num_classes = 4
model = SimpleCNN(num_classes)
model = model.to(device)
criterion = nn.CrossEntropyLoss().to(device)

optimizer = optim.Adam(model.parameters(), lr=0.0001)

# Training loop
num_epochs = 100
all_metrics = []

best_f1 = -100
best_epoch = 0
best_metric = 0
with open('Results/resnet50_pretrained.csv', 'w') as f:
    f.write("Epoch,Train Loss,Val Loss,Accuracy,Precision,Recall,F1 Score,AUC,AUPR,Specificity,MCC\n")
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for images, features, labels in train_loader:
            images, features, labels = images.to(device), features.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images, features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * images.size(0)

        train_loss = running_loss / len(train_loader.dataset)
        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {train_loss:.4f}")

        # Validation loop
        model.eval()
        running_loss = 0.0
        with torch.no_grad():
            y_pred = []
            y_true = []
            y_proba = []
            for images, features, labels in val_loader:
                images, features, labels = images.to(device), features.to(device), labels.to(device)

                outputs = model(images, features)
                loss = criterion(outputs, labels)

                running_loss += loss.item() * images.size(0)

                # Apply softmax to get probabilities
                probabilities = F.softmax(outputs, dim=1)

                # Get the predicted class and corresponding probability
                proba, predicted = torch.max(probabilities, 1)

                # Store results
                y_pred.extend(predicted.cpu().tolist())
                y_true.extend(labels.cpu().tolist())
                y_proba.extend(probabilities.cpu().tolist())

            val_loss = running_loss / len(val_loader.dataset)
            print(f"Epoch {epoch+1}/{num_epochs}, Loss: {val_loss:.4f}")
            # Convert lists to tensors
            y_pred = torch.tensor(y_pred)
            y_true = torch.tensor(y_true)
            y_proba = torch.tensor(y_proba)

            metrics = calculate_metrics(y_pred, y_proba, y_true, num_classes)
            all_metrics.append(metrics)

            if best_f1 < float(metrics["f1_score"]):
                best_f1 = float(metrics["f1_score"])
                best_epoch = epoch+1
                best_metric = metrics
            print('---------------------------------------------------------------------------------------------------')

            f.write(f"{epoch+1},{train_loss},{val_loss},{metrics['accuracy']},{metrics['precision']},{metrics['recall']},{metrics['f1_score']},{metrics['auc']},{metrics['aupr']},{metrics['macro_specificity']},{metrics['macro_mcc']}\n")
            f.flush()
    print("Training and validating complete")
# Out:
# <ipython-input-14-54d133f9d5eb>:155: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   image_path = os.path.join(dataset_path, row[1], row[0])
# 1262
# <ipython-input-14-54d133f9d5eb>:179: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   image = torch.tensor(image, dtype=torch.float32)
# 1762
# <ipython-input-14-54d133f9d5eb>:188: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   image_path = os.path.join(dataset_path, row[1], row[0])
# 316
# (1762, 512)
# (316, 512)
# model.safetensors:   0%|          | 0.00/102M [00:00<?, ?B/s]
# Epoch 1/100, Loss: 1.2454
# Epoch 1/100, Loss: 1.0201
# Accuracy: 0.6281
# Precision: 0.6736
# Recall: 0.6281
# F1 Score: 0.6250
# AUC: 0.8634
# AUPR: 0.6771
# Specificity per class: [0.8491379310344828, 0.9045226130653267, 0.8755555555555555, 0.9863013698630136]
# Macro-average Specificity: 0.9039
# MCC per class: [0.5428261550524173, 0.6052135880305155, 0.7826709811685572, 0.25797486094539523]
# Macro-average MCC: 0.5472
# F1 Score (micro): 0.7278
# F1 Score (weighted): 0.7125
# ---------------------------------------------------------------------------------------------------
# Epoch 2/100, Loss: 0.9460
# Epoch 2/100, Loss: 0.7355
# Accuracy: 0.6612
# Precision: 0.8476
# Recall: 0.6612
# F1 Score: 0.6368
# AUC: 0.9215
# AUPR: 0.7454
# Specificity per class: [0.8318965517241379, 0.9296482412060302, 0.9422222222222222, 1.0]
# Macro-average Specificity: 0.9259
# MCC per class: [0.6763988573985117, 0.6690311672687865, 0.8996259975843229, 0.1965307574511904]
# Macro-average MCC: 0.6104
# F1 Score (micro): 0.7911
# F1 Score (weighted): 0.7635
# ---------------------------------------------------------------------------------------------------
# Epoch 3/100, Loss: 0.8055
# Epoch 3/100, Loss: 0.6837
# Accuracy: 0.6592
# Precision: 0.6153
# Recall: 0.6592
# F1 Score: 0.6271
# AUC: 0.9330
# AUPR: 0.8054
# Specificity per class: [0.7931034482758621, 0.964824120603015, 0.9644444444444444, 1.0]
# Macro-average Specificity: 0.9306
# MCC per class: [0.6511231690592238, 0.755017442413992, 0.9090176919496351, 0.0]
# Macro-average MCC: 0.5788
# F1 Score (micro): 0.8006
# F1 Score (weighted): 0.7742
# ---------------------------------------------------------------------------------------------------
# Epoch 4/100, Loss: 0.7076
# Epoch 4/100, Loss: 0.7134
# Accuracy: 0.5902
# Precision: 0.5987
# Recall: 0.5902
# F1 Score: 0.5498
# AUC: 0.9308
# AUPR: 0.7871
# Specificity per class: [0.6163793103448276, 0.9949748743718593, 0.9733333333333334, 1.0]
# Macro-average Specificity: 0.8962
# MCC per class: [0.5253407423185584, 0.5813950629769522, 0.8993801494380657, 0.0]
# Macro-average MCC: 0.5015
# F1 Score (micro): 0.6962
# F1 Score (weighted): 0.6707
# ---------------------------------------------------------------------------------------------------
# Epoch 5/100, Loss: 0.6130
# Epoch 5/100, Loss: 0.4808
# Accuracy: 0.7007
# Precision: 0.8917
# Recall: 0.7007
# F1 Score: 0.6777
# AUC: 0.9668
# AUPR: 0.8767
# Specificity per class: [0.8405172413793104, 0.9949748743718593, 0.9511111111111111, 1.0]
# Macro-average Specificity: 0.9467
# MCC per class: [0.7446354385246632, 0.8602480293342325, 0.888080228417077, 0.1965307574511904]
# Macro-average MCC: 0.6724
# F1 Score (micro): 0.8449
# F1 Score (weighted): 0.8200
# ---------------------------------------------------------------------------------------------------
# Epoch 6/100, Loss: 0.5434
# Epoch 6/100, Loss: 0.4572
# Accuracy: 0.6558
# Precision: 0.6465
# Recall: 0.6558
# F1 Score: 0.6367
# AUC: 0.9816
# AUPR: 0.9126
# Specificity per class: [0.9956896551724138, 0.7939698492462312, 0.9377777777777778, 1.0]
# Macro-average Specificity: 0.9319
# MCC per class: [0.7440031401584559, 0.7585332234241318, 0.8931165071612532, 0.0]
# Macro-average MCC: 0.5989
# F1 Score (micro): 0.8228
# F1 Score (weighted): 0.7859
# ---------------------------------------------------------------------------------------------------
# Epoch 7/100, Loss: 0.4881
# Epoch 7/100, Loss: 0.3673
# Accuracy: 0.7334
# Precision: 0.9140
# Recall: 0.7334
# F1 Score: 0.7237
# AUC: 0.9889
# AUPR: 0.9453
# Specificity per class: [0.896551724137931, 0.949748743718593, 0.9866666666666667, 1.0]
# Macro-average Specificity: 0.9582
# MCC per class: [0.8165955928288878, 0.8854246802404337, 0.9301151455930349, 0.2783786847881383]
# Macro-average MCC: 0.7276
# F1 Score (micro): 0.8829
# F1 Score (weighted): 0.8583
# ---------------------------------------------------------------------------------------------------
# Epoch 8/100, Loss: 0.4254
# Epoch 8/100, Loss: 0.3780
# Accuracy: 0.8479
# Precision: 0.8949
# Recall: 0.8479
# F1 Score: 0.8620
# AUC: 0.9917
# AUPR: 0.9615
# Specificity per class: [0.9137931034482759, 0.9849246231155779, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9710
# MCC per class: [0.8500177493225112, 0.9050106221559147, 0.9612965996570492, 0.6420842352406705]
# Macro-average MCC: 0.8396
# F1 Score (micro): 0.9146
# F1 Score (weighted): 0.9126
# ---------------------------------------------------------------------------------------------------
# Epoch 9/100, Loss: 0.4046
# Epoch 9/100, Loss: 0.3982
# Accuracy: 0.7455
# Precision: 0.8978
# Recall: 0.7455
# F1 Score: 0.7626
# AUC: 0.9745
# AUPR: 0.9058
# Specificity per class: [0.8103448275862069, 0.9748743718592965, 0.9955555555555555, 1.0]
# Macro-average Specificity: 0.9452
# MCC per class: [0.7194377043384881, 0.8169192400720001, 0.9148856195602327, 0.5249955051947106]
# Macro-average MCC: 0.7441
# F1 Score (micro): 0.8418
# F1 Score (weighted): 0.8373
# ---------------------------------------------------------------------------------------------------
# Epoch 10/100, Loss: 0.3644
# Epoch 10/100, Loss: 0.4807
# Accuracy: 0.7289
# Precision: 0.8577
# Recall: 0.7289
# F1 Score: 0.7391
# AUC: 0.9749
# AUPR: 0.9034
# Specificity per class: [0.771551724137931, 0.9949748743718593, 0.9822222222222222, 0.9965753424657534]
# Macro-average Specificity: 0.9363
# MCC per class: [0.6877995423234428, 0.7634935038578184, 0.9145244185610277, 0.4861093461844201]
# Macro-average MCC: 0.7130
# F1 Score (micro): 0.8133
# F1 Score (weighted): 0.8092
# ---------------------------------------------------------------------------------------------------
# Epoch 11/100, Loss: 0.3294
# Epoch 11/100, Loss: 0.2442
# Accuracy: 0.8922
# Precision: 0.9155
# Recall: 0.8922
# F1 Score: 0.9017
# AUC: 0.9924
# AUPR: 0.9683
# Specificity per class: [0.9525862068965517, 0.9798994974874372, 0.9866666666666667, 0.9897260273972602]
# Macro-average Specificity: 0.9772
# MCC per class: [0.8916088805902701, 0.925150601458725, 0.9458339132861252, 0.7595013469791785]
# Macro-average MCC: 0.8805
# F1 Score (micro): 0.9335
# F1 Score (weighted): 0.9328
# ---------------------------------------------------------------------------------------------------
# Epoch 12/100, Loss: 0.2974
# Epoch 12/100, Loss: 0.4451
# Accuracy: 0.7874
# Precision: 0.8231
# Recall: 0.7874
# F1 Score: 0.7836
# AUC: 0.9865
# AUPR: 0.9332
# Specificity per class: [0.7974137931034483, 1.0, 0.9866666666666667, 0.9794520547945206]
# Macro-average Specificity: 0.9409
# MCC per class: [0.7150655690892043, 0.7275380601018006, 0.9536996336996337, 0.5807359307779387]
# Macro-average MCC: 0.7443
# F1 Score (micro): 0.8228
# F1 Score (weighted): 0.8214
# ---------------------------------------------------------------------------------------------------
# Epoch 13/100, Loss: 0.2630
# Epoch 13/100, Loss: 0.2018
# Accuracy: 0.9415
# Precision: 0.9276
# Recall: 0.9415
# F1 Score: 0.9341
# AUC: 0.9961
# AUPR: 0.9824
# Specificity per class: [0.9827586206896551, 0.9899497487437185, 0.9866666666666667, 0.9828767123287672]
# Macro-average Specificity: 0.9856
# MCC per class: [0.9434925890878169, 0.9456797751166062, 0.9615706499287768, 0.8270585437664306]
# Macro-average MCC: 0.9195
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9561
# ---------------------------------------------------------------------------------------------------
# Epoch 14/100, Loss: 0.2480
# Epoch 14/100, Loss: 0.1735
# Accuracy: 0.9109
# Precision: 0.9308
# Recall: 0.9109
# F1 Score: 0.9199
# AUC: 0.9962
# AUPR: 0.9791
# Specificity per class: [0.9741379310344828, 0.9748743718592965, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9825
# MCC per class: [0.9196546412641213, 0.9459885105169251, 0.9613185012354785, 0.7867690928682439]
# Macro-average MCC: 0.9034
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9487
# ---------------------------------------------------------------------------------------------------
# Epoch 15/100, Loss: 0.2189
# Epoch 15/100, Loss: 0.2181
# Accuracy: 0.9206
# Precision: 0.9006
# Recall: 0.9206
# F1 Score: 0.9090
# AUC: 0.9958
# AUPR: 0.9750
# Specificity per class: [0.9568965517241379, 0.9899497487437185, 0.9955555555555555, 0.976027397260274]
# Macro-average Specificity: 0.9796
# MCC per class: [0.9073772042004405, 0.9121185533761437, 0.9690466897894506, 0.7670229738811488]
# Macro-average MCC: 0.8889
# F1 Score (micro): 0.9367
# F1 Score (weighted): 0.9377
# ---------------------------------------------------------------------------------------------------
# Epoch 16/100, Loss: 0.1915
# Epoch 16/100, Loss: 0.1884
# Accuracy: 0.9312
# Precision: 0.9077
# Recall: 0.9312
# F1 Score: 0.9166
# AUC: 0.9978
# AUPR: 0.9887
# Specificity per class: [0.9482758620689655, 1.0, 0.9911111111111112, 0.9794520547945206]
# Macro-average Specificity: 0.9797
# MCC per class: [0.9109014103130726, 0.9003820048251676, 0.9691330891330892, 0.8097555655148659]
# Macro-average MCC: 0.8975
# F1 Score (micro): 0.9367
# F1 Score (weighted): 0.9372
# ---------------------------------------------------------------------------------------------------
# Epoch 17/100, Loss: 0.1985
# Epoch 17/100, Loss: 0.2732
# Accuracy: 0.9098
# Precision: 0.8927
# Recall: 0.9098
# F1 Score: 0.8945
# AUC: 0.9962
# AUPR: 0.9800
# Specificity per class: [0.9008620689655172, 1.0, 0.9911111111111112, 0.9828767123287672]
# Macro-average Specificity: 0.9687
# MCC per class: [0.8409630315871762, 0.8358022036135844, 0.9691330891330892, 0.8270585437664306]
# Macro-average MCC: 0.8682
# F1 Score (micro): 0.9051
# F1 Score (weighted): 0.9052
# ---------------------------------------------------------------------------------------------------
# Epoch 18/100, Loss: 0.1775
# Epoch 18/100, Loss: 0.1437
# Accuracy: 0.9417
# Precision: 0.9330
# Recall: 0.9417
# F1 Score: 0.9371
# AUC: 0.9979
# AUPR: 0.9923
# Specificity per class: [0.9741379310344828, 0.9899497487437185, 0.9911111111111112, 0.9863013698630136]
# Macro-average Specificity: 0.9854
# MCC per class: [0.9365879961071812, 0.9456797751166062, 0.9613185012354785, 0.8453483040258218]
# Macro-average MCC: 0.9222
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9560
# ---------------------------------------------------------------------------------------------------
# Epoch 19/100, Loss: 0.1542
# Epoch 19/100, Loss: 0.2560
# Accuracy: 0.9018
# Precision: 0.9112
# Recall: 0.9018
# F1 Score: 0.9013
# AUC: 0.9950
# AUPR: 0.9757
# Specificity per class: [0.9051724137931034, 1.0, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9726
# MCC per class: [0.8469394554034326, 0.8744166094066612, 0.9768030891848316, 0.8133573344341013]
# Macro-average MCC: 0.8779
# F1 Score (micro): 0.9177
# F1 Score (weighted): 0.9185
# ---------------------------------------------------------------------------------------------------
# Epoch 20/100, Loss: 0.1486
# Epoch 20/100, Loss: 0.1322
# Accuracy: 0.9660
# Precision: 0.9541
# Recall: 0.9660
# F1 Score: 0.9596
# AUC: 0.9990
# AUPR: 0.9964
# Specificity per class: [0.9956896551724138, 0.9798994974874372, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9891
# MCC per class: [0.9674507616545168, 0.9526028896362934, 0.9613185012354785, 0.9140014911483973]
# Macro-average MCC: 0.9488
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9685
# ---------------------------------------------------------------------------------------------------
# Epoch 21/100, Loss: 0.1515
# Epoch 21/100, Loss: 0.1617
# Accuracy: 0.9317
# Precision: 0.9506
# Recall: 0.9317
# F1 Score: 0.9398
# AUC: 0.9968
# AUPR: 0.9848
# Specificity per class: [0.9698275862068966, 0.9899497487437185, 0.9777777777777777, 0.9965753424657534]
# Macro-average Specificity: 0.9835
# MCC per class: [0.9206073369943373, 0.9389331631730534, 0.9547410841058538, 0.882686929807428]
# Macro-average MCC: 0.9242
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9523
# ---------------------------------------------------------------------------------------------------
# Epoch 22/100, Loss: 0.1570
# Epoch 22/100, Loss: 0.1294
# Accuracy: 0.9385
# Precision: 0.9440
# Recall: 0.9385
# F1 Score: 0.9411
# AUC: 0.9977
# AUPR: 0.9899
# Specificity per class: [0.9741379310344828, 0.9798994974874372, 0.9866666666666667, 0.9931506849315068]
# Macro-average Specificity: 0.9835
# MCC per class: [0.9196546412641213, 0.931985936148579, 0.9615706499287768, 0.8853080854491499]
# Macro-average MCC: 0.9246
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9525
# ---------------------------------------------------------------------------------------------------
# Epoch 23/100, Loss: 0.1124
# Epoch 23/100, Loss: 0.1326
# Accuracy: 0.9606
# Precision: 0.9506
# Recall: 0.9606
# F1 Score: 0.9553
# AUC: 0.9977
# AUPR: 0.9921
# Specificity per class: [0.978448275862069, 0.9849246231155779, 0.9866666666666667, 0.9931506849315068]
# Macro-average Specificity: 0.9858
# MCC per class: [0.9273382946495989, 0.9252324391444847, 0.9773317271860865, 0.9338605850305136]
# Macro-average MCC: 0.9409
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9587
# ---------------------------------------------------------------------------------------------------
# Epoch 24/100, Loss: 0.1122
# Epoch 24/100, Loss: 0.1454
# Accuracy: 0.9507
# Precision: 0.9255
# Recall: 0.9507
# F1 Score: 0.9365
# AUC: 0.9981
# AUPR: 0.9910
# Specificity per class: [0.9612068965517241, 0.9849246231155779, 0.9911111111111112, 0.9863013698630136]
# Macro-average Specificity: 0.9809
# MCC per class: [0.9059017880597403, 0.8849256439201393, 0.9847826631637365, 0.8952207487823]
# Macro-average MCC: 0.9177
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9429
# ---------------------------------------------------------------------------------------------------
# Epoch 25/100, Loss: 0.1231
# Epoch 25/100, Loss: 0.1711
# Accuracy: 0.9006
# Precision: 0.9519
# Recall: 0.9006
# F1 Score: 0.9180
# AUC: 0.9960
# AUPR: 0.9829
# Specificity per class: [0.9310344827586207, 0.9949748743718593, 0.9911111111111112, 1.0]
# Macro-average Specificity: 0.9793
# MCC per class: [0.8754129782615152, 0.9193034230536933, 0.9847826631637365, 0.8317152629997844]
# Macro-average MCC: 0.9028
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9394
# ---------------------------------------------------------------------------------------------------
# Epoch 26/100, Loss: 0.0980
# Epoch 26/100, Loss: 0.2363
# Accuracy: 0.9135
# Precision: 0.9068
# Recall: 0.9135
# F1 Score: 0.9056
# AUC: 0.9971
# AUPR: 0.9836
# Specificity per class: [0.9181034482758621, 1.0, 0.9911111111111112, 0.9863013698630136]
# Macro-average Specificity: 0.9739
# MCC per class: [0.8653002714427839, 0.8615051608615831, 0.9847826631637365, 0.819634703196347]
# Macro-average MCC: 0.8828
# F1 Score (micro): 0.9209
# F1 Score (weighted): 0.9207
# ---------------------------------------------------------------------------------------------------
# Epoch 27/100, Loss: 0.0920
# Epoch 27/100, Loss: 0.1064
# Accuracy: 0.9502
# Precision: 0.9542
# Recall: 0.9502
# F1 Score: 0.9518
# AUC: 0.9987
# AUPR: 0.9942
# Specificity per class: [0.9741379310344828, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9882
# MCC per class: [0.9450526993977326, 0.9456797751166062, 0.9845665445665446, 0.8853080854491499]
# Macro-average MCC: 0.9402
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9651
# ---------------------------------------------------------------------------------------------------
# Epoch 28/100, Loss: 0.0994
# Epoch 28/100, Loss: 0.1214
# Accuracy: 0.9551
# Precision: 0.9455
# Recall: 0.9551
# F1 Score: 0.9498
# AUC: 0.9993
# AUPR: 0.9973
# Specificity per class: [0.9698275862068966, 0.9949748743718593, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9875
# MCC per class: [0.937645518934311, 0.9526338872016222, 0.9690466897894506, 0.8896044445281678]
# Macro-average MCC: 0.9372
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9623
# ---------------------------------------------------------------------------------------------------
# Epoch 29/100, Loss: 0.0880
# Epoch 29/100, Loss: 0.1157
# Accuracy: 0.9568
# Precision: 0.9528
# Recall: 0.9568
# F1 Score: 0.9541
# AUC: 0.9989
# AUPR: 0.9954
# Specificity per class: [0.9568965517241379, 0.9849246231155779, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9835
# MCC per class: [0.9073772042004405, 0.9117352234683014, 0.9768030891848316, 0.9549086757990868]
# Macro-average MCC: 0.9377
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9527
# ---------------------------------------------------------------------------------------------------
# Epoch 30/100, Loss: 0.0758
# Epoch 30/100, Loss: 0.0992
# Accuracy: 0.9808
# Precision: 0.9758
# Recall: 0.9808
# F1 Score: 0.9780
# AUC: 0.9988
# AUPR: 0.9972
# Specificity per class: [0.9956896551724138, 0.9798994974874372, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9919
# MCC per class: [0.9511202607580309, 0.9595142500456046, 0.9923377950662305, 0.9781167255328594]
# Macro-average MCC: 0.9703
# F1 Score (micro): 0.9778
# F1 Score (weighted): 0.9777
# ---------------------------------------------------------------------------------------------------
# Epoch 31/100, Loss: 0.0821
# Epoch 31/100, Loss: 0.1568
# Accuracy: 0.9591
# Precision: 0.9394
# Recall: 0.9591
# F1 Score: 0.9474
# AUC: 0.9986
# AUPR: 0.9945
# Specificity per class: [0.9568965517241379, 0.9949748743718593, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9843
# MCC per class: [0.9247156569570832, 0.90608495842879, 0.9845665445665446, 0.9140014911483973]
# Macro-average MCC: 0.9323
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9525
# ---------------------------------------------------------------------------------------------------
# Epoch 32/100, Loss: 0.0704
# Epoch 32/100, Loss: 0.1500
# Accuracy: 0.9064
# Precision: 0.9507
# Recall: 0.9064
# F1 Score: 0.9214
# AUC: 0.9973
# AUPR: 0.9889
# Specificity per class: [0.9224137931034483, 0.9949748743718593, 0.9955555555555555, 1.0]
# Macro-average Specificity: 0.9782
# MCC per class: [0.8715703577096539, 0.9126866390039042, 0.9768030891848316, 0.8572626953618478]
# Macro-average MCC: 0.9046
# F1 Score (micro): 0.9367
# F1 Score (weighted): 0.9371
# ---------------------------------------------------------------------------------------------------
# Epoch 33/100, Loss: 0.0700
# Epoch 33/100, Loss: 0.1143
# Accuracy: 0.9275
# Precision: 0.9535
# Recall: 0.9275
# F1 Score: 0.9376
# AUC: 0.9988
# AUPR: 0.9947
# Specificity per class: [0.9525862068965517, 0.9949748743718593, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9849
# MCC per class: [0.9177618162470923, 0.9459330151619536, 0.9768030891848316, 0.8576217172348696]
# Macro-average MCC: 0.9245
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9555
# ---------------------------------------------------------------------------------------------------
# Epoch 34/100, Loss: 0.0785
# Epoch 34/100, Loss: 0.1431
# Accuracy: 0.9249
# Precision: 0.9444
# Recall: 0.9249
# F1 Score: 0.9328
# AUC: 0.9963
# AUPR: 0.9864
# Specificity per class: [0.9482758620689655, 0.9798994974874372, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9801
# MCC per class: [0.8933760872875811, 0.911531715115916, 0.9690466897894506, 0.882686929807428]
# Macro-average MCC: 0.9142
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9432
# ---------------------------------------------------------------------------------------------------
# Epoch 35/100, Loss: 0.0711
# Epoch 35/100, Loss: 0.0812
# Accuracy: 0.9704
# Precision: 0.9727
# Recall: 0.9704
# F1 Score: 0.9714
# AUC: 0.9990
# AUPR: 0.9965
# Specificity per class: [0.9956896551724138, 0.9798994974874372, 0.9911111111111112, 0.9965753424657534]
# Macro-average Specificity: 0.9908
# MCC per class: [0.9511202607580309, 0.9595142500456046, 0.9847826631637365, 0.9549086757990868]
# Macro-average MCC: 0.9626
# F1 Score (micro): 0.9747
# F1 Score (weighted): 0.9746
# ---------------------------------------------------------------------------------------------------
# Epoch 36/100, Loss: 0.0631
# Epoch 36/100, Loss: 0.1214
# Accuracy: 0.9478
# Precision: 0.9357
# Recall: 0.9478
# F1 Score: 0.9406
# AUC: 0.9987
# AUPR: 0.9935
# Specificity per class: [0.9568965517241379, 0.9899497487437185, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9830
# MCC per class: [0.9160470173873222, 0.9054549279550154, 0.9845665445665446, 0.8896044445281678]
# Macro-average MCC: 0.9239
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9494
# ---------------------------------------------------------------------------------------------------
# Epoch 37/100, Loss: 0.0675
# Epoch 37/100, Loss: 0.0937
# Accuracy: 0.9511
# Precision: 0.9589
# Recall: 0.9511
# F1 Score: 0.9549
# AUC: 0.9986
# AUPR: 0.9951
# Specificity per class: [0.978448275862069, 0.9698492462311558, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9851
# MCC per class: [0.9273382946495989, 0.9255057149918547, 0.9768030891848316, 0.9312905566854962]
# Macro-average MCC: 0.9402
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9589
# ---------------------------------------------------------------------------------------------------
# Epoch 38/100, Loss: 0.0555
# Epoch 38/100, Loss: 0.0809
# Accuracy: 0.9691
# Precision: 0.9768
# Recall: 0.9691
# F1 Score: 0.9729
# AUC: 0.9990
# AUPR: 0.9975
# Specificity per class: [0.9827586206896551, 0.9798994974874372, 0.9955555555555555, 1.0]
# Macro-average Specificity: 0.9896
# MCC per class: [0.9351395730706076, 0.945711463299403, 0.9923377950662305, 0.9772730279218427]
# Macro-average MCC: 0.9626
# F1 Score (micro): 0.9715
# F1 Score (weighted): 0.9715
# ---------------------------------------------------------------------------------------------------
# Epoch 39/100, Loss: 0.0589
# Epoch 39/100, Loss: 0.1017
# Accuracy: 0.9367
# Precision: 0.9702
# Recall: 0.9367
# F1 Score: 0.9514
# AUC: 0.9982
# AUPR: 0.9938
# Specificity per class: [0.9741379310344828, 0.9698492462311558, 1.0, 1.0]
# Macro-average Specificity: 0.9860
# MCC per class: [0.9196546412641213, 0.9464350583554156, 0.9845836908536074, 0.9066819023627151]
# Macro-average MCC: 0.9393
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9618
# ---------------------------------------------------------------------------------------------------
# Epoch 40/100, Loss: 0.0529
# Epoch 40/100, Loss: 0.1675
# Accuracy: 0.9428
# Precision: 0.9289
# Recall: 0.9428
# F1 Score: 0.9330
# AUC: 0.9980
# AUPR: 0.9917
# Specificity per class: [0.9396551724137931, 1.0, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9801
# MCC per class: [0.8974512350049014, 0.8873740653620525, 0.9847826631637365, 0.8896044445281678]
# Macro-average MCC: 0.9148
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9397
# ---------------------------------------------------------------------------------------------------
# Epoch 41/100, Loss: 0.0577
# Epoch 41/100, Loss: 0.1085
# Accuracy: 0.9502
# Precision: 0.9708
# Recall: 0.9502
# F1 Score: 0.9590
# AUC: 0.9987
# AUPR: 0.9926
# Specificity per class: [0.9655172413793104, 0.9899497487437185, 0.9955555555555555, 1.0]
# Macro-average Specificity: 0.9878
# MCC per class: [0.9303440963742202, 0.9456797751166062, 0.9845665445665446, 0.93064584827702]
# Macro-average MCC: 0.9478
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9652
# ---------------------------------------------------------------------------------------------------
# Epoch 42/100, Loss: 0.0552
# Epoch 42/100, Loss: 0.1030
# Accuracy: 0.9394
# Precision: 0.9607
# Recall: 0.9394
# F1 Score: 0.9487
# AUC: 0.9985
# AUPR: 0.9947
# Specificity per class: [0.9612068965517241, 0.9798994974874372, 0.9911111111111112, 1.0]
# Macro-average Specificity: 0.9831
# MCC per class: [0.9059017880597403, 0.925150601458725, 0.9691330891330892, 0.93064584827702]
# Macro-average MCC: 0.9327
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9526
# ---------------------------------------------------------------------------------------------------
# Epoch 43/100, Loss: 0.0570
# Epoch 43/100, Loss: 0.1169
# Accuracy: 0.9383
# Precision: 0.9658
# Recall: 0.9383
# F1 Score: 0.9491
# AUC: 0.9983
# AUPR: 0.9923
# Specificity per class: [0.9525862068965517, 0.9949748743718593, 0.9955555555555555, 1.0]
# Macro-average Specificity: 0.9858
# MCC per class: [0.9090458721223321, 0.939250105582329, 0.9923377950662305, 0.9066819023627151]
# Macro-average MCC: 0.9368
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9589
# ---------------------------------------------------------------------------------------------------
# Epoch 44/100, Loss: 0.0621
# Epoch 44/100, Loss: 0.1086
# Accuracy: 0.9488
# Precision: 0.9716
# Recall: 0.9488
# F1 Score: 0.9590
# AUC: 0.9980
# AUPR: 0.9916
# Specificity per class: [0.9741379310344828, 0.9798994974874372, 0.9955555555555555, 1.0]
# Macro-average Specificity: 0.9874
# MCC per class: [0.9365879961071812, 0.945711463299403, 0.9768030891848316, 0.93064584827702]
# Macro-average MCC: 0.9474
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9651
# ---------------------------------------------------------------------------------------------------
# Epoch 45/100, Loss: 0.0548
# Epoch 45/100, Loss: 0.0898
# Accuracy: 0.9710
# Precision: 0.9613
# Recall: 0.9710
# F1 Score: 0.9659
# AUC: 0.9988
# AUPR: 0.9965
# Specificity per class: [0.9827586206896551, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9904
# MCC per class: [0.960196523248786, 0.9456797751166062, 0.9845665445665446, 0.9338605850305136]
# Macro-average MCC: 0.9561
# F1 Score (micro): 0.9715
# F1 Score (weighted): 0.9715
# ---------------------------------------------------------------------------------------------------
# Epoch 46/100, Loss: 0.0440
# Epoch 46/100, Loss: 0.1038
# Accuracy: 0.9763
# Precision: 0.9542
# Recall: 0.9763
# F1 Score: 0.9644
# AUC: 0.9987
# AUPR: 0.9971
# Specificity per class: [0.9913793103448276, 0.9849246231155779, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9893
# MCC per class: [0.9675697865353038, 0.9320062537742658, 0.9769542224975036, 0.937953340416017]
# Macro-average MCC: 0.9536
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9684
# ---------------------------------------------------------------------------------------------------
# Epoch 47/100, Loss: 0.0544
# Epoch 47/100, Loss: 0.1145
# Accuracy: 0.9432
# Precision: 0.9547
# Recall: 0.9432
# F1 Score: 0.9479
# AUC: 0.9987
# AUPR: 0.9935
# Specificity per class: [0.9612068965517241, 0.9849246231155779, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9846
# MCC per class: [0.923145527810611, 0.9252324391444847, 0.9768030891848316, 0.9072291086054585]
# Macro-average MCC: 0.9331
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9557
# ---------------------------------------------------------------------------------------------------
# Epoch 48/100, Loss: 0.0456
# Epoch 48/100, Loss: 0.0983
# Accuracy: 0.9517
# Precision: 0.9739
# Recall: 0.9517
# F1 Score: 0.9616
# AUC: 0.9987
# AUPR: 0.9969
# Specificity per class: [0.9741379310344828, 0.9849246231155779, 0.9955555555555555, 1.0]
# Macro-average Specificity: 0.9887
# MCC per class: [0.9450526993977326, 0.952435741621506, 0.9768030891848316, 0.93064584827702]
# Macro-average MCC: 0.9512
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9683
# ---------------------------------------------------------------------------------------------------
# Epoch 49/100, Loss: 0.0394
# Epoch 49/100, Loss: 0.1183
# Accuracy: 0.9395
# Precision: 0.9342
# Recall: 0.9395
# F1 Score: 0.9360
# AUC: 0.9983
# AUPR: 0.9929
# Specificity per class: [0.9612068965517241, 0.9899497487437185, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9830
# MCC per class: [0.923145527810611, 0.9121185533761437, 0.9769542224975036, 0.8647260273972602]
# Macro-average MCC: 0.9192
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9493
# ---------------------------------------------------------------------------------------------------
# Epoch 50/100, Loss: 0.0425
# Epoch 50/100, Loss: 0.0755
# Accuracy: 0.9787
# Precision: 0.9691
# Recall: 0.9787
# F1 Score: 0.9737
# AUC: 0.9992
# AUPR: 0.9985
# Specificity per class: [0.9827586206896551, 0.9849246231155779, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9900
# MCC per class: [0.960196523248786, 0.9387976740971787, 0.9768030891848316, 0.9781167255328594]
# Macro-average MCC: 0.9635
# F1 Score (micro): 0.9715
# F1 Score (weighted): 0.9715
# ---------------------------------------------------------------------------------------------------
# Epoch 51/100, Loss: 0.0387
# Epoch 51/100, Loss: 0.1005
# Accuracy: 0.9721
# Precision: 0.9608
# Recall: 0.9721
# F1 Score: 0.9660
# AUC: 0.9986
# AUPR: 0.9964
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9867
# MCC per class: [0.9291271099667554, 0.918475629152568, 0.9845665445665446, 0.9781167255328594]
# Macro-average MCC: 0.9526
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9620
# ---------------------------------------------------------------------------------------------------
# Epoch 52/100, Loss: 0.0465
# Epoch 52/100, Loss: 0.0850
# Accuracy: 0.9489
# Precision: 0.9684
# Recall: 0.9489
# F1 Score: 0.9566
# AUC: 0.9993
# AUPR: 0.9975
# Specificity per class: [0.9568965517241379, 0.9949748743718593, 0.9955555555555555, 1.0]
# Macro-average Specificity: 0.9869
# MCC per class: [0.9247156569570832, 0.939250105582329, 0.9845665445665446, 0.93064584827702]
# Macro-average MCC: 0.9448
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9622
# ---------------------------------------------------------------------------------------------------
# Epoch 53/100, Loss: 0.0416
# Epoch 53/100, Loss: 0.0748
# Accuracy: 0.9710
# Precision: 0.9682
# Recall: 0.9710
# F1 Score: 0.9695
# AUC: 0.9995
# AUPR: 0.9985
# Specificity per class: [0.9827586206896551, 0.9899497487437185, 0.9911111111111112, 0.9965753424657534]
# Macro-average Specificity: 0.9901
# MCC per class: [0.960196523248786, 0.9456797751166062, 0.9769542224975036, 0.9549086757990868]
# Macro-average MCC: 0.9594
# F1 Score (micro): 0.9715
# F1 Score (weighted): 0.9715
# ---------------------------------------------------------------------------------------------------
# Epoch 54/100, Loss: 0.0379
# Epoch 54/100, Loss: 0.0890
# Accuracy: 0.9551
# Precision: 0.9499
# Recall: 0.9551
# F1 Score: 0.9515
# AUC: 0.9994
# AUPR: 0.9965
# Specificity per class: [0.9612068965517241, 0.9949748743718593, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9862
# MCC per class: [0.9317654609958362, 0.9259358814138647, 0.9845665445665446, 0.9098173515981736]
# Macro-average MCC: 0.9380
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9589
# ---------------------------------------------------------------------------------------------------
# Epoch 55/100, Loss: 0.0371
# Epoch 55/100, Loss: 0.0838
# Accuracy: 0.9481
# Precision: 0.9516
# Recall: 0.9481
# F1 Score: 0.9493
# AUC: 0.9991
# AUPR: 0.9956
# Specificity per class: [0.9698275862068966, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9871
# MCC per class: [0.937645518934311, 0.9389331631730534, 0.9845665445665446, 0.8853080854491499]
# Macro-average MCC: 0.9366
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9620
# ---------------------------------------------------------------------------------------------------
# Epoch 56/100, Loss: 0.0515
# Epoch 56/100, Loss: 0.1005
# Accuracy: 0.9555
# Precision: 0.9601
# Recall: 0.9555
# F1 Score: 0.9574
# AUC: 0.9988
# AUPR: 0.9969
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9867
# MCC per class: [0.9291271099667554, 0.9320062537742658, 0.9845665445665446, 0.9312905566854962]
# Macro-average MCC: 0.9442
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9621
# ---------------------------------------------------------------------------------------------------
# Epoch 57/100, Loss: 0.0399
# Epoch 57/100, Loss: 0.1015
# Accuracy: 0.9417
# Precision: 0.9520
# Recall: 0.9417
# F1 Score: 0.9454
# AUC: 0.9988
# AUPR: 0.9956
# Specificity per class: [0.9525862068965517, 0.9899497487437185, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9837
# MCC per class: [0.9090458721223321, 0.918797603624423, 0.9845665445665446, 0.9072291086054585]
# Macro-average MCC: 0.9299
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9527
# ---------------------------------------------------------------------------------------------------
# Epoch 58/100, Loss: 0.0362
# Epoch 58/100, Loss: 0.0863
# Accuracy: 0.9485
# Precision: 0.9715
# Recall: 0.9485
# F1 Score: 0.9589
# AUC: 0.9988
# AUPR: 0.9971
# Specificity per class: [0.9741379310344828, 0.9798994974874372, 0.9955555555555555, 1.0]
# Macro-average Specificity: 0.9874
# MCC per class: [0.9281223053474523, 0.945711463299403, 0.9845665445665446, 0.93064584827702]
# Macro-average MCC: 0.9473
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9651
# ---------------------------------------------------------------------------------------------------
# Epoch 59/100, Loss: 0.0387
# Epoch 59/100, Loss: 0.0994
# Accuracy: 0.9444
# Precision: 0.9461
# Recall: 0.9444
# F1 Score: 0.9443
# AUC: 0.9987
# AUPR: 0.9951
# Specificity per class: [0.9612068965517241, 0.9949748743718593, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9851
# MCC per class: [0.923145527810611, 0.9259358814138647, 0.9847826631637365, 0.8853080854491499]
# Macro-average MCC: 0.9298
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9556
# ---------------------------------------------------------------------------------------------------
# Epoch 60/100, Loss: 0.0386
# Epoch 60/100, Loss: 0.0899
# Accuracy: 0.9362
# Precision: 0.9570
# Recall: 0.9362
# F1 Score: 0.9454
# AUC: 0.9988
# AUPR: 0.9959
# Specificity per class: [0.9698275862068966, 0.9798994974874372, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9855
# MCC per class: [0.9291271099667554, 0.9388393513815171, 0.9768030891848316, 0.882686929807428]
# Macro-average MCC: 0.9319
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9587
# ---------------------------------------------------------------------------------------------------
# Epoch 61/100, Loss: 0.0490
# Epoch 61/100, Loss: 0.1541
# Accuracy: 0.9177
# Precision: 0.9179
# Recall: 0.9177
# F1 Score: 0.9138
# AUC: 0.9988
# AUPR: 0.9924
# Specificity per class: [0.9224137931034483, 1.0, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9758
# MCC per class: [0.8715703577096539, 0.8744166094066612, 0.9847826631637365, 0.8393256142128035]
# Macro-average MCC: 0.8925
# F1 Score (micro): 0.9272
# F1 Score (weighted): 0.9271
# ---------------------------------------------------------------------------------------------------
# Epoch 62/100, Loss: 0.0304
# Epoch 62/100, Loss: 0.0736
# Accuracy: 0.9570
# Precision: 0.9634
# Recall: 0.9570
# F1 Score: 0.9600
# AUC: 0.9994
# AUPR: 0.9980
# Specificity per class: [0.978448275862069, 0.9798994974874372, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9876
# MCC per class: [0.9441594142981191, 0.9388393513815171, 0.9768030891848316, 0.9312905566854962]
# Macro-average MCC: 0.9478
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9652
# ---------------------------------------------------------------------------------------------------
# Epoch 63/100, Loss: 0.0259
# Epoch 63/100, Loss: 0.1434
# Accuracy: 0.9342
# Precision: 0.9433
# Recall: 0.9342
# F1 Score: 0.9371
# AUC: 0.9982
# AUPR: 0.9919
# Specificity per class: [0.9525862068965517, 0.9949748743718593, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9841
# MCC per class: [0.9177618162470923, 0.9259358814138647, 0.9845665445665446, 0.8602932215197799]
# Macro-average MCC: 0.9221
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9525
# ---------------------------------------------------------------------------------------------------
# Epoch 64/100, Loss: 0.0390
# Epoch 64/100, Loss: 0.0758
# Accuracy: 0.9755
# Precision: 0.9604
# Recall: 0.9755
# F1 Score: 0.9675
# AUC: 0.9991
# AUPR: 0.9978
# Specificity per class: [0.9870689655172413, 0.9798994974874372, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9889
# MCC per class: [0.9513546798029556, 0.931985936148579, 0.9845665445665446, 0.9574729648393807]
# Macro-average MCC: 0.9563
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9683
# ---------------------------------------------------------------------------------------------------
# Epoch 65/100, Loss: 0.0292
# Epoch 65/100, Loss: 0.1106
# Accuracy: 0.9285
# Precision: 0.9469
# Recall: 0.9285
# F1 Score: 0.9356
# AUC: 0.9989
# AUPR: 0.9954
# Specificity per class: [0.9482758620689655, 0.9849246231155779, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9813
# MCC per class: [0.9021394970306476, 0.9117352234683014, 0.9768030891848316, 0.882686929807428]
# Macro-average MCC: 0.9183
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9463
# ---------------------------------------------------------------------------------------------------
# Epoch 66/100, Loss: 0.0304
# Epoch 66/100, Loss: 0.1382
# Accuracy: 0.9425
# Precision: 0.9442
# Recall: 0.9425
# F1 Score: 0.9419
# AUC: 0.9984
# AUPR: 0.9929
# Specificity per class: [0.9525862068965517, 0.9949748743718593, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9841
# MCC per class: [0.9177618162470923, 0.9193034230536933, 0.9845665445665446, 0.8853080854491499]
# Macro-average MCC: 0.9267
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9526
# ---------------------------------------------------------------------------------------------------
# Epoch 67/100, Loss: 0.0373
# Epoch 67/100, Loss: 0.1030
# Accuracy: 0.9502
# Precision: 0.9708
# Recall: 0.9502
# F1 Score: 0.9590
# AUC: 0.9982
# AUPR: 0.9911
# Specificity per class: [0.9655172413793104, 0.9899497487437185, 0.9955555555555555, 1.0]
# Macro-average Specificity: 0.9878
# MCC per class: [0.9303440963742202, 0.9456797751166062, 0.9845665445665446, 0.93064584827702]
# Macro-average MCC: 0.9478
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9652
# ---------------------------------------------------------------------------------------------------
# Epoch 68/100, Loss: 0.0394
# Epoch 68/100, Loss: 0.0959
# Accuracy: 0.9377
# Precision: 0.9659
# Recall: 0.9377
# F1 Score: 0.9492
# AUC: 0.9987
# AUPR: 0.9944
# Specificity per class: [0.9568965517241379, 0.9899497487437185, 0.9955555555555555, 1.0]
# Macro-average Specificity: 0.9856
# MCC per class: [0.9160470173873222, 0.9389331631730534, 0.9845665445665446, 0.9066819023627151]
# Macro-average MCC: 0.9366
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9589
# ---------------------------------------------------------------------------------------------------
# Epoch 69/100, Loss: 0.0295
# Epoch 69/100, Loss: 0.1238
# Accuracy: 0.9404
# Precision: 0.9344
# Recall: 0.9404
# F1 Score: 0.9360
# AUC: 0.9988
# AUPR: 0.9929
# Specificity per class: [0.9568965517241379, 0.9949748743718593, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9832
# MCC per class: [0.9247156569570832, 0.9126866390039042, 0.9769542224975036, 0.8647260273972602]
# Macro-average MCC: 0.9198
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9493
# ---------------------------------------------------------------------------------------------------
# Epoch 70/100, Loss: 0.0247
# Epoch 70/100, Loss: 0.0832
# Accuracy: 0.9636
# Precision: 0.9464
# Recall: 0.9636
# F1 Score: 0.9543
# AUC: 0.9990
# AUPR: 0.9962
# Specificity per class: [0.978448275862069, 0.9949748743718593, 0.9866666666666667, 0.9897260273972602]
# Macro-average Specificity: 0.9875
# MCC per class: [0.9357496161555404, 0.939250105582329, 0.9773317271860865, 0.9140014911483973]
# Macro-average MCC: 0.9416
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9621
# ---------------------------------------------------------------------------------------------------
# Epoch 71/100, Loss: 0.0335
# Epoch 71/100, Loss: 0.1146
# Accuracy: 0.9478
# Precision: 0.9351
# Recall: 0.9478
# F1 Score: 0.9403
# AUC: 0.9988
# AUPR: 0.9942
# Specificity per class: [0.9612068965517241, 0.9949748743718593, 0.9866666666666667, 0.9897260273972602]
# Macro-average Specificity: 0.9831
# MCC per class: [0.923145527810611, 0.9126866390039042, 0.9694477535121453, 0.8896044445281678]
# Macro-average MCC: 0.9237
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9493
# ---------------------------------------------------------------------------------------------------
# Epoch 72/100, Loss: 0.0245
# Epoch 72/100, Loss: 0.1088
# Accuracy: 0.9570
# Precision: 0.9518
# Recall: 0.9570
# F1 Score: 0.9536
# AUC: 0.9989
# AUPR: 0.9956
# Specificity per class: [0.9655172413793104, 1.0, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9874
# MCC per class: [0.9303440963742202, 0.9397532094515858, 0.9847826631637365, 0.9098173515981736]
# Macro-average MCC: 0.9412
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9621
# ---------------------------------------------------------------------------------------------------
# Epoch 73/100, Loss: 0.0223
# Epoch 73/100, Loss: 0.1178
# Accuracy: 0.9404
# Precision: 0.9347
# Recall: 0.9404
# F1 Score: 0.9361
# AUC: 0.9988
# AUPR: 0.9929
# Specificity per class: [0.9525862068965517, 0.9949748743718593, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9832
# MCC per class: [0.9177618162470923, 0.9126866390039042, 0.9845665445665446, 0.8647260273972602]
# Macro-average MCC: 0.9199
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9494
# ---------------------------------------------------------------------------------------------------
# Epoch 74/100, Loss: 0.0211
# Epoch 74/100, Loss: 0.0799
# Accuracy: 0.9555
# Precision: 0.9527
# Recall: 0.9555
# F1 Score: 0.9539
# AUC: 0.9990
# AUPR: 0.9962
# Specificity per class: [0.9741379310344828, 0.9849246231155779, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9869
# MCC per class: [0.9365879961071812, 0.9320062537742658, 0.9845665445665446, 0.9098173515981736]
# Macro-average MCC: 0.9407
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9620
# ---------------------------------------------------------------------------------------------------
# Epoch 75/100, Loss: 0.0421
# Epoch 75/100, Loss: 0.0951
# Accuracy: 0.9623
# Precision: 0.9547
# Recall: 0.9623
# F1 Score: 0.9583
# AUC: 0.9985
# AUPR: 0.9959
# Specificity per class: [0.978448275862069, 0.9748743718592965, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9866
# MCC per class: [0.9357496161555404, 0.925242961141528, 0.9845836908536074, 0.9338605850305136]
# Macro-average MCC: 0.9449
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9622
# ---------------------------------------------------------------------------------------------------
# Epoch 76/100, Loss: 0.0204
# Epoch 76/100, Loss: 0.0912
# Accuracy: 0.9741
# Precision: 0.9621
# Recall: 0.9741
# F1 Score: 0.9676
# AUC: 0.9983
# AUPR: 0.9956
# Specificity per class: [0.9913793103448276, 0.9698492462311558, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9886
# MCC per class: [0.9511093868051034, 0.9324627709882455, 0.9845836908536074, 0.9574729648393807]
# Macro-average MCC: 0.9564
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9685
# ---------------------------------------------------------------------------------------------------
# Epoch 77/100, Loss: 0.0210
# Epoch 77/100, Loss: 0.1006
# Accuracy: 0.9734
# Precision: 0.9511
# Recall: 0.9734
# F1 Score: 0.9613
# AUC: 0.9984
# AUPR: 0.9958
# Specificity per class: [0.9827586206896551, 0.9849246231155779, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9882
# MCC per class: [0.9434925890878169, 0.9320062537742658, 0.9845665445665446, 0.937953340416017]
# Macro-average MCC: 0.9495
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9653
# ---------------------------------------------------------------------------------------------------
# Epoch 78/100, Loss: 0.0259
# Epoch 78/100, Loss: 0.1111
# Accuracy: 0.9729
# Precision: 0.9480
# Recall: 0.9729
# F1 Score: 0.9592
# AUC: 0.9982
# AUPR: 0.9927
# Specificity per class: [0.978448275862069, 0.9899497487437185, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9873
# MCC per class: [0.9525686552200252, 0.918797603624423, 0.9769542224975036, 0.937953340416017]
# Macro-average MCC: 0.9466
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9619
# ---------------------------------------------------------------------------------------------------
# Epoch 79/100, Loss: 0.0179
# Epoch 79/100, Loss: 0.1409
# Accuracy: 0.9352
# Precision: 0.9369
# Recall: 0.9352
# F1 Score: 0.9344
# AUC: 0.9979
# AUPR: 0.9917
# Specificity per class: [0.9439655172413793, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9807
# MCC per class: [0.895325390526334, 0.8988061414620218, 0.9845665445665446, 0.8853080854491499]
# Macro-average MCC: 0.9160
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9432
# ---------------------------------------------------------------------------------------------------
# Epoch 80/100, Loss: 0.0199
# Epoch 80/100, Loss: 0.1298
# Accuracy: 0.9686
# Precision: 0.9428
# Recall: 0.9686
# F1 Score: 0.9541
# AUC: 0.9981
# AUPR: 0.9934
# Specificity per class: [0.9655172413793104, 0.9899497487437185, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9852
# MCC per class: [0.9303440963742202, 0.9054549279550154, 0.9845665445665446, 0.937953340416017]
# Macro-average MCC: 0.9396
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9556
# ---------------------------------------------------------------------------------------------------
# Epoch 81/100, Loss: 0.0234
# Epoch 81/100, Loss: 0.0973
# Accuracy: 0.9674
# Precision: 0.9523
# Recall: 0.9674
# F1 Score: 0.9594
# AUC: 0.9983
# AUPR: 0.9963
# Specificity per class: [0.978448275862069, 0.9748743718592965, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9855
# MCC per class: [0.9189244663382594, 0.9183645700774931, 0.9845665445665446, 0.9574729648393807]
# Macro-average MCC: 0.9448
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9588
# ---------------------------------------------------------------------------------------------------
# Epoch 82/100, Loss: 0.0275
# Epoch 82/100, Loss: 0.1263
# Accuracy: 0.9673
# Precision: 0.9405
# Recall: 0.9673
# F1 Score: 0.9515
# AUC: 0.9986
# AUPR: 0.9931
# Specificity per class: [0.9568965517241379, 0.9949748743718593, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9843
# MCC per class: [0.9247156569570832, 0.8994978103502184, 0.9845665445665446, 0.937953340416017]
# Macro-average MCC: 0.9367
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9523
# ---------------------------------------------------------------------------------------------------
# Epoch 83/100, Loss: 0.0264
# Epoch 83/100, Loss: 0.1269
# Accuracy: 0.9272
# Precision: 0.9538
# Recall: 0.9272
# F1 Score: 0.9378
# AUC: 0.9981
# AUPR: 0.9923
# Specificity per class: [0.9525862068965517, 0.9899497487437185, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9848
# MCC per class: [0.9090458721223321, 0.9389331631730534, 0.9922876771341849, 0.8576217172348696]
# Macro-average MCC: 0.9245
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9556
# ---------------------------------------------------------------------------------------------------
# Epoch 84/100, Loss: 0.0255
# Epoch 84/100, Loss: 0.1199
# Accuracy: 0.9431
# Precision: 0.9371
# Recall: 0.9431
# F1 Score: 0.9385
# AUC: 0.9986
# AUPR: 0.9930
# Specificity per class: [0.9525862068965517, 1.0, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9845
# MCC per class: [0.9177618162470923, 0.9199983092652494, 0.9923377950662305, 0.8647260273972602]
# Macro-average MCC: 0.9237
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9526
# ---------------------------------------------------------------------------------------------------
# Epoch 85/100, Loss: 0.0255
# Epoch 85/100, Loss: 0.1115
# Accuracy: 0.9549
# Precision: 0.9608
# Recall: 0.9549
# F1 Score: 0.9575
# AUC: 0.9983
# AUPR: 0.9959
# Specificity per class: [0.9698275862068966, 0.9798994974874372, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9866
# MCC per class: [0.9291271099667554, 0.931985936148579, 0.9845836908536074, 0.9312905566854962]
# Macro-average MCC: 0.9442
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9622
# ---------------------------------------------------------------------------------------------------
# Epoch 86/100, Loss: 0.0252
# Epoch 86/100, Loss: 0.1493
# Accuracy: 0.9132
# Precision: 0.9562
# Recall: 0.9132
# F1 Score: 0.9286
# AUC: 0.9976
# AUPR: 0.9880
# Specificity per class: [0.9396551724137931, 0.9949748743718593, 0.9911111111111112, 1.0]
# Macro-average Specificity: 0.9814
# MCC per class: [0.888601140084966, 0.9259358814138647, 0.9847826631637365, 0.8572626953618478]
# Macro-average MCC: 0.9141
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9459
# ---------------------------------------------------------------------------------------------------
# Epoch 87/100, Loss: 0.0160
# Epoch 87/100, Loss: 0.1065
# Accuracy: 0.9451
# Precision: 0.9492
# Recall: 0.9451
# F1 Score: 0.9468
# AUC: 0.9981
# AUPR: 0.9921
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9859
# MCC per class: [0.9291271099667554, 0.9320062537742658, 0.9845665445665446, 0.8853080854491499]
# Macro-average MCC: 0.9328
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9588
# ---------------------------------------------------------------------------------------------------
# Epoch 88/100, Loss: 0.0217
# Epoch 88/100, Loss: 0.0939
# Accuracy: 0.9675
# Precision: 0.9598
# Recall: 0.9675
# F1 Score: 0.9635
# AUC: 0.9984
# AUPR: 0.9957
# Specificity per class: [0.9870689655172413, 0.9798994974874372, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9889
# MCC per class: [0.9596468835260349, 0.9388393513815171, 0.9768030891848316, 0.9338605850305136]
# Macro-average MCC: 0.9523
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9684
# ---------------------------------------------------------------------------------------------------
# Epoch 89/100, Loss: 0.0256
# Epoch 89/100, Loss: 0.1071
# Accuracy: 0.9640
# Precision: 0.9537
# Recall: 0.9640
# F1 Score: 0.9584
# AUC: 0.9982
# AUPR: 0.9939
# Specificity per class: [0.9741379310344828, 0.9849246231155779, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9869
# MCC per class: [0.9450526993977326, 0.9252324391444847, 0.9768030891848316, 0.9338605850305136]
# Macro-average MCC: 0.9452
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9620
# ---------------------------------------------------------------------------------------------------
# Epoch 90/100, Loss: 0.0191
# Epoch 90/100, Loss: 0.0879
# Accuracy: 0.9689
# Precision: 0.9586
# Recall: 0.9689
# F1 Score: 0.9634
# AUC: 0.9987
# AUPR: 0.9961
# Specificity per class: [0.978448275862069, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9893
# MCC per class: [0.9525686552200252, 0.9389331631730534, 0.9845665445665446, 0.9338605850305136]
# Macro-average MCC: 0.9525
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9684
# ---------------------------------------------------------------------------------------------------
# Epoch 91/100, Loss: 0.0177
# Epoch 91/100, Loss: 0.1054
# Accuracy: 0.9646
# Precision: 0.9533
# Recall: 0.9646
# F1 Score: 0.9583
# AUC: 0.9986
# AUPR: 0.9945
# Specificity per class: [0.9698275862068966, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9871
# MCC per class: [0.937645518934311, 0.9254926645253152, 0.9845665445665446, 0.9338605850305136]
# Macro-average MCC: 0.9454
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9620
# ---------------------------------------------------------------------------------------------------
# Epoch 92/100, Loss: 0.0219
# Epoch 92/100, Loss: 0.0944
# Accuracy: 0.9481
# Precision: 0.9594
# Recall: 0.9481
# F1 Score: 0.9528
# AUC: 0.9983
# AUPR: 0.9938
# Specificity per class: [0.9655172413793104, 0.9899497487437185, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9869
# MCC per class: [0.9303440963742202, 0.9389331631730534, 0.9845665445665446, 0.9072291086054585]
# Macro-average MCC: 0.9403
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9620
# ---------------------------------------------------------------------------------------------------
# Epoch 93/100, Loss: 0.0186
# Epoch 93/100, Loss: 0.0906
# Accuracy: 0.9768
# Precision: 0.9699
# Recall: 0.9768
# F1 Score: 0.9732
# AUC: 0.9984
# AUPR: 0.9964
# Specificity per class: [0.9913793103448276, 0.9798994974874372, 0.9911111111111112, 0.9965753424657534]
# Macro-average Specificity: 0.9897
# MCC per class: [0.9511093868051034, 0.945711463299403, 0.9769542224975036, 0.9781167255328594]
# Macro-average MCC: 0.9630
# F1 Score (micro): 0.9715
# F1 Score (weighted): 0.9715
# ---------------------------------------------------------------------------------------------------
# Epoch 94/100, Loss: 0.0155
# Epoch 94/100, Loss: 0.1519
# Accuracy: 0.9306
# Precision: 0.9407
# Recall: 0.9306
# F1 Score: 0.9343
# AUC: 0.9972
# AUPR: 0.9880
# Specificity per class: [0.9525862068965517, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9828
# MCC per class: [0.9090458721223321, 0.9254926645253152, 0.9768030891848316, 0.8602932215197799]
# Macro-average MCC: 0.9179
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9495
# ---------------------------------------------------------------------------------------------------
# Epoch 95/100, Loss: 0.0175
# Epoch 95/100, Loss: 0.1643
# Accuracy: 0.9276
# Precision: 0.9361
# Recall: 0.9276
# F1 Score: 0.9295
# AUC: 0.9974
# AUPR: 0.9883
# Specificity per class: [0.9396551724137931, 0.9949748743718593, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9808
# MCC per class: [0.888601140084966, 0.90608495842879, 0.9923377950662305, 0.8602932215197799]
# Macro-average MCC: 0.9118
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9431
# ---------------------------------------------------------------------------------------------------
# Epoch 96/100, Loss: 0.0265
# Epoch 96/100, Loss: 0.1035
# Accuracy: 0.9347
# Precision: 0.9457
# Recall: 0.9347
# F1 Score: 0.9394
# AUC: 0.9982
# AUPR: 0.9922
# Specificity per class: [0.9655172413793104, 0.9849246231155779, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9848
# MCC per class: [0.9217736534970257, 0.9320062537742658, 0.9845665445665446, 0.8602932215197799]
# Macro-average MCC: 0.9247
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9556
# ---------------------------------------------------------------------------------------------------
# Epoch 97/100, Loss: 0.0176
# Epoch 97/100, Loss: 0.1125
# Accuracy: 0.9623
# Precision: 0.9615
# Recall: 0.9623
# F1 Score: 0.9619
# AUC: 0.9978
# AUPR: 0.9934
# Specificity per class: [0.978448275862069, 0.9748743718592965, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9864
# MCC per class: [0.9357496161555404, 0.925242961141528, 0.9768030891848316, 0.9549086757990868]
# Macro-average MCC: 0.9482
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9621
# ---------------------------------------------------------------------------------------------------
# Epoch 98/100, Loss: 0.0176
# Epoch 98/100, Loss: 0.1058
# Accuracy: 0.9536
# Precision: 0.9502
# Recall: 0.9536
# F1 Score: 0.9515
# AUC: 0.9986
# AUPR: 0.9945
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9859
# MCC per class: [0.937645518934311, 0.9252324391444847, 0.9768030891848316, 0.9098173515981736]
# Macro-average MCC: 0.9374
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9589
# ---------------------------------------------------------------------------------------------------
# Epoch 99/100, Loss: 0.0200
# Epoch 99/100, Loss: 0.1224
# Accuracy: 0.9466
# Precision: 0.9427
# Recall: 0.9466
# F1 Score: 0.9438
# AUC: 0.9981
# AUPR: 0.9913
# Specificity per class: [0.9568965517241379, 0.9849246231155779, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9826
# MCC per class: [0.9160470173873222, 0.9117352234683014, 0.9690466897894506, 0.9098173515981736]
# Macro-average MCC: 0.9267
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9495
# ---------------------------------------------------------------------------------------------------
# Epoch 100/100, Loss: 0.0292
# Epoch 100/100, Loss: 0.1505
# Accuracy: 0.9448
# Precision: 0.9468
# Recall: 0.9448
# F1 Score: 0.9446
# AUC: 0.9978
# AUPR: 0.9906
# Specificity per class: [0.9525862068965517, 0.9899497487437185, 0.9866666666666667, 0.9965753424657534]
# Macro-average Specificity: 0.9814
# MCC per class: [0.9003285737788081, 0.9054549279550154, 0.9694477535121453, 0.9312905566854962]
# Macro-average MCC: 0.9266
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9462
# ---------------------------------------------------------------------------------------------------
# Training and validating complete

# %% [markdown]
# # swinv2_tiny_window8_256 pretrained

# %%
import os
import pandas as pd
from PIL import Image
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torch.nn.functional as F
import torchvision.models as models
import numpy as np
import timm
import torch
import torch.nn.functional as F
import numpy as np
from torcheval.metrics import MulticlassAccuracy, MulticlassPrecision, MulticlassRecall, MulticlassF1Score, MulticlassAUROC, MulticlassAUPRC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import matthews_corrcoef
import random


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)  # For CPU
    torch.cuda.manual_seed(seed)  # For GPU (if used)
    torch.cuda.manual_seed_all(seed)  # For all GPUs
    torch.backends.cudnn.deterministic = True  # Ensure deterministic behavior
    torch.backends.cudnn.benchmark = False


def calculate_metrics(predicted, probabilities, labels, num_classes):
    # Initialize Torcheval metrics
    accuracy_metric = MulticlassAccuracy(num_classes=num_classes, average="macro")
    precision_metric = MulticlassPrecision(num_classes=num_classes, average="macro")
    recall_metric = MulticlassRecall(num_classes=num_classes, average="macro")
    f1_score_metric = MulticlassF1Score(num_classes=num_classes, average="macro")
    auc_metric = MulticlassAUROC(num_classes=num_classes, average="macro")
    aupr_metric = MulticlassAUPRC(num_classes=num_classes, average="macro")

    # Update metrics with predictions
    accuracy_metric.update(predicted, labels)
    precision_metric.update(predicted, labels)
    recall_metric.update(predicted, labels)
    f1_score_metric.update(predicted, labels)
    auc_metric.update(probabilities, labels)
    aupr_metric.update(probabilities, labels)

    # Compute metrics
    accuracy = accuracy_metric.compute()
    precision = precision_metric.compute()
    recall = recall_metric.compute()
    f1_score = f1_score_metric.compute()
    auc = auc_metric.compute()
    aupr = aupr_metric.compute()

    # Specificity calculation
    conf_matrix = confusion_matrix(labels.cpu().numpy(), predicted.cpu().numpy(), labels=range(num_classes))
    specificity_per_class = []

    for i in range(num_classes):
        TP = conf_matrix[i, i]
        FP = conf_matrix[:, i].sum() - TP
        FN = conf_matrix[i, :].sum() - TP
        TN = conf_matrix.sum() - (TP + FP + FN)

        specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
        specificity_per_class.append(specificity)

    macro_specificity = np.mean(specificity_per_class)

    # MCC calculation for multi-class classification
    mcc_per_class = []
    for i in range(num_classes):
        # Treat each class as the positive class and others as negative
        binary_pred = (predicted == i).int()
        binary_labels = (labels == i).int()
        mcc = matthews_corrcoef(binary_labels.cpu().numpy(), binary_pred.cpu().numpy())
        mcc_per_class.append(mcc)

    macro_mcc = np.mean(mcc_per_class)

    # Print all metrics
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1_score:.4f}")
    print(f"AUC: {auc:.4f}")
    print(f"AUPR: {aupr:.4f}")
    print(f"Specificity per class: {specificity_per_class}")
    print(f"Macro-average Specificity: {macro_specificity:.4f}")
    print(f"MCC per class: {mcc_per_class}")
    print(f"Macro-average MCC: {macro_mcc:.4f}")

    f1_score_metric_micro = MulticlassF1Score(num_classes=num_classes, average="micro")
    f1_score_metric_micro.update(predicted, labels)
    f1_score_micro = f1_score_metric_micro.compute()
    print(f"F1 Score (micro): {f1_score_micro:.4f}")

    f1_score_metric_weighted = MulticlassF1Score(num_classes=num_classes, average="weighted")
    f1_score_metric_weighted.update(predicted, labels)
    f1_score_weighted = f1_score_metric_weighted.compute()
    print(f"F1 Score (weighted): {f1_score_weighted:.4f}")


    # Return metrics as a dictionary
    return {
        "accuracy": "{:.4f}".format(accuracy.item()),
        "precision": "{:.4f}".format(precision.item()),
        "recall": "{:.4f}".format(recall.item()),
        "f1_score": "{:.4f}".format(f1_score.item()),
        "auc": "{:.4f}".format(auc.item()),
        "aupr": "{:.4f}".format(aupr.item()),
        "macro_specificity": "{:.4f}".format(macro_specificity.item()),
        "macro_mcc": "{:.4f}".format(macro_mcc.item())
    }


class ImageDataset(Dataset):
    def __init__(self, images, features, labels, transform=None):
        self.images = images
        self.features = features
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        feature = self.features[idx]
        label = self.labels[idx]
        return image, feature, label


# Image transformations
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

set_seed(42)

dataset_path = "baldder_tissue_classification"

train_df = pd.read_csv("train_df.csv")
val_df = pd.read_csv("val_df.csv")

train_images = []
train_labels = []
for idx, row in train_df.iterrows():
    image_path = os.path.join(dataset_path, row[1], row[0])
    image = Image.open(image_path)
    image = transform(image)
    train_images.append(image)
    train_labels.append(row['encoded_label'])

loaded_images = np.load("top_images.npy")
loaded_labels = np.load("top_labels.npy")
print(len(train_images))
for i in range(len(loaded_images)):
    image = loaded_images[i]
    label = loaded_labels[i]

    # Denormalize the image
    image = (image * np.array([0.229, 0.224, 0.225])[:, None, None]) + np.array([0.485, 0.456, 0.406])[:, None, None]
    image = (image * 255).astype(np.uint8)  # Convert to integer type for PIL compatibility

    # Convert NumPy array to PIL image
    image = Image.fromarray(image.transpose(1, 2, 0))  # H x W x C format

    # Apply transformations
    image = transform(image)

    # Convert back to PyTorch tensor (if required)
    image = torch.tensor(image, dtype=torch.float32)
    train_images.append(image)
    train_labels.append(label)

print(len(train_images))

val_images = []
val_labels = []
for idx, row in val_df.iterrows():
    image_path = os.path.join(dataset_path, row[1], row[0])
    image = Image.open(image_path)
    image = transform(image)
    val_images.append(image)
    val_labels.append(row['encoded_label'])

print(len(val_images))

train_features = np.load("features_RFE.npy")[:-val_df.shape[0]]
augmented_features = np.load("features_top_images_RFE.npy")
train_features = np.concatenate((train_features, augmented_features), axis=0)
val_features = np.load("features_RFE.npy")[-val_df.shape[0]:]

print(train_features.shape)
print(val_features.shape)

# Create DataLoaders
train_dataset = ImageDataset(train_images, train_features, train_labels, transform=transform)
val_dataset = ImageDataset(val_images, val_features, val_labels, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)


# Define the CNN model
class SimpleCNN(nn.Module):
    def __init__(self, num_classes):
        super(SimpleCNN, self).__init__()
        self.block = timm.create_model('swinv2_tiny_window8_256.ms_in1k', pretrained=True)
        # self.block.head = nn.Linear(self.block.num_features, 1000)

        self.fc1 = nn.Linear(1000, 512)
        self.bn1 = nn.BatchNorm1d(512)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(0.2)
        self.fc2 = nn.Linear(512, 256)
        self.bn2 = nn.BatchNorm1d(256)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(0.2)

        self.fc_ann1 = nn.Linear(512, 256)
        self.bn_ann1 = nn.BatchNorm1d(256)
        self.relu_ann1 = nn.ReLU()
        self.dropout_ann1 = nn.Dropout(0.2)
        self.fc_ann2 = nn.Linear(256, 128)
        self.bn_ann2 = nn.BatchNorm1d(128)
        self.relu_ann2 = nn.ReLU()
        self.dropout_ann2 = nn.Dropout(0.2)

        self.fc_comb = nn.Linear(384, 256)
        self.bn_comb = nn.BatchNorm1d(256)
        self.relu_comb = nn.ReLU()
        self.dropout_comb = nn.Dropout(0.2)

        self.fc3 = nn.Linear(256, 128)
        self.bn3 = nn.BatchNorm1d(128)
        self.relu3 = nn.ReLU()
        self.dropout3 = nn.Dropout(0.2)
        self.fc4 = nn.Linear(128, num_classes)

        self.relu = nn.ReLU()


    def forward(self, x, features):
        features = features.float()
        x = self.block(x)
        # print(x.shape)
        x = x.view(-1, 1000)  # Flatten
        x = self.dropout1(self.relu1(self.bn1(self.fc1(x))))
        x = self.dropout2(self.relu2(self.bn2(self.fc2(x))))

        features = self.dropout_ann1(self.relu_ann1(self.bn_ann1(self.fc_ann1(features))))
        features = self.dropout_ann2(self.relu_ann2(self.bn_ann2(self.fc_ann2(features))))

        x = torch.cat((x, features), dim=1)
        x = self.dropout_comb(self.relu_comb(self.bn_comb(self.fc_comb(x))))

        x = self.dropout3(self.relu3(self.bn3(self.fc3(x))))
        x = self.fc4(x)
        return x


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")
# Instantiate model, loss function, and optimizer
num_classes = 4
model = SimpleCNN(num_classes)
model = model.to(device)
criterion = nn.CrossEntropyLoss().to(device)

optimizer = optim.Adam(model.parameters(), lr=0.0001)

# Training loop
num_epochs = 100
all_metrics = []

best_f1 = -100
best_epoch = 0
best_metric = 0
with open('Results/swinv2_tiny_window8_256_pretrained.csv', 'w') as f:
    f.write("Epoch,Train Loss,Val Loss,Accuracy,Precision,Recall,F1 Score,AUC,AUPR,Specificity,MCC\n")
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for images, features, labels in train_loader:
            images, features, labels = images.to(device), features.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images, features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * images.size(0)

        train_loss = running_loss / len(train_loader.dataset)
        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {train_loss:.4f}")

        # Validation loop
        model.eval()
        running_loss = 0.0
        with torch.no_grad():
            y_pred = []
            y_true = []
            y_proba = []
            for images, features, labels in val_loader:
                images, features, labels = images.to(device), features.to(device), labels.to(device)

                outputs = model(images, features)
                loss = criterion(outputs, labels)

                running_loss += loss.item() * images.size(0)

                # Apply softmax to get probabilities
                probabilities = F.softmax(outputs, dim=1)

                # Get the predicted class and corresponding probability
                proba, predicted = torch.max(probabilities, 1)

                # Store results
                y_pred.extend(predicted.cpu().tolist())
                y_true.extend(labels.cpu().tolist())
                y_proba.extend(probabilities.cpu().tolist())

            val_loss = running_loss / len(val_loader.dataset)
            print(f"Epoch {epoch+1}/{num_epochs}, Loss: {val_loss:.4f}")
            # Convert lists to tensors
            y_pred = torch.tensor(y_pred)
            y_true = torch.tensor(y_true)
            y_proba = torch.tensor(y_proba)

            metrics = calculate_metrics(y_pred, y_proba, y_true, num_classes)
            all_metrics.append(metrics)

            if best_f1 < float(metrics["f1_score"]):
                best_f1 = float(metrics["f1_score"])
                best_epoch = epoch+1
                best_metric = metrics
            print('---------------------------------------------------------------------------------------------------')

            f.write(f"{epoch+1},{train_loss},{val_loss},{metrics['accuracy']},{metrics['precision']},{metrics['recall']},{metrics['f1_score']},{metrics['auc']},{metrics['aupr']},{metrics['macro_specificity']},{metrics['macro_mcc']}\n")
            f.flush()
    print("Training and validating complete")
# Out:
# <ipython-input-17-bd95416032f4>:155: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   image_path = os.path.join(dataset_path, row[1], row[0])
# 1262
# <ipython-input-17-bd95416032f4>:179: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   image = torch.tensor(image, dtype=torch.float32)
# 1762
# <ipython-input-17-bd95416032f4>:188: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   image_path = os.path.join(dataset_path, row[1], row[0])
# 316
# (1762, 512)
# (316, 512)
# model.safetensors:   0%|          | 0.00/115M [00:00<?, ?B/s]
# Epoch 1/100, Loss: 1.0639
# Epoch 1/100, Loss: 0.6123
# Accuracy: 0.7697
# Precision: 0.8716
# Recall: 0.7697
# F1 Score: 0.7931
# AUC: 0.9622
# AUPR: 0.8818
# Specificity per class: [1.0, 0.9095477386934674, 0.8844444444444445, 0.9931506849315068]
# Macro-average Specificity: 0.9468
# MCC per class: [0.7628961803617725, 0.8579945078563536, 0.829398115845401, 0.6022078852755764]
# Macro-average MCC: 0.7631
# F1 Score (micro): 0.8544
# F1 Score (weighted): 0.8449
# ---------------------------------------------------------------------------------------------------
# Epoch 2/100, Loss: 0.7498
# Epoch 2/100, Loss: 0.6010
# Accuracy: 0.7392
# Precision: 0.8515
# Recall: 0.7392
# F1 Score: 0.7378
# AUC: 0.9600
# AUPR: 0.8622
# Specificity per class: [0.875, 0.9899497487437185, 0.9511111111111111, 0.9965753424657534]
# Macro-average Specificity: 0.9532
# MCC per class: [0.7689369528217611, 0.8591921352460316, 0.9211624748169529, 0.3465483067411199]
# Macro-average MCC: 0.7240
# F1 Score (micro): 0.8639
# F1 Score (weighted): 0.8473
# ---------------------------------------------------------------------------------------------------
# Epoch 3/100, Loss: 0.6797
# Epoch 3/100, Loss: 0.4535
# Accuracy: 0.7517
# Precision: 0.8641
# Recall: 0.7517
# F1 Score: 0.7555
# AUC: 0.9669
# AUPR: 0.8629
# Specificity per class: [0.8793103448275862, 0.9949748743718593, 0.9511111111111111, 0.9965753424657534]
# Macro-average Specificity: 0.9555
# MCC per class: [0.7746441532432965, 0.8732831003040421, 0.9211624748169529, 0.3977415127859719]
# Macro-average MCC: 0.7417
# F1 Score (micro): 0.8703
# F1 Score (weighted): 0.8562
# ---------------------------------------------------------------------------------------------------
# Epoch 4/100, Loss: 0.5940
# Epoch 4/100, Loss: 1.2921
# Accuracy: 0.4981
# Precision: 0.8352
# Recall: 0.4981
# F1 Score: 0.4539
# AUC: 0.8689
# AUPR: 0.6845
# Specificity per class: [0.9956896551724138, 0.457286432160804, 0.9866666666666667, 1.0]
# Macro-average Specificity: 0.8599
# MCC per class: [0.2014632560738836, 0.4876360781603614, 0.8908534839645138, 0.1965307574511904]
# Macro-average MCC: 0.4441
# F1 Score (micro): 0.6456
# F1 Score (weighted): 0.5593
# ---------------------------------------------------------------------------------------------------
# Epoch 5/100, Loss: 0.6969
# Epoch 5/100, Loss: 0.4744
# Accuracy: 0.7250
# Precision: 0.8911
# Recall: 0.7250
# F1 Score: 0.7410
# AUC: 0.9676
# AUPR: 0.8793
# Specificity per class: [0.8836206896551724, 0.9045226130653267, 0.9955555555555555, 1.0]
# Macro-average Specificity: 0.9459
# MCC per class: [0.686699951839997, 0.8446916147459759, 0.9226140414116607, 0.4422731886731076]
# Macro-average MCC: 0.7241
# F1 Score (micro): 0.8513
# F1 Score (weighted): 0.8376
# ---------------------------------------------------------------------------------------------------
# Epoch 6/100, Loss: 0.6652
# Epoch 6/100, Loss: 0.6853
# Accuracy: 0.6625
# Precision: 0.6996
# Recall: 0.6625
# F1 Score: 0.6606
# AUC: 0.9392
# AUPR: 0.8073
# Specificity per class: [0.8146551724137931, 0.9246231155778895, 1.0, 0.9554794520547946]
# Macro-average Specificity: 0.9237
# MCC per class: [0.6656922784840444, 0.846753692086911, 0.7138661631691728, 0.18724078658207788]
# Macro-average MCC: 0.6034
# F1 Score (micro): 0.7753
# F1 Score (weighted): 0.7682
# ---------------------------------------------------------------------------------------------------
# Epoch 7/100, Loss: 0.6870
# Epoch 7/100, Loss: 0.5102
# Accuracy: 0.7262
# Precision: 0.8582
# Recall: 0.7262
# F1 Score: 0.7382
# AUC: 0.9622
# AUPR: 0.8649
# Specificity per class: [0.7629310344827587, 0.9798994974874372, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9349
# MCC per class: [0.6790079883010443, 0.7385784874948884, 0.9384943201352342, 0.4861093461844201]
# Macro-average MCC: 0.7105
# F1 Score (micro): 0.8101
# F1 Score (weighted): 0.8073
# ---------------------------------------------------------------------------------------------------
# Epoch 8/100, Loss: 0.5728
# Epoch 8/100, Loss: 0.4006
# Accuracy: 0.7622
# Precision: 0.8465
# Recall: 0.7622
# F1 Score: 0.7702
# AUC: 0.9795
# AUPR: 0.8976
# Specificity per class: [0.9008620689655172, 0.9798994974874372, 0.9555555555555556, 0.9931506849315068]
# Macro-average Specificity: 0.9574
# MCC per class: [0.7949637063310795, 0.8777579377576595, 0.9114122949461327, 0.4100645177714118]
# Macro-average MCC: 0.7485
# F1 Score (micro): 0.8766
# F1 Score (weighted): 0.8646
# ---------------------------------------------------------------------------------------------------
# Epoch 9/100, Loss: 0.5490
# Epoch 9/100, Loss: 0.3557
# Accuracy: 0.8007
# Precision: 0.8313
# Recall: 0.8007
# F1 Score: 0.8073
# AUC: 0.9840
# AUPR: 0.9156
# Specificity per class: [0.896551724137931, 0.9798994974874372, 0.9866666666666667, 0.9794520547945206]
# Macro-average Specificity: 0.9606
# MCC per class: [0.8073631156402177, 0.8576565971896685, 0.9536996336996337, 0.4786320722417028]
# Macro-average MCC: 0.7743
# F1 Score (micro): 0.8829
# F1 Score (weighted): 0.8794
# ---------------------------------------------------------------------------------------------------
# Epoch 10/100, Loss: 0.4372
# Epoch 10/100, Loss: 0.3144
# Accuracy: 0.8127
# Precision: 0.8611
# Recall: 0.8127
# F1 Score: 0.8257
# AUC: 0.9861
# AUPR: 0.9279
# Specificity per class: [0.9224137931034483, 0.9698492462311558, 0.9866666666666667, 0.9863013698630136]
# Macro-average Specificity: 0.9663
# MCC per class: [0.8355039675821079, 0.8909856897472449, 0.9536996336996337, 0.518800225859527]
# Macro-average MCC: 0.7997
# F1 Score (micro): 0.9019
# F1 Score (weighted): 0.8966
# ---------------------------------------------------------------------------------------------------
# Epoch 11/100, Loss: 0.3922
# Epoch 11/100, Loss: 0.2960
# Accuracy: 0.8447
# Precision: 0.8556
# Recall: 0.8447
# F1 Score: 0.8463
# AUC: 0.9872
# AUPR: 0.9312
# Specificity per class: [0.9094827586206896, 0.9849246231155779, 0.9955555555555555, 0.976027397260274]
# Macro-average Specificity: 0.9665
# MCC per class: [0.8347352272022384, 0.8716036682431851, 0.9612965996570492, 0.5949334189898758]
# Macro-average MCC: 0.8156
# F1 Score (micro): 0.8987
# F1 Score (weighted): 0.8987
# ---------------------------------------------------------------------------------------------------
# Epoch 12/100, Loss: 0.3468
# Epoch 12/100, Loss: 0.2932
# Accuracy: 0.8726
# Precision: 0.8482
# Recall: 0.8726
# F1 Score: 0.8547
# AUC: 0.9912
# AUPR: 0.9451
# Specificity per class: [0.9137931034482759, 0.9899497487437185, 0.9866666666666667, 0.9657534246575342]
# Macro-average Specificity: 0.9640
# MCC per class: [0.8409276971582241, 0.8199632626528196, 0.9615706499287768, 0.6672448365369286]
# Macro-average MCC: 0.8224
# F1 Score (micro): 0.8892
# F1 Score (weighted): 0.8899
# ---------------------------------------------------------------------------------------------------
# Epoch 13/100, Loss: 0.3094
# Epoch 13/100, Loss: 0.2553
# Accuracy: 0.8855
# Precision: 0.8697
# Recall: 0.8855
# F1 Score: 0.8744
# AUC: 0.9920
# AUPR: 0.9527
# Specificity per class: [0.9267241379310345, 0.9899497487437185, 0.9911111111111112, 0.9726027397260274]
# Macro-average Specificity: 0.9701
# MCC per class: [0.859969113749979, 0.8591921352460316, 0.9691330891330892, 0.6966441226934804]
# Macro-average MCC: 0.8462
# F1 Score (micro): 0.9082
# F1 Score (weighted): 0.9090
# ---------------------------------------------------------------------------------------------------
# Epoch 14/100, Loss: 0.2705
# Epoch 14/100, Loss: 0.2377
# Accuracy: 0.8970
# Precision: 0.8816
# Recall: 0.8970
# F1 Score: 0.8872
# AUC: 0.9927
# AUPR: 0.9564
# Specificity per class: [0.9439655172413793, 0.9899497487437185, 0.9955555555555555, 0.9726027397260274]
# Macro-average Specificity: 0.9755
# MCC per class: [0.895325390526334, 0.8855507392967018, 0.9768030891848316, 0.6966441226934804]
# Macro-average MCC: 0.8636
# F1 Score (micro): 0.9241
# F1 Score (weighted): 0.9248
# ---------------------------------------------------------------------------------------------------
# Epoch 15/100, Loss: 0.2521
# Epoch 15/100, Loss: 0.2205
# Accuracy: 0.8991
# Precision: 0.8886
# Recall: 0.8991
# F1 Score: 0.8921
# AUC: 0.9939
# AUPR: 0.9614
# Specificity per class: [0.9439655172413793, 0.9899497487437185, 0.9955555555555555, 0.976027397260274]
# Macro-average Specificity: 0.9764
# MCC per class: [0.895325390526334, 0.8921716075923306, 0.9768030891848316, 0.7125798825187842]
# Macro-average MCC: 0.8692
# F1 Score (micro): 0.9272
# F1 Score (weighted): 0.9277
# ---------------------------------------------------------------------------------------------------
# Epoch 16/100, Loss: 0.2364
# Epoch 16/100, Loss: 0.2304
# Accuracy: 0.9062
# Precision: 0.9096
# Recall: 0.9062
# F1 Score: 0.9072
# AUC: 0.9930
# AUPR: 0.9631
# Specificity per class: [0.9568965517241379, 0.9798994974874372, 1.0, 0.9828767123287672]
# Macro-average Specificity: 0.9799
# MCC per class: [0.9073772042004405, 0.9183327324319255, 0.9768873266890564, 0.7473606717401108]
# Macro-average MCC: 0.8875
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9400
# ---------------------------------------------------------------------------------------------------
# Epoch 17/100, Loss: 0.1894
# Epoch 17/100, Loss: 0.1948
# Accuracy: 0.8926
# Precision: 0.9009
# Recall: 0.8926
# F1 Score: 0.8961
# AUC: 0.9945
# AUPR: 0.9675
# Specificity per class: [0.9612068965517241, 0.9798994974874372, 0.9866666666666667, 0.9828767123287672]
# Macro-average Specificity: 0.9777
# MCC per class: [0.8972759311048011, 0.9183327324319255, 0.9615706499287768, 0.7194855602627441]
# Macro-average MCC: 0.8742
# F1 Score (micro): 0.9335
# F1 Score (weighted): 0.9330
# ---------------------------------------------------------------------------------------------------
# Epoch 18/100, Loss: 0.2032
# Epoch 18/100, Loss: 0.2424
# Accuracy: 0.9046
# Precision: 0.9075
# Recall: 0.9046
# F1 Score: 0.9029
# AUC: 0.9926
# AUPR: 0.9640
# Specificity per class: [0.9181034482758621, 0.9949748743718593, 1.0, 0.9863013698630136]
# Macro-average Specificity: 0.9748
# MCC per class: [0.8562490274339389, 0.8929246233267382, 0.9768873266890564, 0.7933431429764571]
# Macro-average MCC: 0.8799
# F1 Score (micro): 0.9241
# F1 Score (weighted): 0.9251
# ---------------------------------------------------------------------------------------------------
# Epoch 19/100, Loss: 0.1697
# Epoch 19/100, Loss: 0.1758
# Accuracy: 0.9183
# Precision: 0.8934
# Recall: 0.9183
# F1 Score: 0.9039
# AUC: 0.9957
# AUPR: 0.9745
# Specificity per class: [0.9612068965517241, 0.9899497487437185, 0.9911111111111112, 0.9726027397260274]
# Macro-average Specificity: 0.9787
# MCC per class: [0.9059017880597403, 0.9054549279550154, 0.9691330891330892, 0.7513155575678971]
# Macro-average MCC: 0.8830
# F1 Score (micro): 0.9335
# F1 Score (weighted): 0.9347
# ---------------------------------------------------------------------------------------------------
# Epoch 20/100, Loss: 0.1493
# Epoch 20/100, Loss: 0.1533
# Accuracy: 0.9260
# Precision: 0.9178
# Recall: 0.9260
# F1 Score: 0.9216
# AUC: 0.9960
# AUPR: 0.9779
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 0.9911111111111112, 0.9828767123287672]
# Macro-average Specificity: 0.9822
# MCC per class: [0.9120851963967855, 0.9320062537742658, 0.9691330891330892, 0.801092163523476]
# Macro-average MCC: 0.9036
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9465
# ---------------------------------------------------------------------------------------------------
# Epoch 21/100, Loss: 0.1624
# Epoch 21/100, Loss: 0.1733
# Accuracy: 0.9191
# Precision: 0.8902
# Recall: 0.9191
# F1 Score: 0.9020
# AUC: 0.9960
# AUPR: 0.9758
# Specificity per class: [0.9612068965517241, 0.9899497487437185, 0.9955555555555555, 0.9691780821917808]
# Macro-average Specificity: 0.9790
# MCC per class: [0.9145246423032853, 0.8988061414620218, 0.9768030891848316, 0.736390739042166]
# Macro-average MCC: 0.8816
# F1 Score (micro): 0.9335
# F1 Score (weighted): 0.9350
# ---------------------------------------------------------------------------------------------------
# Epoch 22/100, Loss: 0.1662
# Epoch 22/100, Loss: 0.1520
# Accuracy: 0.9219
# Precision: 0.9026
# Recall: 0.9219
# F1 Score: 0.9112
# AUC: 0.9967
# AUPR: 0.9809
# Specificity per class: [0.9655172413793104, 0.9899497487437185, 0.9911111111111112, 0.976027397260274]
# Macro-average Specificity: 0.9807
# MCC per class: [0.9132015205357783, 0.9254926645253152, 0.9613185012354785, 0.7670229738811488]
# Macro-average MCC: 0.8918
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9408
# ---------------------------------------------------------------------------------------------------
# Epoch 23/100, Loss: 0.1459
# Epoch 23/100, Loss: 0.1979
# Accuracy: 0.9044
# Precision: 0.8930
# Recall: 0.9044
# F1 Score: 0.8966
# AUC: 0.9957
# AUPR: 0.9719
# Specificity per class: [0.9396551724137931, 0.9949748743718593, 0.9866666666666667, 0.9794520547945206]
# Macro-average Specificity: 0.9752
# MCC per class: [0.8797493707395952, 0.8929246233267382, 0.9615706499287768, 0.7568360230211301]
# Macro-average MCC: 0.8728
# F1 Score (micro): 0.9241
# F1 Score (weighted): 0.9245
# ---------------------------------------------------------------------------------------------------
# Epoch 24/100, Loss: 0.1228
# Epoch 24/100, Loss: 0.1483
# Accuracy: 0.9513
# Precision: 0.9281
# Recall: 0.9513
# F1 Score: 0.9384
# AUC: 0.9971
# AUPR: 0.9861
# Specificity per class: [0.9827586206896551, 0.9849246231155779, 1.0, 0.9794520547945206]
# Macro-average Specificity: 0.9868
# MCC per class: [0.9434925890878169, 0.945607302219665, 0.9768873266890564, 0.8353862785988658]
# Macro-average MCC: 0.9253
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9597
# ---------------------------------------------------------------------------------------------------
# Epoch 25/100, Loss: 0.1072
# Epoch 25/100, Loss: 0.2064
# Accuracy: 0.9145
# Precision: 0.9330
# Recall: 0.9145
# F1 Score: 0.9213
# AUC: 0.9942
# AUPR: 0.9695
# Specificity per class: [0.9353448275862069, 0.9899497487437185, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9796
# MCC per class: [0.8730702794507377, 0.9254926645253152, 0.9768873266890564, 0.834728011337836]
# Macro-average MCC: 0.9025
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9405
# ---------------------------------------------------------------------------------------------------
# Epoch 26/100, Loss: 0.1002
# Epoch 26/100, Loss: 0.1663
# Accuracy: 0.9222
# Precision: 0.8956
# Recall: 0.9222
# F1 Score: 0.9066
# AUC: 0.9965
# AUPR: 0.9806
# Specificity per class: [0.9655172413793104, 0.9899497487437185, 1.0, 0.9691780821917808]
# Macro-average Specificity: 0.9812
# MCC per class: [0.9217736534970257, 0.9254926645253152, 0.96919786333672, 0.736390739042166]
# Macro-average MCC: 0.8882
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9417
# ---------------------------------------------------------------------------------------------------
# Epoch 27/100, Loss: 0.1065
# Epoch 27/100, Loss: 0.1518
# Accuracy: 0.9121
# Precision: 0.9022
# Recall: 0.9121
# F1 Score: 0.9066
# AUC: 0.9965
# AUPR: 0.9796
# Specificity per class: [0.9698275862068966, 0.9899497487437185, 0.9777777777777777, 0.9794520547945206]
# Macro-average Specificity: 0.9793
# MCC per class: [0.9206073369943373, 0.918797603624423, 0.9467568508579206, 0.7568360230211301]
# Macro-average MCC: 0.8857
# F1 Score (micro): 0.9367
# F1 Score (weighted): 0.9369
# ---------------------------------------------------------------------------------------------------
# Epoch 28/100, Loss: 0.1095
# Epoch 28/100, Loss: 0.1295
# Accuracy: 0.9460
# Precision: 0.9386
# Recall: 0.9460
# F1 Score: 0.9420
# AUC: 0.9973
# AUPR: 0.9877
# Specificity per class: [0.9741379310344828, 0.9899497487437185, 1.0, 0.9863013698630136]
# Macro-average Specificity: 0.9876
# MCC per class: [0.9365879961071812, 0.9592286682907512, 0.9768873266890564, 0.8453483040258218]
# Macro-average MCC: 0.9295
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9624
# ---------------------------------------------------------------------------------------------------
# Epoch 29/100, Loss: 0.0904
# Epoch 29/100, Loss: 0.1265
# Accuracy: 0.9506
# Precision: 0.9244
# Recall: 0.9506
# F1 Score: 0.9360
# AUC: 0.9978
# AUPR: 0.9853
# Specificity per class: [0.9827586206896551, 0.9949748743718593, 0.9866666666666667, 0.9794520547945206]
# Macro-average Specificity: 0.9860
# MCC per class: [0.9518445910469595, 0.939250105582329, 0.9615706499287768, 0.8353862785988658]
# Macro-average MCC: 0.9220
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9564
# ---------------------------------------------------------------------------------------------------
# Epoch 30/100, Loss: 0.0857
# Epoch 30/100, Loss: 0.1441
# Accuracy: 0.9286
# Precision: 0.9111
# Recall: 0.9286
# F1 Score: 0.9188
# AUC: 0.9971
# AUPR: 0.9844
# Specificity per class: [0.9698275862068966, 0.9899497487437185, 1.0, 0.976027397260274]
# Macro-average Specificity: 0.9840
# MCC per class: [0.9291271099667554, 0.9456797751166062, 0.96919786333672, 0.7670229738811488]
# Macro-average MCC: 0.9028
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9504
# ---------------------------------------------------------------------------------------------------
# Epoch 31/100, Loss: 0.0891
# Epoch 31/100, Loss: 0.1872
# Accuracy: 0.9236
# Precision: 0.9199
# Recall: 0.9236
# F1 Score: 0.9200
# AUC: 0.9959
# AUPR: 0.9777
# Specificity per class: [0.9396551724137931, 0.9949748743718593, 1.0, 0.9863013698630136]
# Macro-average Specificity: 0.9802
# MCC per class: [0.888601140084966, 0.9193034230536933, 0.9768873266890564, 0.819634703196347]
# Macro-average MCC: 0.9011
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9407
# ---------------------------------------------------------------------------------------------------
# Epoch 32/100, Loss: 0.0731
# Epoch 32/100, Loss: 0.1474
# Accuracy: 0.9362
# Precision: 0.9104
# Recall: 0.9362
# F1 Score: 0.9213
# AUC: 0.9975
# AUPR: 0.9835
# Specificity per class: [0.9655172413793104, 0.9949748743718593, 0.9955555555555555, 0.976027397260274]
# Macro-average Specificity: 0.9830
# MCC per class: [0.9303440963742202, 0.9259358814138647, 0.9690466897894506, 0.7933509180833815]
# Macro-average MCC: 0.9047
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9472
# ---------------------------------------------------------------------------------------------------
# Epoch 33/100, Loss: 0.0776
# Epoch 33/100, Loss: 0.1615
# Accuracy: 0.9166
# Precision: 0.9272
# Recall: 0.9166
# F1 Score: 0.9204
# AUC: 0.9963
# AUPR: 0.9775
# Specificity per class: [0.9439655172413793, 0.9899497487437185, 1.0, 0.9897260273972602]
# Macro-average Specificity: 0.9809
# MCC per class: [0.8865171778142027, 0.9322043221572608, 0.9768873266890564, 0.8133573344341013]
# Macro-average MCC: 0.9022
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9435
# ---------------------------------------------------------------------------------------------------
# Epoch 34/100, Loss: 0.0651
# Epoch 34/100, Loss: 0.1327
# Accuracy: 0.9506
# Precision: 0.9295
# Recall: 0.9506
# F1 Score: 0.9389
# AUC: 0.9978
# AUPR: 0.9869
# Specificity per class: [0.9698275862068966, 0.9899497487437185, 1.0, 0.9828767123287672]
# Macro-average Specificity: 0.9857
# MCC per class: [0.9291271099667554, 0.9322043221572608, 0.9845836908536074, 0.852488157148583]
# Macro-average MCC: 0.9246
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9563
# ---------------------------------------------------------------------------------------------------
# Epoch 35/100, Loss: 0.0573
# Epoch 35/100, Loss: 0.1474
# Accuracy: 0.9280
# Precision: 0.9410
# Recall: 0.9280
# F1 Score: 0.9331
# AUC: 0.9970
# AUPR: 0.9859
# Specificity per class: [0.9482758620689655, 0.9899497487437185, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9828
# MCC per class: [0.8933760872875811, 0.9524447467356325, 0.9615145720873706, 0.8602932215197799]
# Macro-average MCC: 0.9169
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9498
# ---------------------------------------------------------------------------------------------------
# Epoch 36/100, Loss: 0.0599
# Epoch 36/100, Loss: 0.1224
# Accuracy: 0.9400
# Precision: 0.9247
# Recall: 0.9400
# F1 Score: 0.9318
# AUC: 0.9978
# AUPR: 0.9883
# Specificity per class: [0.9741379310344828, 0.9899497487437185, 0.9911111111111112, 0.9828767123287672]
# Macro-average Specificity: 0.9845
# MCC per class: [0.9281223053474523, 0.9322043221572608, 0.9769542224975036, 0.8270585437664306]
# Macro-average MCC: 0.9161
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9529
# ---------------------------------------------------------------------------------------------------
# Epoch 37/100, Loss: 0.0613
# Epoch 37/100, Loss: 0.1512
# Accuracy: 0.9216
# Precision: 0.9264
# Recall: 0.9216
# F1 Score: 0.9225
# AUC: 0.9971
# AUPR: 0.9831
# Specificity per class: [0.9396551724137931, 0.9899497487437185, 1.0, 0.9897260273972602]
# Macro-average Specificity: 0.9798
# MCC per class: [0.8797493707395952, 0.9322043221572608, 0.9615145720873706, 0.8393256142128035]
# Macro-average MCC: 0.9032
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9407
# ---------------------------------------------------------------------------------------------------
# Epoch 38/100, Loss: 0.0559
# Epoch 38/100, Loss: 0.1692
# Accuracy: 0.9143
# Precision: 0.9490
# Recall: 0.9143
# F1 Score: 0.9269
# AUC: 0.9955
# AUPR: 0.9747
# Specificity per class: [0.9353448275862069, 1.0, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9830
# MCC per class: [0.8908568427730515, 0.9530075466393428, 0.9768873266890564, 0.8319853203258969]
# Macro-average MCC: 0.9132
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9496
# ---------------------------------------------------------------------------------------------------
# Epoch 39/100, Loss: 0.0711
# Epoch 39/100, Loss: 0.1368
# Accuracy: 0.9488
# Precision: 0.9248
# Recall: 0.9488
# F1 Score: 0.9353
# AUC: 0.9973
# AUPR: 0.9859
# Specificity per class: [0.978448275862069, 0.9899497487437185, 0.9955555555555555, 0.9794520547945206]
# Macro-average Specificity: 0.9859
# MCC per class: [0.9441594142981191, 0.9524447467356325, 0.9535520638570569, 0.8353862785988658]
# Macro-average MCC: 0.9214
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9565
# ---------------------------------------------------------------------------------------------------
# Epoch 40/100, Loss: 0.0517
# Epoch 40/100, Loss: 0.1345
# Accuracy: 0.9290
# Precision: 0.9323
# Recall: 0.9290
# F1 Score: 0.9302
# AUC: 0.9976
# AUPR: 0.9864
# Specificity per class: [0.9655172413793104, 0.9899497487437185, 0.9866666666666667, 0.9897260273972602]
# Macro-average Specificity: 0.9830
# MCC per class: [0.9132015205357783, 0.9389331631730534, 0.9615706499287768, 0.8393256142128035]
# Macro-average MCC: 0.9133
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9494
# ---------------------------------------------------------------------------------------------------
# Epoch 41/100, Loss: 0.0558
# Epoch 41/100, Loss: 0.1060
# Accuracy: 0.9532
# Precision: 0.9469
# Recall: 0.9532
# F1 Score: 0.9500
# AUC: 0.9983
# AUPR: 0.9923
# Specificity per class: [0.9870689655172413, 0.9798994974874372, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9870
# MCC per class: [0.9430620346419998, 0.945711463299403, 0.9691330891330892, 0.8896044445281678]
# Macro-average MCC: 0.9369
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9621
# ---------------------------------------------------------------------------------------------------
# Epoch 42/100, Loss: 0.0511
# Epoch 42/100, Loss: 0.1224
# Accuracy: 0.9341
# Precision: 0.9457
# Recall: 0.9341
# F1 Score: 0.9389
# AUC: 0.9976
# AUPR: 0.9859
# Specificity per class: [0.9568965517241379, 0.9899497487437185, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9850
# MCC per class: [0.9073772042004405, 0.9456797751166062, 0.9845836908536074, 0.8602932215197799]
# Macro-average MCC: 0.9245
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9559
# ---------------------------------------------------------------------------------------------------
# Epoch 43/100, Loss: 0.0476
# Epoch 43/100, Loss: 0.1195
# Accuracy: 0.9319
# Precision: 0.9233
# Recall: 0.9319
# F1 Score: 0.9271
# AUC: 0.9976
# AUPR: 0.9841
# Specificity per class: [0.9655172413793104, 0.9899497487437185, 1.0, 0.9828767123287672]
# Macro-average Specificity: 0.9846
# MCC per class: [0.9217736534970257, 0.9389331631730534, 0.9845836908536074, 0.801092163523476]
# Macro-average MCC: 0.9116
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9530
# ---------------------------------------------------------------------------------------------------
# Epoch 44/100, Loss: 0.0581
# Epoch 44/100, Loss: 0.1101
# Accuracy: 0.9315
# Precision: 0.9457
# Recall: 0.9315
# F1 Score: 0.9382
# AUC: 0.9979
# AUPR: 0.9918
# Specificity per class: [0.9741379310344828, 0.9798994974874372, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9846
# MCC per class: [0.911184000211381, 0.9526028896362934, 0.9691330891330892, 0.8602932215197799]
# Macro-average MCC: 0.9233
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9554
# ---------------------------------------------------------------------------------------------------
# Epoch 45/100, Loss: 0.0604
# Epoch 45/100, Loss: 0.1206
# Accuracy: 0.9383
# Precision: 0.9370
# Recall: 0.9383
# F1 Score: 0.9376
# AUC: 0.9979
# AUPR: 0.9901
# Specificity per class: [0.9698275862068966, 0.9798994974874372, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9838
# MCC per class: [0.9035596663727024, 0.931985936148579, 0.9845665445665446, 0.8647260273972602]
# Macro-average MCC: 0.9212
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9526
# ---------------------------------------------------------------------------------------------------
# Epoch 46/100, Loss: 0.0433
# Epoch 46/100, Loss: 0.1182
# Accuracy: 0.9415
# Precision: 0.9328
# Recall: 0.9415
# F1 Score: 0.9369
# AUC: 0.9977
# AUPR: 0.9894
# Specificity per class: [0.9741379310344828, 0.9899497487437185, 0.9911111111111112, 0.9863013698630136]
# Macro-average Specificity: 0.9854
# MCC per class: [0.9281223053474523, 0.9456797751166062, 0.9691330891330892, 0.8453483040258218]
# Macro-average MCC: 0.9221
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9560
# ---------------------------------------------------------------------------------------------------
# Epoch 47/100, Loss: 0.0422
# Epoch 47/100, Loss: 0.1242
# Accuracy: 0.9468
# Precision: 0.9320
# Recall: 0.9468
# F1 Score: 0.9390
# AUC: 0.9980
# AUPR: 0.9905
# Specificity per class: [0.978448275862069, 0.9849246231155779, 0.9866666666666667, 0.9863013698630136]
# Macro-average Specificity: 0.9841
# MCC per class: [0.9273382946495989, 0.9320062537742658, 0.9615706499287768, 0.870530017457414]
# Macro-average MCC: 0.9229
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9528
# ---------------------------------------------------------------------------------------------------
# Epoch 48/100, Loss: 0.0402
# Epoch 48/100, Loss: 0.1436
# Accuracy: 0.9473
# Precision: 0.9323
# Recall: 0.9473
# F1 Score: 0.9388
# AUC: 0.9976
# AUPR: 0.9878
# Specificity per class: [0.9612068965517241, 0.9899497487437185, 1.0, 0.9863013698630136]
# Macro-average Specificity: 0.9844
# MCC per class: [0.9145246423032853, 0.9389331631730534, 0.96919786333672, 0.870530017457414]
# Macro-average MCC: 0.9233
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9532
# ---------------------------------------------------------------------------------------------------
# Epoch 49/100, Loss: 0.0475
# Epoch 49/100, Loss: 0.1320
# Accuracy: 0.9341
# Precision: 0.9203
# Recall: 0.9341
# F1 Score: 0.9261
# AUC: 0.9979
# AUPR: 0.9904
# Specificity per class: [0.9568965517241379, 0.9899497487437185, 1.0, 0.9828767123287672]
# Macro-average Specificity: 0.9824
# MCC per class: [0.9073772042004405, 0.9389331631730534, 0.9615145720873706, 0.8270585437664306]
# Macro-average MCC: 0.9087
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9470
# ---------------------------------------------------------------------------------------------------
# Epoch 50/100, Loss: 0.0503
# Epoch 50/100, Loss: 0.1821
# Accuracy: 0.9189
# Precision: 0.9362
# Recall: 0.9189
# F1 Score: 0.9243
# AUC: 0.9964
# AUPR: 0.9795
# Specificity per class: [0.9310344827586207, 1.0, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9810
# MCC per class: [0.8843466319929314, 0.9265671365457867, 0.9845836908536074, 0.834728011337836]
# Macro-average MCC: 0.9076
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9436
# ---------------------------------------------------------------------------------------------------
# Epoch 51/100, Loss: 0.0328
# Epoch 51/100, Loss: 0.1189
# Accuracy: 0.9443
# Precision: 0.9417
# Recall: 0.9443
# F1 Score: 0.9428
# AUC: 0.9982
# AUPR: 0.9914
# Specificity per class: [0.9698275862068966, 0.9899497487437185, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9863
# MCC per class: [0.9206073369943373, 0.9456797751166062, 0.9845665445665446, 0.8647260273972602]
# Macro-average MCC: 0.9289
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9590
# ---------------------------------------------------------------------------------------------------
# Epoch 52/100, Loss: 0.0396
# Epoch 52/100, Loss: 0.1444
# Accuracy: 0.9423
# Precision: 0.9388
# Recall: 0.9423
# F1 Score: 0.9401
# AUC: 0.9975
# AUPR: 0.9840
# Specificity per class: [0.9655172413793104, 0.9949748743718593, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9853
# MCC per class: [0.9217736534970257, 0.9459330151619536, 0.9691330891330892, 0.8647260273972602]
# Macro-average MCC: 0.9254
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9559
# ---------------------------------------------------------------------------------------------------
# Epoch 53/100, Loss: 0.0379
# Epoch 53/100, Loss: 0.1506
# Accuracy: 0.9370
# Precision: 0.9566
# Recall: 0.9370
# F1 Score: 0.9449
# AUC: 0.9968
# AUPR: 0.9822
# Specificity per class: [0.9525862068965517, 0.9949748743718593, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9860
# MCC per class: [0.9090458721223321, 0.9526338872016222, 0.9845836908536074, 0.882686929807428]
# Macro-average MCC: 0.9322
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9591
# ---------------------------------------------------------------------------------------------------
# Epoch 54/100, Loss: 0.0396
# Epoch 54/100, Loss: 0.1472
# Accuracy: 0.9293
# Precision: 0.9394
# Recall: 0.9293
# F1 Score: 0.9318
# AUC: 0.9971
# AUPR: 0.9814
# Specificity per class: [0.9353448275862069, 1.0, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9821
# MCC per class: [0.8908568427730515, 0.9265671365457867, 0.9845836908536074, 0.8602932215197799]
# Macro-average MCC: 0.9156
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9468
# ---------------------------------------------------------------------------------------------------
# Epoch 55/100, Loss: 0.0355
# Epoch 55/100, Loss: 0.1109
# Accuracy: 0.9362
# Precision: 0.9408
# Recall: 0.9362
# F1 Score: 0.9380
# AUC: 0.9979
# AUPR: 0.9882
# Specificity per class: [0.9655172413793104, 0.9899497487437185, 1.0, 0.9897260273972602]
# Macro-average Specificity: 0.9863
# MCC per class: [0.9217736534970257, 0.9524447467356325, 0.9845836908536074, 0.8393256142128035]
# Macro-average MCC: 0.9245
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9590
# ---------------------------------------------------------------------------------------------------
# Epoch 56/100, Loss: 0.0320
# Epoch 56/100, Loss: 0.1376
# Accuracy: 0.9185
# Precision: 0.9369
# Recall: 0.9185
# F1 Score: 0.9262
# AUC: 0.9973
# AUPR: 0.9855
# Specificity per class: [0.9525862068965517, 0.9849246231155779, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9816
# MCC per class: [0.8916088805902701, 0.9320062537742658, 0.9768030891848316, 0.834728011337836]
# Macro-average MCC: 0.9088
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9462
# ---------------------------------------------------------------------------------------------------
# Epoch 57/100, Loss: 0.0367
# Epoch 57/100, Loss: 0.1859
# Accuracy: 0.9306
# Precision: 0.9411
# Recall: 0.9306
# F1 Score: 0.9343
# AUC: 0.9952
# AUPR: 0.9781
# Specificity per class: [0.9482758620689655, 0.9899497487437185, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9828
# MCC per class: [0.9021394970306476, 0.9254926645253152, 0.9845836908536074, 0.8602932215197799]
# Macro-average MCC: 0.9181
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9496
# ---------------------------------------------------------------------------------------------------
# Epoch 58/100, Loss: 0.0420
# Epoch 58/100, Loss: 0.1213
# Accuracy: 0.9287
# Precision: 0.9403
# Recall: 0.9287
# F1 Score: 0.9339
# AUC: 0.9980
# AUPR: 0.9922
# Specificity per class: [0.9655172413793104, 0.9798994974874372, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9824
# MCC per class: [0.9046266778814934, 0.925150601458725, 0.9769542224975036, 0.8602932215197799]
# Macro-average MCC: 0.9168
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9492
# ---------------------------------------------------------------------------------------------------
# Epoch 59/100, Loss: 0.0349
# Epoch 59/100, Loss: 0.1352
# Accuracy: 0.9324
# Precision: 0.9211
# Recall: 0.9324
# F1 Score: 0.9262
# AUC: 0.9968
# AUPR: 0.9888
# Specificity per class: [0.9698275862068966, 0.9748743718592965, 1.0, 0.9828767123287672]
# Macro-average Specificity: 0.9819
# MCC per class: [0.9120851963967855, 0.9321393291242538, 0.9615145720873706, 0.8270585437664306]
# Macro-average MCC: 0.9082
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9468
# ---------------------------------------------------------------------------------------------------
# Epoch 60/100, Loss: 0.0362
# Epoch 60/100, Loss: 0.1616
# Accuracy: 0.9228
# Precision: 0.9163
# Recall: 0.9228
# F1 Score: 0.9190
# AUC: 0.9959
# AUPR: 0.9820
# Specificity per class: [0.9612068965517241, 0.9798994974874372, 1.0, 0.9828767123287672]
# Macro-average Specificity: 0.9810
# MCC per class: [0.9059017880597403, 0.931985936148579, 0.9615145720873706, 0.801092163523476]
# Macro-average MCC: 0.9001
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9436
# ---------------------------------------------------------------------------------------------------
# Epoch 61/100, Loss: 0.0381
# Epoch 61/100, Loss: 0.1459
# Accuracy: 0.9255
# Precision: 0.9211
# Recall: 0.9255
# F1 Score: 0.9225
# AUC: 0.9976
# AUPR: 0.9870
# Specificity per class: [0.9568965517241379, 0.9899497487437185, 0.9911111111111112, 0.9863013698630136]
# Macro-average Specificity: 0.9811
# MCC per class: [0.9073772042004405, 0.918797603624423, 0.9691330891330892, 0.819634703196347]
# Macro-average MCC: 0.9037
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9432
# ---------------------------------------------------------------------------------------------------
# Epoch 62/100, Loss: 0.0478
# Epoch 62/100, Loss: 0.1330
# Accuracy: 0.9324
# Precision: 0.9641
# Recall: 0.9324
# F1 Score: 0.9461
# AUC: 0.9971
# AUPR: 0.9877
# Specificity per class: [0.9612068965517241, 0.9748743718592965, 1.0, 1.0]
# Macro-average Specificity: 0.9840
# MCC per class: [0.8972759311048011, 0.939054302314074, 0.9845836908536074, 0.9066819023627151]
# Macro-average MCC: 0.9319
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9557
# ---------------------------------------------------------------------------------------------------
# Epoch 63/100, Loss: 0.0352
# Epoch 63/100, Loss: 0.1101
# Accuracy: 0.9415
# Precision: 0.9463
# Recall: 0.9415
# F1 Score: 0.9436
# AUC: 0.9982
# AUPR: 0.9915
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9848
# MCC per class: [0.9206073369943373, 0.9387976740971787, 0.9691330891330892, 0.8853080854491499]
# Macro-average MCC: 0.9285
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9557
# ---------------------------------------------------------------------------------------------------
# Epoch 64/100, Loss: 0.0297
# Epoch 64/100, Loss: 0.1354
# Accuracy: 0.9362
# Precision: 0.9568
# Recall: 0.9362
# F1 Score: 0.9451
# AUC: 0.9972
# AUPR: 0.9855
# Specificity per class: [0.9612068965517241, 0.9849246231155779, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9857
# MCC per class: [0.9145246423032853, 0.945607302219665, 0.9845836908536074, 0.882686929807428]
# Macro-average MCC: 0.9319
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9589
# ---------------------------------------------------------------------------------------------------
# Epoch 65/100, Loss: 0.0359
# Epoch 65/100, Loss: 0.1308
# Accuracy: 0.9258
# Precision: 0.9187
# Recall: 0.9258
# F1 Score: 0.9216
# AUC: 0.9974
# AUPR: 0.9872
# Specificity per class: [0.9612068965517241, 0.9849246231155779, 1.0, 0.9828767123287672]
# Macro-average Specificity: 0.9823
# MCC per class: [0.9145246423032853, 0.9387976740971787, 0.9615145720873706, 0.801092163523476]
# Macro-average MCC: 0.9040
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9468
# ---------------------------------------------------------------------------------------------------
# Epoch 66/100, Loss: 0.0328
# Epoch 66/100, Loss: 0.1517
# Accuracy: 0.9143
# Precision: 0.9312
# Recall: 0.9143
# F1 Score: 0.9210
# AUC: 0.9971
# AUPR: 0.9836
# Specificity per class: [0.9482758620689655, 0.9899497487437185, 0.9866666666666667, 0.9931506849315068]
# Macro-average Specificity: 0.9795
# MCC per class: [0.8846101301702942, 0.9254926645253152, 0.9615706499287768, 0.834728011337836]
# Macro-average MCC: 0.9016
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9398
# ---------------------------------------------------------------------------------------------------
# Epoch 67/100, Loss: 0.0252
# Epoch 67/100, Loss: 0.1622
# Accuracy: 0.9198
# Precision: 0.9302
# Recall: 0.9198
# F1 Score: 0.9228
# AUC: 0.9967
# AUPR: 0.9820
# Specificity per class: [0.9396551724137931, 1.0, 1.0, 0.9897260273972602]
# Macro-average Specificity: 0.9823
# MCC per class: [0.8974512350049014, 0.9463715665614397, 0.96919786333672, 0.8133573344341013]
# Macro-average MCC: 0.9066
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9468
# ---------------------------------------------------------------------------------------------------
# Epoch 68/100, Loss: 0.0275
# Epoch 68/100, Loss: 0.1207
# Accuracy: 0.9362
# Precision: 0.9568
# Recall: 0.9362
# F1 Score: 0.9451
# AUC: 0.9978
# AUPR: 0.9900
# Specificity per class: [0.9612068965517241, 0.9849246231155779, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9857
# MCC per class: [0.9145246423032853, 0.945607302219665, 0.9845836908536074, 0.882686929807428]
# Macro-average MCC: 0.9319
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9589
# ---------------------------------------------------------------------------------------------------
# Epoch 69/100, Loss: 0.0283
# Epoch 69/100, Loss: 0.1297
# Accuracy: 0.9300
# Precision: 0.9208
# Recall: 0.9300
# F1 Score: 0.9244
# AUC: 0.9975
# AUPR: 0.9859
# Specificity per class: [0.9568965517241379, 0.9949748743718593, 1.0, 0.9828767123287672]
# Macro-average Specificity: 0.9837
# MCC per class: [0.9160470173873222, 0.939250105582329, 0.9768873266890564, 0.801092163523476]
# Macro-average MCC: 0.9083
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9500
# ---------------------------------------------------------------------------------------------------
# Epoch 70/100, Loss: 0.0299
# Epoch 70/100, Loss: 0.1672
# Accuracy: 0.9232
# Precision: 0.9405
# Recall: 0.9232
# F1 Score: 0.9291
# AUC: 0.9965
# AUPR: 0.9824
# Specificity per class: [0.9396551724137931, 1.0, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9832
# MCC per class: [0.8974512350049014, 0.9397532094515858, 0.9845836908536074, 0.834728011337836]
# Macro-average MCC: 0.9141
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9497
# ---------------------------------------------------------------------------------------------------
# Epoch 71/100, Loss: 0.0346
# Epoch 71/100, Loss: 0.2105
# Accuracy: 0.9260
# Precision: 0.9165
# Recall: 0.9260
# F1 Score: 0.9193
# AUC: 0.9943
# AUPR: 0.9758
# Specificity per class: [0.9439655172413793, 1.0, 1.0, 0.9828767123287672]
# Macro-average Specificity: 0.9817
# MCC per class: [0.9041320007191944, 0.9331519181523712, 0.96919786333672, 0.801092163523476]
# Macro-average MCC: 0.9019
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9440
# ---------------------------------------------------------------------------------------------------
# Epoch 72/100, Loss: 0.0356
# Epoch 72/100, Loss: 0.1468
# Accuracy: 0.9341
# Precision: 0.9108
# Recall: 0.9341
# F1 Score: 0.9207
# AUC: 0.9970
# AUPR: 0.9861
# Specificity per class: [0.9655172413793104, 0.9899497487437185, 1.0, 0.976027397260274]
# Macro-average Specificity: 0.9829
# MCC per class: [0.9217736534970257, 0.9389331631730534, 0.9615145720873706, 0.7933509180833815]
# Macro-average MCC: 0.9039
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9474
# ---------------------------------------------------------------------------------------------------
# Epoch 73/100, Loss: 0.0278
# Epoch 73/100, Loss: 0.1487
# Accuracy: 0.9353
# Precision: 0.9196
# Recall: 0.9353
# F1 Score: 0.9266
# AUC: 0.9971
# AUPR: 0.9876
# Specificity per class: [0.9655172413793104, 0.9899497487437185, 0.9911111111111112, 0.9828767123287672]
# Macro-average Specificity: 0.9824
# MCC per class: [0.9217736534970257, 0.9254926645253152, 0.9613185012354785, 0.8270585437664306]
# Macro-average MCC: 0.9089
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9467
# ---------------------------------------------------------------------------------------------------
# Epoch 74/100, Loss: 0.0280
# Epoch 74/100, Loss: 0.1256
# Accuracy: 0.9383
# Precision: 0.9688
# Recall: 0.9383
# F1 Score: 0.9513
# AUC: 0.9976
# AUPR: 0.9905
# Specificity per class: [0.9612068965517241, 0.9849246231155779, 1.0, 1.0]
# Macro-average Specificity: 0.9865
# MCC per class: [0.9145246423032853, 0.952435741621506, 0.9845836908536074, 0.9066819023627151]
# Macro-average MCC: 0.9396
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9621
# ---------------------------------------------------------------------------------------------------
# Epoch 75/100, Loss: 0.0360
# Epoch 75/100, Loss: 0.1206
# Accuracy: 0.9551
# Precision: 0.9390
# Recall: 0.9551
# F1 Score: 0.9465
# AUC: 0.9978
# AUPR: 0.9927
# Specificity per class: [0.978448275862069, 0.9849246231155779, 0.9822222222222222, 0.9897260273972602]
# Macro-average Specificity: 0.9838
# MCC per class: [0.9273382946495989, 0.9252324391444847, 0.9541128438605541, 0.9140014911483973]
# Macro-average MCC: 0.9302
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9526
# ---------------------------------------------------------------------------------------------------
# Epoch 76/100, Loss: 0.0286
# Epoch 76/100, Loss: 0.1494
# Accuracy: 0.9145
# Precision: 0.9249
# Recall: 0.9145
# F1 Score: 0.9180
# AUC: 0.9975
# AUPR: 0.9880
# Specificity per class: [0.9396551724137931, 0.9899497487437185, 1.0, 0.9897260273972602]
# Macro-average Specificity: 0.9798
# MCC per class: [0.8797493707395952, 0.9254926645253152, 0.9768873266890564, 0.8133573344341013]
# Macro-average MCC: 0.8989
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9404
# ---------------------------------------------------------------------------------------------------
# Epoch 77/100, Loss: 0.0228
# Epoch 77/100, Loss: 0.1423
# Accuracy: 0.9215
# Precision: 0.9480
# Recall: 0.9215
# F1 Score: 0.9322
# AUC: 0.9970
# AUPR: 0.9863
# Specificity per class: [0.9525862068965517, 0.9899497487437185, 0.9911111111111112, 0.9965753424657534]
# Macro-average Specificity: 0.9826
# MCC per class: [0.9003285737788081, 0.9389331631730534, 0.9691330891330892, 0.8576217172348696]
# Macro-average MCC: 0.9165
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9492
# ---------------------------------------------------------------------------------------------------
# Epoch 78/100, Loss: 0.0281
# Epoch 78/100, Loss: 0.1760
# Accuracy: 0.9139
# Precision: 0.9244
# Recall: 0.9139
# F1 Score: 0.9176
# AUC: 0.9957
# AUPR: 0.9804
# Specificity per class: [0.9439655172413793, 0.9899497487437185, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9798
# MCC per class: [0.8865171778142027, 0.9322043221572608, 0.9612965996570492, 0.8133573344341013]
# Macro-average MCC: 0.8983
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9402
# ---------------------------------------------------------------------------------------------------
# Epoch 79/100, Loss: 0.0189
# Epoch 79/100, Loss: 0.1133
# Accuracy: 0.9496
# Precision: 0.9470
# Recall: 0.9496
# F1 Score: 0.9482
# AUC: 0.9982
# AUPR: 0.9927
# Specificity per class: [0.9741379310344828, 0.9849246231155779, 0.9866666666666667, 0.9931506849315068]
# Macro-average Specificity: 0.9847
# MCC per class: [0.9196546412641213, 0.9320062537742658, 0.9694477535121453, 0.9098173515981736]
# Macro-average MCC: 0.9327
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9557
# ---------------------------------------------------------------------------------------------------
# Epoch 80/100, Loss: 0.0266
# Epoch 80/100, Loss: 0.1467
# Accuracy: 0.9612
# Precision: 0.9269
# Recall: 0.9612
# F1 Score: 0.9417
# AUC: 0.9978
# AUPR: 0.9911
# Specificity per class: [0.978448275862069, 0.9899497487437185, 0.9822222222222222, 0.9828767123287672]
# Macro-average Specificity: 0.9834
# MCC per class: [0.9273382946495989, 0.918797603624423, 0.9541128438605541, 0.9018953432650142]
# Macro-average MCC: 0.9255
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9496
# ---------------------------------------------------------------------------------------------------
# Epoch 81/100, Loss: 0.0267
# Epoch 81/100, Loss: 0.1237
# Accuracy: 0.9236
# Precision: 0.9418
# Recall: 0.9236
# F1 Score: 0.9312
# AUC: 0.9978
# AUPR: 0.9913
# Specificity per class: [0.9568965517241379, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9839
# MCC per class: [0.9073772042004405, 0.9456797751166062, 0.9768030891848316, 0.834728011337836]
# Macro-average MCC: 0.9161
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9524
# ---------------------------------------------------------------------------------------------------
# Epoch 82/100, Loss: 0.0222
# Epoch 82/100, Loss: 0.1557
# Accuracy: 0.9230
# Precision: 0.9512
# Recall: 0.9230
# F1 Score: 0.9345
# AUC: 0.9964
# AUPR: 0.9826
# Specificity per class: [0.9482758620689655, 0.9899497487437185, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9837
# MCC per class: [0.8933760872875811, 0.9524447467356325, 0.9768873266890564, 0.8576217172348696]
# Macro-average MCC: 0.9201
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9527
# ---------------------------------------------------------------------------------------------------
# Epoch 83/100, Loss: 0.0205
# Epoch 83/100, Loss: 0.1125
# Accuracy: 0.9519
# Precision: 0.9499
# Recall: 0.9519
# F1 Score: 0.9508
# AUC: 0.9982
# AUPR: 0.9935
# Specificity per class: [0.9741379310344828, 0.9849246231155779, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9858
# MCC per class: [0.9281223053474523, 0.9387976740971787, 0.9691330891330892, 0.9098173515981736]
# Macro-average MCC: 0.9365
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9589
# ---------------------------------------------------------------------------------------------------
# Epoch 84/100, Loss: 0.0175
# Epoch 84/100, Loss: 0.1163
# Accuracy: 0.9362
# Precision: 0.9566
# Recall: 0.9362
# F1 Score: 0.9451
# AUC: 0.9981
# AUPR: 0.9932
# Specificity per class: [0.9655172413793104, 0.9849246231155779, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9856
# MCC per class: [0.9217736534970257, 0.945607302219665, 0.9768030891848316, 0.882686929807428]
# Macro-average MCC: 0.9317
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9587
# ---------------------------------------------------------------------------------------------------
# Epoch 85/100, Loss: 0.0228
# Epoch 85/100, Loss: 0.1367
# Accuracy: 0.9249
# Precision: 0.9637
# Recall: 0.9249
# F1 Score: 0.9410
# AUC: 0.9973
# AUPR: 0.9881
# Specificity per class: [0.9612068965517241, 0.9798994974874372, 0.9955555555555555, 1.0]
# Macro-average Specificity: 0.9842
# MCC per class: [0.9059017880597403, 0.945711463299403, 0.9768030891848316, 0.8822351982354886]
# Macro-average MCC: 0.9277
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9554
# ---------------------------------------------------------------------------------------------------
# Epoch 86/100, Loss: 0.0164
# Epoch 86/100, Loss: 0.1121
# Accuracy: 0.9271
# Precision: 0.9656
# Recall: 0.9271
# F1 Score: 0.9431
# AUC: 0.9979
# AUPR: 0.9905
# Specificity per class: [0.9655172413793104, 0.9849246231155779, 0.9911111111111112, 1.0]
# Macro-average Specificity: 0.9854
# MCC per class: [0.9132015205357783, 0.9592835974745523, 0.9691330891330892, 0.8822351982354886]
# Macro-average MCC: 0.9310
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9584
# ---------------------------------------------------------------------------------------------------
# Epoch 87/100, Loss: 0.0183
# Epoch 87/100, Loss: 0.1119
# Accuracy: 0.9507
# Precision: 0.9736
# Recall: 0.9507
# F1 Score: 0.9611
# AUC: 0.9980
# AUPR: 0.9925
# Specificity per class: [0.978448275862069, 0.9849246231155779, 0.9911111111111112, 1.0]
# Macro-average Specificity: 0.9886
# MCC per class: [0.9357496161555404, 0.9592835974745523, 0.9769542224975036, 0.93064584827702]
# Macro-average MCC: 0.9507
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9682
# ---------------------------------------------------------------------------------------------------
# Epoch 88/100, Loss: 0.0236
# Epoch 88/100, Loss: 0.1031
# Accuracy: 0.9443
# Precision: 0.9490
# Recall: 0.9443
# F1 Score: 0.9464
# AUC: 0.9984
# AUPR: 0.9931
# Specificity per class: [0.9741379310344828, 0.9849246231155779, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9858
# MCC per class: [0.9281223053474523, 0.9387976740971787, 0.9769542224975036, 0.8853080854491499]
# Macro-average MCC: 0.9323
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9588
# ---------------------------------------------------------------------------------------------------
# Epoch 89/100, Loss: 0.0302
# Epoch 89/100, Loss: 0.1604
# Accuracy: 0.9230
# Precision: 0.9512
# Recall: 0.9230
# F1 Score: 0.9345
# AUC: 0.9968
# AUPR: 0.9829
# Specificity per class: [0.9482758620689655, 0.9899497487437185, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9837
# MCC per class: [0.8933760872875811, 0.9524447467356325, 0.9768873266890564, 0.8576217172348696]
# Macro-average MCC: 0.9201
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9527
# ---------------------------------------------------------------------------------------------------
# Epoch 90/100, Loss: 0.0312
# Epoch 90/100, Loss: 0.1659
# Accuracy: 0.9148
# Precision: 0.9277
# Recall: 0.9148
# F1 Score: 0.9200
# AUC: 0.9963
# AUPR: 0.9818
# Specificity per class: [0.9525862068965517, 0.9798994974874372, 1.0, 0.9897260273972602]
# Macro-average Specificity: 0.9806
# MCC per class: [0.9003285737788081, 0.9388393513815171, 0.9538367162324234, 0.8133573344341013]
# Macro-average MCC: 0.9016
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9431
# ---------------------------------------------------------------------------------------------------
# Epoch 91/100, Loss: 0.0313
# Epoch 91/100, Loss: 0.1501
# Accuracy: 0.9164
# Precision: 0.9261
# Recall: 0.9164
# F1 Score: 0.9204
# AUC: 0.9969
# AUPR: 0.9839
# Specificity per class: [0.9612068965517241, 0.9849246231155779, 0.9866666666666667, 0.9897260273972602]
# Macro-average Specificity: 0.9806
# MCC per class: [0.9059017880597403, 0.9252324391444847, 0.9615706499287768, 0.8133573344341013]
# Macro-average MCC: 0.9015
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9428
# ---------------------------------------------------------------------------------------------------
# Epoch 92/100, Loss: 0.0203
# Epoch 92/100, Loss: 0.1555
# Accuracy: 0.9228
# Precision: 0.9605
# Recall: 0.9228
# F1 Score: 0.9382
# AUC: 0.9967
# AUPR: 0.9841
# Specificity per class: [0.9568965517241379, 0.9849246231155779, 0.9911111111111112, 1.0]
# Macro-average Specificity: 0.9832
# MCC per class: [0.8987051882323505, 0.945607302219665, 0.9691330891330892, 0.8822351982354886]
# Macro-average MCC: 0.9239
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9523
# ---------------------------------------------------------------------------------------------------
# Epoch 93/100, Loss: 0.0269
# Epoch 93/100, Loss: 0.1195
# Accuracy: 0.9641
# Precision: 0.9502
# Recall: 0.9641
# F1 Score: 0.9567
# AUC: 0.9977
# AUPR: 0.9941
# Specificity per class: [0.9827586206896551, 0.9849246231155779, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9882
# MCC per class: [0.9518445910469595, 0.952435741621506, 0.9612965996570492, 0.9140014911483973]
# Macro-average MCC: 0.9449
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9654
# ---------------------------------------------------------------------------------------------------
# Epoch 94/100, Loss: 0.0213
# Epoch 94/100, Loss: 0.1360
# Accuracy: 0.9301
# Precision: 0.9689
# Recall: 0.9301
# F1 Score: 0.9460
# AUC: 0.9969
# AUPR: 0.9875
# Specificity per class: [0.9612068965517241, 0.9849246231155779, 1.0, 1.0]
# Macro-average Specificity: 0.9865
# MCC per class: [0.9145246423032853, 0.9592835974745523, 0.9845836908536074, 0.8822351982354886]
# Macro-average MCC: 0.9352
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9618
# ---------------------------------------------------------------------------------------------------
# Epoch 95/100, Loss: 0.0178
# Epoch 95/100, Loss: 0.1573
# Accuracy: 0.9313
# Precision: 0.9435
# Recall: 0.9313
# F1 Score: 0.9364
# AUC: 0.9964
# AUPR: 0.9863
# Specificity per class: [0.9568965517241379, 0.9849246231155779, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9837
# MCC per class: [0.9073772042004405, 0.9387976740971787, 0.9768873266890564, 0.8602932215197799]
# Macro-average MCC: 0.9208
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9527
# ---------------------------------------------------------------------------------------------------
# Epoch 96/100, Loss: 0.0296
# Epoch 96/100, Loss: 0.1202
# Accuracy: 0.9570
# Precision: 0.9629
# Recall: 0.9570
# F1 Score: 0.9596
# AUC: 0.9974
# AUPR: 0.9915
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9878
# MCC per class: [0.9291271099667554, 0.945607302219665, 0.9845836908536074, 0.9312905566854962]
# Macro-average MCC: 0.9477
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9654
# ---------------------------------------------------------------------------------------------------
# Epoch 97/100, Loss: 0.0251
# Epoch 97/100, Loss: 0.1232
# Accuracy: 0.9488
# Precision: 0.9711
# Recall: 0.9488
# F1 Score: 0.9587
# AUC: 0.9975
# AUPR: 0.9915
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 0.9955555555555555, 1.0]
# Macro-average Specificity: 0.9876
# MCC per class: [0.9291271099667554, 0.952435741621506, 0.9768030891848316, 0.93064584827702]
# Macro-average MCC: 0.9473
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9652
# ---------------------------------------------------------------------------------------------------
# Epoch 98/100, Loss: 0.0273
# Epoch 98/100, Loss: 0.1350
# Accuracy: 0.9476
# Precision: 0.9375
# Recall: 0.9476
# F1 Score: 0.9421
# AUC: 0.9973
# AUPR: 0.9875
# Specificity per class: [0.9655172413793104, 0.9899497487437185, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9841
# MCC per class: [0.9132015205357783, 0.9322043221572608, 0.9691330891330892, 0.8896044445281678]
# Macro-average MCC: 0.9260
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9528
# ---------------------------------------------------------------------------------------------------
# Epoch 99/100, Loss: 0.0122
# Epoch 99/100, Loss: 0.1279
# Accuracy: 0.9362
# Precision: 0.9565
# Recall: 0.9362
# F1 Score: 0.9448
# AUC: 0.9974
# AUPR: 0.9894
# Specificity per class: [0.9568965517241379, 0.9899497487437185, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9859
# MCC per class: [0.9073772042004405, 0.9524447467356325, 0.9845836908536074, 0.882686929807428]
# Macro-average MCC: 0.9318
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9590
# ---------------------------------------------------------------------------------------------------
# Epoch 100/100, Loss: 0.0172
# Epoch 100/100, Loss: 0.1423
# Accuracy: 0.9292
# Precision: 0.9336
# Recall: 0.9292
# F1 Score: 0.9307
# AUC: 0.9970
# AUPR: 0.9876
# Specificity per class: [0.9568965517241379, 0.9849246231155779, 1.0, 0.9897260273972602]
# Macro-average Specificity: 0.9829
# MCC per class: [0.9073772042004405, 0.9320062537742658, 0.9768873266890564, 0.8393256142128035]
# Macro-average MCC: 0.9139
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9496
# ---------------------------------------------------------------------------------------------------
# Training and validating complete

# %% [markdown]
# # densenet201 pretrained

# %%
import os
import pandas as pd
from PIL import Image
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torch.nn.functional as F
import torchvision.models as models
import numpy as np
import timm
import torch
import torch.nn.functional as F
import numpy as np
from torcheval.metrics import MulticlassAccuracy, MulticlassPrecision, MulticlassRecall, MulticlassF1Score, MulticlassAUROC, MulticlassAUPRC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import matthews_corrcoef
import random


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)  # For CPU
    torch.cuda.manual_seed(seed)  # For GPU (if used)
    torch.cuda.manual_seed_all(seed)  # For all GPUs
    torch.backends.cudnn.deterministic = True  # Ensure deterministic behavior
    torch.backends.cudnn.benchmark = False


def calculate_metrics(predicted, probabilities, labels, num_classes):
    # Initialize Torcheval metrics
    accuracy_metric = MulticlassAccuracy(num_classes=num_classes, average="macro")
    precision_metric = MulticlassPrecision(num_classes=num_classes, average="macro")
    recall_metric = MulticlassRecall(num_classes=num_classes, average="macro")
    f1_score_metric = MulticlassF1Score(num_classes=num_classes, average="macro")
    auc_metric = MulticlassAUROC(num_classes=num_classes, average="macro")
    aupr_metric = MulticlassAUPRC(num_classes=num_classes, average="macro")

    # Update metrics with predictions
    accuracy_metric.update(predicted, labels)
    precision_metric.update(predicted, labels)
    recall_metric.update(predicted, labels)
    f1_score_metric.update(predicted, labels)
    auc_metric.update(probabilities, labels)
    aupr_metric.update(probabilities, labels)

    # Compute metrics
    accuracy = accuracy_metric.compute()
    precision = precision_metric.compute()
    recall = recall_metric.compute()
    f1_score = f1_score_metric.compute()
    auc = auc_metric.compute()
    aupr = aupr_metric.compute()

    # Specificity calculation
    conf_matrix = confusion_matrix(labels.cpu().numpy(), predicted.cpu().numpy(), labels=range(num_classes))
    specificity_per_class = []

    for i in range(num_classes):
        TP = conf_matrix[i, i]
        FP = conf_matrix[:, i].sum() - TP
        FN = conf_matrix[i, :].sum() - TP
        TN = conf_matrix.sum() - (TP + FP + FN)

        specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
        specificity_per_class.append(specificity)

    macro_specificity = np.mean(specificity_per_class)

    # MCC calculation for multi-class classification
    mcc_per_class = []
    for i in range(num_classes):
        # Treat each class as the positive class and others as negative
        binary_pred = (predicted == i).int()
        binary_labels = (labels == i).int()
        mcc = matthews_corrcoef(binary_labels.cpu().numpy(), binary_pred.cpu().numpy())
        mcc_per_class.append(mcc)

    macro_mcc = np.mean(mcc_per_class)

    # Print all metrics
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1_score:.4f}")
    print(f"AUC: {auc:.4f}")
    print(f"AUPR: {aupr:.4f}")
    print(f"Specificity per class: {specificity_per_class}")
    print(f"Macro-average Specificity: {macro_specificity:.4f}")
    print(f"MCC per class: {mcc_per_class}")
    print(f"Macro-average MCC: {macro_mcc:.4f}")

    f1_score_metric_micro = MulticlassF1Score(num_classes=num_classes, average="micro")
    f1_score_metric_micro.update(predicted, labels)
    f1_score_micro = f1_score_metric_micro.compute()
    print(f"F1 Score (micro): {f1_score_micro:.4f}")

    f1_score_metric_weighted = MulticlassF1Score(num_classes=num_classes, average="weighted")
    f1_score_metric_weighted.update(predicted, labels)
    f1_score_weighted = f1_score_metric_weighted.compute()
    print(f"F1 Score (weighted): {f1_score_weighted:.4f}")


    # Return metrics as a dictionary
    return {
        "accuracy": "{:.4f}".format(accuracy.item()),
        "precision": "{:.4f}".format(precision.item()),
        "recall": "{:.4f}".format(recall.item()),
        "f1_score": "{:.4f}".format(f1_score.item()),
        "auc": "{:.4f}".format(auc.item()),
        "aupr": "{:.4f}".format(aupr.item()),
        "macro_specificity": "{:.4f}".format(macro_specificity.item()),
        "macro_mcc": "{:.4f}".format(macro_mcc.item())
    }


class ImageDataset(Dataset):
    def __init__(self, images, features, labels, transform=None):
        self.images = images
        self.features = features
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        feature = self.features[idx]
        label = self.labels[idx]
        return image, feature, label


# Image transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

set_seed(42)

dataset_path = "baldder_tissue_classification"

train_df = pd.read_csv("train_df.csv")
val_df = pd.read_csv("val_df.csv")

train_images = []
train_labels = []
for idx, row in train_df.iterrows():
    image_path = os.path.join(dataset_path, row[1], row[0])
    image = Image.open(image_path)
    image = transform(image)
    train_images.append(image)
    train_labels.append(row['encoded_label'])

loaded_images = np.load("top_images.npy")
loaded_labels = np.load("top_labels.npy")
print(len(train_images))
for i in range(len(loaded_images)):
    image = loaded_images[i]
    label = loaded_labels[i]

    # Denormalize the image
    image = (image * np.array([0.229, 0.224, 0.225])[:, None, None]) + np.array([0.485, 0.456, 0.406])[:, None, None]
    image = (image * 255).astype(np.uint8)  # Convert to integer type for PIL compatibility

    # Convert NumPy array to PIL image
    image = Image.fromarray(image.transpose(1, 2, 0))  # H x W x C format

    # Apply transformations
    image = transform(image)

    # Convert back to PyTorch tensor (if required)
    image = torch.tensor(image, dtype=torch.float32)
    train_images.append(image)
    train_labels.append(label)

print(len(train_images))

val_images = []
val_labels = []
for idx, row in val_df.iterrows():
    image_path = os.path.join(dataset_path, row[1], row[0])
    image = Image.open(image_path)
    image = transform(image)
    val_images.append(image)
    val_labels.append(row['encoded_label'])

print(len(val_images))

train_features = np.load("features_RFE.npy")[:-val_df.shape[0]]
augmented_features = np.load("features_top_images_RFE.npy")
train_features = np.concatenate((train_features, augmented_features), axis=0)
val_features = np.load("features_RFE.npy")[-val_df.shape[0]:]

print(train_features.shape)
print(val_features.shape)

# Create DataLoaders
train_dataset = ImageDataset(train_images, train_features, train_labels, transform=transform)
val_dataset = ImageDataset(val_images, val_features, val_labels, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)


# Define the CNN model
class SimpleCNN(nn.Module):
    def __init__(self, num_classes):
        super(SimpleCNN, self).__init__()
        self.block = timm.create_model('densenet201.tv_in1k', pretrained=True)
        # self.block.head = nn.Linear(self.block.num_features, 1000)

        self.fc1 = nn.Linear(1000, 512)
        self.bn1 = nn.BatchNorm1d(512)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(0.2)
        self.fc2 = nn.Linear(512, 256)
        self.bn2 = nn.BatchNorm1d(256)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(0.2)

        self.fc_ann1 = nn.Linear(512, 256)
        self.bn_ann1 = nn.BatchNorm1d(256)
        self.relu_ann1 = nn.ReLU()
        self.dropout_ann1 = nn.Dropout(0.2)
        self.fc_ann2 = nn.Linear(256, 128)
        self.bn_ann2 = nn.BatchNorm1d(128)
        self.relu_ann2 = nn.ReLU()
        self.dropout_ann2 = nn.Dropout(0.2)

        self.fc_comb = nn.Linear(384, 256)
        self.bn_comb = nn.BatchNorm1d(256)
        self.relu_comb = nn.ReLU()
        self.dropout_comb = nn.Dropout(0.2)

        self.fc3 = nn.Linear(256, 128)
        self.bn3 = nn.BatchNorm1d(128)
        self.relu3 = nn.ReLU()
        self.dropout3 = nn.Dropout(0.2)
        self.fc4 = nn.Linear(128, num_classes)

        self.relu = nn.ReLU()


    def forward(self, x, features):
        features = features.float()
        x = self.block(x)
        # print(x.shape)
        x = x.view(-1, 1000)  # Flatten
        x = self.dropout1(self.relu1(self.bn1(self.fc1(x))))
        x = self.dropout2(self.relu2(self.bn2(self.fc2(x))))

        features = self.dropout_ann1(self.relu_ann1(self.bn_ann1(self.fc_ann1(features))))
        features = self.dropout_ann2(self.relu_ann2(self.bn_ann2(self.fc_ann2(features))))

        x = torch.cat((x, features), dim=1)
        x = self.dropout_comb(self.relu_comb(self.bn_comb(self.fc_comb(x))))

        x = self.dropout3(self.relu3(self.bn3(self.fc3(x))))
        x = self.fc4(x)
        return x


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")
# Instantiate model, loss function, and optimizer
num_classes = 4
model = SimpleCNN(num_classes)
model = model.to(device)
criterion = nn.CrossEntropyLoss().to(device)

optimizer = optim.Adam(model.parameters(), lr=0.0001)

# Training loop
num_epochs = 100
all_metrics = []

best_f1 = -100
best_epoch = 0
best_metric = 0
with open('Results/densenet201_pretrained.csv', 'w') as f:
    f.write("Epoch,Train Loss,Val Loss,Accuracy,Precision,Recall,F1 Score,AUC,AUPR,Specificity,MCC\n")
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for images, features, labels in train_loader:
            images, features, labels = images.to(device), features.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images, features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * images.size(0)

        train_loss = running_loss / len(train_loader.dataset)
        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {train_loss:.4f}")

        # Validation loop
        model.eval()
        running_loss = 0.0
        with torch.no_grad():
            y_pred = []
            y_true = []
            y_proba = []
            for images, features, labels in val_loader:
                images, features, labels = images.to(device), features.to(device), labels.to(device)

                outputs = model(images, features)
                loss = criterion(outputs, labels)

                running_loss += loss.item() * images.size(0)

                # Apply softmax to get probabilities
                probabilities = F.softmax(outputs, dim=1)

                # Get the predicted class and corresponding probability
                proba, predicted = torch.max(probabilities, 1)

                # Store results
                y_pred.extend(predicted.cpu().tolist())
                y_true.extend(labels.cpu().tolist())
                y_proba.extend(probabilities.cpu().tolist())

            val_loss = running_loss / len(val_loader.dataset)
            print(f"Epoch {epoch+1}/{num_epochs}, Loss: {val_loss:.4f}")
            # Convert lists to tensors
            y_pred = torch.tensor(y_pred)
            y_true = torch.tensor(y_true)
            y_proba = torch.tensor(y_proba)

            metrics = calculate_metrics(y_pred, y_proba, y_true, num_classes)
            all_metrics.append(metrics)

            if best_f1 < float(metrics["f1_score"]):
                best_f1 = float(metrics["f1_score"])
                best_epoch = epoch+1
                best_metric = metrics
            print('---------------------------------------------------------------------------------------------------')

            f.write(f"{epoch+1},{train_loss},{val_loss},{metrics['accuracy']},{metrics['precision']},{metrics['recall']},{metrics['f1_score']},{metrics['auc']},{metrics['aupr']},{metrics['macro_specificity']},{metrics['macro_mcc']}\n")
            f.flush()
    print("Training and validating complete")
# Out:
# <ipython-input-19-1e6270576aaf>:155: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   image_path = os.path.join(dataset_path, row[1], row[0])
# 1262
# <ipython-input-19-1e6270576aaf>:179: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   image = torch.tensor(image, dtype=torch.float32)
# 1762
# <ipython-input-19-1e6270576aaf>:188: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   image_path = os.path.join(dataset_path, row[1], row[0])
# 316
# (1762, 512)
# (316, 512)
# model.safetensors:   0%|          | 0.00/81.1M [00:00<?, ?B/s]
# Epoch 1/100, Loss: 1.0940
# Epoch 1/100, Loss: 0.5481
# Accuracy: 0.7882
# Precision: 0.9360
# Recall: 0.7882
# F1 Score: 0.8051
# AUC: 0.9844
# AUPR: 0.9283
# Specificity per class: [0.9698275862068966, 0.9346733668341709, 0.9688888888888889, 1.0]
# Macro-average Specificity: 0.9683
# MCC per class: [0.8950297057731631, 0.89529475693873, 0.9485159670150733, 0.4852668039004337]
# Macro-average MCC: 0.8060
# F1 Score (micro): 0.9146
# F1 Score (weighted): 0.8990
# ---------------------------------------------------------------------------------------------------
# Epoch 2/100, Loss: 0.5833
# Epoch 2/100, Loss: 0.3756
# Accuracy: 0.9020
# Precision: 0.9507
# Recall: 0.9020
# F1 Score: 0.9199
# AUC: 0.9874
# AUPR: 0.9604
# Specificity per class: [0.9612068965517241, 0.9949748743718593, 0.9866666666666667, 0.9965753424657534]
# Macro-average Specificity: 0.9849
# MCC per class: [0.9317654609958362, 0.9728500343618371, 0.9536996336996337, 0.7787696499643428]
# Macro-average MCC: 0.9093
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9539
# ---------------------------------------------------------------------------------------------------
# Epoch 3/100, Loss: 0.3762
# Epoch 3/100, Loss: 0.2358
# Accuracy: 0.9367
# Precision: 0.9664
# Recall: 0.9367
# F1 Score: 0.9495
# AUC: 0.9986
# AUPR: 0.9883
# Specificity per class: [0.9741379310344828, 0.9899497487437185, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9902
# MCC per class: [0.9450526993977326, 0.9865657291029639, 0.9768873266890564, 0.8576217172348696]
# Macro-average MCC: 0.9415
# F1 Score (micro): 0.9715
# F1 Score (weighted): 0.9709
# ---------------------------------------------------------------------------------------------------
# Epoch 4/100, Loss: 0.3051
# Epoch 4/100, Loss: 0.2197
# Accuracy: 0.9492
# Precision: 0.9689
# Recall: 0.9492
# F1 Score: 0.9576
# AUC: 0.9972
# AUPR: 0.9828
# Specificity per class: [0.9698275862068966, 1.0, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9916
# MCC per class: [0.9461635504451551, 0.9797388920125402, 0.9922876771341849, 0.882686929807428]
# Macro-average MCC: 0.9502
# F1 Score (micro): 0.9747
# F1 Score (weighted): 0.9745
# ---------------------------------------------------------------------------------------------------
# Epoch 5/100, Loss: 0.1936
# Epoch 5/100, Loss: 0.1511
# Accuracy: 0.9458
# Precision: 0.9585
# Recall: 0.9458
# F1 Score: 0.9514
# AUC: 0.9986
# AUPR: 0.9889
# Specificity per class: [0.9741379310344828, 0.9949748743718593, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9906
# MCC per class: [0.9535173843715963, 0.979628522101484, 0.9768873266890564, 0.8602932215197799]
# Macro-average MCC: 0.9426
# F1 Score (micro): 0.9715
# F1 Score (weighted): 0.9713
# ---------------------------------------------------------------------------------------------------
# Epoch 6/100, Loss: 0.1363
# Epoch 6/100, Loss: 0.1602
# Accuracy: 0.9261
# Precision: 0.9642
# Recall: 0.9261
# F1 Score: 0.9421
# AUC: 0.9983
# AUPR: 0.9884
# Specificity per class: [0.978448275862069, 0.9798994974874372, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9887
# MCC per class: [0.9441594142981191, 0.9733992632366592, 0.9845836908536074, 0.8319853203258969]
# Macro-average MCC: 0.9335
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9673
# ---------------------------------------------------------------------------------------------------
# Epoch 7/100, Loss: 0.2524
# Epoch 7/100, Loss: 0.1319
# Accuracy: 0.9594
# Precision: 0.9646
# Recall: 0.9594
# F1 Score: 0.9618
# AUC: 0.9965
# AUPR: 0.9880
# Specificity per class: [0.9870689655172413, 0.9949748743718593, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9927
# MCC per class: [0.9679395659383785, 0.9728500343618371, 0.9923377950662305, 0.8853080854491499]
# Macro-average MCC: 0.9546
# F1 Score (micro): 0.9778
# F1 Score (weighted): 0.9777
# ---------------------------------------------------------------------------------------------------
# Epoch 8/100, Loss: 0.1794
# Epoch 8/100, Loss: 0.1346
# Accuracy: 0.9449
# Precision: 0.9837
# Recall: 0.9449
# F1 Score: 0.9611
# AUC: 0.9957
# AUPR: 0.9885
# Specificity per class: [0.978448275862069, 0.9949748743718593, 1.0, 1.0]
# Macro-average Specificity: 0.9934
# MCC per class: [0.9525686552200252, 0.9932486516029513, 1.0, 0.8822351982354886]
# Macro-average MCC: 0.9570
# F1 Score (micro): 0.9810
# F1 Score (weighted): 0.9803
# ---------------------------------------------------------------------------------------------------
# Epoch 9/100, Loss: 0.2877
# Epoch 9/100, Loss: 0.1596
# Accuracy: 0.9649
# Precision: 0.9700
# Recall: 0.9649
# F1 Score: 0.9672
# AUC: 0.9887
# AUPR: 0.9827
# Specificity per class: [0.978448275862069, 0.9949748743718593, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9914
# MCC per class: [0.9525686552200252, 0.9660918193740864, 0.9845665445665446, 0.9312905566854962]
# Macro-average MCC: 0.9586
# F1 Score (micro): 0.9747
# F1 Score (weighted): 0.9747
# ---------------------------------------------------------------------------------------------------
# Epoch 10/100, Loss: 0.1454
# Epoch 10/100, Loss: 0.0953
# Accuracy: 0.9713
# Precision: 0.9783
# Recall: 0.9713
# F1 Score: 0.9746
# AUC: 0.9909
# AUPR: 0.9839
# Specificity per class: [0.9870689655172413, 0.9949748743718593, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9947
# MCC per class: [0.9679395659383785, 0.9864278658248508, 0.9922876771341849, 0.9312905566854962]
# Macro-average MCC: 0.9695
# F1 Score (micro): 0.9842
# F1 Score (weighted): 0.9841
# ---------------------------------------------------------------------------------------------------
# Epoch 11/100, Loss: 0.1022
# Epoch 11/100, Loss: 0.1094
# Accuracy: 0.9590
# Precision: 0.9808
# Recall: 0.9590
# F1 Score: 0.9684
# AUC: 0.9900
# AUPR: 0.9820
# Specificity per class: [0.9698275862068966, 1.0, 1.0, 1.0]
# Macro-average Specificity: 0.9925
# MCC per class: [0.9461635504451551, 0.9864714004329231, 0.9845836908536074, 0.93064584827702]
# Macro-average MCC: 0.9620
# F1 Score (micro): 0.9778
# F1 Score (weighted): 0.9779
# ---------------------------------------------------------------------------------------------------
# Epoch 12/100, Loss: 0.2618
# Epoch 12/100, Loss: 0.0909
# Accuracy: 0.9647
# Precision: 0.9748
# Recall: 0.9647
# F1 Score: 0.9696
# AUC: 0.9996
# AUPR: 0.9968
# Specificity per class: [0.9913793103448276, 0.9798994974874372, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9920
# MCC per class: [0.959339487282751, 0.9733992632366592, 0.9845836908536074, 0.9312905566854962]
# Macro-average MCC: 0.9622
# F1 Score (micro): 0.9778
# F1 Score (weighted): 0.9778
# ---------------------------------------------------------------------------------------------------
# Epoch 13/100, Loss: 0.1478
# Epoch 13/100, Loss: 0.0766
# Accuracy: 0.9796
# Precision: 0.9714
# Recall: 0.9796
# F1 Score: 0.9754
# AUC: 0.9991
# AUPR: 0.9948
# Specificity per class: [0.9913793103448276, 1.0, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9950
# MCC per class: [0.9758011779642528, 0.9864714004329231, 0.9845665445665446, 0.9338605850305136]
# Macro-average MCC: 0.9702
# F1 Score (micro): 0.9842
# F1 Score (weighted): 0.9843
# ---------------------------------------------------------------------------------------------------
# Epoch 14/100, Loss: 0.3672
# Epoch 14/100, Loss: 0.1401
# Accuracy: 0.9495
# Precision: 0.9663
# Recall: 0.9495
# F1 Score: 0.9568
# AUC: 0.9980
# AUPR: 0.9892
# Specificity per class: [0.978448275862069, 0.9798994974874372, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9887
# MCC per class: [0.9609782888287097, 0.9733992632366592, 0.9461635504451551, 0.9072291086054585]
# Macro-average MCC: 0.9469
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9680
# ---------------------------------------------------------------------------------------------------
# Epoch 15/100, Loss: 0.2058
# Epoch 15/100, Loss: 0.1019
# Accuracy: 0.9679
# Precision: 0.9843
# Recall: 0.9679
# F1 Score: 0.9755
# AUC: 0.9966
# AUPR: 0.9885
# Specificity per class: [0.9827586206896551, 0.9899497487437185, 1.0, 1.0]
# Macro-average Specificity: 0.9932
# MCC per class: [0.960196523248786, 0.9865657291029639, 0.9768873266890564, 0.9541649956911371]
# Macro-average MCC: 0.9695
# F1 Score (micro): 0.9810
# F1 Score (weighted): 0.9810
# ---------------------------------------------------------------------------------------------------
# Epoch 16/100, Loss: 0.2488
# Epoch 16/100, Loss: 0.1432
# Accuracy: 0.9190
# Precision: 0.9520
# Recall: 0.9190
# F1 Score: 0.9320
# AUC: 0.9974
# AUPR: 0.9825
# Specificity per class: [0.9655172413793104, 0.9949748743718593, 0.9822222222222222, 0.9965753424657534]
# Macro-average Specificity: 0.9848
# MCC per class: [0.9303440963742202, 0.9526338872016222, 0.9620442890220036, 0.8319853203258969]
# Macro-average MCC: 0.9193
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9549
# ---------------------------------------------------------------------------------------------------
# Epoch 17/100, Loss: 0.2937
# Epoch 17/100, Loss: 0.1348
# Accuracy: 0.9435
# Precision: 0.9561
# Recall: 0.9435
# F1 Score: 0.9491
# AUC: 0.9945
# AUPR: 0.9751
# Specificity per class: [0.9741379310344828, 0.9899497487437185, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9893
# MCC per class: [0.9450526993977326, 0.9660321318614951, 0.9845836908536074, 0.8602932215197799]
# Macro-average MCC: 0.9390
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9682
# ---------------------------------------------------------------------------------------------------
# Epoch 18/100, Loss: 0.2571
# Epoch 18/100, Loss: 0.1590
# Accuracy: 0.8742
# Precision: 0.9267
# Recall: 0.8742
# F1 Score: 0.8928
# AUC: 0.9944
# AUPR: 0.9588
# Specificity per class: [0.9525862068965517, 0.9849246231155779, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9804
# MCC per class: [0.8828857341614156, 0.9661514769585127, 0.9691330891330892, 0.6965682895736597]
# Macro-average MCC: 0.8787
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9402
# ---------------------------------------------------------------------------------------------------
# Epoch 19/100, Loss: 0.1840
# Epoch 19/100, Loss: 0.1559
# Accuracy: 0.9312
# Precision: 0.9262
# Recall: 0.9312
# F1 Score: 0.9284
# AUC: 0.9941
# AUPR: 0.9699
# Specificity per class: [0.9741379310344828, 0.9849246231155779, 1.0, 0.9828767123287672]
# Macro-average Specificity: 0.9855
# MCC per class: [0.9196546412641213, 0.9661514769585127, 0.96919786333672, 0.801092163523476]
# Macro-average MCC: 0.9140
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9561
# ---------------------------------------------------------------------------------------------------
# Epoch 20/100, Loss: 0.1578
# Epoch 20/100, Loss: 0.1172
# Accuracy: 0.9343
# Precision: 0.9467
# Recall: 0.9343
# F1 Score: 0.9400
# AUC: 0.9963
# AUPR: 0.9788
# Specificity per class: [0.9741379310344828, 0.9949748743718593, 1.0, 0.9897260273972602]
# Macro-average Specificity: 0.9897
# MCC per class: [0.9365879961071812, 0.9864278658248508, 0.9845836908536074, 0.8133573344341013]
# Macro-average MCC: 0.9302
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9681
# ---------------------------------------------------------------------------------------------------
# Epoch 21/100, Loss: 0.1521
# Epoch 21/100, Loss: 0.1390
# Accuracy: 0.9182
# Precision: 0.9560
# Recall: 0.9182
# F1 Score: 0.9339
# AUC: 0.9944
# AUPR: 0.9786
# Specificity per class: [0.9655172413793104, 0.9798994974874372, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9855
# MCC per class: [0.9132015205357783, 0.966446166424597, 0.9768873266890564, 0.8319853203258969]
# Macro-average MCC: 0.9221
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9581
# ---------------------------------------------------------------------------------------------------
# Epoch 22/100, Loss: 0.1622
# Epoch 22/100, Loss: 0.1163
# Accuracy: 0.9441
# Precision: 0.9637
# Recall: 0.9441
# F1 Score: 0.9526
# AUC: 0.9974
# AUPR: 0.9833
# Specificity per class: [0.9698275862068966, 0.9949748743718593, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9892
# MCC per class: [0.937645518934311, 0.9660918193740864, 0.9845665445665446, 0.882686929807428]
# Macro-average MCC: 0.9427
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9682
# ---------------------------------------------------------------------------------------------------
# Epoch 23/100, Loss: 0.1519
# Epoch 23/100, Loss: 0.1285
# Accuracy: 0.9313
# Precision: 0.9423
# Recall: 0.9313
# F1 Score: 0.9358
# AUC: 0.9969
# AUPR: 0.9850
# Specificity per class: [0.9568965517241379, 0.9949748743718593, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9840
# MCC per class: [0.9073772042004405, 0.9526338872016222, 0.9613185012354785, 0.8602932215197799]
# Macro-average MCC: 0.9204
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9527
# ---------------------------------------------------------------------------------------------------
# Epoch 24/100, Loss: 0.1340
# Epoch 24/100, Loss: 0.1347
# Accuracy: 0.9294
# Precision: 0.9332
# Recall: 0.9294
# F1 Score: 0.9304
# AUC: 0.9954
# AUPR: 0.9826
# Specificity per class: [0.9568965517241379, 0.9899497487437185, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9830
# MCC per class: [0.9160470173873222, 0.9389331631730534, 0.9612965996570492, 0.8393256142128035]
# Macro-average MCC: 0.9139
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9496
# ---------------------------------------------------------------------------------------------------
# Epoch 25/100, Loss: 0.1098
# Epoch 25/100, Loss: 0.1129
# Accuracy: 0.9435
# Precision: 0.9632
# Recall: 0.9435
# F1 Score: 0.9520
# AUC: 0.9976
# AUPR: 0.9879
# Specificity per class: [0.9698275862068966, 1.0, 0.9911111111111112, 0.9965753424657534]
# Macro-average Specificity: 0.9894
# MCC per class: [0.937645518934311, 0.9797388920125402, 0.9691330891330892, 0.882686929807428]
# Macro-average MCC: 0.9423
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9682
# ---------------------------------------------------------------------------------------------------
# Epoch 26/100, Loss: 0.0932
# Epoch 26/100, Loss: 0.0962
# Accuracy: 0.9390
# Precision: 0.9612
# Recall: 0.9390
# F1 Score: 0.9489
# AUC: 0.9981
# AUPR: 0.9899
# Specificity per class: [0.9698275862068966, 0.9899497487437185, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9880
# MCC per class: [0.9206073369943373, 0.979700064280732, 0.9690466897894506, 0.882686929807428]
# Macro-average MCC: 0.9380
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9650
# ---------------------------------------------------------------------------------------------------
# Epoch 27/100, Loss: 0.0787
# Epoch 27/100, Loss: 0.0910
# Accuracy: 0.9458
# Precision: 0.9585
# Recall: 0.9458
# F1 Score: 0.9514
# AUC: 0.9983
# AUPR: 0.9887
# Specificity per class: [0.9741379310344828, 0.9949748743718593, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9906
# MCC per class: [0.9535173843715963, 0.979628522101484, 0.9768873266890564, 0.8602932215197799]
# Macro-average MCC: 0.9426
# F1 Score (micro): 0.9715
# F1 Score (weighted): 0.9713
# ---------------------------------------------------------------------------------------------------
# Epoch 28/100, Loss: 0.0830
# Epoch 28/100, Loss: 0.0952
# Accuracy: 0.9454
# Precision: 0.9661
# Recall: 0.9454
# F1 Score: 0.9547
# AUC: 0.9980
# AUPR: 0.9893
# Specificity per class: [0.978448275862069, 0.9949748743718593, 0.9911111111111112, 0.9965753424657534]
# Macro-average Specificity: 0.9903
# MCC per class: [0.9441594142981191, 0.979628522101484, 0.9769542224975036, 0.882686929807428]
# Macro-average MCC: 0.9459
# F1 Score (micro): 0.9715
# F1 Score (weighted): 0.9712
# ---------------------------------------------------------------------------------------------------
# Epoch 29/100, Loss: 0.0679
# Epoch 29/100, Loss: 0.1102
# Accuracy: 0.9413
# Precision: 0.9611
# Recall: 0.9413
# F1 Score: 0.9498
# AUC: 0.9974
# AUPR: 0.9883
# Specificity per class: [0.9655172413793104, 0.9949748743718593, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9882
# MCC per class: [0.9303440963742202, 0.9660918193740864, 0.9768030891848316, 0.882686929807428]
# Macro-average MCC: 0.9390
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9651
# ---------------------------------------------------------------------------------------------------
# Epoch 30/100, Loss: 0.0726
# Epoch 30/100, Loss: 0.0977
# Accuracy: 0.9370
# Precision: 0.9562
# Recall: 0.9370
# F1 Score: 0.9449
# AUC: 0.9977
# AUPR: 0.9888
# Specificity per class: [0.9568965517241379, 0.9949748743718593, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9860
# MCC per class: [0.9160470173873222, 0.9526338872016222, 0.9768030891848316, 0.882686929807428]
# Macro-average MCC: 0.9320
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9590
# ---------------------------------------------------------------------------------------------------
# Epoch 31/100, Loss: 0.0545
# Epoch 31/100, Loss: 0.0795
# Accuracy: 0.9424
# Precision: 0.9645
# Recall: 0.9424
# F1 Score: 0.9524
# AUC: 0.9990
# AUPR: 0.9936
# Specificity per class: [0.978448275862069, 0.9849246231155779, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9889
# MCC per class: [0.9357496161555404, 0.9661514769585127, 0.9845665445665446, 0.882686929807428]
# Macro-average MCC: 0.9423
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9680
# ---------------------------------------------------------------------------------------------------
# Epoch 32/100, Loss: 0.0572
# Epoch 32/100, Loss: 0.0838
# Accuracy: 0.9413
# Precision: 0.9523
# Recall: 0.9413
# F1 Score: 0.9461
# AUC: 0.9990
# AUPR: 0.9931
# Specificity per class: [0.9698275862068966, 1.0, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9885
# MCC per class: [0.937645518934311, 0.9730268178012867, 0.9691330891330892, 0.8602932215197799]
# Macro-average MCC: 0.9350
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9651
# ---------------------------------------------------------------------------------------------------
# Epoch 33/100, Loss: 0.1026
# Epoch 33/100, Loss: 0.0922
# Accuracy: 0.9471
# Precision: 0.9714
# Recall: 0.9471
# F1 Score: 0.9581
# AUC: 0.9991
# AUPR: 0.9967
# Specificity per class: [0.9741379310344828, 0.9798994974874372, 0.9955555555555555, 1.0]
# Macro-average Specificity: 0.9874
# MCC per class: [0.9196546412641213, 0.9595142500456046, 0.9768030891848316, 0.93064584827702]
# Macro-average MCC: 0.9467
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9651
# ---------------------------------------------------------------------------------------------------
# Epoch 34/100, Loss: 0.0710
# Epoch 34/100, Loss: 0.0848
# Accuracy: 0.9484
# Precision: 0.9665
# Recall: 0.9484
# F1 Score: 0.9568
# AUC: 0.9991
# AUPR: 0.9945
# Specificity per class: [0.9870689655172413, 0.9748743718592965, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9885
# MCC per class: [0.9347680119556898, 0.9669128730967155, 0.9768030891848316, 0.9072291086054585]
# Macro-average MCC: 0.9464
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9681
# ---------------------------------------------------------------------------------------------------
# Epoch 35/100, Loss: 0.0531
# Epoch 35/100, Loss: 0.0864
# Accuracy: 0.9447
# Precision: 0.9609
# Recall: 0.9447
# F1 Score: 0.9523
# AUC: 0.9990
# AUPR: 0.9963
# Specificity per class: [0.9870689655172413, 0.9748743718592965, 0.9866666666666667, 0.9965753424657534]
# Macro-average Specificity: 0.9863
# MCC per class: [0.9347680119556898, 0.9459885105169251, 0.9694477535121453, 0.9072291086054585]
# Macro-average MCC: 0.9394
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9618
# ---------------------------------------------------------------------------------------------------
# Epoch 36/100, Loss: 0.0710
# Epoch 36/100, Loss: 0.0763
# Accuracy: 0.9605
# Precision: 0.9757
# Recall: 0.9605
# F1 Score: 0.9676
# AUC: 0.9987
# AUPR: 0.9937
# Specificity per class: [0.9741379310344828, 0.9899497487437185, 0.9955555555555555, 1.0]
# Macro-average Specificity: 0.9899
# MCC per class: [0.9281223053474523, 0.9728557316497015, 0.9768030891848316, 0.9541649956911371]
# Macro-average MCC: 0.9580
# F1 Score (micro): 0.9715
# F1 Score (weighted): 0.9716
# ---------------------------------------------------------------------------------------------------
# Epoch 37/100, Loss: 0.0552
# Epoch 37/100, Loss: 0.0812
# Accuracy: 0.9694
# Precision: 0.9678
# Recall: 0.9694
# F1 Score: 0.9684
# AUC: 0.9975
# AUPR: 0.9897
# Specificity per class: [0.9827586206896551, 1.0, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9940
# MCC per class: [0.9685493143328691, 0.9864714004329231, 0.9845836908536074, 0.9098173515981736]
# Macro-average MCC: 0.9624
# F1 Score (micro): 0.9810
# F1 Score (weighted): 0.9811
# ---------------------------------------------------------------------------------------------------
# Epoch 38/100, Loss: 0.0456
# Epoch 38/100, Loss: 0.1118
# Accuracy: 0.9271
# Precision: 0.9670
# Recall: 0.9271
# F1 Score: 0.9438
# AUC: 0.9979
# AUPR: 0.9918
# Specificity per class: [0.9655172413793104, 0.9748743718592965, 1.0, 1.0]
# Macro-average Specificity: 0.9851
# MCC per class: [0.9132015205357783, 0.9459885105169251, 0.9845836908536074, 0.8822351982354886]
# Macro-average MCC: 0.9315
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9585
# ---------------------------------------------------------------------------------------------------
# Epoch 39/100, Loss: 0.1395
# Epoch 39/100, Loss: 0.1894
# Accuracy: 0.9212
# Precision: 0.9230
# Recall: 0.9212
# F1 Score: 0.9209
# AUC: 0.9932
# AUPR: 0.9701
# Specificity per class: [0.9482758620689655, 0.9849246231155779, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9785
# MCC per class: [0.8933760872875811, 0.8983012253384226, 0.9691330891330892, 0.8393256142128035]
# Macro-average MCC: 0.9000
# F1 Score (micro): 0.9367
# F1 Score (weighted): 0.9368
# ---------------------------------------------------------------------------------------------------
# Epoch 40/100, Loss: 0.1024
# Epoch 40/100, Loss: 0.1745
# Accuracy: 0.9232
# Precision: 0.9076
# Recall: 0.9232
# F1 Score: 0.9141
# AUC: 0.9943
# AUPR: 0.9762
# Specificity per class: [0.9482758620689655, 0.9798994974874372, 0.9955555555555555, 0.9828767123287672]
# Macro-average Specificity: 0.9767
# MCC per class: [0.8846101301702942, 0.8912236406874062, 0.9612965996570492, 0.8270585437664306]
# Macro-average MCC: 0.8910
# F1 Score (micro): 0.9304
# F1 Score (weighted): 0.9311
# ---------------------------------------------------------------------------------------------------
# Epoch 41/100, Loss: 0.1074
# Epoch 41/100, Loss: 0.2138
# Accuracy: 0.9215
# Precision: 0.9110
# Recall: 0.9215
# F1 Score: 0.9145
# AUC: 0.9903
# AUPR: 0.9652
# Specificity per class: [0.9439655172413793, 0.9949748743718593, 0.9955555555555555, 0.9828767123287672]
# Macro-average Specificity: 0.9793
# MCC per class: [0.895325390526334, 0.9126866390039042, 0.9690466897894506, 0.801092163523476]
# Macro-average MCC: 0.8945
# F1 Score (micro): 0.9367
# F1 Score (weighted): 0.9374
# ---------------------------------------------------------------------------------------------------
# Epoch 42/100, Loss: 0.0673
# Epoch 42/100, Loss: 0.1622
# Accuracy: 0.9389
# Precision: 0.9284
# Recall: 0.9389
# F1 Score: 0.9324
# AUC: 0.9958
# AUPR: 0.9792
# Specificity per class: [0.9525862068965517, 0.9949748743718593, 1.0, 0.9863013698630136]
# Macro-average Specificity: 0.9835
# MCC per class: [0.9090458721223321, 0.9259358814138647, 0.9845836908536074, 0.8453483040258218]
# Macro-average MCC: 0.9162
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9499
# ---------------------------------------------------------------------------------------------------
# Epoch 43/100, Loss: 0.0728
# Epoch 43/100, Loss: 0.1545
# Accuracy: 0.9372
# Precision: 0.9283
# Recall: 0.9372
# F1 Score: 0.9323
# AUC: 0.9935
# AUPR: 0.9783
# Specificity per class: [0.9612068965517241, 0.9849246231155779, 1.0, 0.9863013698630136]
# Macro-average Specificity: 0.9831
# MCC per class: [0.9059017880597403, 0.9252324391444847, 0.9845836908536074, 0.8453483040258218]
# Macro-average MCC: 0.9153
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9498
# ---------------------------------------------------------------------------------------------------
# Epoch 44/100, Loss: 0.0539
# Epoch 44/100, Loss: 0.1565
# Accuracy: 0.9464
# Precision: 0.9236
# Recall: 0.9464
# F1 Score: 0.9336
# AUC: 0.9963
# AUPR: 0.9842
# Specificity per class: [0.9698275862068966, 0.9949748743718593, 0.9866666666666667, 0.9828767123287672]
# Macro-average Specificity: 0.9836
# MCC per class: [0.9291271099667554, 0.9259358814138647, 0.9615706499287768, 0.852488157148583]
# Macro-average MCC: 0.9173
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9498
# ---------------------------------------------------------------------------------------------------
# Epoch 45/100, Loss: 0.0734
# Epoch 45/100, Loss: 0.1583
# Accuracy: 0.9410
# Precision: 0.9370
# Recall: 0.9410
# F1 Score: 0.9383
# AUC: 0.9939
# AUPR: 0.9816
# Specificity per class: [0.9612068965517241, 0.9899497487437185, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9841
# MCC per class: [0.923145527810611, 0.9254926645253152, 0.9768030891848316, 0.8647260273972602]
# Macro-average MCC: 0.9225
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9527
# ---------------------------------------------------------------------------------------------------
# Epoch 46/100, Loss: 0.0457
# Epoch 46/100, Loss: 0.1824
# Accuracy: 0.9389
# Precision: 0.9349
# Recall: 0.9389
# F1 Score: 0.9356
# AUC: 0.9930
# AUPR: 0.9797
# Specificity per class: [0.9482758620689655, 0.9949748743718593, 1.0, 0.9897260273972602]
# Macro-average Specificity: 0.9832
# MCC per class: [0.9021394970306476, 0.9259358814138647, 0.9845836908536074, 0.8647260273972602]
# Macro-average MCC: 0.9193
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9499
# ---------------------------------------------------------------------------------------------------
# Epoch 47/100, Loss: 0.0615
# Epoch 47/100, Loss: 0.1308
# Accuracy: 0.9381
# Precision: 0.9340
# Recall: 0.9381
# F1 Score: 0.9354
# AUC: 0.9969
# AUPR: 0.9866
# Specificity per class: [0.9612068965517241, 0.9899497487437185, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9830
# MCC per class: [0.9145246423032853, 0.9254926645253152, 0.9691330891330892, 0.8647260273972602]
# Macro-average MCC: 0.9185
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9495
# ---------------------------------------------------------------------------------------------------
# Epoch 48/100, Loss: 0.0648
# Epoch 48/100, Loss: 0.1510
# Accuracy: 0.9332
# Precision: 0.9290
# Recall: 0.9332
# F1 Score: 0.9302
# AUC: 0.9965
# AUPR: 0.9877
# Specificity per class: [0.9525862068965517, 0.9899497487437185, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9808
# MCC per class: [0.9003285737788081, 0.918797603624423, 0.9613185012354785, 0.8647260273972602]
# Macro-average MCC: 0.9113
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9434
# ---------------------------------------------------------------------------------------------------
# Epoch 49/100, Loss: 0.0647
# Epoch 49/100, Loss: 0.1596
# Accuracy: 0.9549
# Precision: 0.9439
# Recall: 0.9549
# F1 Score: 0.9482
# AUC: 0.9962
# AUPR: 0.9865
# Specificity per class: [0.9525862068965517, 0.9849246231155779, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9827
# MCC per class: [0.9090458721223321, 0.9050106221559147, 0.9768873266890564, 0.9338605850305136]
# Macro-average MCC: 0.9312
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9497
# ---------------------------------------------------------------------------------------------------
# Epoch 50/100, Loss: 0.0597
# Epoch 50/100, Loss: 0.1785
# Accuracy: 0.9285
# Precision: 0.9469
# Recall: 0.9285
# F1 Score: 0.9351
# AUC: 0.9946
# AUPR: 0.9826
# Specificity per class: [0.9396551724137931, 0.9949748743718593, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9817
# MCC per class: [0.888601140084966, 0.9259358814138647, 0.9768030891848316, 0.882686929807428]
# Macro-average MCC: 0.9185
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9467
# ---------------------------------------------------------------------------------------------------
# Epoch 51/100, Loss: 0.0559
# Epoch 51/100, Loss: 0.1523
# Accuracy: 0.9525
# Precision: 0.9398
# Recall: 0.9525
# F1 Score: 0.9452
# AUC: 0.9963
# AUPR: 0.9884
# Specificity per class: [0.9655172413793104, 0.9899497487437185, 0.9777777777777777, 0.9931506849315068]
# Macro-average Specificity: 0.9816
# MCC per class: [0.9217736534970257, 0.9054549279550154, 0.9467568508579206, 0.9338605850305136]
# Macro-average MCC: 0.9270
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9460
# ---------------------------------------------------------------------------------------------------
# Epoch 52/100, Loss: 0.0505
# Epoch 52/100, Loss: 0.1633
# Accuracy: 0.9447
# Precision: 0.9497
# Recall: 0.9447
# F1 Score: 0.9466
# AUC: 0.9955
# AUPR: 0.9848
# Specificity per class: [0.9655172413793104, 0.9849246231155779, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9859
# MCC per class: [0.9303440963742202, 0.9387976740971787, 0.9768873266890564, 0.8853080854491499]
# Macro-average MCC: 0.9328
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9590
# ---------------------------------------------------------------------------------------------------
# Epoch 53/100, Loss: 0.0507
# Epoch 53/100, Loss: 0.1314
# Accuracy: 0.9381
# Precision: 0.9340
# Recall: 0.9381
# F1 Score: 0.9354
# AUC: 0.9975
# AUPR: 0.9886
# Specificity per class: [0.9612068965517241, 0.9899497487437185, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9830
# MCC per class: [0.9145246423032853, 0.9254926645253152, 0.9691330891330892, 0.8647260273972602]
# Macro-average MCC: 0.9185
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9495
# ---------------------------------------------------------------------------------------------------
# Epoch 54/100, Loss: 0.0392
# Epoch 54/100, Loss: 0.1254
# Accuracy: 0.9466
# Precision: 0.9599
# Recall: 0.9466
# F1 Score: 0.9525
# AUC: 0.9967
# AUPR: 0.9892
# Specificity per class: [0.9655172413793104, 0.9849246231155779, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9868
# MCC per class: [0.9217736534970257, 0.945607302219665, 0.9845836908536074, 0.9072291086054585]
# Macro-average MCC: 0.9398
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9622
# ---------------------------------------------------------------------------------------------------
# Epoch 55/100, Loss: 0.0494
# Epoch 55/100, Loss: 0.2020
# Accuracy: 0.9285
# Precision: 0.9312
# Recall: 0.9285
# F1 Score: 0.9283
# AUC: 0.9902
# AUPR: 0.9708
# Specificity per class: [0.9439655172413793, 0.9949748743718593, 1.0, 0.9897260273972602]
# Macro-average Specificity: 0.9822
# MCC per class: [0.895325390526334, 0.9259358814138647, 0.9845836908536074, 0.8393256142128035]
# Macro-average MCC: 0.9113
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9467
# ---------------------------------------------------------------------------------------------------
# Epoch 56/100, Loss: 0.0540
# Epoch 56/100, Loss: 0.1521
# Accuracy: 0.9332
# Precision: 0.9545
# Recall: 0.9332
# F1 Score: 0.9425
# AUC: 0.9945
# AUPR: 0.9802
# Specificity per class: [0.9612068965517241, 0.9798994974874372, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9844
# MCC per class: [0.9059017880597403, 0.9388393513815171, 0.9845836908536074, 0.882686929807428]
# Macro-average MCC: 0.9280
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9557
# ---------------------------------------------------------------------------------------------------
# Epoch 57/100, Loss: 0.0445
# Epoch 57/100, Loss: 0.1585
# Accuracy: 0.9404
# Precision: 0.9376
# Recall: 0.9404
# F1 Score: 0.9383
# AUC: 0.9944
# AUPR: 0.9812
# Specificity per class: [0.9612068965517241, 0.9849246231155779, 1.0, 0.9897260273972602]
# Macro-average Specificity: 0.9840
# MCC per class: [0.923145527810611, 0.9252324391444847, 0.9768873266890564, 0.8647260273972602]
# Macro-average MCC: 0.9225
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9528
# ---------------------------------------------------------------------------------------------------
# Epoch 58/100, Loss: 0.0662
# Epoch 58/100, Loss: 0.1733
# Accuracy: 0.9260
# Precision: 0.9443
# Recall: 0.9260
# F1 Score: 0.9346
# AUC: 0.9938
# AUPR: 0.9823
# Specificity per class: [0.9655172413793104, 0.949748743718593, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9780
# MCC per class: [0.8702791461412152, 0.8996063994209373, 0.9768873266890564, 0.9072291086054585]
# Macro-average MCC: 0.9135
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9400
# ---------------------------------------------------------------------------------------------------
# Epoch 59/100, Loss: 0.0378
# Epoch 59/100, Loss: 0.1692
# Accuracy: 0.9410
# Precision: 0.9310
# Recall: 0.9410
# F1 Score: 0.9352
# AUC: 0.9936
# AUPR: 0.9790
# Specificity per class: [0.9612068965517241, 0.9899497487437185, 1.0, 0.9863013698630136]
# Macro-average Specificity: 0.9844
# MCC per class: [0.923145527810611, 0.9254926645253152, 0.9845836908536074, 0.8453483040258218]
# Macro-average MCC: 0.9196
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9529
# ---------------------------------------------------------------------------------------------------
# Epoch 60/100, Loss: 0.0513
# Epoch 60/100, Loss: 0.1372
# Accuracy: 0.9415
# Precision: 0.9391
# Recall: 0.9415
# F1 Score: 0.9400
# AUC: 0.9963
# AUPR: 0.9831
# Specificity per class: [0.9655172413793104, 0.9899497487437185, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9852
# MCC per class: [0.9132015205357783, 0.9456797751166062, 0.9768030891848316, 0.8647260273972602]
# Macro-average MCC: 0.9251
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9560
# ---------------------------------------------------------------------------------------------------
# Epoch 61/100, Loss: 0.0446
# Epoch 61/100, Loss: 0.1455
# Accuracy: 0.9358
# Precision: 0.9427
# Recall: 0.9358
# F1 Score: 0.9390
# AUC: 0.9952
# AUPR: 0.9800
# Specificity per class: [0.9655172413793104, 0.9698492462311558, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9821
# MCC per class: [0.9046266778814934, 0.9185671949491045, 0.9768873266890564, 0.8853080854491499]
# Macro-average MCC: 0.9213
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9496
# ---------------------------------------------------------------------------------------------------
# Epoch 62/100, Loss: 0.0376
# Epoch 62/100, Loss: 0.1286
# Accuracy: 0.9549
# Precision: 0.9519
# Recall: 0.9549
# F1 Score: 0.9530
# AUC: 0.9967
# AUPR: 0.9878
# Specificity per class: [0.9655172413793104, 0.9949748743718593, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9873
# MCC per class: [0.9217736534970257, 0.9526338872016222, 0.9768030891848316, 0.9098173515981736]
# Macro-average MCC: 0.9403
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9623
# ---------------------------------------------------------------------------------------------------
# Epoch 63/100, Loss: 0.0510
# Epoch 63/100, Loss: 0.1233
# Accuracy: 0.9511
# Precision: 0.9576
# Recall: 0.9511
# F1 Score: 0.9542
# AUC: 0.9966
# AUPR: 0.9886
# Specificity per class: [0.9698275862068966, 0.9798994974874372, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9855
# MCC per class: [0.9120851963967855, 0.9388393513815171, 0.9768030891848316, 0.9312905566854962]
# Macro-average MCC: 0.9398
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9590
# ---------------------------------------------------------------------------------------------------
# Epoch 64/100, Loss: 0.0298
# Epoch 64/100, Loss: 0.1444
# Accuracy: 0.9536
# Precision: 0.9502
# Recall: 0.9536
# F1 Score: 0.9512
# AUC: 0.9959
# AUPR: 0.9869
# Specificity per class: [0.9612068965517241, 0.9899497487437185, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9861
# MCC per class: [0.923145527810611, 0.9322043221572608, 0.9845836908536074, 0.9098173515981736]
# Macro-average MCC: 0.9374
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9591
# ---------------------------------------------------------------------------------------------------
# Epoch 65/100, Loss: 0.0429
# Epoch 65/100, Loss: 0.1308
# Accuracy: 0.9522
# Precision: 0.9582
# Recall: 0.9522
# F1 Score: 0.9547
# AUC: 0.9965
# AUPR: 0.9878
# Specificity per class: [0.9655172413793104, 0.9798994974874372, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9855
# MCC per class: [0.9217736534970257, 0.931985936148579, 0.9768873266890564, 0.9312905566854962]
# Macro-average MCC: 0.9405
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9591
# ---------------------------------------------------------------------------------------------------
# Epoch 66/100, Loss: 0.0439
# Epoch 66/100, Loss: 0.1412
# Accuracy: 0.9441
# Precision: 0.9669
# Recall: 0.9441
# F1 Score: 0.9539
# AUC: 0.9969
# AUPR: 0.9911
# Specificity per class: [0.9612068965517241, 0.9798994974874372, 1.0, 1.0]
# Macro-average Specificity: 0.9853
# MCC per class: [0.923145527810611, 0.9388393513815171, 0.96919786333672, 0.93064584827702]
# Macro-average MCC: 0.9405
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9591
# ---------------------------------------------------------------------------------------------------
# Epoch 67/100, Loss: 0.0485
# Epoch 67/100, Loss: 0.1219
# Accuracy: 0.9655
# Precision: 0.9561
# Recall: 0.9655
# F1 Score: 0.9603
# AUC: 0.9969
# AUPR: 0.9908
# Specificity per class: [0.9698275862068966, 0.9899497487437185, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9882
# MCC per class: [0.937645518934311, 0.9456797751166062, 0.9768873266890564, 0.9338605850305136]
# Macro-average MCC: 0.9485
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9654
# ---------------------------------------------------------------------------------------------------
# Epoch 68/100, Loss: 0.0331
# Epoch 68/100, Loss: 0.1465
# Accuracy: 0.9524
# Precision: 0.9581
# Recall: 0.9524
# F1 Score: 0.9545
# AUC: 0.9959
# AUPR: 0.9874
# Specificity per class: [0.9612068965517241, 0.9849246231155779, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9857
# MCC per class: [0.923145527810611, 0.9387976740971787, 0.96919786333672, 0.9312905566854962]
# Macro-average MCC: 0.9406
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9592
# ---------------------------------------------------------------------------------------------------
# Epoch 69/100, Loss: 0.0293
# Epoch 69/100, Loss: 0.1523
# Accuracy: 0.9277
# Precision: 0.9466
# Recall: 0.9277
# F1 Score: 0.9350
# AUC: 0.9963
# AUPR: 0.9876
# Specificity per class: [0.9439655172413793, 0.9899497487437185, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9815
# MCC per class: [0.8865171778142027, 0.9254926645253152, 0.9768030891848316, 0.882686929807428]
# Macro-average MCC: 0.9179
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9466
# ---------------------------------------------------------------------------------------------------
# Epoch 70/100, Loss: 0.0309
# Epoch 70/100, Loss: 0.1571
# Accuracy: 0.9585
# Precision: 0.9488
# Recall: 0.9585
# F1 Score: 0.9529
# AUC: 0.9958
# AUPR: 0.9890
# Specificity per class: [0.9612068965517241, 0.9849246231155779, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9848
# MCC per class: [0.923145527810611, 0.9252324391444847, 0.96919786333672, 0.9338605850305136]
# Macro-average MCC: 0.9379
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9560
# ---------------------------------------------------------------------------------------------------
# Epoch 71/100, Loss: 0.0395
# Epoch 71/100, Loss: 0.1474
# Accuracy: 0.9543
# Precision: 0.9530
# Recall: 0.9543
# F1 Score: 0.9534
# AUC: 0.9955
# AUPR: 0.9862
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9870
# MCC per class: [0.9291271099667554, 0.945607302219665, 0.9768873266890564, 0.9098173515981736]
# Macro-average MCC: 0.9404
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9622
# ---------------------------------------------------------------------------------------------------
# Epoch 72/100, Loss: 0.0354
# Epoch 72/100, Loss: 0.1286
# Accuracy: 0.9621
# Precision: 0.9539
# Recall: 0.9621
# F1 Score: 0.9579
# AUC: 0.9970
# AUPR: 0.9904
# Specificity per class: [0.978448275862069, 0.9798994974874372, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9868
# MCC per class: [0.9273382946495989, 0.931985936148579, 0.9845665445665446, 0.9338605850305136]
# Macro-average MCC: 0.9444
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9621
# ---------------------------------------------------------------------------------------------------
# Epoch 73/100, Loss: 0.0288
# Epoch 73/100, Loss: 0.1368
# Accuracy: 0.9528
# Precision: 0.9569
# Recall: 0.9528
# F1 Score: 0.9544
# AUC: 0.9963
# AUPR: 0.9881
# Specificity per class: [0.9655172413793104, 0.9899497487437185, 0.9911111111111112, 0.9965753424657534]
# Macro-average Specificity: 0.9858
# MCC per class: [0.9217736534970257, 0.9389331631730534, 0.9691330891330892, 0.9312905566854962]
# Macro-average MCC: 0.9403
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9590
# ---------------------------------------------------------------------------------------------------
# Epoch 74/100, Loss: 0.0288
# Epoch 74/100, Loss: 0.1476
# Accuracy: 0.9589
# Precision: 0.9410
# Recall: 0.9589
# F1 Score: 0.9491
# AUC: 0.9969
# AUPR: 0.9893
# Specificity per class: [0.9698275862068966, 0.9949748743718593, 0.9866666666666667, 0.9897260273972602]
# Macro-average Specificity: 0.9853
# MCC per class: [0.9291271099667554, 0.9325845850929314, 0.9615706499287768, 0.9140014911483973]
# Macro-average MCC: 0.9343
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9558
# ---------------------------------------------------------------------------------------------------
# Epoch 75/100, Loss: 0.0314
# Epoch 75/100, Loss: 0.1351
# Accuracy: 0.9604
# Precision: 0.9437
# Recall: 0.9604
# F1 Score: 0.9513
# AUC: 0.9969
# AUPR: 0.9897
# Specificity per class: [0.9698275862068966, 0.9949748743718593, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9864
# MCC per class: [0.9291271099667554, 0.9459330151619536, 0.9613185012354785, 0.9140014911483973]
# Macro-average MCC: 0.9376
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9591
# ---------------------------------------------------------------------------------------------------
# Epoch 76/100, Loss: 0.0403
# Epoch 76/100, Loss: 0.1475
# Accuracy: 0.9540
# Precision: 0.9209
# Recall: 0.9540
# F1 Score: 0.9348
# AUC: 0.9967
# AUPR: 0.9877
# Specificity per class: [0.9655172413793104, 0.9949748743718593, 0.9955555555555555, 0.9794520547945206]
# Macro-average Specificity: 0.9839
# MCC per class: [0.9217736534970257, 0.9259358814138647, 0.9690466897894506, 0.8605191922093021]
# Macro-average MCC: 0.9193
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9502
# ---------------------------------------------------------------------------------------------------
# Epoch 77/100, Loss: 0.0312
# Epoch 77/100, Loss: 0.1602
# Accuracy: 0.9426
# Precision: 0.9469
# Recall: 0.9426
# F1 Score: 0.9439
# AUC: 0.9966
# AUPR: 0.9887
# Specificity per class: [0.9568965517241379, 0.9899497487437185, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9850
# MCC per class: [0.9160470173873222, 0.9389331631730534, 0.9768873266890564, 0.8853080854491499]
# Macro-average MCC: 0.9293
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9560
# ---------------------------------------------------------------------------------------------------
# Epoch 78/100, Loss: 0.0230
# Epoch 78/100, Loss: 0.1479
# Accuracy: 0.9369
# Precision: 0.9416
# Recall: 0.9369
# F1 Score: 0.9385
# AUC: 0.9967
# AUPR: 0.9893
# Specificity per class: [0.9568965517241379, 0.9849246231155779, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9826
# MCC per class: [0.9073772042004405, 0.9320062537742658, 0.9612965996570492, 0.8853080854491499]
# Macro-average MCC: 0.9215
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9497
# ---------------------------------------------------------------------------------------------------
# Epoch 79/100, Loss: 0.0266
# Epoch 79/100, Loss: 0.1446
# Accuracy: 0.9485
# Precision: 0.9375
# Recall: 0.9485
# F1 Score: 0.9422
# AUC: 0.9972
# AUPR: 0.9913
# Specificity per class: [0.9612068965517241, 0.9949748743718593, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9843
# MCC per class: [0.9145246423032853, 0.9325845850929314, 0.9691330891330892, 0.8896044445281678]
# Macro-average MCC: 0.9265
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9528
# ---------------------------------------------------------------------------------------------------
# Epoch 80/100, Loss: 0.0402
# Epoch 80/100, Loss: 0.1780
# Accuracy: 0.9546
# Precision: 0.9361
# Recall: 0.9546
# F1 Score: 0.9441
# AUC: 0.9965
# AUPR: 0.9878
# Specificity per class: [0.9568965517241379, 0.9949748743718593, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9832
# MCC per class: [0.9073772042004405, 0.9193034230536933, 0.9691330891330892, 0.9140014911483973]
# Macro-average MCC: 0.9275
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9496
# ---------------------------------------------------------------------------------------------------
# Epoch 81/100, Loss: 0.0353
# Epoch 81/100, Loss: 0.1280
# Accuracy: 0.9645
# Precision: 0.9556
# Recall: 0.9645
# F1 Score: 0.9598
# AUC: 0.9975
# AUPR: 0.9925
# Specificity per class: [0.9741379310344828, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9882
# MCC per class: [0.9281223053474523, 0.9524447467356325, 0.9768030891848316, 0.9338605850305136]
# Macro-average MCC: 0.9478
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9654
# ---------------------------------------------------------------------------------------------------
# Epoch 82/100, Loss: 0.0313
# Epoch 82/100, Loss: 0.1666
# Accuracy: 0.9610
# Precision: 0.9437
# Recall: 0.9610
# F1 Score: 0.9516
# AUC: 0.9969
# AUPR: 0.9900
# Specificity per class: [0.9698275862068966, 0.9949748743718593, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9864
# MCC per class: [0.9291271099667554, 0.939250105582329, 0.9691330891330892, 0.9140014911483973]
# Macro-average MCC: 0.9379
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9591
# ---------------------------------------------------------------------------------------------------
# Epoch 83/100, Loss: 0.0233
# Epoch 83/100, Loss: 0.1609
# Accuracy: 0.9294
# Precision: 0.9339
# Recall: 0.9294
# F1 Score: 0.9307
# AUC: 0.9957
# AUPR: 0.9859
# Specificity per class: [0.9568965517241379, 0.9849246231155779, 1.0, 0.9897260273972602]
# Macro-average Specificity: 0.9829
# MCC per class: [0.9160470173873222, 0.9320062537742658, 0.96919786333672, 0.8393256142128035]
# Macro-average MCC: 0.9141
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9496
# ---------------------------------------------------------------------------------------------------
# Epoch 84/100, Loss: 0.0317
# Epoch 84/100, Loss: 0.1506
# Accuracy: 0.9298
# Precision: 0.9403
# Recall: 0.9298
# F1 Score: 0.9337
# AUC: 0.9972
# AUPR: 0.9885
# Specificity per class: [0.9482758620689655, 0.9949748743718593, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9830
# MCC per class: [0.8933760872875811, 0.939250105582329, 0.9768030891848316, 0.8602932215197799]
# Macro-average MCC: 0.9174
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9497
# ---------------------------------------------------------------------------------------------------
# Epoch 85/100, Loss: 0.0295
# Epoch 85/100, Loss: 0.1431
# Accuracy: 0.9575
# Precision: 0.9358
# Recall: 0.9575
# F1 Score: 0.9456
# AUC: 0.9976
# AUPR: 0.9918
# Specificity per class: [0.9698275862068966, 0.9899497487437185, 0.9955555555555555, 0.9863013698630136]
# Macro-average Specificity: 0.9854
# MCC per class: [0.9206073369943373, 0.9389331631730534, 0.9690466897894506, 0.8952207487823]
# Macro-average MCC: 0.9310
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9561
# ---------------------------------------------------------------------------------------------------
# Epoch 86/100, Loss: 0.0311
# Epoch 86/100, Loss: 0.1721
# Accuracy: 0.9322
# Precision: 0.9436
# Recall: 0.9322
# F1 Score: 0.9365
# AUC: 0.9957
# AUPR: 0.9843
# Specificity per class: [0.9525862068965517, 0.9899497487437185, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9839
# MCC per class: [0.9090458721223321, 0.9389331631730534, 0.9768873266890564, 0.8602932215197799]
# Macro-average MCC: 0.9213
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9528
# ---------------------------------------------------------------------------------------------------
# Epoch 87/100, Loss: 0.0242
# Epoch 87/100, Loss: 0.1324
# Accuracy: 0.9402
# Precision: 0.9515
# Recall: 0.9402
# F1 Score: 0.9448
# AUC: 0.9970
# AUPR: 0.9904
# Specificity per class: [0.9568965517241379, 0.9899497487437185, 0.9911111111111112, 0.9965753424657534]
# Macro-average Specificity: 0.9836
# MCC per class: [0.9073772042004405, 0.9322043221572608, 0.9691330891330892, 0.9072291086054585]
# Macro-average MCC: 0.9290
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9527
# ---------------------------------------------------------------------------------------------------
# Epoch 88/100, Loss: 0.0330
# Epoch 88/100, Loss: 0.1267
# Accuracy: 0.9596
# Precision: 0.9507
# Recall: 0.9596
# F1 Score: 0.9549
# AUC: 0.9979
# AUPR: 0.9933
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9859
# MCC per class: [0.9206073369943373, 0.9387976740971787, 0.9690466897894506, 0.9338605850305136]
# Macro-average MCC: 0.9406
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9591
# ---------------------------------------------------------------------------------------------------
# Epoch 89/100, Loss: 0.0306
# Epoch 89/100, Loss: 0.1640
# Accuracy: 0.9568
# Precision: 0.9522
# Recall: 0.9568
# F1 Score: 0.9535
# AUC: 0.9968
# AUPR: 0.9874
# Specificity per class: [0.9525862068965517, 0.9949748743718593, 0.9911111111111112, 0.9965753424657534]
# Macro-average Specificity: 0.9838
# MCC per class: [0.9003285737788081, 0.9259358814138647, 0.9691330891330892, 0.9549086757990868]
# Macro-average MCC: 0.9376
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9529
# ---------------------------------------------------------------------------------------------------
# Epoch 90/100, Loss: 0.0229
# Epoch 90/100, Loss: 0.1392
# Accuracy: 0.9417
# Precision: 0.9390
# Recall: 0.9417
# F1 Score: 0.9398
# AUC: 0.9972
# AUPR: 0.9900
# Specificity per class: [0.9612068965517241, 0.9949748743718593, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9854
# MCC per class: [0.9145246423032853, 0.9526338872016222, 0.9690466897894506, 0.8647260273972602]
# Macro-average MCC: 0.9252
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9561
# ---------------------------------------------------------------------------------------------------
# Epoch 91/100, Loss: 0.0273
# Epoch 91/100, Loss: 0.1663
# Accuracy: 0.9479
# Precision: 0.9377
# Recall: 0.9479
# F1 Score: 0.9420
# AUC: 0.9961
# AUPR: 0.9835
# Specificity per class: [0.9568965517241379, 0.9949748743718593, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9843
# MCC per class: [0.9073772042004405, 0.939250105582329, 0.9690466897894506, 0.8896044445281678]
# Macro-average MCC: 0.9263
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9530
# ---------------------------------------------------------------------------------------------------
# Epoch 92/100, Loss: 0.0163
# Epoch 92/100, Loss: 0.1258
# Accuracy: 0.9596
# Precision: 0.9507
# Recall: 0.9596
# F1 Score: 0.9549
# AUC: 0.9974
# AUPR: 0.9899
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9859
# MCC per class: [0.9206073369943373, 0.9387976740971787, 0.9690466897894506, 0.9338605850305136]
# Macro-average MCC: 0.9406
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9591
# ---------------------------------------------------------------------------------------------------
# Epoch 93/100, Loss: 0.0226
# Epoch 93/100, Loss: 0.1630
# Accuracy: 0.9506
# Precision: 0.9467
# Recall: 0.9506
# F1 Score: 0.9480
# AUC: 0.9967
# AUPR: 0.9890
# Specificity per class: [0.9612068965517241, 0.9949748743718593, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9851
# MCC per class: [0.9145246423032853, 0.939250105582329, 0.9691330891330892, 0.9098173515981736]
# Macro-average MCC: 0.9332
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9560
# ---------------------------------------------------------------------------------------------------
# Epoch 94/100, Loss: 0.0256
# Epoch 94/100, Loss: 0.1181
# Accuracy: 0.9623
# Precision: 0.9603
# Recall: 0.9623
# F1 Score: 0.9612
# AUC: 0.9976
# AUPR: 0.9925
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9867
# MCC per class: [0.9206073369943373, 0.9387976740971787, 0.9768030891848316, 0.9549086757990868]
# Macro-average MCC: 0.9478
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9622
# ---------------------------------------------------------------------------------------------------
# Epoch 95/100, Loss: 0.0232
# Epoch 95/100, Loss: 0.1396
# Accuracy: 0.9583
# Precision: 0.9360
# Recall: 0.9583
# F1 Score: 0.9460
# AUC: 0.9970
# AUPR: 0.9893
# Specificity per class: [0.9698275862068966, 0.9899497487437185, 0.9955555555555555, 0.9863013698630136]
# Macro-average Specificity: 0.9854
# MCC per class: [0.9291271099667554, 0.9322043221572608, 0.9690466897894506, 0.8952207487823]
# Macro-average MCC: 0.9314
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9561
# ---------------------------------------------------------------------------------------------------
# Epoch 96/100, Loss: 0.0278
# Epoch 96/100, Loss: 0.1422
# Accuracy: 0.9575
# Precision: 0.9555
# Recall: 0.9575
# F1 Score: 0.9562
# AUC: 0.9967
# AUPR: 0.9920
# Specificity per class: [0.9655172413793104, 0.9798994974874372, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9844
# MCC per class: [0.9132015205357783, 0.925150601458725, 0.9690466897894506, 0.9549086757990868]
# Macro-average MCC: 0.9406
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9559
# ---------------------------------------------------------------------------------------------------
# Epoch 97/100, Loss: 0.0268
# Epoch 97/100, Loss: 0.1460
# Accuracy: 0.9541
# Precision: 0.9405
# Recall: 0.9541
# F1 Score: 0.9466
# AUC: 0.9966
# AUPR: 0.9905
# Specificity per class: [0.9698275862068966, 0.9748743718592965, 1.0, 0.9897260273972602]
# Macro-average Specificity: 0.9836
# MCC per class: [0.9206073369943373, 0.925242961141528, 0.9615145720873706, 0.9140014911483973]
# Macro-average MCC: 0.9303
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9529
# ---------------------------------------------------------------------------------------------------
# Epoch 98/100, Loss: 0.0259
# Epoch 98/100, Loss: 0.1500
# Accuracy: 0.9503
# Precision: 0.9379
# Recall: 0.9503
# F1 Score: 0.9436
# AUC: 0.9966
# AUPR: 0.9898
# Specificity per class: [0.9741379310344828, 0.9698492462311558, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9823
# MCC per class: [0.911184000211381, 0.9255057149918547, 0.9535520638570569, 0.9140014911483973]
# Macro-average MCC: 0.9261
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9496
# ---------------------------------------------------------------------------------------------------
# Epoch 99/100, Loss: 0.0310
# Epoch 99/100, Loss: 0.1748
# Accuracy: 0.9228
# Precision: 0.9514
# Recall: 0.9228
# F1 Score: 0.9349
# AUC: 0.9949
# AUPR: 0.9832
# Specificity per class: [0.9568965517241379, 0.9798994974874372, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9833
# MCC per class: [0.8987051882323505, 0.9388393513815171, 0.9845836908536074, 0.8576217172348696]
# Macro-average MCC: 0.9199
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9524
# ---------------------------------------------------------------------------------------------------
# Epoch 100/100, Loss: 0.0225
# Epoch 100/100, Loss: 0.1494
# Accuracy: 0.9345
# Precision: 0.9318
# Recall: 0.9345
# F1 Score: 0.9326
# AUC: 0.9965
# AUPR: 0.9897
# Specificity per class: [0.9568965517241379, 0.9849246231155779, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9818
# MCC per class: [0.8987051882323505, 0.9252324391444847, 0.9690466897894506, 0.8647260273972602]
# Macro-average MCC: 0.9144
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9466
# ---------------------------------------------------------------------------------------------------
# Training and validating complete

# %% [markdown]
# # efficientformerv2 pretrained

# %%
import os
import pandas as pd
from PIL import Image
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torch.nn.functional as F
import torchvision.models as models
import numpy as np
import timm
import torch
import torch.nn.functional as F
import numpy as np
from torcheval.metrics import MulticlassAccuracy, MulticlassPrecision, MulticlassRecall, MulticlassF1Score, MulticlassAUROC, MulticlassAUPRC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import matthews_corrcoef
import random


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)  # For CPU
    torch.cuda.manual_seed(seed)  # For GPU (if used)
    torch.cuda.manual_seed_all(seed)  # For all GPUs
    torch.backends.cudnn.deterministic = True  # Ensure deterministic behavior
    torch.backends.cudnn.benchmark = False


def calculate_metrics(predicted, probabilities, labels, num_classes):
    # Initialize Torcheval metrics
    accuracy_metric = MulticlassAccuracy(num_classes=num_classes, average="macro")
    precision_metric = MulticlassPrecision(num_classes=num_classes, average="macro")
    recall_metric = MulticlassRecall(num_classes=num_classes, average="macro")
    f1_score_metric = MulticlassF1Score(num_classes=num_classes, average="macro")
    auc_metric = MulticlassAUROC(num_classes=num_classes, average="macro")
    aupr_metric = MulticlassAUPRC(num_classes=num_classes, average="macro")

    # Update metrics with predictions
    accuracy_metric.update(predicted, labels)
    precision_metric.update(predicted, labels)
    recall_metric.update(predicted, labels)
    f1_score_metric.update(predicted, labels)
    auc_metric.update(probabilities, labels)
    aupr_metric.update(probabilities, labels)

    # Compute metrics
    accuracy = accuracy_metric.compute()
    precision = precision_metric.compute()
    recall = recall_metric.compute()
    f1_score = f1_score_metric.compute()
    auc = auc_metric.compute()
    aupr = aupr_metric.compute()

    # Specificity calculation
    conf_matrix = confusion_matrix(labels.cpu().numpy(), predicted.cpu().numpy(), labels=range(num_classes))
    specificity_per_class = []

    for i in range(num_classes):
        TP = conf_matrix[i, i]
        FP = conf_matrix[:, i].sum() - TP
        FN = conf_matrix[i, :].sum() - TP
        TN = conf_matrix.sum() - (TP + FP + FN)

        specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
        specificity_per_class.append(specificity)

    macro_specificity = np.mean(specificity_per_class)

    # MCC calculation for multi-class classification
    mcc_per_class = []
    for i in range(num_classes):
        # Treat each class as the positive class and others as negative
        binary_pred = (predicted == i).int()
        binary_labels = (labels == i).int()
        mcc = matthews_corrcoef(binary_labels.cpu().numpy(), binary_pred.cpu().numpy())
        mcc_per_class.append(mcc)

    macro_mcc = np.mean(mcc_per_class)

    # Print all metrics
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1_score:.4f}")
    print(f"AUC: {auc:.4f}")
    print(f"AUPR: {aupr:.4f}")
    print(f"Specificity per class: {specificity_per_class}")
    print(f"Macro-average Specificity: {macro_specificity:.4f}")
    print(f"MCC per class: {mcc_per_class}")
    print(f"Macro-average MCC: {macro_mcc:.4f}")

    f1_score_metric_micro = MulticlassF1Score(num_classes=num_classes, average="micro")
    f1_score_metric_micro.update(predicted, labels)
    f1_score_micro = f1_score_metric_micro.compute()
    print(f"F1 Score (micro): {f1_score_micro:.4f}")

    f1_score_metric_weighted = MulticlassF1Score(num_classes=num_classes, average="weighted")
    f1_score_metric_weighted.update(predicted, labels)
    f1_score_weighted = f1_score_metric_weighted.compute()
    print(f"F1 Score (weighted): {f1_score_weighted:.4f}")


    # Return metrics as a dictionary
    return {
        "accuracy": "{:.4f}".format(accuracy.item()),
        "precision": "{:.4f}".format(precision.item()),
        "recall": "{:.4f}".format(recall.item()),
        "f1_score": "{:.4f}".format(f1_score.item()),
        "auc": "{:.4f}".format(auc.item()),
        "aupr": "{:.4f}".format(aupr.item()),
        "macro_specificity": "{:.4f}".format(macro_specificity.item()),
        "macro_mcc": "{:.4f}".format(macro_mcc.item())
    }


class ImageDataset(Dataset):
    def __init__(self, images, features, labels, transform=None):
        self.images = images
        self.features = features
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        feature = self.features[idx]
        label = self.labels[idx]
        return image, feature, label


# Image transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

set_seed(42)

dataset_path = "baldder_tissue_classification"

train_df = pd.read_csv("train_df.csv")
val_df = pd.read_csv("val_df.csv")

train_images = []
train_labels = []
for idx, row in train_df.iterrows():
    image_path = os.path.join(dataset_path, row[1], row[0])
    image = Image.open(image_path)
    image = transform(image)
    train_images.append(image)
    train_labels.append(row['encoded_label'])

loaded_images = np.load("top_images.npy")
loaded_labels = np.load("top_labels.npy")
print(len(train_images))
for i in range(len(loaded_images)):
    image = loaded_images[i]
    label = loaded_labels[i]

    # Denormalize the image
    image = (image * np.array([0.229, 0.224, 0.225])[:, None, None]) + np.array([0.485, 0.456, 0.406])[:, None, None]
    image = (image * 255).astype(np.uint8)  # Convert to integer type for PIL compatibility

    # Convert NumPy array to PIL image
    image = Image.fromarray(image.transpose(1, 2, 0))  # H x W x C format

    # Apply transformations
    image = transform(image)

    # Convert back to PyTorch tensor (if required)
    image = torch.tensor(image, dtype=torch.float32)
    train_images.append(image)
    train_labels.append(label)

print(len(train_images))

val_images = []
val_labels = []
for idx, row in val_df.iterrows():
    image_path = os.path.join(dataset_path, row[1], row[0])
    image = Image.open(image_path)
    image = transform(image)
    val_images.append(image)
    val_labels.append(row['encoded_label'])

print(len(val_images))

train_features = np.load("features_RFE.npy")[:-val_df.shape[0]]
augmented_features = np.load("features_top_images_RFE.npy")
train_features = np.concatenate((train_features, augmented_features), axis=0)
val_features = np.load("features_RFE.npy")[-val_df.shape[0]:]

print(train_features.shape)
print(val_features.shape)

# Create DataLoaders
train_dataset = ImageDataset(train_images, train_features, train_labels, transform=transform)
val_dataset = ImageDataset(val_images, val_features, val_labels, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)


# Define the CNN model
class SimpleCNN(nn.Module):
    def __init__(self, num_classes):
        super(SimpleCNN, self).__init__()
        self.block = timm.create_model('efficientformerv2_l.snap_dist_in1k', pretrained=True)
        # self.block.head = nn.Linear(self.block.num_features, 1000)

        self.fc1 = nn.Linear(1000, 512)
        self.bn1 = nn.BatchNorm1d(512)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(0.2)
        self.fc2 = nn.Linear(512, 256)
        self.bn2 = nn.BatchNorm1d(256)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(0.2)

        self.fc_ann1 = nn.Linear(512, 256)
        self.bn_ann1 = nn.BatchNorm1d(256)
        self.relu_ann1 = nn.ReLU()
        self.dropout_ann1 = nn.Dropout(0.2)
        self.fc_ann2 = nn.Linear(256, 128)
        self.bn_ann2 = nn.BatchNorm1d(128)
        self.relu_ann2 = nn.ReLU()
        self.dropout_ann2 = nn.Dropout(0.2)

        self.fc_comb = nn.Linear(384, 256)
        self.bn_comb = nn.BatchNorm1d(256)
        self.relu_comb = nn.ReLU()
        self.dropout_comb = nn.Dropout(0.2)

        self.fc3 = nn.Linear(256, 128)
        self.bn3 = nn.BatchNorm1d(128)
        self.relu3 = nn.ReLU()
        self.dropout3 = nn.Dropout(0.2)
        self.fc4 = nn.Linear(128, num_classes)

        self.relu = nn.ReLU()


    def forward(self, x, features):
        features = features.float()
        x = self.block(x)
        # print(x.shape)
        x = x.view(-1, 1000)  # Flatten
        x = self.dropout1(self.relu1(self.bn1(self.fc1(x))))
        x = self.dropout2(self.relu2(self.bn2(self.fc2(x))))

        features = self.dropout_ann1(self.relu_ann1(self.bn_ann1(self.fc_ann1(features))))
        features = self.dropout_ann2(self.relu_ann2(self.bn_ann2(self.fc_ann2(features))))

        x = torch.cat((x, features), dim=1)
        x = self.dropout_comb(self.relu_comb(self.bn_comb(self.fc_comb(x))))

        x = self.dropout3(self.relu3(self.bn3(self.fc3(x))))
        x = self.fc4(x)
        return x


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")
# Instantiate model, loss function, and optimizer
num_classes = 4
model = SimpleCNN(num_classes)
model = model.to(device)
criterion = nn.CrossEntropyLoss().to(device)

optimizer = optim.Adam(model.parameters(), lr=0.0001)

# Training loop
num_epochs = 100
all_metrics = []

best_f1 = -100
best_epoch = 0
best_metric = 0
with open('Results/efficientformerv2_pretrained.csv', 'w') as f:
    f.write("Epoch,Train Loss,Val Loss,Accuracy,Precision,Recall,F1 Score,AUC,AUPR,Specificity,MCC\n")
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for images, features, labels in train_loader:
            images, features, labels = images.to(device), features.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images, features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * images.size(0)

        train_loss = running_loss / len(train_loader.dataset)
        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {train_loss:.4f}")

        # Validation loop
        model.eval()
        running_loss = 0.0
        with torch.no_grad():
            y_pred = []
            y_true = []
            y_proba = []
            for images, features, labels in val_loader:
                images, features, labels = images.to(device), features.to(device), labels.to(device)

                outputs = model(images, features)
                loss = criterion(outputs, labels)

                running_loss += loss.item() * images.size(0)

                # Apply softmax to get probabilities
                probabilities = F.softmax(outputs, dim=1)

                # Get the predicted class and corresponding probability
                proba, predicted = torch.max(probabilities, 1)

                # Store results
                y_pred.extend(predicted.cpu().tolist())
                y_true.extend(labels.cpu().tolist())
                y_proba.extend(probabilities.cpu().tolist())

            val_loss = running_loss / len(val_loader.dataset)
            print(f"Epoch {epoch+1}/{num_epochs}, Loss: {val_loss:.4f}")
            # Convert lists to tensors
            y_pred = torch.tensor(y_pred)
            y_true = torch.tensor(y_true)
            y_proba = torch.tensor(y_proba)

            metrics = calculate_metrics(y_pred, y_proba, y_true, num_classes)
            all_metrics.append(metrics)

            if best_f1 < float(metrics["f1_score"]):
                best_f1 = float(metrics["f1_score"])
                best_epoch = epoch+1
                best_metric = metrics
            print('---------------------------------------------------------------------------------------------------')

            f.write(f"{epoch+1},{train_loss},{val_loss},{metrics['accuracy']},{metrics['precision']},{metrics['recall']},{metrics['f1_score']},{metrics['auc']},{metrics['aupr']},{metrics['macro_specificity']},{metrics['macro_mcc']}\n")
            f.flush()
    print("Training and validating complete")
# Out:
# <ipython-input-21-0c9ff24b5fb9>:155: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   image_path = os.path.join(dataset_path, row[1], row[0])
# 1262
# <ipython-input-21-0c9ff24b5fb9>:179: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   image = torch.tensor(image, dtype=torch.float32)
# 1762
# <ipython-input-21-0c9ff24b5fb9>:188: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   image_path = os.path.join(dataset_path, row[1], row[0])
# 316
# (1762, 512)
# (316, 512)
# pytorch_model.bin:   0%|          | 0.00/107M [00:00<?, ?B/s]
# Epoch 1/100, Loss: 1.2642
# Epoch 1/100, Loss: 0.7910
# Accuracy: 0.7279
# Precision: 0.8139
# Recall: 0.7279
# F1 Score: 0.7327
# AUC: 0.9559
# AUPR: 0.8151
# Specificity per class: [0.9267241379310345, 0.964824120603015, 0.8977777777777778, 0.9931506849315068]
# Macro-average Specificity: 0.9456
# MCC per class: [0.7698712156569839, 0.8294036537526095, 0.8465501600550782, 0.36266812785466307]
# Macro-average MCC: 0.7021
# F1 Score (micro): 0.8449
# F1 Score (weighted): 0.8302
# ---------------------------------------------------------------------------------------------------
# Epoch 2/100, Loss: 0.8451
# Epoch 2/100, Loss: 0.5205
# Accuracy: 0.7144
# Precision: 0.7763
# Recall: 0.7144
# F1 Score: 0.6954
# AUC: 0.9566
# AUPR: 0.8491
# Specificity per class: [0.9181034482758621, 0.949748743718593, 0.9511111111111111, 0.9965753424657534]
# Macro-average Specificity: 0.9539
# MCC per class: [0.7836875934443235, 0.8713113657029775, 0.9211624748169529, 0.12774912247126896]
# Macro-average MCC: 0.6760
# F1 Score (micro): 0.8703
# F1 Score (weighted): 0.8417
# ---------------------------------------------------------------------------------------------------
# Epoch 3/100, Loss: 0.6524
# Epoch 3/100, Loss: 0.3947
# Accuracy: 0.7386
# Precision: 0.9049
# Recall: 0.7386
# F1 Score: 0.7335
# AUC: 0.9804
# AUPR: 0.9375
# Specificity per class: [0.9181034482758621, 0.9798994974874372, 0.9288888888888889, 1.0]
# Macro-average Specificity: 0.9567
# MCC per class: [0.8200171507264095, 0.8844838973007015, 0.8888136001344761, 0.34148706934575346]
# Macro-average MCC: 0.7337
# F1 Score (micro): 0.8766
# F1 Score (weighted): 0.8546
# ---------------------------------------------------------------------------------------------------
# Epoch 4/100, Loss: 0.5565
# Epoch 4/100, Loss: 6.1783
# Accuracy: 0.8309
# Precision: 0.9015
# Recall: 0.8309
# F1 Score: 0.8522
# AUC: 0.9786
# AUPR: 0.9381
# Specificity per class: [0.9568965517241379, 0.9597989949748744, 0.9377777777777778, 0.9965753424657534]
# Macro-average Specificity: 0.9628
# MCC per class: [0.8465668224585093, 0.856728819001641, 0.9015213479118177, 0.6929583753336175]
# Macro-average MCC: 0.8244
# F1 Score (micro): 0.8956
# F1 Score (weighted): 0.8916
# ---------------------------------------------------------------------------------------------------
# Epoch 5/100, Loss: 0.4882
# Epoch 5/100, Loss: 0.2892
# Accuracy: 0.8919
# Precision: 0.9312
# Recall: 0.8919
# F1 Score: 0.9061
# AUC: 0.9884
# AUPR: 0.9706
# Specificity per class: [0.9525862068965517, 0.9899497487437185, 0.9644444444444444, 0.9965753424657534]
# Macro-average Specificity: 0.9759
# MCC per class: [0.8916088805902701, 0.9121185533761437, 0.9334070323655743, 0.8057225485326348]
# Macro-average MCC: 0.8857
# F1 Score (micro): 0.9304
# F1 Score (weighted): 0.9293
# ---------------------------------------------------------------------------------------------------
# Epoch 6/100, Loss: 0.4497
# Epoch 6/100, Loss: 5.6525
# Accuracy: 0.9187
# Precision: 0.9307
# Recall: 0.9187
# F1 Score: 0.9240
# AUC: 0.9793
# AUPR: 0.9036
# Specificity per class: [0.978448275862069, 0.9748743718592965, 0.9644444444444444, 0.9931506849315068]
# Macro-average Specificity: 0.9777
# MCC per class: [0.9189244663382594, 0.9046592110895852, 0.9252730589900069, 0.8602932215197799]
# Macro-average MCC: 0.9023
# F1 Score (micro): 0.9367
# F1 Score (weighted): 0.9364
# ---------------------------------------------------------------------------------------------------
# Epoch 7/100, Loss: 0.4000
# Epoch 7/100, Loss: 1.3885
# Accuracy: 0.9216
# Precision: 0.9159
# Recall: 0.9216
# F1 Score: 0.9177
# AUC: 0.9869
# AUPR: 0.9266
# Specificity per class: [0.9698275862068966, 0.9899497487437185, 0.9688888888888889, 0.9863013698630136]
# Macro-average Specificity: 0.9787
# MCC per class: [0.9206073369943373, 0.8988061414620218, 0.9485159670150733, 0.819634703196347]
# Macro-average MCC: 0.8969
# F1 Score (micro): 0.9367
# F1 Score (weighted): 0.9363
# ---------------------------------------------------------------------------------------------------
# Epoch 8/100, Loss: 0.3628
# Epoch 8/100, Loss: 4.0904
# Accuracy: 0.9203
# Precision: 0.9137
# Recall: 0.9203
# F1 Score: 0.9154
# AUC: 0.9848
# AUPR: 0.9122
# Specificity per class: [0.9698275862068966, 0.9949748743718593, 0.96, 0.9863013698630136]
# Macro-average Specificity: 0.9778
# MCC per class: [0.9291271099667554, 0.8929246233267382, 0.9346657156438337, 0.819634703196347]
# Macro-average MCC: 0.8941
# F1 Score (micro): 0.9335
# F1 Score (weighted): 0.9330
# ---------------------------------------------------------------------------------------------------
# Epoch 9/100, Loss: 0.3137
# Epoch 9/100, Loss: 17.3452
# Accuracy: 0.9404
# Precision: 0.9280
# Recall: 0.9404
# F1 Score: 0.9332
# AUC: 0.9859
# AUPR: 0.9102
# Specificity per class: [0.9698275862068966, 0.9899497487437185, 0.9866666666666667, 0.9863013698630136]
# Macro-average Specificity: 0.9832
# MCC per class: [0.9461635504451551, 0.9054549279550154, 0.9694477535121453, 0.8453483040258218]
# Macro-average MCC: 0.9166
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9491
# ---------------------------------------------------------------------------------------------------
# Epoch 10/100, Loss: 0.3095
# Epoch 10/100, Loss: 2.4766
# Accuracy: 0.9485
# Precision: 0.9330
# Recall: 0.9485
# F1 Score: 0.9403
# AUC: 0.9849
# AUPR: 0.9093
# Specificity per class: [0.9870689655172413, 0.9798994974874372, 0.9822222222222222, 0.9863013698630136]
# Macro-average Specificity: 0.9839
# MCC per class: [0.9596468835260349, 0.911531715115916, 0.9541128438605541, 0.870530017457414]
# Macro-average MCC: 0.9240
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9526
# ---------------------------------------------------------------------------------------------------
# Epoch 11/100, Loss: 0.2879
# Epoch 11/100, Loss: 0.9180
# Accuracy: 0.9334
# Precision: 0.9281
# Recall: 0.9334
# F1 Score: 0.9306
# AUC: 0.9880
# AUPR: 0.9218
# Specificity per class: [0.9913793103448276, 0.964824120603015, 0.9822222222222222, 0.9863013698630136]
# Macro-average Specificity: 0.9812
# MCC per class: [0.9428785766150074, 0.9049950607739552, 0.9541128438605541, 0.8453483040258218]
# Macro-average MCC: 0.9118
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9463
# ---------------------------------------------------------------------------------------------------
# Epoch 12/100, Loss: 0.2925
# Epoch 12/100, Loss: 1.3768
# Accuracy: 0.9528
# Precision: 0.9384
# Recall: 0.9528
# F1 Score: 0.9452
# AUC: 0.9881
# AUPR: 0.9325
# Specificity per class: [0.9870689655172413, 0.9798994974874372, 0.9911111111111112, 0.9863013698630136]
# Macro-average Specificity: 0.9861
# MCC per class: [0.9596468835260349, 0.925150601458725, 0.9691330891330892, 0.870530017457414]
# Macro-average MCC: 0.9311
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9591
# ---------------------------------------------------------------------------------------------------
# Epoch 13/100, Loss: 0.2408
# Epoch 13/100, Loss: 3.9513
# Accuracy: 0.9475
# Precision: 0.9338
# Recall: 0.9475
# F1 Score: 0.9402
# AUC: 0.9842
# AUPR: 0.9042
# Specificity per class: [0.9870689655172413, 0.9849246231155779, 0.9955555555555555, 0.9828767123287672]
# Macro-average Specificity: 0.9876
# MCC per class: [0.9679395659383785, 0.9387976740971787, 0.9768030891848316, 0.8270585437664306]
# Macro-average MCC: 0.9276
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9624
# ---------------------------------------------------------------------------------------------------
# Epoch 14/100, Loss: 0.2195
# Epoch 14/100, Loss: 0.5354
# Accuracy: 0.9468
# Precision: 0.9488
# Recall: 0.9468
# F1 Score: 0.9471
# AUC: 0.9900
# AUPR: 0.9474
# Specificity per class: [0.978448275862069, 0.9949748743718593, 0.9777777777777777, 0.9931506849315068]
# Macro-average Specificity: 0.9861
# MCC per class: [0.9609782888287097, 0.9325845850929314, 0.9547410841058538, 0.8853080854491499]
# Macro-average MCC: 0.9334
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9586
# ---------------------------------------------------------------------------------------------------
# Epoch 15/100, Loss: 0.2444
# Epoch 15/100, Loss: 0.4230
# Accuracy: 0.9587
# Precision: 0.9621
# Recall: 0.9587
# F1 Score: 0.9598
# AUC: 0.9918
# AUPR: 0.9691
# Specificity per class: [0.9741379310344828, 0.9949748743718593, 0.9866666666666667, 0.9965753424657534]
# Macro-average Specificity: 0.9881
# MCC per class: [0.9535173843715963, 0.9459330151619536, 0.9615706499287768, 0.9312905566854962]
# Macro-average MCC: 0.9481
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9651
# ---------------------------------------------------------------------------------------------------
# Epoch 16/100, Loss: 0.1905
# Epoch 16/100, Loss: 6.8423
# Accuracy: 0.9500
# Precision: 0.9254
# Recall: 0.9500
# F1 Score: 0.9364
# AUC: 0.9850
# AUPR: 0.9102
# Specificity per class: [0.9870689655172413, 0.9849246231155779, 0.9911111111111112, 0.9794520547945206]
# Macro-average Specificity: 0.9856
# MCC per class: [0.9596468835260349, 0.9320062537742658, 0.9613185012354785, 0.8353862785988658]
# Macro-average MCC: 0.9221
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9564
# ---------------------------------------------------------------------------------------------------
# Epoch 17/100, Loss: 0.1869
# Epoch 17/100, Loss: 3.4632
# Accuracy: 0.9438
# Precision: 0.9303
# Recall: 0.9438
# F1 Score: 0.9366
# AUC: 0.9825
# AUPR: 0.9024
# Specificity per class: [0.9870689655172413, 0.9798994974874372, 0.9777777777777777, 0.9863013698630136]
# Macro-average Specificity: 0.9828
# MCC per class: [0.9347680119556898, 0.925150601458725, 0.9467568508579206, 0.870530017457414]
# Macro-average MCC: 0.9193
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9495
# ---------------------------------------------------------------------------------------------------
# Epoch 18/100, Loss: 0.1747
# Epoch 18/100, Loss: 8.4029
# Accuracy: 0.9483
# Precision: 0.9328
# Recall: 0.9483
# F1 Score: 0.9399
# AUC: 0.9840
# AUPR: 0.9119
# Specificity per class: [0.978448275862069, 0.9949748743718593, 0.9955555555555555, 0.9828767123287672]
# Macro-average Specificity: 0.9880
# MCC per class: [0.9609782888287097, 0.9459330151619536, 0.9768030891848316, 0.8270585437664306]
# Macro-average MCC: 0.9277
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9624
# ---------------------------------------------------------------------------------------------------
# Epoch 19/100, Loss: 0.1534
# Epoch 19/100, Loss: 0.1017
# Accuracy: 0.9745
# Precision: 0.9672
# Recall: 0.9745
# F1 Score: 0.9706
# AUC: 0.9984
# AUPR: 0.9925
# Specificity per class: [1.0, 0.9949748743718593, 0.9822222222222222, 0.9931506849315068]
# Macro-average Specificity: 0.9926
# MCC per class: [0.9837921365039303, 0.9728500343618371, 0.9620442890220036, 0.9338605850305136]
# Macro-average MCC: 0.9631
# F1 Score (micro): 0.9778
# F1 Score (weighted): 0.9780
# ---------------------------------------------------------------------------------------------------
# Epoch 20/100, Loss: 0.1459
# Epoch 20/100, Loss: 13.6748
# Accuracy: 0.9379
# Precision: 0.9232
# Recall: 0.9379
# F1 Score: 0.9299
# AUC: 0.9856
# AUPR: 0.9093
# Specificity per class: [0.978448275862069, 0.9949748743718593, 0.9955555555555555, 0.9794520547945206]
# Macro-average Specificity: 0.9871
# MCC per class: [0.9609782888287097, 0.9459330151619536, 0.9768030891848316, 0.7835870700754473]
# Macro-average MCC: 0.9168
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9594
# ---------------------------------------------------------------------------------------------------
# Epoch 21/100, Loss: 0.1383
# Epoch 21/100, Loss: 1.0261
# Accuracy: 0.9530
# Precision: 0.9277
# Recall: 0.9530
# F1 Score: 0.9388
# AUC: 0.9901
# AUPR: 0.9376
# Specificity per class: [0.9827586206896551, 0.9899497487437185, 0.9955555555555555, 0.9794520547945206]
# Macro-average Specificity: 0.9869
# MCC per class: [0.960196523248786, 0.9389331631730534, 0.9690466897894506, 0.8353862785988658]
# Macro-average MCC: 0.9259
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9596
# ---------------------------------------------------------------------------------------------------
# Epoch 22/100, Loss: 0.1157
# Epoch 22/100, Loss: 0.0927
# Accuracy: 0.9657
# Precision: 0.9564
# Recall: 0.9657
# F1 Score: 0.9608
# AUC: 0.9990
# AUPR: 0.9948
# Specificity per class: [0.9870689655172413, 0.9949748743718593, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9918
# MCC per class: [0.9762336321994528, 0.9593532964589464, 0.9845665445665446, 0.8896044445281678]
# Macro-average MCC: 0.9524
# F1 Score (micro): 0.9747
# F1 Score (weighted): 0.9748
# ---------------------------------------------------------------------------------------------------
# Epoch 23/100, Loss: 0.1189
# Epoch 23/100, Loss: 0.4093
# Accuracy: 0.9542
# Precision: 0.9321
# Recall: 0.9542
# F1 Score: 0.9420
# AUC: 0.9927
# AUPR: 0.9436
# Specificity per class: [0.9870689655172413, 0.9949748743718593, 0.9822222222222222, 0.9828767123287672]
# Macro-average Specificity: 0.9868
# MCC per class: [0.9679395659383785, 0.9325845850929314, 0.9620442890220036, 0.852488157148583]
# Macro-average MCC: 0.9288
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9592
# ---------------------------------------------------------------------------------------------------
# Epoch 24/100, Loss: 0.1032
# Epoch 24/100, Loss: 0.9214
# Accuracy: 0.9560
# Precision: 0.9300
# Recall: 0.9560
# F1 Score: 0.9414
# AUC: 0.9923
# AUPR: 0.9488
# Specificity per class: [0.9827586206896551, 0.9949748743718593, 0.9955555555555555, 0.9794520547945206]
# Macro-average Specificity: 0.9882
# MCC per class: [0.9685493143328691, 0.9459330151619536, 0.9690466897894506, 0.8353862785988658]
# Macro-average MCC: 0.9297
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9627
# ---------------------------------------------------------------------------------------------------
# Epoch 25/100, Loss: 0.0980
# Epoch 25/100, Loss: 0.1398
# Accuracy: 0.9413
# Precision: 0.9307
# Recall: 0.9413
# F1 Score: 0.9350
# AUC: 0.9986
# AUPR: 0.9911
# Specificity per class: [0.9612068965517241, 0.9949748743718593, 0.9955555555555555, 0.9863013698630136]
# Macro-average Specificity: 0.9845
# MCC per class: [0.9317654609958362, 0.9325845850929314, 0.9690466897894506, 0.8453483040258218]
# Macro-average MCC: 0.9197
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9529
# ---------------------------------------------------------------------------------------------------
# Epoch 26/100, Loss: 0.1132
# Epoch 26/100, Loss: 0.1710
# Accuracy: 0.9355
# Precision: 0.9172
# Recall: 0.9355
# F1 Score: 0.9244
# AUC: 0.9968
# AUPR: 0.9815
# Specificity per class: [0.9568965517241379, 1.0, 0.9866666666666667, 0.9828767123287672]
# Macro-average Specificity: 0.9816
# MCC per class: [0.9247156569570832, 0.913444881403735, 0.9615706499287768, 0.8270585437664306]
# Macro-average MCC: 0.9067
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9433
# ---------------------------------------------------------------------------------------------------
# Epoch 27/100, Loss: 0.1037
# Epoch 27/100, Loss: 0.1354
# Accuracy: 0.9323
# Precision: 0.9492
# Recall: 0.9323
# F1 Score: 0.9391
# AUC: 0.9968
# AUPR: 0.9840
# Specificity per class: [0.9612068965517241, 1.0, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9875
# MCC per class: [0.9317654609958362, 0.9596617081666465, 0.9845665445665446, 0.834728011337836]
# Macro-average MCC: 0.9277
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9618
# ---------------------------------------------------------------------------------------------------
# Epoch 28/100, Loss: 0.1206
# Epoch 28/100, Loss: 0.1089
# Accuracy: 0.9413
# Precision: 0.9538
# Recall: 0.9413
# F1 Score: 0.9470
# AUC: 0.9986
# AUPR: 0.9903
# Specificity per class: [0.978448275862069, 0.9849246231155779, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9880
# MCC per class: [0.9525686552200252, 0.952435741621506, 0.9768030891848316, 0.8602932215197799]
# Macro-average MCC: 0.9355
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9649
# ---------------------------------------------------------------------------------------------------
# Epoch 29/100, Loss: 0.0952
# Epoch 29/100, Loss: 0.1423
# Accuracy: 0.9385
# Precision: 0.9402
# Recall: 0.9385
# F1 Score: 0.9385
# AUC: 0.9975
# AUPR: 0.9847
# Specificity per class: [0.9655172413793104, 1.0, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9866
# MCC per class: [0.9389138514207814, 0.9463715665614397, 0.9769542224975036, 0.8393256142128035]
# Macro-average MCC: 0.9254
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9588
# ---------------------------------------------------------------------------------------------------
# Epoch 30/100, Loss: 0.0934
# Epoch 30/100, Loss: 0.1229
# Accuracy: 0.9646
# Precision: 0.9408
# Recall: 0.9646
# F1 Score: 0.9514
# AUC: 0.9976
# AUPR: 0.9885
# Specificity per class: [0.9827586206896551, 1.0, 0.9822222222222222, 0.9863013698630136]
# Macro-average Specificity: 0.9878
# MCC per class: [0.960196523248786, 0.9397532094515858, 0.9620442890220036, 0.8952207487823]
# Macro-average MCC: 0.9393
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9622
# ---------------------------------------------------------------------------------------------------
# Epoch 31/100, Loss: 0.0862
# Epoch 31/100, Loss: 0.1236
# Accuracy: 0.9609
# Precision: 0.9506
# Recall: 0.9609
# F1 Score: 0.9551
# AUC: 0.9973
# AUPR: 0.9874
# Specificity per class: [0.9741379310344828, 1.0, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9899
# MCC per class: [0.9535173843715963, 0.9596617081666465, 0.9768030891848316, 0.8896044445281678]
# Macro-average MCC: 0.9449
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9686
# ---------------------------------------------------------------------------------------------------
# Epoch 32/100, Loss: 0.0829
# Epoch 32/100, Loss: 0.1007
# Accuracy: 0.9509
# Precision: 0.9574
# Recall: 0.9509
# F1 Score: 0.9540
# AUC: 0.9984
# AUPR: 0.9934
# Specificity per class: [0.9827586206896551, 0.9849246231155779, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9891
# MCC per class: [0.9518445910469595, 0.9592835974745523, 0.9768030891848316, 0.8853080854491499]
# Macro-average MCC: 0.9433
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9683
# ---------------------------------------------------------------------------------------------------
# Epoch 33/100, Loss: 0.0893
# Epoch 33/100, Loss: 0.1096
# Accuracy: 0.9555
# Precision: 0.9400
# Recall: 0.9555
# F1 Score: 0.9473
# AUC: 0.9981
# AUPR: 0.9882
# Specificity per class: [0.9827586206896551, 0.9899497487437185, 0.9911111111111112, 0.9863013698630136]
# Macro-average Specificity: 0.9875
# MCC per class: [0.9518445910469595, 0.9389331631730534, 0.9769542224975036, 0.870530017457414]
# Macro-average MCC: 0.9346
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9622
# ---------------------------------------------------------------------------------------------------
# Epoch 34/100, Loss: 0.0766
# Epoch 34/100, Loss: 0.1677
# Accuracy: 0.9453
# Precision: 0.9216
# Recall: 0.9453
# F1 Score: 0.9312
# AUC: 0.9969
# AUPR: 0.9859
# Specificity per class: [0.9568965517241379, 1.0, 0.9911111111111112, 0.9828767123287672]
# Macro-average Specificity: 0.9827
# MCC per class: [0.9247156569570832, 0.9199983092652494, 0.9613185012354785, 0.852488157148583]
# Macro-average MCC: 0.9146
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9467
# ---------------------------------------------------------------------------------------------------
# Epoch 35/100, Loss: 0.0691
# Epoch 35/100, Loss: 0.1155
# Accuracy: 0.9483
# Precision: 0.9442
# Recall: 0.9483
# F1 Score: 0.9455
# AUC: 0.9975
# AUPR: 0.9890
# Specificity per class: [0.9655172413793104, 1.0, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9877
# MCC per class: [0.9389138514207814, 0.9530075466393428, 0.9768030891848316, 0.8647260273972602]
# Macro-average MCC: 0.9334
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9622
# ---------------------------------------------------------------------------------------------------
# Epoch 36/100, Loss: 0.0713
# Epoch 36/100, Loss: 0.1163
# Accuracy: 0.9689
# Precision: 0.9460
# Recall: 0.9689
# F1 Score: 0.9564
# AUC: 0.9971
# AUPR: 0.9859
# Specificity per class: [0.9827586206896551, 1.0, 0.9911111111111112, 0.9863013698630136]
# Macro-average Specificity: 0.9900
# MCC per class: [0.960196523248786, 0.9530075466393428, 0.9769542224975036, 0.8952207487823]
# Macro-average MCC: 0.9463
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9686
# ---------------------------------------------------------------------------------------------------
# Epoch 37/100, Loss: 0.0703
# Epoch 37/100, Loss: 0.1548
# Accuracy: 0.9208
# Precision: 0.9286
# Recall: 0.9208
# F1 Score: 0.9231
# AUC: 0.9971
# AUPR: 0.9862
# Specificity per class: [0.9525862068965517, 1.0, 0.9866666666666667, 0.9897260273972602]
# Macro-average Specificity: 0.9822
# MCC per class: [0.9090458721223321, 0.9331519181523712, 0.9694477535121453, 0.8133573344341013]
# Macro-average MCC: 0.9063
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9461
# ---------------------------------------------------------------------------------------------------
# Epoch 38/100, Loss: 0.0659
# Epoch 38/100, Loss: 0.1288
# Accuracy: 0.9697
# Precision: 0.9462
# Recall: 0.9697
# F1 Score: 0.9567
# AUC: 0.9978
# AUPR: 0.9879
# Specificity per class: [0.978448275862069, 1.0, 0.9955555555555555, 0.9863013698630136]
# Macro-average Specificity: 0.9901
# MCC per class: [0.9609782888287097, 0.9463715665614397, 0.9845665445665446, 0.8952207487823]
# Macro-average MCC: 0.9468
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9686
# ---------------------------------------------------------------------------------------------------
# Epoch 39/100, Loss: 0.0653
# Epoch 39/100, Loss: 0.1249
# Accuracy: 0.9521
# Precision: 0.9340
# Recall: 0.9521
# F1 Score: 0.9419
# AUC: 0.9974
# AUPR: 0.9869
# Specificity per class: [0.9698275862068966, 1.0, 0.9866666666666667, 0.9863013698630136]
# Macro-average Specificity: 0.9857
# MCC per class: [0.937645518934311, 0.9331519181523712, 0.9694477535121453, 0.870530017457414]
# Macro-average MCC: 0.9277
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9559
# ---------------------------------------------------------------------------------------------------
# Epoch 40/100, Loss: 0.0586
# Epoch 40/100, Loss: 0.1195
# Accuracy: 0.9668
# Precision: 0.9434
# Recall: 0.9668
# F1 Score: 0.9539
# AUC: 0.9977
# AUPR: 0.9915
# Specificity per class: [0.9827586206896551, 1.0, 0.9866666666666667, 0.9863013698630136]
# Macro-average Specificity: 0.9889
# MCC per class: [0.960196523248786, 0.9463715665614397, 0.9694477535121453, 0.8952207487823]
# Macro-average MCC: 0.9428
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9654
# ---------------------------------------------------------------------------------------------------
# Epoch 41/100, Loss: 0.0535
# Epoch 41/100, Loss: 0.1191
# Accuracy: 0.9459
# Precision: 0.9412
# Recall: 0.9459
# F1 Score: 0.9430
# AUC: 0.9980
# AUPR: 0.9903
# Specificity per class: [0.9698275862068966, 1.0, 0.9866666666666667, 0.9897260273972602]
# Macro-average Specificity: 0.9866
# MCC per class: [0.937645518934311, 0.9463715665614397, 0.9694477535121453, 0.8647260273972602]
# Macro-average MCC: 0.9295
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9589
# ---------------------------------------------------------------------------------------------------
# Epoch 42/100, Loss: 0.0723
# Epoch 42/100, Loss: 0.1426
# Accuracy: 0.9134
# Precision: 0.9365
# Recall: 0.9134
# F1 Score: 0.9214
# AUC: 0.9973
# AUPR: 0.9853
# Specificity per class: [0.9396551724137931, 1.0, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9821
# MCC per class: [0.8974512350049014, 0.9331519181523712, 0.9845665445665446, 0.808561532107024]
# Macro-average MCC: 0.9059
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9460
# ---------------------------------------------------------------------------------------------------
# Epoch 43/100, Loss: 0.0608
# Epoch 43/100, Loss: 0.1332
# Accuracy: 0.9104
# Precision: 0.9331
# Recall: 0.9104
# F1 Score: 0.9185
# AUC: 0.9977
# AUPR: 0.9882
# Specificity per class: [0.9439655172413793, 1.0, 0.9866666666666667, 0.9931506849315068]
# Macro-average Specificity: 0.9809
# MCC per class: [0.895325390526334, 0.9331519181523712, 0.9694477535121453, 0.808561532107024]
# Macro-average MCC: 0.9016
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9427
# ---------------------------------------------------------------------------------------------------
# Epoch 44/100, Loss: 0.0512
# Epoch 44/100, Loss: 0.1021
# Accuracy: 0.9689
# Precision: 0.9460
# Recall: 0.9689
# F1 Score: 0.9564
# AUC: 0.9985
# AUPR: 0.9934
# Specificity per class: [0.9827586206896551, 1.0, 0.9911111111111112, 0.9863013698630136]
# Macro-average Specificity: 0.9900
# MCC per class: [0.960196523248786, 0.9530075466393428, 0.9769542224975036, 0.8952207487823]
# Macro-average MCC: 0.9463
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9686
# ---------------------------------------------------------------------------------------------------
# Epoch 45/100, Loss: 0.0507
# Epoch 45/100, Loss: 0.0894
# Accuracy: 0.9598
# Precision: 0.9577
# Recall: 0.9598
# F1 Score: 0.9586
# AUC: 0.9989
# AUPR: 0.9950
# Specificity per class: [0.978448275862069, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9893
# MCC per class: [0.9441594142981191, 0.9524447467356325, 0.9845665445665446, 0.9098173515981736]
# Macro-average MCC: 0.9477
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9684
# ---------------------------------------------------------------------------------------------------
# Epoch 46/100, Loss: 0.0464
# Epoch 46/100, Loss: 0.3671
# Accuracy: 0.8600
# Precision: 0.8987
# Recall: 0.8600
# F1 Score: 0.8632
# AUC: 0.9961
# AUPR: 0.9799
# Specificity per class: [0.8448275862068966, 1.0, 0.9777777777777777, 0.9965753424657534]
# Macro-average Specificity: 0.9548
# MCC per class: [0.769011905203572, 0.7720272056620909, 0.9547410841058538, 0.8319853203258969]
# Macro-average MCC: 0.8319
# F1 Score (micro): 0.8671
# F1 Score (weighted): 0.8663
# ---------------------------------------------------------------------------------------------------
# Epoch 47/100, Loss: 0.0540
# Epoch 47/100, Loss: 0.1057
# Accuracy: 0.9606
# Precision: 0.9504
# Recall: 0.9606
# F1 Score: 0.9551
# AUC: 0.9985
# AUPR: 0.9927
# Specificity per class: [0.978448275862069, 1.0, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9898
# MCC per class: [0.9525686552200252, 0.9596617081666465, 0.9769542224975036, 0.8896044445281678]
# Macro-average MCC: 0.9447
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9685
# ---------------------------------------------------------------------------------------------------
# Epoch 48/100, Loss: 0.0580
# Epoch 48/100, Loss: 0.1089
# Accuracy: 0.9630
# Precision: 0.9467
# Recall: 0.9630
# F1 Score: 0.9543
# AUC: 0.9977
# AUPR: 0.9925
# Specificity per class: [0.978448275862069, 0.9899497487437185, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9873
# MCC per class: [0.9357496161555404, 0.9389331631730534, 0.9769542224975036, 0.9140014911483973]
# Macro-average MCC: 0.9414
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9621
# ---------------------------------------------------------------------------------------------------
# Epoch 49/100, Loss: 0.0562
# Epoch 49/100, Loss: 0.1414
# Accuracy: 0.9459
# Precision: 0.9413
# Recall: 0.9459
# F1 Score: 0.9429
# AUC: 0.9966
# AUPR: 0.9867
# Specificity per class: [0.9655172413793104, 1.0, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9866
# MCC per class: [0.9303440963742202, 0.9463715665614397, 0.9769542224975036, 0.8647260273972602]
# Macro-average MCC: 0.9296
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9590
# ---------------------------------------------------------------------------------------------------
# Epoch 50/100, Loss: 0.0410
# Epoch 50/100, Loss: 0.1546
# Accuracy: 0.9125
# Precision: 0.9453
# Recall: 0.9125
# F1 Score: 0.9245
# AUC: 0.9964
# AUPR: 0.9871
# Specificity per class: [0.9396551724137931, 1.0, 0.9911111111111112, 0.9965753424657534]
# Macro-average Specificity: 0.9818
# MCC per class: [0.888601140084966, 0.9397532094515858, 0.9769542224975036, 0.8319853203258969]
# Macro-average MCC: 0.9093
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9461
# ---------------------------------------------------------------------------------------------------
# Epoch 51/100, Loss: 0.0386
# Epoch 51/100, Loss: 0.1195
# Accuracy: 0.9578
# Precision: 0.9416
# Recall: 0.9578
# F1 Score: 0.9492
# AUC: 0.9973
# AUPR: 0.9893
# Specificity per class: [0.9741379310344828, 0.9849246231155779, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9850
# MCC per class: [0.9196546412641213, 0.9252324391444847, 0.9769542224975036, 0.9140014911483973]
# Macro-average MCC: 0.9340
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9558
# ---------------------------------------------------------------------------------------------------
# Epoch 52/100, Loss: 0.0460
# Epoch 52/100, Loss: 0.1335
# Accuracy: 0.9243
# Precision: 0.9416
# Recall: 0.9243
# F1 Score: 0.9315
# AUC: 0.9969
# AUPR: 0.9887
# Specificity per class: [0.9612068965517241, 0.9899497487437185, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9839
# MCC per class: [0.9145246423032853, 0.9389331631730534, 0.9769542224975036, 0.834728011337836]
# Macro-average MCC: 0.9163
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9522
# ---------------------------------------------------------------------------------------------------
# Epoch 53/100, Loss: 0.0398
# Epoch 53/100, Loss: 0.1247
# Accuracy: 0.9451
# Precision: 0.9484
# Recall: 0.9451
# F1 Score: 0.9462
# AUC: 0.9973
# AUPR: 0.9902
# Specificity per class: [0.9655172413793104, 0.9949748743718593, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9862
# MCC per class: [0.9217736534970257, 0.9459330151619536, 0.9769542224975036, 0.8853080854491499]
# Macro-average MCC: 0.9325
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9589
# ---------------------------------------------------------------------------------------------------
# Epoch 54/100, Loss: 0.0312
# Epoch 54/100, Loss: 0.1729
# Accuracy: 0.8996
# Precision: 0.9309
# Recall: 0.8996
# F1 Score: 0.9104
# AUC: 0.9956
# AUPR: 0.9795
# Specificity per class: [0.9310344827586207, 1.0, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9799
# MCC per class: [0.8843466319929314, 0.9397532094515858, 0.9690466897894506, 0.7817354424163053]
# Macro-average MCC: 0.8937
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9398
# ---------------------------------------------------------------------------------------------------
# Epoch 55/100, Loss: 0.0514
# Epoch 55/100, Loss: 0.1197
# Accuracy: 0.9466
# Precision: 0.9519
# Recall: 0.9466
# F1 Score: 0.9490
# AUC: 0.9968
# AUPR: 0.9876
# Specificity per class: [0.9741379310344828, 0.9849246231155779, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9869
# MCC per class: [0.9365879961071812, 0.945607302219665, 0.9768030891848316, 0.8853080854491499]
# Macro-average MCC: 0.9361
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9620
# ---------------------------------------------------------------------------------------------------
# Epoch 56/100, Loss: 0.0422
# Epoch 56/100, Loss: 0.1285
# Accuracy: 0.9549
# Precision: 0.9522
# Recall: 0.9549
# F1 Score: 0.9533
# AUC: 0.9961
# AUPR: 0.9874
# Specificity per class: [0.9741379310344828, 0.9899497487437185, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9871
# MCC per class: [0.9365879961071812, 0.9456797751166062, 0.9691330891330892, 0.9098173515981736]
# Macro-average MCC: 0.9403
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9621
# ---------------------------------------------------------------------------------------------------
# Epoch 57/100, Loss: 0.0495
# Epoch 57/100, Loss: 0.1327
# Accuracy: 0.9215
# Precision: 0.9308
# Recall: 0.9215
# F1 Score: 0.9252
# AUC: 0.9965
# AUPR: 0.9843
# Specificity per class: [0.9612068965517241, 0.9949748743718593, 0.9866666666666667, 0.9897260273972602]
# Macro-average Specificity: 0.9831
# MCC per class: [0.9145246423032853, 0.9459330151619536, 0.9615706499287768, 0.8133573344341013]
# Macro-average MCC: 0.9088
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9492
# ---------------------------------------------------------------------------------------------------
# Epoch 58/100, Loss: 0.0441
# Epoch 58/100, Loss: 0.1164
# Accuracy: 0.9347
# Precision: 0.9310
# Recall: 0.9347
# F1 Score: 0.9325
# AUC: 0.9969
# AUPR: 0.9880
# Specificity per class: [0.9741379310344828, 0.9949748743718593, 0.9866666666666667, 0.9863013698630136]
# Macro-average Specificity: 0.9855
# MCC per class: [0.9365879961071812, 0.9459330151619536, 0.9694477535121453, 0.819634703196347]
# Macro-average MCC: 0.9179
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9557
# ---------------------------------------------------------------------------------------------------
# Epoch 59/100, Loss: 0.0397
# Epoch 59/100, Loss: 0.1170
# Accuracy: 0.9402
# Precision: 0.9361
# Recall: 0.9402
# F1 Score: 0.9376
# AUC: 0.9975
# AUPR: 0.9904
# Specificity per class: [0.9655172413793104, 0.9949748743718593, 0.9866666666666667, 0.9897260273972602]
# Macro-average Specificity: 0.9842
# MCC per class: [0.9217736534970257, 0.939250105582329, 0.9615706499287768, 0.8647260273972602]
# Macro-average MCC: 0.9218
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9527
# ---------------------------------------------------------------------------------------------------
# Epoch 60/100, Loss: 0.0406
# Epoch 60/100, Loss: 0.1574
# Accuracy: 0.9088
# Precision: 0.9498
# Recall: 0.9088
# F1 Score: 0.9237
# AUC: 0.9972
# AUPR: 0.9868
# Specificity per class: [0.9439655172413793, 1.0, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9840
# MCC per class: [0.9041320007191944, 0.9596617081666465, 0.9768030891848316, 0.8057225485326348]
# Macro-average MCC: 0.9116
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9519
# ---------------------------------------------------------------------------------------------------
# Epoch 61/100, Loss: 0.0424
# Epoch 61/100, Loss: 0.1360
# Accuracy: 0.9430
# Precision: 0.9457
# Recall: 0.9430
# F1 Score: 0.9437
# AUC: 0.9973
# AUPR: 0.9879
# Specificity per class: [0.9655172413793104, 0.9949748743718593, 0.9866666666666667, 0.9931506849315068]
# Macro-average Specificity: 0.9851
# MCC per class: [0.9217736534970257, 0.939250105582329, 0.9694477535121453, 0.8853080854491499]
# Macro-average MCC: 0.9289
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9557
# ---------------------------------------------------------------------------------------------------
# Epoch 62/100, Loss: 0.0499
# Epoch 62/100, Loss: 0.1119
# Accuracy: 0.9436
# Precision: 0.9567
# Recall: 0.9436
# F1 Score: 0.9496
# AUC: 0.9975
# AUPR: 0.9908
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 0.9911111111111112, 0.9965753424657534]
# Macro-average Specificity: 0.9856
# MCC per class: [0.9206073369943373, 0.945607302219665, 0.9691330891330892, 0.9072291086054585]
# Macro-average MCC: 0.9356
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9588
# ---------------------------------------------------------------------------------------------------
# Epoch 63/100, Loss: 0.0430
# Epoch 63/100, Loss: 0.1239
# Accuracy: 0.9252
# Precision: 0.9535
# Recall: 0.9252
# F1 Score: 0.9371
# AUC: 0.9979
# AUPR: 0.9930
# Specificity per class: [0.9612068965517241, 0.9849246231155779, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9846
# MCC per class: [0.9145246423032853, 0.952435741621506, 0.9690466897894506, 0.8576217172348696]
# Macro-average MCC: 0.9234
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9554
# ---------------------------------------------------------------------------------------------------
# Epoch 64/100, Loss: 0.0389
# Epoch 64/100, Loss: 0.1143
# Accuracy: 0.9710
# Precision: 0.9604
# Recall: 0.9710
# F1 Score: 0.9653
# AUC: 0.9974
# AUPR: 0.9905
# Specificity per class: [0.978448275862069, 1.0, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9907
# MCC per class: [0.9525686552200252, 0.9596617081666465, 0.9769542224975036, 0.9338605850305136]
# Macro-average MCC: 0.9558
# F1 Score (micro): 0.9715
# F1 Score (weighted): 0.9716
# ---------------------------------------------------------------------------------------------------
# Epoch 65/100, Loss: 0.0364
# Epoch 65/100, Loss: 0.1059
# Accuracy: 0.9522
# Precision: 0.9500
# Recall: 0.9522
# F1 Score: 0.9509
# AUC: 0.9973
# AUPR: 0.9910
# Specificity per class: [0.9741379310344828, 0.9849246231155779, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9858
# MCC per class: [0.9365879961071812, 0.9387976740971787, 0.9613185012354785, 0.9098173515981736]
# Macro-average MCC: 0.9366
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9589
# ---------------------------------------------------------------------------------------------------
# Epoch 66/100, Loss: 0.0329
# Epoch 66/100, Loss: 0.1191
# Accuracy: 0.9683
# Precision: 0.9581
# Recall: 0.9683
# F1 Score: 0.9628
# AUC: 0.9972
# AUPR: 0.9888
# Specificity per class: [0.978448275862069, 0.9949748743718593, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9894
# MCC per class: [0.9525686552200252, 0.9526338872016222, 0.9691330891330892, 0.9338605850305136]
# Macro-average MCC: 0.9520
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9684
# ---------------------------------------------------------------------------------------------------
# Epoch 67/100, Loss: 0.0282
# Epoch 67/100, Loss: 0.0984
# Accuracy: 0.9528
# Precision: 0.9495
# Recall: 0.9528
# F1 Score: 0.9508
# AUC: 0.9979
# AUPR: 0.9913
# Specificity per class: [0.9698275862068966, 0.9899497487437185, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9860
# MCC per class: [0.9291271099667554, 0.9389331631730534, 0.9691330891330892, 0.9098173515981736]
# Macro-average MCC: 0.9368
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9590
# ---------------------------------------------------------------------------------------------------
# Epoch 68/100, Loss: 0.0321
# Epoch 68/100, Loss: 0.1023
# Accuracy: 0.9588
# Precision: 0.9518
# Recall: 0.9588
# F1 Score: 0.9551
# AUC: 0.9977
# AUPR: 0.9914
# Specificity per class: [0.978448275862069, 0.9748743718592965, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9855
# MCC per class: [0.9273382946495989, 0.9321393291242538, 0.9690466897894506, 0.9338605850305136]
# Macro-average MCC: 0.9406
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9590
# ---------------------------------------------------------------------------------------------------
# Epoch 69/100, Loss: 0.0401
# Epoch 69/100, Loss: 0.1353
# Accuracy: 0.9496
# Precision: 0.9475
# Recall: 0.9496
# F1 Score: 0.9483
# AUC: 0.9971
# AUPR: 0.9899
# Specificity per class: [0.9827586206896551, 0.9849246231155779, 0.9777777777777777, 0.9931506849315068]
# Macro-average Specificity: 0.9847
# MCC per class: [0.9351395730706076, 0.9320062537742658, 0.9547410841058538, 0.9098173515981736]
# Macro-average MCC: 0.9329
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9556
# ---------------------------------------------------------------------------------------------------
# Epoch 70/100, Loss: 0.0335
# Epoch 70/100, Loss: 0.1272
# Accuracy: 0.9404
# Precision: 0.9367
# Recall: 0.9404
# F1 Score: 0.9380
# AUC: 0.9979
# AUPR: 0.9888
# Specificity per class: [0.9655172413793104, 0.9899497487437185, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9841
# MCC per class: [0.9303440963742202, 0.9322043221572608, 0.9613185012354785, 0.8647260273972602]
# Macro-average MCC: 0.9221
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9526
# ---------------------------------------------------------------------------------------------------
# Epoch 71/100, Loss: 0.0298
# Epoch 71/100, Loss: 0.1101
# Accuracy: 0.9434
# Precision: 0.9468
# Recall: 0.9434
# F1 Score: 0.9442
# AUC: 0.9981
# AUPR: 0.9925
# Specificity per class: [0.9612068965517241, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9850
# MCC per class: [0.9317654609958362, 0.9322043221572608, 0.9690466897894506, 0.8853080854491499]
# Macro-average MCC: 0.9296
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9558
# ---------------------------------------------------------------------------------------------------
# Epoch 72/100, Loss: 0.0244
# Epoch 72/100, Loss: 0.1128
# Accuracy: 0.9421
# Precision: 0.9463
# Recall: 0.9421
# F1 Score: 0.9439
# AUC: 0.9978
# AUPR: 0.9901
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9848
# MCC per class: [0.9206073369943373, 0.9320062537742658, 0.9769542224975036, 0.8853080854491499]
# Macro-average MCC: 0.9287
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9556
# ---------------------------------------------------------------------------------------------------
# Epoch 73/100, Loss: 0.0279
# Epoch 73/100, Loss: 0.1070
# Accuracy: 0.9541
# Precision: 0.9539
# Recall: 0.9541
# F1 Score: 0.9540
# AUC: 0.9975
# AUPR: 0.9913
# Specificity per class: [0.9827586206896551, 0.9748743718592965, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9866
# MCC per class: [0.9434925890878169, 0.9321393291242538, 0.9768030891848316, 0.9098173515981736]
# Macro-average MCC: 0.9406
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9621
# ---------------------------------------------------------------------------------------------------
# Epoch 74/100, Loss: 0.0240
# Epoch 74/100, Loss: 0.1117
# Accuracy: 0.9659
# Precision: 0.9557
# Recall: 0.9659
# F1 Score: 0.9605
# AUC: 0.9975
# AUPR: 0.9903
# Specificity per class: [0.978448275862069, 0.9899497487437185, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9882
# MCC per class: [0.9441594142981191, 0.9389331631730534, 0.9769542224975036, 0.9338605850305136]
# Macro-average MCC: 0.9485
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9652
# ---------------------------------------------------------------------------------------------------
# Epoch 75/100, Loss: 0.0276
# Epoch 75/100, Loss: 0.1492
# Accuracy: 0.9523
# Precision: 0.9346
# Recall: 0.9523
# F1 Score: 0.9420
# AUC: 0.9959
# AUPR: 0.9824
# Specificity per class: [0.9612068965517241, 1.0, 0.9955555555555555, 0.9863013698630136]
# Macro-average Specificity: 0.9858
# MCC per class: [0.9317654609958362, 0.9331519181523712, 0.9768030891848316, 0.870530017457414]
# Macro-average MCC: 0.9281
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9561
# ---------------------------------------------------------------------------------------------------
# Epoch 76/100, Loss: 0.0261
# Epoch 76/100, Loss: 0.1501
# Accuracy: 0.9279
# Precision: 0.9383
# Recall: 0.9279
# F1 Score: 0.9316
# AUC: 0.9962
# AUPR: 0.9864
# Specificity per class: [0.9482758620689655, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9817
# MCC per class: [0.9021394970306476, 0.9254926645253152, 0.9690466897894506, 0.8602932215197799]
# Macro-average MCC: 0.9142
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9464
# ---------------------------------------------------------------------------------------------------
# Epoch 77/100, Loss: 0.0228
# Epoch 77/100, Loss: 0.1158
# Accuracy: 0.9681
# Precision: 0.9590
# Recall: 0.9681
# F1 Score: 0.9634
# AUC: 0.9964
# AUPR: 0.9894
# Specificity per class: [0.9827586206896551, 0.9849246231155779, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9891
# MCC per class: [0.9518445910469595, 0.9387976740971787, 0.9845665445665446, 0.9338605850305136]
# Macro-average MCC: 0.9523
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9684
# ---------------------------------------------------------------------------------------------------
# Epoch 78/100, Loss: 0.0302
# Epoch 78/100, Loss: 0.1071
# Accuracy: 0.9747
# Precision: 0.9610
# Recall: 0.9747
# F1 Score: 0.9673
# AUC: 0.9973
# AUPR: 0.9923
# Specificity per class: [0.9956896551724138, 0.9798994974874372, 0.9866666666666667, 0.9931506849315068]
# Macro-average Specificity: 0.9889
# MCC per class: [0.959285494578132, 0.9388393513815171, 0.9694477535121453, 0.9574729648393807]
# Macro-average MCC: 0.9563
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9683
# ---------------------------------------------------------------------------------------------------
# Epoch 79/100, Loss: 0.0328
# Epoch 79/100, Loss: 0.1278
# Accuracy: 0.9438
# Precision: 0.9461
# Recall: 0.9438
# F1 Score: 0.9440
# AUC: 0.9969
# AUPR: 0.9887
# Specificity per class: [0.9612068965517241, 0.9949748743718593, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9851
# MCC per class: [0.923145527810611, 0.9325845850929314, 0.9769542224975036, 0.8853080854491499]
# Macro-average MCC: 0.9295
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9557
# ---------------------------------------------------------------------------------------------------
# Epoch 80/100, Loss: 0.0178
# Epoch 80/100, Loss: 0.1290
# Accuracy: 0.9347
# Precision: 0.9451
# Recall: 0.9347
# F1 Score: 0.9391
# AUC: 0.9968
# AUPR: 0.9877
# Specificity per class: [0.9698275862068966, 0.9899497487437185, 0.9866666666666667, 0.9931506849315068]
# Macro-average Specificity: 0.9849
# MCC per class: [0.9291271099667554, 0.9389331631730534, 0.9694477535121453, 0.8602932215197799]
# Macro-average MCC: 0.9245
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9555
# ---------------------------------------------------------------------------------------------------
# Epoch 81/100, Loss: 0.0210
# Epoch 81/100, Loss: 0.1247
# Accuracy: 0.9168
# Precision: 0.9409
# Recall: 0.9168
# F1 Score: 0.9264
# AUC: 0.9971
# AUPR: 0.9877
# Specificity per class: [0.9568965517241379, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9839
# MCC per class: [0.9160470173873222, 0.9389331631730534, 0.9845665445665446, 0.808561532107024]
# Macro-average MCC: 0.9120
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9520
# ---------------------------------------------------------------------------------------------------
# Epoch 82/100, Loss: 0.0272
# Epoch 82/100, Loss: 0.1200
# Accuracy: 0.9377
# Precision: 0.9476
# Recall: 0.9377
# F1 Score: 0.9417
# AUC: 0.9974
# AUPR: 0.9877
# Specificity per class: [0.9655172413793104, 0.9949748743718593, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9862
# MCC per class: [0.9303440963742202, 0.9459330151619536, 0.9769542224975036, 0.8602932215197799]
# Macro-average MCC: 0.9284
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9587
# ---------------------------------------------------------------------------------------------------
# Epoch 83/100, Loss: 0.0244
# Epoch 83/100, Loss: 0.1374
# Accuracy: 0.9217
# Precision: 0.9397
# Recall: 0.9217
# F1 Score: 0.9289
# AUC: 0.9962
# AUPR: 0.9843
# Specificity per class: [0.9525862068965517, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9828
# MCC per class: [0.9090458721223321, 0.9389331631730534, 0.9690466897894506, 0.834728011337836]
# Macro-average MCC: 0.9129
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9493
# ---------------------------------------------------------------------------------------------------
# Epoch 84/100, Loss: 0.0273
# Epoch 84/100, Loss: 0.1243
# Accuracy: 0.9338
# Precision: 0.9454
# Recall: 0.9338
# F1 Score: 0.9390
# AUC: 0.9965
# AUPR: 0.9870
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9848
# MCC per class: [0.9206073369943373, 0.9387976740971787, 0.9769542224975036, 0.8602932215197799]
# Macro-average MCC: 0.9242
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9555
# ---------------------------------------------------------------------------------------------------
# Epoch 85/100, Loss: 0.0287
# Epoch 85/100, Loss: 0.1342
# Accuracy: 0.9653
# Precision: 0.9558
# Recall: 0.9653
# F1 Score: 0.9603
# AUC: 0.9967
# AUPR: 0.9874
# Specificity per class: [0.9827586206896551, 0.9899497487437185, 0.9866666666666667, 0.9931506849315068]
# Macro-average Specificity: 0.9881
# MCC per class: [0.9518445910469595, 0.9456797751166062, 0.9615706499287768, 0.9338605850305136]
# Macro-average MCC: 0.9482
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9652
# ---------------------------------------------------------------------------------------------------
# Epoch 86/100, Loss: 0.0321
# Epoch 86/100, Loss: 0.1218
# Accuracy: 0.9594
# Precision: 0.9512
# Recall: 0.9594
# F1 Score: 0.9552
# AUC: 0.9970
# AUPR: 0.9894
# Specificity per class: [0.9827586206896551, 0.9798994974874372, 0.9866666666666667, 0.9931506849315068]
# Macro-average Specificity: 0.9856
# MCC per class: [0.9351395730706076, 0.931985936148579, 0.9615706499287768, 0.9338605850305136]
# Macro-average MCC: 0.9406
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9589
# ---------------------------------------------------------------------------------------------------
# Epoch 87/100, Loss: 0.0322
# Epoch 87/100, Loss: 0.1211
# Accuracy: 0.9596
# Precision: 0.9506
# Recall: 0.9596
# F1 Score: 0.9549
# AUC: 0.9968
# AUPR: 0.9908
# Specificity per class: [0.978448275862069, 0.9849246231155779, 0.9866666666666667, 0.9931506849315068]
# Macro-average Specificity: 0.9858
# MCC per class: [0.9357496161555404, 0.9387976740971787, 0.9536996336996337, 0.9338605850305136]
# Macro-average MCC: 0.9405
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9589
# ---------------------------------------------------------------------------------------------------
# Epoch 88/100, Loss: 0.0305
# Epoch 88/100, Loss: 0.1546
# Accuracy: 0.9247
# Precision: 0.9422
# Recall: 0.9247
# F1 Score: 0.9314
# AUC: 0.9959
# AUPR: 0.9847
# Specificity per class: [0.9525862068965517, 0.9949748743718593, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9841
# MCC per class: [0.9177618162470923, 0.9459330151619536, 0.9690466897894506, 0.834728011337836]
# Macro-average MCC: 0.9169
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9525
# ---------------------------------------------------------------------------------------------------
# Epoch 89/100, Loss: 0.0294
# Epoch 89/100, Loss: 0.1084
# Accuracy: 0.9547
# Precision: 0.9528
# Recall: 0.9547
# F1 Score: 0.9536
# AUC: 0.9972
# AUPR: 0.9889
# Specificity per class: [0.9827586206896551, 0.9849246231155779, 0.9866666666666667, 0.9931506849315068]
# Macro-average Specificity: 0.9869
# MCC per class: [0.9434925890878169, 0.9387976740971787, 0.9694477535121453, 0.9098173515981736]
# Macro-average MCC: 0.9404
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9620
# ---------------------------------------------------------------------------------------------------
# Epoch 90/100, Loss: 0.0279
# Epoch 90/100, Loss: 0.1320
# Accuracy: 0.9551
# Precision: 0.9525
# Recall: 0.9551
# F1 Score: 0.9534
# AUC: 0.9962
# AUPR: 0.9856
# Specificity per class: [0.9698275862068966, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9871
# MCC per class: [0.937645518934311, 0.9456797751166062, 0.9690466897894506, 0.9098173515981736]
# Macro-average MCC: 0.9405
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9622
# ---------------------------------------------------------------------------------------------------
# Epoch 91/100, Loss: 0.0223
# Epoch 91/100, Loss: 0.1185
# Accuracy: 0.9755
# Precision: 0.9601
# Recall: 0.9755
# F1 Score: 0.9673
# AUC: 0.9970
# AUPR: 0.9891
# Specificity per class: [0.9913793103448276, 0.9849246231155779, 0.9866666666666667, 0.9931506849315068]
# Macro-average Specificity: 0.9890
# MCC per class: [0.959339487282751, 0.9387976740971787, 0.9694477535121453, 0.9574729648393807]
# Macro-average MCC: 0.9563
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9683
# ---------------------------------------------------------------------------------------------------
# Epoch 92/100, Loss: 0.0330
# Epoch 92/100, Loss: 0.1249
# Accuracy: 0.9519
# Precision: 0.9499
# Recall: 0.9519
# F1 Score: 0.9508
# AUC: 0.9970
# AUPR: 0.9895
# Specificity per class: [0.978448275862069, 0.9849246231155779, 0.9866666666666667, 0.9931506849315068]
# Macro-average Specificity: 0.9858
# MCC per class: [0.9357496161555404, 0.9387976740971787, 0.9615706499287768, 0.9098173515981736]
# Macro-average MCC: 0.9365
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9589
# ---------------------------------------------------------------------------------------------------
# Epoch 93/100, Loss: 0.0288
# Epoch 93/100, Loss: 0.1453
# Accuracy: 0.9623
# Precision: 0.9535
# Recall: 0.9623
# F1 Score: 0.9578
# AUC: 0.9961
# AUPR: 0.9856
# Specificity per class: [0.9827586206896551, 0.9849246231155779, 0.9866666666666667, 0.9931506849315068]
# Macro-average Specificity: 0.9869
# MCC per class: [0.9434925890878169, 0.9387976740971787, 0.9615706499287768, 0.9338605850305136]
# Macro-average MCC: 0.9444
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9620
# ---------------------------------------------------------------------------------------------------
# Epoch 94/100, Loss: 0.0278
# Epoch 94/100, Loss: 0.1570
# Accuracy: 0.9530
# Precision: 0.9496
# Recall: 0.9530
# F1 Score: 0.9506
# AUC: 0.9957
# AUPR: 0.9857
# Specificity per class: [0.9612068965517241, 0.9949748743718593, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9862
# MCC per class: [0.923145527810611, 0.9459330151619536, 0.9690466897894506, 0.9098173515981736]
# Macro-average MCC: 0.9370
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9592
# ---------------------------------------------------------------------------------------------------
# Epoch 95/100, Loss: 0.0260
# Epoch 95/100, Loss: 0.1223
# Accuracy: 0.9623
# Precision: 0.9535
# Recall: 0.9623
# F1 Score: 0.9578
# AUC: 0.9971
# AUPR: 0.9898
# Specificity per class: [0.9827586206896551, 0.9849246231155779, 0.9866666666666667, 0.9931506849315068]
# Macro-average Specificity: 0.9869
# MCC per class: [0.9434925890878169, 0.9387976740971787, 0.9615706499287768, 0.9338605850305136]
# Macro-average MCC: 0.9444
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9620
# ---------------------------------------------------------------------------------------------------
# Epoch 96/100, Loss: 0.0237
# Epoch 96/100, Loss: 0.1366
# Accuracy: 0.9557
# Precision: 0.9525
# Recall: 0.9557
# F1 Score: 0.9537
# AUC: 0.9962
# AUPR: 0.9859
# Specificity per class: [0.9698275862068966, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9871
# MCC per class: [0.937645518934311, 0.9389331631730534, 0.9768030891848316, 0.9098173515981736]
# Macro-average MCC: 0.9408
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9621
# ---------------------------------------------------------------------------------------------------
# Epoch 97/100, Loss: 0.0206
# Epoch 97/100, Loss: 0.1417
# Accuracy: 0.9646
# Precision: 0.9528
# Recall: 0.9646
# F1 Score: 0.9581
# AUC: 0.9964
# AUPR: 0.9854
# Specificity per class: [0.9741379310344828, 0.9949748743718593, 0.9866666666666667, 0.9931506849315068]
# Macro-average Specificity: 0.9872
# MCC per class: [0.9450526993977326, 0.9325845850929314, 0.9694477535121453, 0.9338605850305136]
# Macro-average MCC: 0.9452
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9620
# ---------------------------------------------------------------------------------------------------
# Epoch 98/100, Loss: 0.0232
# Epoch 98/100, Loss: 0.1311
# Accuracy: 0.9655
# Precision: 0.9559
# Recall: 0.9655
# F1 Score: 0.9603
# AUC: 0.9963
# AUPR: 0.9899
# Specificity per class: [0.9741379310344828, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9882
# MCC per class: [0.9450526993977326, 0.9456797751166062, 0.9690466897894506, 0.9338605850305136]
# Macro-average MCC: 0.9484
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9653
# ---------------------------------------------------------------------------------------------------
# Epoch 99/100, Loss: 0.0196
# Epoch 99/100, Loss: 0.1112
# Accuracy: 0.9683
# Precision: 0.9586
# Recall: 0.9683
# F1 Score: 0.9631
# AUC: 0.9971
# AUPR: 0.9899
# Specificity per class: [0.978448275862069, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9893
# MCC per class: [0.9525686552200252, 0.9456797751166062, 0.9768030891848316, 0.9338605850305136]
# Macro-average MCC: 0.9522
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9684
# ---------------------------------------------------------------------------------------------------
# Epoch 100/100, Loss: 0.0326
# Epoch 100/100, Loss: 0.1379
# Accuracy: 0.9579
# Precision: 0.9551
# Recall: 0.9579
# F1 Score: 0.9562
# AUC: 0.9958
# AUPR: 0.9842
# Specificity per class: [0.9741379310344828, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9882
# MCC per class: [0.9450526993977326, 0.9456797751166062, 0.9768030891848316, 0.9098173515981736]
# Macro-average MCC: 0.9443
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9653
# ---------------------------------------------------------------------------------------------------
# Training and validating complete

# %% [markdown]
# # twins_pcpvt_base pretrained

# %%
import os
import pandas as pd
from PIL import Image
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torch.nn.functional as F
import torchvision.models as models
import numpy as np
import timm
import torch
import torch.nn.functional as F
import numpy as np
from torcheval.metrics import MulticlassAccuracy, MulticlassPrecision, MulticlassRecall, MulticlassF1Score, MulticlassAUROC, MulticlassAUPRC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import matthews_corrcoef
import random


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)  # For CPU
    torch.cuda.manual_seed(seed)  # For GPU (if used)
    torch.cuda.manual_seed_all(seed)  # For all GPUs
    torch.backends.cudnn.deterministic = True  # Ensure deterministic behavior
    torch.backends.cudnn.benchmark = False


def calculate_metrics(predicted, probabilities, labels, num_classes):
    # Initialize Torcheval metrics
    accuracy_metric = MulticlassAccuracy(num_classes=num_classes, average="macro")
    precision_metric = MulticlassPrecision(num_classes=num_classes, average="macro")
    recall_metric = MulticlassRecall(num_classes=num_classes, average="macro")
    f1_score_metric = MulticlassF1Score(num_classes=num_classes, average="macro")
    auc_metric = MulticlassAUROC(num_classes=num_classes, average="macro")
    aupr_metric = MulticlassAUPRC(num_classes=num_classes, average="macro")

    # Update metrics with predictions
    accuracy_metric.update(predicted, labels)
    precision_metric.update(predicted, labels)
    recall_metric.update(predicted, labels)
    f1_score_metric.update(predicted, labels)
    auc_metric.update(probabilities, labels)
    aupr_metric.update(probabilities, labels)

    # Compute metrics
    accuracy = accuracy_metric.compute()
    precision = precision_metric.compute()
    recall = recall_metric.compute()
    f1_score = f1_score_metric.compute()
    auc = auc_metric.compute()
    aupr = aupr_metric.compute()

    # Specificity calculation
    conf_matrix = confusion_matrix(labels.cpu().numpy(), predicted.cpu().numpy(), labels=range(num_classes))
    specificity_per_class = []

    for i in range(num_classes):
        TP = conf_matrix[i, i]
        FP = conf_matrix[:, i].sum() - TP
        FN = conf_matrix[i, :].sum() - TP
        TN = conf_matrix.sum() - (TP + FP + FN)

        specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
        specificity_per_class.append(specificity)

    macro_specificity = np.mean(specificity_per_class)

    # MCC calculation for multi-class classification
    mcc_per_class = []
    for i in range(num_classes):
        # Treat each class as the positive class and others as negative
        binary_pred = (predicted == i).int()
        binary_labels = (labels == i).int()
        mcc = matthews_corrcoef(binary_labels.cpu().numpy(), binary_pred.cpu().numpy())
        mcc_per_class.append(mcc)

    macro_mcc = np.mean(mcc_per_class)

    # Print all metrics
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1_score:.4f}")
    print(f"AUC: {auc:.4f}")
    print(f"AUPR: {aupr:.4f}")
    print(f"Specificity per class: {specificity_per_class}")
    print(f"Macro-average Specificity: {macro_specificity:.4f}")
    print(f"MCC per class: {mcc_per_class}")
    print(f"Macro-average MCC: {macro_mcc:.4f}")

    f1_score_metric_micro = MulticlassF1Score(num_classes=num_classes, average="micro")
    f1_score_metric_micro.update(predicted, labels)
    f1_score_micro = f1_score_metric_micro.compute()
    print(f"F1 Score (micro): {f1_score_micro:.4f}")

    f1_score_metric_weighted = MulticlassF1Score(num_classes=num_classes, average="weighted")
    f1_score_metric_weighted.update(predicted, labels)
    f1_score_weighted = f1_score_metric_weighted.compute()
    print(f"F1 Score (weighted): {f1_score_weighted:.4f}")


    # Return metrics as a dictionary
    return {
        "accuracy": "{:.4f}".format(accuracy.item()),
        "precision": "{:.4f}".format(precision.item()),
        "recall": "{:.4f}".format(recall.item()),
        "f1_score": "{:.4f}".format(f1_score.item()),
        "auc": "{:.4f}".format(auc.item()),
        "aupr": "{:.4f}".format(aupr.item()),
        "macro_specificity": "{:.4f}".format(macro_specificity.item()),
        "macro_mcc": "{:.4f}".format(macro_mcc.item())
    }


class ImageDataset(Dataset):
    def __init__(self, images, features, labels, transform=None):
        self.images = images
        self.features = features
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        feature = self.features[idx]
        label = self.labels[idx]
        return image, feature, label


# Image transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

set_seed(42)

dataset_path = "baldder_tissue_classification"

train_df = pd.read_csv("train_df.csv")
val_df = pd.read_csv("val_df.csv")

train_images = []
train_labels = []
for idx, row in train_df.iterrows():
    image_path = os.path.join(dataset_path, row[1], row[0])
    image = Image.open(image_path)
    image = transform(image)
    train_images.append(image)
    train_labels.append(row['encoded_label'])

loaded_images = np.load("top_images.npy")
loaded_labels = np.load("top_labels.npy")
print(len(train_images))
for i in range(len(loaded_images)):
    image = loaded_images[i]
    label = loaded_labels[i]

    # Denormalize the image
    image = (image * np.array([0.229, 0.224, 0.225])[:, None, None]) + np.array([0.485, 0.456, 0.406])[:, None, None]
    image = (image * 255).astype(np.uint8)  # Convert to integer type for PIL compatibility

    # Convert NumPy array to PIL image
    image = Image.fromarray(image.transpose(1, 2, 0))  # H x W x C format

    # Apply transformations
    image = transform(image)

    # Convert back to PyTorch tensor (if required)
    image = torch.tensor(image, dtype=torch.float32)
    train_images.append(image)
    train_labels.append(label)

print(len(train_images))

val_images = []
val_labels = []
for idx, row in val_df.iterrows():
    image_path = os.path.join(dataset_path, row[1], row[0])
    image = Image.open(image_path)
    image = transform(image)
    val_images.append(image)
    val_labels.append(row['encoded_label'])

print(len(val_images))

train_features = np.load("features_RFE.npy")[:-val_df.shape[0]]
augmented_features = np.load("features_top_images_RFE.npy")
train_features = np.concatenate((train_features, augmented_features), axis=0)
val_features = np.load("features_RFE.npy")[-val_df.shape[0]:]

print(train_features.shape)
print(val_features.shape)

# Create DataLoaders
train_dataset = ImageDataset(train_images, train_features, train_labels, transform=transform)
val_dataset = ImageDataset(val_images, val_features, val_labels, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)


# Define the CNN model
class SimpleCNN(nn.Module):
    def __init__(self, num_classes):
        super(SimpleCNN, self).__init__()
        self.block = timm.create_model('twins_pcpvt_base.in1k', pretrained=True)
        # self.block.head = nn.Linear(self.block.num_features, 1000)

        self.fc1 = nn.Linear(1000, 512)
        self.bn1 = nn.BatchNorm1d(512)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(0.2)
        self.fc2 = nn.Linear(512, 256)
        self.bn2 = nn.BatchNorm1d(256)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(0.2)

        self.fc_ann1 = nn.Linear(512, 256)
        self.bn_ann1 = nn.BatchNorm1d(256)
        self.relu_ann1 = nn.ReLU()
        self.dropout_ann1 = nn.Dropout(0.2)
        self.fc_ann2 = nn.Linear(256, 128)
        self.bn_ann2 = nn.BatchNorm1d(128)
        self.relu_ann2 = nn.ReLU()
        self.dropout_ann2 = nn.Dropout(0.2)

        self.fc_comb = nn.Linear(384, 256)
        self.bn_comb = nn.BatchNorm1d(256)
        self.relu_comb = nn.ReLU()
        self.dropout_comb = nn.Dropout(0.2)

        self.fc3 = nn.Linear(256, 128)
        self.bn3 = nn.BatchNorm1d(128)
        self.relu3 = nn.ReLU()
        self.dropout3 = nn.Dropout(0.2)
        self.fc4 = nn.Linear(128, num_classes)

        self.relu = nn.ReLU()


    def forward(self, x, features):
        features = features.float()
        x = self.block(x)
        # print(x.shape)
        x = x.view(-1, 1000)  # Flatten
        x = self.dropout1(self.relu1(self.bn1(self.fc1(x))))
        x = self.dropout2(self.relu2(self.bn2(self.fc2(x))))

        features = self.dropout_ann1(self.relu_ann1(self.bn_ann1(self.fc_ann1(features))))
        features = self.dropout_ann2(self.relu_ann2(self.bn_ann2(self.fc_ann2(features))))

        x = torch.cat((x, features), dim=1)
        x = self.dropout_comb(self.relu_comb(self.bn_comb(self.fc_comb(x))))

        x = self.dropout3(self.relu3(self.bn3(self.fc3(x))))
        x = self.fc4(x)
        return x


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")
# Instantiate model, loss function, and optimizer
num_classes = 4
model = SimpleCNN(num_classes)
model = model.to(device)
criterion = nn.CrossEntropyLoss().to(device)

optimizer = optim.Adam(model.parameters(), lr=0.0001)

# Training loop
num_epochs = 100
all_metrics = []

best_f1 = -100
best_epoch = 0
best_metric = 0
with open('Results/twins_pcpvt_base_pretrained.csv', 'w') as f:
    f.write("Epoch,Train Loss,Val Loss,Accuracy,Precision,Recall,F1 Score,AUC,AUPR,Specificity,MCC\n")
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for images, features, labels in train_loader:
            images, features, labels = images.to(device), features.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images, features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * images.size(0)

        train_loss = running_loss / len(train_loader.dataset)
        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {train_loss:.4f}")

        # Validation loop
        model.eval()
        running_loss = 0.0
        with torch.no_grad():
            y_pred = []
            y_true = []
            y_proba = []
            for images, features, labels in val_loader:
                images, features, labels = images.to(device), features.to(device), labels.to(device)

                outputs = model(images, features)
                loss = criterion(outputs, labels)

                running_loss += loss.item() * images.size(0)

                # Apply softmax to get probabilities
                probabilities = F.softmax(outputs, dim=1)

                # Get the predicted class and corresponding probability
                proba, predicted = torch.max(probabilities, 1)

                # Store results
                y_pred.extend(predicted.cpu().tolist())
                y_true.extend(labels.cpu().tolist())
                y_proba.extend(probabilities.cpu().tolist())

            val_loss = running_loss / len(val_loader.dataset)
            print(f"Epoch {epoch+1}/{num_epochs}, Loss: {val_loss:.4f}")
            # Convert lists to tensors
            y_pred = torch.tensor(y_pred)
            y_true = torch.tensor(y_true)
            y_proba = torch.tensor(y_proba)

            metrics = calculate_metrics(y_pred, y_proba, y_true, num_classes)
            all_metrics.append(metrics)

            if best_f1 < float(metrics["f1_score"]):
                best_f1 = float(metrics["f1_score"])
                best_epoch = epoch+1
                best_metric = metrics
            print('---------------------------------------------------------------------------------------------------')

            f.write(f"{epoch+1},{train_loss},{val_loss},{metrics['accuracy']},{metrics['precision']},{metrics['recall']},{metrics['f1_score']},{metrics['auc']},{metrics['aupr']},{metrics['macro_specificity']},{metrics['macro_mcc']}\n")
            f.flush()
    print("Training and validating complete")
# Out:
# <ipython-input-25-6b596e4be73e>:155: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   image_path = os.path.join(dataset_path, row[1], row[0])
# 1262
# <ipython-input-25-6b596e4be73e>:179: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   image = torch.tensor(image, dtype=torch.float32)
# 1762
# <ipython-input-25-6b596e4be73e>:188: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   image_path = os.path.join(dataset_path, row[1], row[0])
# 316
# (1762, 512)
# (316, 512)
# model.safetensors:   0%|          | 0.00/175M [00:00<?, ?B/s]
# Epoch 1/100, Loss: 1.0283
# Epoch 1/100, Loss: 0.6086
# Accuracy: 0.7898
# Precision: 0.7865
# Recall: 0.7898
# F1 Score: 0.7863
# AUC: 0.9771
# AUPR: 0.8978
# Specificity per class: [0.9741379310344828, 0.9597989949748744, 0.9333333333333333, 0.952054794520548]
# Macro-average Specificity: 0.9548
# MCC per class: [0.8517175559495883, 0.8292145851498173, 0.8866845818090036, 0.4027868990023631]
# Macro-average MCC: 0.7426
# F1 Score (micro): 0.8639
# F1 Score (weighted): 0.8640
# ---------------------------------------------------------------------------------------------------
# Epoch 2/100, Loss: 0.5586
# Epoch 2/100, Loss: 0.5319
# Accuracy: 0.7124
# Precision: 0.8602
# Recall: 0.7124
# F1 Score: 0.7392
# AUC: 0.9779
# AUPR: 0.9355
# Specificity per class: [0.978448275862069, 0.7386934673366834, 0.9822222222222222, 0.9965753424657534]
# Macro-average Specificity: 0.9240
# MCC per class: [0.5551025765206549, 0.7065517131363608, 0.9620442890220036, 0.5972487489243078]
# Macro-average MCC: 0.7052
# F1 Score (micro): 0.8038
# F1 Score (weighted): 0.7841
# ---------------------------------------------------------------------------------------------------
# Epoch 3/100, Loss: 0.5399
# Epoch 3/100, Loss: 0.3960
# Accuracy: 0.8369
# Precision: 0.8263
# Recall: 0.8369
# F1 Score: 0.8279
# AUC: 0.9840
# AUPR: 0.9275
# Specificity per class: [0.9568965517241379, 0.9949748743718593, 0.9377777777777778, 0.9623287671232876]
# Macro-average Specificity: 0.9630
# MCC per class: [0.8900299226224551, 0.8472549708054556, 0.9015213479118177, 0.5355553205094007]
# Macro-average MCC: 0.7936
# F1 Score (micro): 0.8861
# F1 Score (weighted): 0.8855
# ---------------------------------------------------------------------------------------------------
# Epoch 4/100, Loss: 0.4564
# Epoch 4/100, Loss: 0.7469
# Accuracy: 0.6994
# Precision: 0.7360
# Recall: 0.6994
# F1 Score: 0.6613
# AUC: 0.9644
# AUPR: 0.8860
# Specificity per class: [0.6896551724137931, 1.0, 0.9777777777777777, 0.9554794520547946]
# Macro-average Specificity: 0.9057
# MCC per class: [0.6093872210227981, 0.5035692341495592, 0.9547410841058538, 0.4138127853881279]
# Macro-average MCC: 0.6204
# F1 Score (micro): 0.7152
# F1 Score (weighted): 0.6917
# ---------------------------------------------------------------------------------------------------
# Epoch 5/100, Loss: 0.4327
# Epoch 5/100, Loss: 1.0525
# Accuracy: 0.5767
# Precision: 0.7031
# Recall: 0.5767
# F1 Score: 0.5524
# AUC: 0.8841
# AUPR: 0.7754
# Specificity per class: [0.5344827586206896, 1.0, 1.0, 0.9828767123287672]
# Macro-average Specificity: 0.8793
# MCC per class: [0.4835661349769561, 0.4821731331510052, 0.9001800540180063, 0.18193003253238693]
# Macro-average MCC: 0.5120
# F1 Score (micro): 0.6424
# F1 Score (weighted): 0.6234
# ---------------------------------------------------------------------------------------------------
# Epoch 6/100, Loss: 0.3856
# Epoch 6/100, Loss: 0.3100
# Accuracy: 0.9054
# Precision: 0.8724
# Recall: 0.9054
# F1 Score: 0.8840
# AUC: 0.9949
# AUPR: 0.9734
# Specificity per class: [0.9482758620689655, 0.9949748743718593, 0.9733333333333334, 0.9691780821917808]
# Macro-average Specificity: 0.9714
# MCC per class: [0.8933760872875811, 0.8472549708054556, 0.9555768664876327, 0.736390739042166]
# Macro-average MCC: 0.8581
# F1 Score (micro): 0.9114
# F1 Score (weighted): 0.9113
# ---------------------------------------------------------------------------------------------------
# Epoch 7/100, Loss: 0.2300
# Epoch 7/100, Loss: 0.8510
# Accuracy: 0.6522
# Precision: 0.7053
# Recall: 0.6522
# F1 Score: 0.5662
# AUC: 0.9472
# AUPR: 0.8529
# Specificity per class: [1.0, 0.9748743718592965, 0.7911111111111111, 0.7876712328767124]
# Macro-average Specificity: 0.8884
# MCC per class: [0.42034213448195196, 0.6772873037964915, 0.7222705297853826, 0.32757658613177876]
# Macro-average MCC: 0.5369
# F1 Score (micro): 0.6392
# F1 Score (weighted): 0.6328
# ---------------------------------------------------------------------------------------------------
# Epoch 8/100, Loss: 0.5629
# Epoch 8/100, Loss: 1.2503
# Accuracy: 0.4604
# Precision: 0.4433
# Recall: 0.4604
# F1 Score: 0.4117
# AUC: 0.9082
# AUPR: 0.7302
# Specificity per class: [1.0, 0.38190954773869346, 1.0, 0.9828767123287672]
# Macro-average Specificity: 0.8412
# MCC per class: [0.0, 0.43148685324423625, 0.8310872728411407, 0.11917706184459184]
# Macro-average MCC: 0.3454
# F1 Score (micro): 0.5949
# F1 Score (weighted): 0.5009
# ---------------------------------------------------------------------------------------------------
# Epoch 9/100, Loss: 0.4137
# Epoch 9/100, Loss: 0.9957
# Accuracy: 0.5155
# Precision: 0.5691
# Recall: 0.5155
# F1 Score: 0.4424
# AUC: 0.9132
# AUPR: 0.7432
# Specificity per class: [0.8017241379310345, 0.678391959798995, 1.0, 1.0]
# Macro-average Specificity: 0.8700
# MCC per class: [0.690216327144277, 0.6266842827700855, 0.3124096167732361, 0.0]
# Macro-average MCC: 0.4073
# F1 Score (micro): 0.6519
# F1 Score (weighted): 0.5558
# ---------------------------------------------------------------------------------------------------
# Epoch 10/100, Loss: 0.4543
# Epoch 10/100, Loss: 1.5550
# Accuracy: 0.4829
# Precision: 0.3247
# Recall: 0.4829
# F1 Score: 0.3876
# AUC: 0.9292
# AUPR: 0.7588
# Specificity per class: [1.0, 0.5879396984924623, 0.8488888888888889, 1.0]
# Macro-average Specificity: 0.8592
# MCC per class: [0.0, 0.5130816957705527, 0.7861241066848866, 0.0]
# Macro-average MCC: 0.3248
# F1 Score (micro): 0.6329
# F1 Score (weighted): 0.5047
# ---------------------------------------------------------------------------------------------------
# Epoch 11/100, Loss: 0.4037
# Epoch 11/100, Loss: 1.1215
# Accuracy: 0.3179
# Precision: 0.5718
# Recall: 0.3179
# F1 Score: 0.2316
# AUC: 0.9110
# AUPR: 0.8005
# Specificity per class: [1.0, 0.9949748743718593, 0.14222222222222222, 1.0]
# Macro-average Specificity: 0.7843
# MCC per class: [0.13263389489804825, 0.4000301187840945, 0.21347413194067502, 0.0]
# Macro-average MCC: 0.1865
# F1 Score (micro): 0.3861
# F1 Score (weighted): 0.2982
# ---------------------------------------------------------------------------------------------------
# Epoch 12/100, Loss: 0.3573
# Epoch 12/100, Loss: 0.9595
# Accuracy: 0.4930
# Precision: 0.7127
# Recall: 0.4930
# F1 Score: 0.4629
# AUC: 0.9143
# AUPR: 0.8112
# Specificity per class: [0.40948275862068967, 0.9949748743718593, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.8503
# MCC per class: [0.39451299793427047, 0.4316942190025231, 0.7534076177210839, 0.12774912247126896]
# Macro-average MCC: 0.4268
# F1 Score (micro): 0.5601
# F1 Score (weighted): 0.5406
# ---------------------------------------------------------------------------------------------------
# Epoch 13/100, Loss: 0.2832
# Epoch 13/100, Loss: 0.8684
# Accuracy: 0.5114
# Precision: 0.6306
# Recall: 0.5114
# F1 Score: 0.5135
# AUC: 0.9294
# AUPR: 0.7756
# Specificity per class: [1.0, 0.4623115577889447, 1.0, 1.0]
# Macro-average Specificity: 0.8656
# MCC per class: [0.6144318922292533, 0.4914012955919064, 0.7138661631691728, 0.0]
# Macro-average MCC: 0.4549
# F1 Score (micro): 0.6614
# F1 Score (weighted): 0.6342
# ---------------------------------------------------------------------------------------------------
# Epoch 14/100, Loss: 0.2440
# Epoch 14/100, Loss: 1.9132
# Accuracy: 0.2557
# Precision: 0.5965
# Recall: 0.2557
# F1 Score: 0.1506
# AUC: 0.8943
# AUPR: 0.7161
# Specificity per class: [1.0, 0.06532663316582915, 1.0, 0.9623287671232876]
# Macro-average Specificity: 0.7569
# MCC per class: [0.09363734097620714, 0.15882422856379477, 0.08859623899229176, -0.0544453279406137]
# Macro-average MCC: 0.0717
# F1 Score (micro): 0.3766
# F1 Score (weighted): 0.2188
# ---------------------------------------------------------------------------------------------------
# Epoch 15/100, Loss: 0.2441
# Epoch 15/100, Loss: 6.5990
# Accuracy: 0.2500
# Precision: 0.0720
# Recall: 0.2500
# F1 Score: 0.1118
# AUC: 0.8267
# AUPR: 0.6510
# Specificity per class: [1.0, 1.0, 0.0, 1.0]
# Macro-average Specificity: 0.7500
# MCC per class: [0.0, 0.0, 0.0, 0.0]
# Macro-average MCC: 0.0000
# F1 Score (micro): 0.2880
# F1 Score (weighted): 0.1288
# ---------------------------------------------------------------------------------------------------
# Epoch 16/100, Loss: 0.2875
# Epoch 16/100, Loss: 0.4300
# Accuracy: 0.7004
# Precision: 0.6472
# Recall: 0.7004
# F1 Score: 0.6699
# AUC: 0.9774
# AUPR: 0.9160
# Specificity per class: [0.8793103448275862, 0.9346733668341709, 0.9822222222222222, 1.0]
# Macro-average Specificity: 0.9491
# MCC per class: [0.7933669658198799, 0.8164718392216163, 0.9303493253367721, 0.0]
# Macro-average MCC: 0.6350
# F1 Score (micro): 0.8576
# F1 Score (weighted): 0.8257
# ---------------------------------------------------------------------------------------------------
# Epoch 17/100, Loss: 0.2044
# Epoch 17/100, Loss: 0.3419
# Accuracy: 0.8626
# Precision: 0.8596
# Recall: 0.8626
# F1 Score: 0.8556
# AUC: 0.9914
# AUPR: 0.9563
# Specificity per class: [0.9267241379310345, 0.9949748743718593, 0.9466666666666667, 0.9794520547945206]
# Macro-average Specificity: 0.9620
# MCC per class: [0.8509907844378062, 0.8213760786222203, 0.9145356223410569, 0.7013782005037644]
# Macro-average MCC: 0.8221
# F1 Score (micro): 0.8861
# F1 Score (weighted): 0.8841
# ---------------------------------------------------------------------------------------------------
# Epoch 18/100, Loss: 0.1739
# Epoch 18/100, Loss: 0.4704
# Accuracy: 0.7024
# Precision: 0.6578
# Recall: 0.7024
# F1 Score: 0.6784
# AUC: 0.9891
# AUPR: 0.9623
# Specificity per class: [0.9568965517241379, 0.8793969849246231, 0.9688888888888889, 1.0]
# Macro-average Specificity: 0.9513
# MCC per class: [0.8203783880097956, 0.8311964368521443, 0.9323395316390924, 0.0]
# Macro-average MCC: 0.6460
# F1 Score (micro): 0.8703
# F1 Score (weighted): 0.8358
# ---------------------------------------------------------------------------------------------------
# Epoch 19/100, Loss: 0.1761
# Epoch 19/100, Loss: 0.3662
# Accuracy: 0.8867
# Precision: 0.8815
# Recall: 0.8867
# F1 Score: 0.8648
# AUC: 0.9952
# AUPR: 0.9886
# Specificity per class: [1.0, 0.8693467336683417, 0.9733333333333334, 0.976027397260274]
# Macro-average Specificity: 0.9547
# MCC per class: [0.7119455154566089, 0.8201439860244281, 0.9475354926457952, 0.8692721748727231]
# Macro-average MCC: 0.8372
# F1 Score (micro): 0.8766
# F1 Score (weighted): 0.8678
# ---------------------------------------------------------------------------------------------------
# Epoch 20/100, Loss: 0.1443
# Epoch 20/100, Loss: 0.2399
# Accuracy: 0.8750
# Precision: 0.9103
# Recall: 0.8750
# F1 Score: 0.8897
# AUC: 0.9922
# AUPR: 0.9532
# Specificity per class: [0.9612068965517241, 0.9396984924623115, 1.0, 0.9897260273972602]
# Macro-average Specificity: 0.9727
# MCC per class: [0.8800109784954518, 0.8798423168138997, 0.96919786333672, 0.7314855645067136]
# Macro-average MCC: 0.8651
# F1 Score (micro): 0.9241
# F1 Score (weighted): 0.9230
# ---------------------------------------------------------------------------------------------------
# Epoch 21/100, Loss: 0.1567
# Epoch 21/100, Loss: 1.1661
# Accuracy: 0.4689
# Precision: 0.6234
# Recall: 0.4689
# F1 Score: 0.4279
# AUC: 0.8748
# AUPR: 0.7164
# Specificity per class: [1.0, 0.3969849246231156, 1.0, 1.0]
# Macro-average Specificity: 0.8492
# MCC per class: [0.2678391047317406, 0.4426961706379302, 0.84647998770768, 0.0]
# Macro-average MCC: 0.3893
# F1 Score (micro): 0.6203
# F1 Score (weighted): 0.5434
# ---------------------------------------------------------------------------------------------------
# Epoch 22/100, Loss: 0.1661
# Epoch 22/100, Loss: 0.6221
# Accuracy: 0.6645
# Precision: 0.8664
# Recall: 0.6645
# F1 Score: 0.6849
# AUC: 0.9692
# AUPR: 0.9105
# Specificity per class: [0.6681034482758621, 0.9748743718592965, 1.0, 1.0]
# Macro-average Specificity: 0.9107
# MCC per class: [0.5904030082443077, 0.7437618363043738, 0.7534076177210839, 0.5249955051947106]
# Macro-average MCC: 0.6531
# F1 Score (micro): 0.7405
# F1 Score (weighted): 0.7451
# ---------------------------------------------------------------------------------------------------
# Epoch 23/100, Loss: 0.1540
# Epoch 23/100, Loss: 0.1704
# Accuracy: 0.9508
# Precision: 0.9172
# Recall: 0.9508
# F1 Score: 0.9318
# AUC: 0.9959
# AUPR: 0.9859
# Specificity per class: [0.9741379310344828, 0.9698492462311558, 0.9866666666666667, 0.9828767123287672]
# Macro-average Specificity: 0.9784
# MCC per class: [0.8942296767197464, 0.8772895501384894, 0.9694477535121453, 0.9018953432650142]
# Macro-average MCC: 0.9107
# F1 Score (micro): 0.9367
# F1 Score (weighted): 0.9367
# ---------------------------------------------------------------------------------------------------
# Epoch 24/100, Loss: 0.1159
# Epoch 24/100, Loss: 0.1749
# Accuracy: 0.9460
# Precision: 0.9526
# Recall: 0.9460
# F1 Score: 0.9491
# AUC: 0.9960
# AUPR: 0.9884
# Specificity per class: [0.9655172413793104, 0.9748743718592965, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9831
# MCC per class: [0.8960480874461186, 0.925242961141528, 0.9768030891848316, 0.9312905566854962]
# Macro-average MCC: 0.9323
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9527
# ---------------------------------------------------------------------------------------------------
# Epoch 25/100, Loss: 0.1262
# Epoch 25/100, Loss: 0.5537
# Accuracy: 0.7658
# Precision: 0.7834
# Recall: 0.7658
# F1 Score: 0.7524
# AUC: 0.9746
# AUPR: 0.9303
# Specificity per class: [0.7931034482758621, 0.9346733668341709, 1.0, 0.9657534246575342]
# Macro-average Specificity: 0.9234
# MCC per class: [0.680749080797368, 0.7391247483912774, 0.7218245586321419, 0.6388251989799978]
# Macro-average MCC: 0.6951
# F1 Score (micro): 0.7753
# F1 Score (weighted): 0.7767
# ---------------------------------------------------------------------------------------------------
# Epoch 26/100, Loss: 0.1188
# Epoch 26/100, Loss: 0.1618
# Accuracy: 0.9519
# Precision: 0.9230
# Recall: 0.9519
# F1 Score: 0.9352
# AUC: 0.9967
# AUPR: 0.9898
# Specificity per class: [0.9568965517241379, 0.9949748743718593, 0.9955555555555555, 0.9828767123287672]
# Macro-average Specificity: 0.9826
# MCC per class: [0.9073772042004405, 0.9193034230536933, 0.9690466897894506, 0.8774216391143502]
# Macro-average MCC: 0.9183
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9469
# ---------------------------------------------------------------------------------------------------
# Epoch 27/100, Loss: 0.1047
# Epoch 27/100, Loss: 0.1533
# Accuracy: 0.9605
# Precision: 0.9159
# Recall: 0.9605
# F1 Score: 0.9338
# AUC: 0.9970
# AUPR: 0.9874
# Specificity per class: [0.9655172413793104, 0.9949748743718593, 0.9955555555555555, 0.976027397260274]
# Macro-average Specificity: 0.9830
# MCC per class: [0.9132015205357783, 0.90608495842879, 0.9845665445665446, 0.8692721748727231]
# Macro-average MCC: 0.9183
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9469
# ---------------------------------------------------------------------------------------------------
# Epoch 28/100, Loss: 0.0860
# Epoch 28/100, Loss: 0.1411
# Accuracy: 0.9602
# Precision: 0.9503
# Recall: 0.9602
# F1 Score: 0.9548
# AUC: 0.9969
# AUPR: 0.9882
# Specificity per class: [0.9655172413793104, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9860
# MCC per class: [0.9132015205357783, 0.9389331631730534, 0.9768030891848316, 0.9338605850305136]
# Macro-average MCC: 0.9407
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9591
# ---------------------------------------------------------------------------------------------------
# Epoch 29/100, Loss: 0.1042
# Epoch 29/100, Loss: 0.1289
# Accuracy: 0.9728
# Precision: 0.9563
# Recall: 0.9728
# F1 Score: 0.9640
# AUC: 0.9975
# AUPR: 0.9916
# Specificity per class: [0.9741379310344828, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9882
# MCC per class: [0.9281223053474523, 0.9456797751166062, 0.9768030891848316, 0.9574729648393807]
# Macro-average MCC: 0.9520
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9653
# ---------------------------------------------------------------------------------------------------
# Epoch 30/100, Loss: 0.0827
# Epoch 30/100, Loss: 0.1555
# Accuracy: 0.9602
# Precision: 0.9503
# Recall: 0.9602
# F1 Score: 0.9548
# AUC: 0.9965
# AUPR: 0.9886
# Specificity per class: [0.9655172413793104, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9860
# MCC per class: [0.9132015205357783, 0.9389331631730534, 0.9768030891848316, 0.9338605850305136]
# Macro-average MCC: 0.9407
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9591
# ---------------------------------------------------------------------------------------------------
# Epoch 31/100, Loss: 0.0873
# Epoch 31/100, Loss: 0.1311
# Accuracy: 0.9609
# Precision: 0.9355
# Recall: 0.9609
# F1 Score: 0.9468
# AUC: 0.9975
# AUPR: 0.9917
# Specificity per class: [0.978448275862069, 0.9748743718592965, 0.9955555555555555, 0.9863013698630136]
# Macro-average Specificity: 0.9838
# MCC per class: [0.9020852622568629, 0.925242961141528, 0.9768030891848316, 0.9194569996298345]
# Macro-average MCC: 0.9309
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9527
# ---------------------------------------------------------------------------------------------------
# Epoch 32/100, Loss: 0.0701
# Epoch 32/100, Loss: 0.2118
# Accuracy: 0.8873
# Precision: 0.9131
# Recall: 0.8873
# F1 Score: 0.8978
# AUC: 0.9900
# AUPR: 0.9603
# Specificity per class: [0.9482758620689655, 0.9597989949748744, 1.0, 0.9897260273972602]
# Macro-average Specificity: 0.9745
# MCC per class: [0.8846101301702942, 0.891422926598806, 0.9615145720873706, 0.7595013469791785]
# Macro-average MCC: 0.8743
# F1 Score (micro): 0.9272
# F1 Score (weighted): 0.9268
# ---------------------------------------------------------------------------------------------------
# Epoch 33/100, Loss: 0.0712
# Epoch 33/100, Loss: 0.1270
# Accuracy: 0.9394
# Precision: 0.9438
# Recall: 0.9394
# F1 Score: 0.9411
# AUC: 0.9974
# AUPR: 0.9879
# Specificity per class: [0.9612068965517241, 0.9849246231155779, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9837
# MCC per class: [0.9059017880597403, 0.9320062537742658, 0.9768030891848316, 0.8853080854491499]
# Macro-average MCC: 0.9250
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9527
# ---------------------------------------------------------------------------------------------------
# Epoch 34/100, Loss: 0.0790
# Epoch 34/100, Loss: 0.1448
# Accuracy: 0.9556
# Precision: 0.9555
# Recall: 0.9556
# F1 Score: 0.9547
# AUC: 0.9964
# AUPR: 0.9899
# Specificity per class: [0.9870689655172413, 0.9447236180904522, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9810
# MCC per class: [0.8932432189394343, 0.9076163683387666, 0.9690466897894506, 0.9781167255328594]
# Macro-average MCC: 0.9370
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9492
# ---------------------------------------------------------------------------------------------------
# Epoch 35/100, Loss: 0.0660
# Epoch 35/100, Loss: 0.1201
# Accuracy: 0.9747
# Precision: 0.9596
# Recall: 0.9747
# F1 Score: 0.9667
# AUC: 0.9976
# AUPR: 0.9893
# Specificity per class: [0.9827586206896551, 0.9849246231155779, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9891
# MCC per class: [0.9351395730706076, 0.945607302219665, 0.9845665445665446, 0.9574729648393807]
# Macro-average MCC: 0.9557
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9684
# ---------------------------------------------------------------------------------------------------
# Epoch 36/100, Loss: 0.0612
# Epoch 36/100, Loss: 0.1405
# Accuracy: 0.9575
# Precision: 0.9537
# Recall: 0.9575
# F1 Score: 0.9552
# AUC: 0.9971
# AUPR: 0.9922
# Specificity per class: [0.9913793103448276, 0.964824120603015, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9851
# MCC per class: [0.9264111117062016, 0.9259354233325153, 0.9769542224975036, 0.9338605850305136]
# Macro-average MCC: 0.9408
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9588
# ---------------------------------------------------------------------------------------------------
# Epoch 37/100, Loss: 0.0638
# Epoch 37/100, Loss: 0.1303
# Accuracy: 0.9642
# Precision: 0.9254
# Recall: 0.9642
# F1 Score: 0.9416
# AUC: 0.9978
# AUPR: 0.9910
# Specificity per class: [0.9741379310344828, 0.9899497487437185, 0.9955555555555555, 0.9794520547945206]
# Macro-average Specificity: 0.9848
# MCC per class: [0.9281223053474523, 0.918797603624423, 0.9768030891848316, 0.8851901738245949]
# Macro-average MCC: 0.9272
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9531
# ---------------------------------------------------------------------------------------------------
# Epoch 38/100, Loss: 0.0581
# Epoch 38/100, Loss: 0.1173
# Accuracy: 0.9670
# Precision: 0.9323
# Recall: 0.9670
# F1 Score: 0.9473
# AUC: 0.9982
# AUPR: 0.9922
# Specificity per class: [0.978448275862069, 0.9899497487437185, 0.9911111111111112, 0.9828767123287672]
# Macro-average Specificity: 0.9856
# MCC per class: [0.9357496161555404, 0.918797603624423, 0.9769542224975036, 0.9018953432650142]
# Macro-average MCC: 0.9333
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9559
# ---------------------------------------------------------------------------------------------------
# Epoch 39/100, Loss: 0.0588
# Epoch 39/100, Loss: 0.1989
# Accuracy: 0.8984
# Precision: 0.9558
# Recall: 0.8984
# F1 Score: 0.9210
# AUC: 0.9966
# AUPR: 0.9910
# Specificity per class: [0.9956896551724138, 0.9045226130653267, 0.9911111111111112, 1.0]
# Macro-average Specificity: 0.9728
# MCC per class: [0.8692645322157679, 0.8746000187464837, 0.9769542224975036, 0.8822351982354886]
# Macro-average MCC: 0.9008
# F1 Score (micro): 0.9304
# F1 Score (weighted): 0.9294
# ---------------------------------------------------------------------------------------------------
# Epoch 40/100, Loss: 0.0526
# Epoch 40/100, Loss: 0.1230
# Accuracy: 0.9602
# Precision: 0.9503
# Recall: 0.9602
# F1 Score: 0.9548
# AUC: 0.9978
# AUPR: 0.9881
# Specificity per class: [0.9655172413793104, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9860
# MCC per class: [0.9132015205357783, 0.9389331631730534, 0.9768030891848316, 0.9338605850305136]
# Macro-average MCC: 0.9407
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9591
# ---------------------------------------------------------------------------------------------------
# Epoch 41/100, Loss: 0.0499
# Epoch 41/100, Loss: 0.1203
# Accuracy: 0.9700
# Precision: 0.9541
# Recall: 0.9700
# F1 Score: 0.9615
# AUC: 0.9980
# AUPR: 0.9925
# Specificity per class: [0.9741379310344828, 0.9849246231155779, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9869
# MCC per class: [0.9281223053474523, 0.9387976740971787, 0.9690466897894506, 0.9574729648393807]
# Macro-average MCC: 0.9484
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9621
# ---------------------------------------------------------------------------------------------------
# Epoch 42/100, Loss: 0.0473
# Epoch 42/100, Loss: 0.9896
# Accuracy: 0.5101
# Precision: 0.5676
# Recall: 0.5101
# F1 Score: 0.4490
# AUC: 0.9218
# AUPR: 0.7575
# Specificity per class: [0.8275862068965517, 0.6432160804020101, 1.0, 1.0]
# Macro-average Specificity: 0.8677
# MCC per class: [0.6615101670294722, 0.6143987572207795, 0.3510208751301218, 0.0]
# Macro-average MCC: 0.4067
# F1 Score (micro): 0.6487
# F1 Score (weighted): 0.5629
# ---------------------------------------------------------------------------------------------------
# Epoch 43/100, Loss: 0.0446
# Epoch 43/100, Loss: 0.1368
# Accuracy: 0.9704
# Precision: 0.9542
# Recall: 0.9704
# F1 Score: 0.9618
# AUC: 0.9975
# AUPR: 0.9899
# Specificity per class: [0.9827586206896551, 0.9849246231155779, 0.9866666666666667, 0.9931506849315068]
# Macro-average Specificity: 0.9869
# MCC per class: [0.9351395730706076, 0.9320062537742658, 0.9694477535121453, 0.9574729648393807]
# Macro-average MCC: 0.9485
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9619
# ---------------------------------------------------------------------------------------------------
# Epoch 44/100, Loss: 0.0473
# Epoch 44/100, Loss: 0.1453
# Accuracy: 0.9591
# Precision: 0.9160
# Recall: 0.9591
# F1 Score: 0.9335
# AUC: 0.9971
# AUPR: 0.9871
# Specificity per class: [0.9741379310344828, 0.9899497487437185, 0.9911111111111112, 0.976027397260274]
# Macro-average Specificity: 0.9828
# MCC per class: [0.9196546412641213, 0.9121185533761437, 0.9691330891330892, 0.8692721748727231]
# Macro-average MCC: 0.9175
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9470
# ---------------------------------------------------------------------------------------------------
# Epoch 45/100, Loss: 0.0527
# Epoch 45/100, Loss: 0.1320
# Accuracy: 0.9602
# Precision: 0.9507
# Recall: 0.9602
# F1 Score: 0.9551
# AUC: 0.9973
# AUPR: 0.9875
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9859
# MCC per class: [0.9206073369943373, 0.9320062537742658, 0.9768030891848316, 0.9338605850305136]
# Macro-average MCC: 0.9408
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9590
# ---------------------------------------------------------------------------------------------------
# Epoch 46/100, Loss: 0.0490
# Epoch 46/100, Loss: 0.1346
# Accuracy: 0.9608
# Precision: 0.9337
# Recall: 0.9608
# F1 Score: 0.9457
# AUC: 0.9969
# AUPR: 0.9864
# Specificity per class: [0.9827586206896551, 0.9899497487437185, 0.9911111111111112, 0.9828767123287672]
# Macro-average Specificity: 0.9867
# MCC per class: [0.9434925890878169, 0.9322043221572608, 0.9769542224975036, 0.8774216391143502]
# Macro-average MCC: 0.9325
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9593
# ---------------------------------------------------------------------------------------------------
# Epoch 47/100, Loss: 0.0432
# Epoch 47/100, Loss: 0.1246
# Accuracy: 0.9511
# Precision: 0.9510
# Recall: 0.9511
# F1 Score: 0.9510
# AUC: 0.9972
# AUPR: 0.9871
# Specificity per class: [0.978448275862069, 0.9748743718592965, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9855
# MCC per class: [0.9273382946495989, 0.9321393291242538, 0.9768030891848316, 0.9098173515981736]
# Macro-average MCC: 0.9365
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9589
# ---------------------------------------------------------------------------------------------------
# Epoch 48/100, Loss: 0.0327
# Epoch 48/100, Loss: 0.1429
# Accuracy: 0.9488
# Precision: 0.9350
# Recall: 0.9488
# F1 Score: 0.9414
# AUC: 0.9966
# AUPR: 0.9860
# Specificity per class: [0.9698275862068966, 0.9698492462311558, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9812
# MCC per class: [0.9035596663727024, 0.9116465709015391, 0.9612965996570492, 0.9140014911483973]
# Macro-average MCC: 0.9226
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9465
# ---------------------------------------------------------------------------------------------------
# Epoch 49/100, Loss: 0.0387
# Epoch 49/100, Loss: 0.1137
# Accuracy: 0.9524
# Precision: 0.9618
# Recall: 0.9524
# F1 Score: 0.9569
# AUC: 0.9976
# AUPR: 0.9912
# Specificity per class: [0.9827586206896551, 0.9698492462311558, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9862
# MCC per class: [0.9267845820012487, 0.9394390043632093, 0.9768030891848316, 0.9312905566854962]
# Macro-average MCC: 0.9436
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9620
# ---------------------------------------------------------------------------------------------------
# Epoch 50/100, Loss: 0.0343
# Epoch 50/100, Loss: 0.1291
# Accuracy: 0.9538
# Precision: 0.9306
# Recall: 0.9538
# F1 Score: 0.9408
# AUC: 0.9979
# AUPR: 0.9892
# Specificity per class: [0.9612068965517241, 0.9899497487437185, 0.9955555555555555, 0.9863013698630136]
# Macro-average Specificity: 0.9833
# MCC per class: [0.9059017880597403, 0.918797603624423, 0.9768030891848316, 0.8952207487823]
# Macro-average MCC: 0.9242
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9498
# ---------------------------------------------------------------------------------------------------
# Epoch 51/100, Loss: 0.0413
# Epoch 51/100, Loss: 0.1258
# Accuracy: 0.9428
# Precision: 0.9585
# Recall: 0.9428
# F1 Score: 0.9502
# AUC: 0.9971
# AUPR: 0.9913
# Specificity per class: [0.978448275862069, 0.9698492462311558, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9851
# MCC per class: [0.9273382946495989, 0.9324627709882455, 0.9768030891848316, 0.9072291086054585]
# Macro-average MCC: 0.9360
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9588
# ---------------------------------------------------------------------------------------------------
# Epoch 52/100, Loss: 0.0428
# Epoch 52/100, Loss: 0.1564
# Accuracy: 0.9461
# Precision: 0.9159
# Recall: 0.9461
# F1 Score: 0.9279
# AUC: 0.9977
# AUPR: 0.9911
# Specificity per class: [0.9439655172413793, 0.9949748743718593, 0.9955555555555555, 0.9828767123287672]
# Macro-average Specificity: 0.9793
# MCC per class: [0.8865171778142027, 0.8929246233267382, 0.9768030891848316, 0.8774216391143502]
# Macro-average MCC: 0.9084
# F1 Score (micro): 0.9367
# F1 Score (weighted): 0.9373
# ---------------------------------------------------------------------------------------------------
# Epoch 53/100, Loss: 0.0326
# Epoch 53/100, Loss: 0.1092
# Accuracy: 0.9741
# Precision: 0.9668
# Recall: 0.9741
# F1 Score: 0.9703
# AUC: 0.9979
# AUPR: 0.9923
# Specificity per class: [0.9827586206896551, 0.9798994974874372, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9887
# MCC per class: [0.9351395730706076, 0.945711463299403, 0.9768030891848316, 0.9781167255328594]
# Macro-average MCC: 0.9589
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9684
# ---------------------------------------------------------------------------------------------------
# Epoch 54/100, Loss: 0.0284
# Epoch 54/100, Loss: 0.1142
# Accuracy: 0.9706
# Precision: 0.9541
# Recall: 0.9706
# F1 Score: 0.9619
# AUC: 0.9980
# AUPR: 0.9936
# Specificity per class: [0.978448275862069, 0.9849246231155779, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9869
# MCC per class: [0.9357496161555404, 0.9320062537742658, 0.9691330891330892, 0.9574729648393807]
# Macro-average MCC: 0.9486
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9620
# ---------------------------------------------------------------------------------------------------
# Epoch 55/100, Loss: 0.0355
# Epoch 55/100, Loss: 0.1257
# Accuracy: 0.9449
# Precision: 0.9615
# Recall: 0.9449
# F1 Score: 0.9527
# AUC: 0.9974
# AUPR: 0.9922
# Specificity per class: [0.9827586206896551, 0.9698492462311558, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9862
# MCC per class: [0.9351395730706076, 0.9394390043632093, 0.9768030891848316, 0.9072291086054585]
# Macro-average MCC: 0.9397
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9619
# ---------------------------------------------------------------------------------------------------
# Epoch 56/100, Loss: 0.0440
# Epoch 56/100, Loss: 0.1240
# Accuracy: 0.9602
# Precision: 0.9576
# Recall: 0.9602
# F1 Score: 0.9587
# AUC: 0.9975
# AUPR: 0.9891
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 0.9911111111111112, 0.9965753424657534]
# Macro-average Specificity: 0.9856
# MCC per class: [0.9206073369943373, 0.9320062537742658, 0.9691330891330892, 0.9549086757990868]
# Macro-average MCC: 0.9442
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9590
# ---------------------------------------------------------------------------------------------------
# Epoch 57/100, Loss: 0.0272
# Epoch 57/100, Loss: 0.1178
# Accuracy: 0.9653
# Precision: 0.9626
# Recall: 0.9653
# F1 Score: 0.9638
# AUC: 0.9975
# AUPR: 0.9874
# Specificity per class: [0.9741379310344828, 0.9899497487437185, 0.9911111111111112, 0.9965753424657534]
# Macro-average Specificity: 0.9879
# MCC per class: [0.9365879961071812, 0.9456797751166062, 0.9691330891330892, 0.9549086757990868]
# Macro-average MCC: 0.9516
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9653
# ---------------------------------------------------------------------------------------------------
# Epoch 58/100, Loss: 0.0311
# Epoch 58/100, Loss: 0.1099
# Accuracy: 0.9711
# Precision: 0.9583
# Recall: 0.9711
# F1 Score: 0.9642
# AUC: 0.9980
# AUPR: 0.9941
# Specificity per class: [0.9870689655172413, 0.9748743718592965, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9877
# MCC per class: [0.9347680119556898, 0.939054302314074, 0.9768030891848316, 0.9574729648393807]
# Macro-average MCC: 0.9520
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9652
# ---------------------------------------------------------------------------------------------------
# Epoch 59/100, Loss: 0.0228
# Epoch 59/100, Loss: 0.1189
# Accuracy: 0.9615
# Precision: 0.9607
# Recall: 0.9615
# F1 Score: 0.9611
# AUC: 0.9978
# AUPR: 0.9929
# Specificity per class: [0.9741379310344828, 0.9798994974874372, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9865
# MCC per class: [0.9196546412641213, 0.9388393513815171, 0.9768030891848316, 0.9549086757990868]
# Macro-average MCC: 0.9476
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9621
# ---------------------------------------------------------------------------------------------------
# Epoch 60/100, Loss: 0.0320
# Epoch 60/100, Loss: 0.1327
# Accuracy: 0.9575
# Precision: 0.9418
# Recall: 0.9575
# F1 Score: 0.9490
# AUC: 0.9974
# AUPR: 0.9885
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9850
# MCC per class: [0.9206073369943373, 0.9320062537742658, 0.9690466897894506, 0.9140014911483973]
# Macro-average MCC: 0.9339
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9560
# ---------------------------------------------------------------------------------------------------
# Epoch 61/100, Loss: 0.0327
# Epoch 61/100, Loss: 0.1428
# Accuracy: 0.9309
# Precision: 0.9422
# Recall: 0.9309
# F1 Score: 0.9361
# AUC: 0.9964
# AUPR: 0.9878
# Specificity per class: [0.9870689655172413, 0.9547738693467337, 0.9866666666666667, 0.9931506849315068]
# Macro-average Specificity: 0.9804
# MCC per class: [0.9098680561400194, 0.913067694156093, 0.9615706499287768, 0.8853080854491499]
# Macro-average MCC: 0.9175
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9460
# ---------------------------------------------------------------------------------------------------
# Epoch 62/100, Loss: 0.0340
# Epoch 62/100, Loss: 0.1513
# Accuracy: 0.9462
# Precision: 0.9332
# Recall: 0.9462
# F1 Score: 0.9393
# AUC: 0.9961
# AUPR: 0.9842
# Specificity per class: [0.978448275862069, 0.9748743718592965, 0.9955555555555555, 0.9863013698630136]
# Macro-average Specificity: 0.9838
# MCC per class: [0.9273382946495989, 0.925242961141528, 0.9690466897894506, 0.870530017457414]
# Macro-average MCC: 0.9230
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9529
# ---------------------------------------------------------------------------------------------------
# Epoch 63/100, Loss: 0.0348
# Epoch 63/100, Loss: 0.1627
# Accuracy: 0.8970
# Precision: 0.9277
# Recall: 0.8970
# F1 Score: 0.9084
# AUC: 0.9963
# AUPR: 0.9831
# Specificity per class: [0.9396551724137931, 0.9849246231155779, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9783
# MCC per class: [0.8797493707395952, 0.9117352234683014, 0.9845665445665446, 0.7817354424163053]
# Macro-average MCC: 0.8894
# F1 Score (micro): 0.9367
# F1 Score (weighted): 0.9361
# ---------------------------------------------------------------------------------------------------
# Epoch 64/100, Loss: 0.0296
# Epoch 64/100, Loss: 0.1120
# Accuracy: 0.9532
# Precision: 0.9539
# Recall: 0.9532
# F1 Score: 0.9535
# AUC: 0.9977
# AUPR: 0.9929
# Specificity per class: [0.9827586206896551, 0.9748743718592965, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9866
# MCC per class: [0.9351395730706076, 0.939054302314074, 0.9768030891848316, 0.9098173515981736]
# Macro-average MCC: 0.9402
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9621
# ---------------------------------------------------------------------------------------------------
# Epoch 65/100, Loss: 0.0278
# Epoch 65/100, Loss: 0.1128
# Accuracy: 0.9591
# Precision: 0.9396
# Recall: 0.9591
# F1 Score: 0.9484
# AUC: 0.9980
# AUPR: 0.9932
# Specificity per class: [0.9913793103448276, 0.9849246231155779, 0.9822222222222222, 0.9863013698630136]
# Macro-average Specificity: 0.9862
# MCC per class: [0.9428785766150074, 0.9387976740971787, 0.9620442890220036, 0.8952207487823]
# Macro-average MCC: 0.9347
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9591
# ---------------------------------------------------------------------------------------------------
# Epoch 66/100, Loss: 0.0292
# Epoch 66/100, Loss: 0.1210
# Accuracy: 0.9615
# Precision: 0.9607
# Recall: 0.9615
# F1 Score: 0.9611
# AUC: 0.9974
# AUPR: 0.9897
# Specificity per class: [0.9741379310344828, 0.9798994974874372, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9865
# MCC per class: [0.9196546412641213, 0.9388393513815171, 0.9768030891848316, 0.9549086757990868]
# Macro-average MCC: 0.9476
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9621
# ---------------------------------------------------------------------------------------------------
# Epoch 67/100, Loss: 0.0446
# Epoch 67/100, Loss: 0.1895
# Accuracy: 0.9470
# Precision: 0.9026
# Recall: 0.9470
# F1 Score: 0.9195
# AUC: 0.9976
# AUPR: 0.9912
# Specificity per class: [0.9612068965517241, 0.9949748743718593, 1.0, 0.9691780821917808]
# Macro-average Specificity: 0.9813
# MCC per class: [0.9145246423032853, 0.9126866390039042, 0.96919786333672, 0.8144832377911422]
# Macro-average MCC: 0.9027
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9417
# ---------------------------------------------------------------------------------------------------
# Epoch 68/100, Loss: 0.0333
# Epoch 68/100, Loss: 0.1135
# Accuracy: 0.9636
# Precision: 0.9568
# Recall: 0.9636
# F1 Score: 0.9601
# AUC: 0.9975
# AUPR: 0.9897
# Specificity per class: [0.9827586206896551, 0.9798994974874372, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9878
# MCC per class: [0.9351395730706076, 0.945711463299403, 0.9768030891848316, 0.9338605850305136]
# Macro-average MCC: 0.9479
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9653
# ---------------------------------------------------------------------------------------------------
# Epoch 69/100, Loss: 0.0288
# Epoch 69/100, Loss: 0.1694
# Accuracy: 0.9565
# Precision: 0.9044
# Recall: 0.9565
# F1 Score: 0.9238
# AUC: 0.9979
# AUPR: 0.9922
# Specificity per class: [0.9655172413793104, 0.9949748743718593, 0.9955555555555555, 0.9691780821917808]
# Macro-average Specificity: 0.9813
# MCC per class: [0.9217736534970257, 0.8929246233267382, 0.9768030891848316, 0.8395574947843465]
# Macro-average MCC: 0.9078
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9410
# ---------------------------------------------------------------------------------------------------
# Epoch 70/100, Loss: 0.0350
# Epoch 70/100, Loss: 1.1048
# Accuracy: 0.6425
# Precision: 0.7607
# Recall: 0.6425
# F1 Score: 0.5129
# AUC: 0.9809
# AUPR: 0.9093
# Specificity per class: [0.9568965517241379, 1.0, 1.0, 0.5445205479452054]
# Macro-average Specificity: 0.8754
# MCC per class: [0.8987051882323505, 0.6183548210277544, 0.2842561369430512, 0.28851136871356403]
# Macro-average MCC: 0.5225
# F1 Score (micro): 0.5475
# F1 Score (weighted): 0.5687
# ---------------------------------------------------------------------------------------------------
# Epoch 71/100, Loss: 0.0341
# Epoch 71/100, Loss: 0.6859
# Accuracy: 0.6570
# Precision: 0.8412
# Recall: 0.6570
# F1 Score: 0.6787
# AUC: 0.9633
# AUPR: 0.9150
# Specificity per class: [0.6077586206896551, 0.9899497487437185, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.8986
# MCC per class: [0.5401149302982047, 0.7421264093648461, 0.6654628023775665, 0.5972487489243078]
# Macro-average MCC: 0.6362
# F1 Score (micro): 0.7025
# F1 Score (weighted): 0.7124
# ---------------------------------------------------------------------------------------------------
# Epoch 72/100, Loss: 0.0353
# Epoch 72/100, Loss: 0.1201
# Accuracy: 0.9383
# Precision: 0.9594
# Recall: 0.9383
# F1 Score: 0.9476
# AUC: 0.9975
# AUPR: 0.9875
# Specificity per class: [0.9655172413793104, 0.9849246231155779, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9868
# MCC per class: [0.9217736534970257, 0.952435741621506, 0.9845836908536074, 0.882686929807428]
# Macro-average MCC: 0.9354
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9620
# ---------------------------------------------------------------------------------------------------
# Epoch 73/100, Loss: 0.0295
# Epoch 73/100, Loss: 0.1068
# Accuracy: 0.9696
# Precision: 0.9619
# Recall: 0.9696
# F1 Score: 0.9656
# AUC: 0.9981
# AUPR: 0.9906
# Specificity per class: [0.9827586206896551, 0.9849246231155779, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9902
# MCC per class: [0.9518445910469595, 0.952435741621506, 0.9845836908536074, 0.9338605850305136]
# Macro-average MCC: 0.9557
# F1 Score (micro): 0.9715
# F1 Score (weighted): 0.9716
# ---------------------------------------------------------------------------------------------------
# Epoch 74/100, Loss: 0.0280
# Epoch 74/100, Loss: 0.1106
# Accuracy: 0.9734
# Precision: 0.9371
# Recall: 0.9734
# F1 Score: 0.9523
# AUC: 0.9983
# AUPR: 0.9917
# Specificity per class: [0.9956896551724138, 0.9899497487437185, 0.9911111111111112, 0.9794520547945206]
# Macro-average Specificity: 0.9891
# MCC per class: [0.9674507616545168, 0.9389331631730534, 0.9769542224975036, 0.8851901738245949]
# Macro-average MCC: 0.9421
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9659
# ---------------------------------------------------------------------------------------------------
# Epoch 75/100, Loss: 0.0216
# Epoch 75/100, Loss: 2.3802
# Accuracy: 0.3209
# Precision: 0.8232
# Recall: 0.3209
# F1 Score: 0.2324
# AUC: 0.9264
# AUPR: 0.8384
# Specificity per class: [0.125, 1.0, 1.0, 1.0]
# Macro-average Specificity: 0.7812
# MCC per class: [0.19127301391900148, 0.3986268685834756, 0.08859623899229176, 0.1965307574511904]
# Macro-average MCC: 0.2188
# F1 Score (micro): 0.3576
# F1 Score (weighted): 0.2716
# ---------------------------------------------------------------------------------------------------
# Epoch 76/100, Loss: 0.0297
# Epoch 76/100, Loss: 0.1187
# Accuracy: 0.9619
# Precision: 0.9340
# Recall: 0.9619
# F1 Score: 0.9461
# AUC: 0.9981
# AUPR: 0.9886
# Specificity per class: [0.9741379310344828, 0.9899497487437185, 1.0, 0.9828767123287672]
# Macro-average Specificity: 0.9867
# MCC per class: [0.9450526993977326, 0.9254926645253152, 0.9845836908536074, 0.8774216391143502]
# Macro-average MCC: 0.9331
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9593
# ---------------------------------------------------------------------------------------------------
# Epoch 77/100, Loss: 0.0298
# Epoch 77/100, Loss: 0.1068
# Accuracy: 0.9458
# Precision: 0.9607
# Recall: 0.9458
# F1 Score: 0.9528
# AUC: 0.9980
# AUPR: 0.9904
# Specificity per class: [0.978448275862069, 0.9748743718592965, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9864
# MCC per class: [0.9357496161555404, 0.939054302314074, 0.9768030891848316, 0.9072291086054585]
# Macro-average MCC: 0.9397
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9619
# ---------------------------------------------------------------------------------------------------
# Epoch 78/100, Loss: 0.0289
# Epoch 78/100, Loss: 0.1155
# Accuracy: 0.9557
# Precision: 0.9520
# Recall: 0.9557
# F1 Score: 0.9534
# AUC: 0.9981
# AUPR: 0.9901
# Specificity per class: [0.9698275862068966, 0.9949748743718593, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9873
# MCC per class: [0.937645518934311, 0.9459330151619536, 0.9691330891330892, 0.9098173515981736]
# Macro-average MCC: 0.9406
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9621
# ---------------------------------------------------------------------------------------------------
# Epoch 79/100, Loss: 0.0310
# Epoch 79/100, Loss: 0.0982
# Accuracy: 0.9664
# Precision: 0.9477
# Recall: 0.9664
# F1 Score: 0.9562
# AUC: 0.9984
# AUPR: 0.9925
# Specificity per class: [0.9913793103448276, 0.9849246231155779, 0.9955555555555555, 0.9863013698630136]
# Macro-average Specificity: 0.9895
# MCC per class: [0.9511093868051034, 0.952435741621506, 0.9845665445665446, 0.8952207487823]
# Macro-average MCC: 0.9458
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9687
# ---------------------------------------------------------------------------------------------------
# Epoch 80/100, Loss: 0.0242
# Epoch 80/100, Loss: 0.1017
# Accuracy: 0.9464
# Precision: 0.9390
# Recall: 0.9464
# F1 Score: 0.9425
# AUC: 0.9981
# AUPR: 0.9907
# Specificity per class: [0.9913793103448276, 0.9899497487437185, 0.9822222222222222, 0.9863013698630136]
# Macro-average Specificity: 0.9875
# MCC per class: [0.959339487282751, 0.9524447467356325, 0.9620442890220036, 0.8453483040258218]
# Macro-average MCC: 0.9298
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9622
# ---------------------------------------------------------------------------------------------------
# Epoch 81/100, Loss: 0.0340
# Epoch 81/100, Loss: 0.1169
# Accuracy: 0.9542
# Precision: 0.9268
# Recall: 0.9542
# F1 Score: 0.9387
# AUC: 0.9983
# AUPR: 0.9902
# Specificity per class: [0.978448275862069, 1.0, 0.9911111111111112, 0.9794520547945206]
# Macro-average Specificity: 0.9873
# MCC per class: [0.9525686552200252, 0.9397532094515858, 0.9769542224975036, 0.8353862785988658]
# Macro-average MCC: 0.9262
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9595
# ---------------------------------------------------------------------------------------------------
# Epoch 82/100, Loss: 0.0262
# Epoch 82/100, Loss: 0.0962
# Accuracy: 0.9534
# Precision: 0.9368
# Recall: 0.9534
# F1 Score: 0.9444
# AUC: 0.9987
# AUPR: 0.9934
# Specificity per class: [0.978448275862069, 0.9949748743718593, 0.9866666666666667, 0.9863013698630136]
# Macro-average Specificity: 0.9866
# MCC per class: [0.9441594142981191, 0.939250105582329, 0.9694477535121453, 0.870530017457414]
# Macro-average MCC: 0.9308
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9591
# ---------------------------------------------------------------------------------------------------
# Epoch 83/100, Loss: 0.0254
# Epoch 83/100, Loss: 0.1396
# Accuracy: 0.9421
# Precision: 0.9139
# Recall: 0.9421
# F1 Score: 0.9258
# AUC: 0.9981
# AUPR: 0.9905
# Specificity per class: [0.9612068965517241, 0.9949748743718593, 0.9911111111111112, 0.9794520547945206]
# Macro-average Specificity: 0.9817
# MCC per class: [0.9145246423032853, 0.9126866390039042, 0.9691330891330892, 0.8353862785988658]
# Macro-average MCC: 0.9079
# F1 Score (micro): 0.9430
# F1 Score (weighted): 0.9437
# ---------------------------------------------------------------------------------------------------
# Epoch 84/100, Loss: 0.0264
# Epoch 84/100, Loss: 0.1297
# Accuracy: 0.9462
# Precision: 0.9522
# Recall: 0.9462
# F1 Score: 0.9486
# AUC: 0.9975
# AUPR: 0.9933
# Specificity per class: [0.9956896551724138, 0.9547738693467337, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9837
# MCC per class: [0.9266157487555682, 0.9201657645460524, 0.9769542224975036, 0.9098173515981736]
# Macro-average MCC: 0.9334
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9556
# ---------------------------------------------------------------------------------------------------
# Epoch 85/100, Loss: 0.0255
# Epoch 85/100, Loss: 0.1201
# Accuracy: 0.9506
# Precision: 0.9400
# Recall: 0.9506
# F1 Score: 0.9447
# AUC: 0.9978
# AUPR: 0.9893
# Specificity per class: [0.9655172413793104, 0.9949748743718593, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9853
# MCC per class: [0.9217736534970257, 0.939250105582329, 0.9691330891330892, 0.8896044445281678]
# Macro-average MCC: 0.9299
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9560
# ---------------------------------------------------------------------------------------------------
# Epoch 86/100, Loss: 0.0264
# Epoch 86/100, Loss: 0.1175
# Accuracy: 0.9390
# Precision: 0.9573
# Recall: 0.9390
# F1 Score: 0.9476
# AUC: 0.9979
# AUPR: 0.9937
# Specificity per class: [0.9827586206896551, 0.9597989949748744, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9837
# MCC per class: [0.9184266371062764, 0.9265289888912486, 0.9768030891848316, 0.9072291086054585]
# Macro-average MCC: 0.9322
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9556
# ---------------------------------------------------------------------------------------------------
# Epoch 87/100, Loss: 0.0243
# Epoch 87/100, Loss: 0.1206
# Accuracy: 0.9570
# Precision: 0.9635
# Recall: 0.9570
# F1 Score: 0.9600
# AUC: 0.9974
# AUPR: 0.9900
# Specificity per class: [0.9741379310344828, 0.9798994974874372, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9877
# MCC per class: [0.9365879961071812, 0.9388393513815171, 0.9845836908536074, 0.9312905566854962]
# Macro-average MCC: 0.9478
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9653
# ---------------------------------------------------------------------------------------------------
# Epoch 88/100, Loss: 0.0324
# Epoch 88/100, Loss: 0.1141
# Accuracy: 0.9602
# Precision: 0.9440
# Recall: 0.9602
# F1 Score: 0.9515
# AUC: 0.9978
# AUPR: 0.9911
# Specificity per class: [0.9698275862068966, 0.9899497487437185, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9863
# MCC per class: [0.9206073369943373, 0.9389331631730534, 0.9768030891848316, 0.9140014911483973]
# Macro-average MCC: 0.9376
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9591
# ---------------------------------------------------------------------------------------------------
# Epoch 89/100, Loss: 0.0256
# Epoch 89/100, Loss: 0.1213
# Accuracy: 0.9578
# Precision: 0.9227
# Recall: 0.9578
# F1 Score: 0.9374
# AUC: 0.9980
# AUPR: 0.9920
# Specificity per class: [0.9870689655172413, 0.9899497487437185, 0.9911111111111112, 0.976027397260274]
# Macro-average Specificity: 0.9860
# MCC per class: [0.9430620346419998, 0.9322043221572608, 0.9769542224975036, 0.8444384117429264]
# Macro-average MCC: 0.9242
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9566
# ---------------------------------------------------------------------------------------------------
# Epoch 90/100, Loss: 0.0272
# Epoch 90/100, Loss: 0.1307
# Accuracy: 0.9595
# Precision: 0.9262
# Recall: 0.9595
# F1 Score: 0.9404
# AUC: 0.9980
# AUPR: 0.9907
# Specificity per class: [0.9741379310344828, 0.9949748743718593, 0.9955555555555555, 0.9794520547945206]
# Macro-average Specificity: 0.9860
# MCC per class: [0.9365879961071812, 0.9259358814138647, 0.9845665445665446, 0.8605191922093021]
# Macro-average MCC: 0.9269
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9563
# ---------------------------------------------------------------------------------------------------
# Epoch 91/100, Loss: 0.0317
# Epoch 91/100, Loss: 0.1191
# Accuracy: 0.9576
# Precision: 0.9551
# Recall: 0.9576
# F1 Score: 0.9561
# AUC: 0.9979
# AUPR: 0.9900
# Specificity per class: [0.9698275862068966, 0.9899497487437185, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9882
# MCC per class: [0.9291271099667554, 0.9456797751166062, 0.9922876771341849, 0.9098173515981736]
# Macro-average MCC: 0.9442
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9654
# ---------------------------------------------------------------------------------------------------
# Epoch 92/100, Loss: 0.0231
# Epoch 92/100, Loss: 0.1261
# Accuracy: 0.9570
# Precision: 0.9629
# Recall: 0.9570
# F1 Score: 0.9596
# AUC: 0.9973
# AUPR: 0.9894
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9878
# MCC per class: [0.9291271099667554, 0.945607302219665, 0.9845836908536074, 0.9312905566854962]
# Macro-average MCC: 0.9477
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9654
# ---------------------------------------------------------------------------------------------------
# Epoch 93/100, Loss: 0.0209
# Epoch 93/100, Loss: 0.1049
# Accuracy: 0.9634
# Precision: 0.9642
# Recall: 0.9634
# F1 Score: 0.9638
# AUC: 0.9981
# AUPR: 0.9923
# Specificity per class: [0.9827586206896551, 0.9748743718592965, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9874
# MCC per class: [0.9267845820012487, 0.939054302314074, 0.9845665445665446, 0.9549086757990868]
# Macro-average MCC: 0.9513
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9652
# ---------------------------------------------------------------------------------------------------
# Epoch 94/100, Loss: 0.0399
# Epoch 94/100, Loss: 0.1186
# Accuracy: 0.9630
# Precision: 0.9467
# Recall: 0.9630
# F1 Score: 0.9543
# AUC: 0.9977
# AUPR: 0.9902
# Specificity per class: [0.9741379310344828, 0.9899497487437185, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9873
# MCC per class: [0.9281223053474523, 0.9389331631730534, 0.9845665445665446, 0.9140014911483973]
# Macro-average MCC: 0.9414
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9622
# ---------------------------------------------------------------------------------------------------
# Epoch 95/100, Loss: 0.0217
# Epoch 95/100, Loss: 0.1185
# Accuracy: 0.9623
# Precision: 0.9529
# Recall: 0.9623
# F1 Score: 0.9573
# AUC: 0.9978
# AUPR: 0.9912
# Specificity per class: [0.9698275862068966, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9871
# MCC per class: [0.9206073369943373, 0.9456797751166062, 0.9768030891848316, 0.9338605850305136]
# Macro-average MCC: 0.9442
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9622
# ---------------------------------------------------------------------------------------------------
# Epoch 96/100, Loss: 0.0212
# Epoch 96/100, Loss: 0.1190
# Accuracy: 0.9747
# Precision: 0.9539
# Recall: 0.9747
# F1 Score: 0.9634
# AUC: 0.9976
# AUPR: 0.9925
# Specificity per class: [0.9870689655172413, 0.9849246231155779, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9893
# MCC per class: [0.9430620346419998, 0.945607302219665, 0.9845665445665446, 0.937953340416017]
# Macro-average MCC: 0.9528
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9685
# ---------------------------------------------------------------------------------------------------
# Epoch 97/100, Loss: 0.0249
# Epoch 97/100, Loss: 0.1187
# Accuracy: 0.9634
# Precision: 0.9575
# Recall: 0.9634
# F1 Score: 0.9603
# AUC: 0.9974
# AUPR: 0.9916
# Specificity per class: [0.9870689655172413, 0.9748743718592965, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9877
# MCC per class: [0.9347680119556898, 0.939054302314074, 0.9845665445665446, 0.9338605850305136]
# Macro-average MCC: 0.9481
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9652
# ---------------------------------------------------------------------------------------------------
# Epoch 98/100, Loss: 0.0288
# Epoch 98/100, Loss: 0.1202
# Accuracy: 0.9672
# Precision: 0.9596
# Recall: 0.9672
# F1 Score: 0.9633
# AUC: 0.9968
# AUPR: 0.9896
# Specificity per class: [0.9827586206896551, 0.9798994974874372, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9890
# MCC per class: [0.9434925890878169, 0.9388393513815171, 0.9922876771341849, 0.9338605850305136]
# Macro-average MCC: 0.9521
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9684
# ---------------------------------------------------------------------------------------------------
# Epoch 99/100, Loss: 0.0287
# Epoch 99/100, Loss: 0.1266
# Accuracy: 0.9645
# Precision: 0.9568
# Recall: 0.9645
# F1 Score: 0.9605
# AUC: 0.9970
# AUPR: 0.9899
# Specificity per class: [0.978448275862069, 0.9798994974874372, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9879
# MCC per class: [0.9357496161555404, 0.9388393513815171, 0.9845836908536074, 0.9338605850305136]
# Macro-average MCC: 0.9483
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9653
# ---------------------------------------------------------------------------------------------------
# Epoch 100/100, Loss: 0.0155
# Epoch 100/100, Loss: 0.1046
# Accuracy: 0.9763
# Precision: 0.9478
# Recall: 0.9763
# F1 Score: 0.9605
# AUC: 0.9983
# AUPR: 0.9937
# Specificity per class: [0.9870689655172413, 0.9949748743718593, 0.9911111111111112, 0.9863013698630136]
# Macro-average Specificity: 0.9899
# MCC per class: [0.9596468835260349, 0.9459330151619536, 0.9769542224975036, 0.9194569996298345]
# Macro-average MCC: 0.9505
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9686
# ---------------------------------------------------------------------------------------------------
# Training and validating complete

# %% [markdown]
# # coatnet pretrained

# %%
import os
import pandas as pd
from PIL import Image
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torch.nn.functional as F
import torchvision.models as models
import numpy as np
import timm
import torch
import torch.nn.functional as F
import numpy as np
from torcheval.metrics import MulticlassAccuracy, MulticlassPrecision, MulticlassRecall, MulticlassF1Score, MulticlassAUROC, MulticlassAUPRC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import matthews_corrcoef
import random


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)  # For CPU
    torch.cuda.manual_seed(seed)  # For GPU (if used)
    torch.cuda.manual_seed_all(seed)  # For all GPUs
    torch.backends.cudnn.deterministic = True  # Ensure deterministic behavior
    torch.backends.cudnn.benchmark = False


def calculate_metrics(predicted, probabilities, labels, num_classes):
    # Initialize Torcheval metrics
    accuracy_metric = MulticlassAccuracy(num_classes=num_classes, average="macro")
    precision_metric = MulticlassPrecision(num_classes=num_classes, average="macro")
    recall_metric = MulticlassRecall(num_classes=num_classes, average="macro")
    f1_score_metric = MulticlassF1Score(num_classes=num_classes, average="macro")
    auc_metric = MulticlassAUROC(num_classes=num_classes, average="macro")
    aupr_metric = MulticlassAUPRC(num_classes=num_classes, average="macro")

    # Update metrics with predictions
    accuracy_metric.update(predicted, labels)
    precision_metric.update(predicted, labels)
    recall_metric.update(predicted, labels)
    f1_score_metric.update(predicted, labels)
    auc_metric.update(probabilities, labels)
    aupr_metric.update(probabilities, labels)

    # Compute metrics
    accuracy = accuracy_metric.compute()
    precision = precision_metric.compute()
    recall = recall_metric.compute()
    f1_score = f1_score_metric.compute()
    auc = auc_metric.compute()
    aupr = aupr_metric.compute()

    # Specificity calculation
    conf_matrix = confusion_matrix(labels.cpu().numpy(), predicted.cpu().numpy(), labels=range(num_classes))
    specificity_per_class = []

    for i in range(num_classes):
        TP = conf_matrix[i, i]
        FP = conf_matrix[:, i].sum() - TP
        FN = conf_matrix[i, :].sum() - TP
        TN = conf_matrix.sum() - (TP + FP + FN)

        specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
        specificity_per_class.append(specificity)

    macro_specificity = np.mean(specificity_per_class)

    # MCC calculation for multi-class classification
    mcc_per_class = []
    for i in range(num_classes):
        # Treat each class as the positive class and others as negative
        binary_pred = (predicted == i).int()
        binary_labels = (labels == i).int()
        mcc = matthews_corrcoef(binary_labels.cpu().numpy(), binary_pred.cpu().numpy())
        mcc_per_class.append(mcc)

    macro_mcc = np.mean(mcc_per_class)

    # Print all metrics
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1_score:.4f}")
    print(f"AUC: {auc:.4f}")
    print(f"AUPR: {aupr:.4f}")
    print(f"Specificity per class: {specificity_per_class}")
    print(f"Macro-average Specificity: {macro_specificity:.4f}")
    print(f"MCC per class: {mcc_per_class}")
    print(f"Macro-average MCC: {macro_mcc:.4f}")

    f1_score_metric_micro = MulticlassF1Score(num_classes=num_classes, average="micro")
    f1_score_metric_micro.update(predicted, labels)
    f1_score_micro = f1_score_metric_micro.compute()
    print(f"F1 Score (micro): {f1_score_micro:.4f}")

    f1_score_metric_weighted = MulticlassF1Score(num_classes=num_classes, average="weighted")
    f1_score_metric_weighted.update(predicted, labels)
    f1_score_weighted = f1_score_metric_weighted.compute()
    print(f"F1 Score (weighted): {f1_score_weighted:.4f}")


    # Return metrics as a dictionary
    return {
        "accuracy": "{:.4f}".format(accuracy.item()),
        "precision": "{:.4f}".format(precision.item()),
        "recall": "{:.4f}".format(recall.item()),
        "f1_score": "{:.4f}".format(f1_score.item()),
        "auc": "{:.4f}".format(auc.item()),
        "aupr": "{:.4f}".format(aupr.item()),
        "macro_specificity": "{:.4f}".format(macro_specificity.item()),
        "macro_mcc": "{:.4f}".format(macro_mcc.item())
    }


class ImageDataset(Dataset):
    def __init__(self, images, features, labels, transform=None):
        self.images = images
        self.features = features
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        feature = self.features[idx]
        label = self.labels[idx]
        return image, feature, label


# Image transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

set_seed(42)

dataset_path = "baldder_tissue_classification"

train_df = pd.read_csv("train_df.csv")
val_df = pd.read_csv("val_df.csv")

train_images = []
train_labels = []
for idx, row in train_df.iterrows():
    image_path = os.path.join(dataset_path, row[1], row[0])
    image = Image.open(image_path)
    image = transform(image)
    train_images.append(image)
    train_labels.append(row['encoded_label'])

loaded_images = np.load("top_images.npy")
loaded_labels = np.load("top_labels.npy")
print(len(train_images))
for i in range(len(loaded_images)):
    image = loaded_images[i]
    label = loaded_labels[i]

    # Denormalize the image
    image = (image * np.array([0.229, 0.224, 0.225])[:, None, None]) + np.array([0.485, 0.456, 0.406])[:, None, None]
    image = (image * 255).astype(np.uint8)  # Convert to integer type for PIL compatibility

    # Convert NumPy array to PIL image
    image = Image.fromarray(image.transpose(1, 2, 0))  # H x W x C format

    # Apply transformations
    image = transform(image)

    # Convert back to PyTorch tensor (if required)
    image = torch.tensor(image, dtype=torch.float32)
    train_images.append(image)
    train_labels.append(label)

print(len(train_images))

val_images = []
val_labels = []
for idx, row in val_df.iterrows():
    image_path = os.path.join(dataset_path, row[1], row[0])
    image = Image.open(image_path)
    image = transform(image)
    val_images.append(image)
    val_labels.append(row['encoded_label'])

print(len(val_images))

train_features = np.load("features_RFE.npy")[:-val_df.shape[0]]
augmented_features = np.load("features_top_images_RFE.npy")
train_features = np.concatenate((train_features, augmented_features), axis=0)
val_features = np.load("features_RFE.npy")[-val_df.shape[0]:]

print(train_features.shape)
print(val_features.shape)

# Create DataLoaders
train_dataset = ImageDataset(train_images, train_features, train_labels, transform=transform)
val_dataset = ImageDataset(val_images, val_features, val_labels, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)


# Define the CNN model
class SimpleCNN(nn.Module):
    def __init__(self, num_classes):
        super(SimpleCNN, self).__init__()
        self.block = timm.create_model('coatnet_0_rw_224.sw_in1k', pretrained=True)
        # self.block.head = nn.Linear(self.block.num_features, 1000)

        self.fc1 = nn.Linear(1000, 512)
        self.bn1 = nn.BatchNorm1d(512)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(0.2)
        self.fc2 = nn.Linear(512, 256)
        self.bn2 = nn.BatchNorm1d(256)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(0.2)

        self.fc_ann1 = nn.Linear(512, 256)
        self.bn_ann1 = nn.BatchNorm1d(256)
        self.relu_ann1 = nn.ReLU()
        self.dropout_ann1 = nn.Dropout(0.2)
        self.fc_ann2 = nn.Linear(256, 128)
        self.bn_ann2 = nn.BatchNorm1d(128)
        self.relu_ann2 = nn.ReLU()
        self.dropout_ann2 = nn.Dropout(0.2)

        self.fc_comb = nn.Linear(384, 256)
        self.bn_comb = nn.BatchNorm1d(256)
        self.relu_comb = nn.ReLU()
        self.dropout_comb = nn.Dropout(0.2)

        self.fc3 = nn.Linear(256, 128)
        self.bn3 = nn.BatchNorm1d(128)
        self.relu3 = nn.ReLU()
        self.dropout3 = nn.Dropout(0.2)
        self.fc4 = nn.Linear(128, num_classes)

        self.relu = nn.ReLU()


    def forward(self, x, features):
        features = features.float()
        x = self.block(x)
        # print(x.shape)
        x = x.view(-1, 1000)  # Flatten
        x = self.dropout1(self.relu1(self.bn1(self.fc1(x))))
        x = self.dropout2(self.relu2(self.bn2(self.fc2(x))))

        features = self.dropout_ann1(self.relu_ann1(self.bn_ann1(self.fc_ann1(features))))
        features = self.dropout_ann2(self.relu_ann2(self.bn_ann2(self.fc_ann2(features))))

        x = torch.cat((x, features), dim=1)
        x = self.dropout_comb(self.relu_comb(self.bn_comb(self.fc_comb(x))))

        x = self.dropout3(self.relu3(self.bn3(self.fc3(x))))
        x = self.fc4(x)
        return x


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")
# Instantiate model, loss function, and optimizer
num_classes = 4
model = SimpleCNN(num_classes)
model = model.to(device)
criterion = nn.CrossEntropyLoss().to(device)

optimizer = optim.Adam(model.parameters(), lr=0.0001)

# Training loop
num_epochs = 100
all_metrics = []

best_f1 = -100
best_epoch = 0
best_metric = 0
with open('Results/coatnet_0_rw_224_pretrained.csv', 'w') as f:
    f.write("Epoch,Train Loss,Val Loss,Accuracy,Precision,Recall,F1 Score,AUC,AUPR,Specificity,MCC\n")
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for images, features, labels in train_loader:
            images, features, labels = images.to(device), features.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images, features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * images.size(0)

        train_loss = running_loss / len(train_loader.dataset)
        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {train_loss:.4f}")

        # Validation loop
        model.eval()
        running_loss = 0.0
        with torch.no_grad():
            y_pred = []
            y_true = []
            y_proba = []
            for images, features, labels in val_loader:
                images, features, labels = images.to(device), features.to(device), labels.to(device)

                outputs = model(images, features)
                loss = criterion(outputs, labels)

                running_loss += loss.item() * images.size(0)

                # Apply softmax to get probabilities
                probabilities = F.softmax(outputs, dim=1)

                # Get the predicted class and corresponding probability
                proba, predicted = torch.max(probabilities, 1)

                # Store results
                y_pred.extend(predicted.cpu().tolist())
                y_true.extend(labels.cpu().tolist())
                y_proba.extend(probabilities.cpu().tolist())

            val_loss = running_loss / len(val_loader.dataset)
            print(f"Epoch {epoch+1}/{num_epochs}, Loss: {val_loss:.4f}")
            # Convert lists to tensors
            y_pred = torch.tensor(y_pred)
            y_true = torch.tensor(y_true)
            y_proba = torch.tensor(y_proba)

            metrics = calculate_metrics(y_pred, y_proba, y_true, num_classes)
            all_metrics.append(metrics)

            if best_f1 < float(metrics["f1_score"]):
                best_f1 = float(metrics["f1_score"])
                best_epoch = epoch+1
                best_metric = metrics
            print('---------------------------------------------------------------------------------------------------')

            f.write(f"{epoch+1},{train_loss},{val_loss},{metrics['accuracy']},{metrics['precision']},{metrics['recall']},{metrics['f1_score']},{metrics['auc']},{metrics['aupr']},{metrics['macro_specificity']},{metrics['macro_mcc']}\n")
            f.flush()
    print("Training and validating complete")
# Out:
# <ipython-input-27-1c20469a0934>:155: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   image_path = os.path.join(dataset_path, row[1], row[0])
# 1262
# <ipython-input-27-1c20469a0934>:179: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   image = torch.tensor(image, dtype=torch.float32)
# 1762
# <ipython-input-27-1c20469a0934>:188: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   image_path = os.path.join(dataset_path, row[1], row[0])
# 316
# (1762, 512)
# (316, 512)
# model.safetensors:   0%|          | 0.00/110M [00:00<?, ?B/s]
# Epoch 1/100, Loss: 1.0680
# Epoch 1/100, Loss: 0.8594
# Accuracy: 0.5511
# Precision: 0.5403
# Recall: 0.5511
# F1 Score: 0.4919
# AUC: 0.8937
# AUPR: 0.7409
# Specificity per class: [0.728448275862069, 0.9949748743718593, 0.7866666666666666, 1.0]
# Macro-average Specificity: 0.8775
# MCC per class: [0.512826046448358, 0.4984767351208064, 0.7176433587846222, 0.0]
# Macro-average MCC: 0.4322
# F1 Score (micro): 0.6456
# F1 Score (weighted): 0.5954
# ---------------------------------------------------------------------------------------------------
# Epoch 2/100, Loss: 0.6776
# Epoch 2/100, Loss: 0.3674
# Accuracy: 0.7640
# Precision: 0.9192
# Recall: 0.7640
# F1 Score: 0.7760
# AUC: 0.9866
# AUPR: 0.9455
# Specificity per class: [0.9267241379310345, 0.9396984924623115, 0.9822222222222222, 1.0]
# Macro-average Specificity: 0.9622
# MCC per class: [0.7969989389292474, 0.8942135564132069, 0.9620442890220036, 0.4422731886731076]
# Macro-average MCC: 0.7739
# F1 Score (micro): 0.8956
# F1 Score (weighted): 0.8787
# ---------------------------------------------------------------------------------------------------
# Epoch 3/100, Loss: 0.4214
# Epoch 3/100, Loss: 0.4285
# Accuracy: 0.7553
# Precision: 0.8974
# Recall: 0.7553
# F1 Score: 0.7873
# AUC: 0.9851
# AUPR: 0.9242
# Specificity per class: [1.0, 0.7788944723618091, 0.9777777777777777, 0.9965753424657534]
# Macro-average Specificity: 0.9383
# MCC per class: [0.7033274554536335, 0.7440186734872228, 0.9627314536524979, 0.6305127183107524]
# Macro-average MCC: 0.7601
# F1 Score (micro): 0.8418
# F1 Score (weighted): 0.8301
# ---------------------------------------------------------------------------------------------------
# Epoch 4/100, Loss: 0.3383
# Epoch 4/100, Loss: 0.3132
# Accuracy: 0.9145
# Precision: 0.8846
# Recall: 0.9145
# F1 Score: 0.8935
# AUC: 0.9849
# AUPR: 0.9602
# Specificity per class: [0.9913793103448276, 0.9396984924623115, 0.9911111111111112, 0.9657534246575342]
# Macro-average Specificity: 0.9720
# MCC per class: [0.8520146206244478, 0.8655424437116854, 0.9847826631637365, 0.7748868219231421]
# Macro-average MCC: 0.8693
# F1 Score (micro): 0.9177
# F1 Score (weighted): 0.9184
# ---------------------------------------------------------------------------------------------------
# Epoch 5/100, Loss: 0.5084
# Epoch 5/100, Loss: 0.2859
# Accuracy: 0.8820
# Precision: 0.9450
# Recall: 0.8820
# F1 Score: 0.9059
# AUC: 0.9919
# AUPR: 0.9807
# Specificity per class: [0.9827586206896551, 0.9396984924623115, 0.9688888888888889, 1.0]
# Macro-average Specificity: 0.9728
# MCC per class: [0.8597518059373054, 0.9014276945073506, 0.9485159670150733, 0.8317152629997844]
# Macro-average MCC: 0.8854
# F1 Score (micro): 0.9272
# F1 Score (weighted): 0.9251
# ---------------------------------------------------------------------------------------------------
# Epoch 6/100, Loss: 0.2904
# Epoch 6/100, Loss: 0.8548
# Accuracy: 0.7081
# Precision: 0.6835
# Recall: 0.7081
# F1 Score: 0.6205
# AUC: 0.9472
# AUPR: 0.8536
# Specificity per class: [0.8879310344827587, 1.0, 0.8133333333333334, 0.8767123287671232]
# Macro-average Specificity: 0.8945
# MCC per class: [0.692837133298731, 0.4528438892668327, 0.74598339664511, 0.41483080674134004]
# Macro-average MCC: 0.5766
# F1 Score (micro): 0.6709
# F1 Score (weighted): 0.6410
# ---------------------------------------------------------------------------------------------------
# Epoch 7/100, Loss: 0.5375
# Epoch 7/100, Loss: 0.3347
# Accuracy: 0.7476
# Precision: 0.9067
# Recall: 0.7476
# F1 Score: 0.7685
# AUC: 0.9842
# AUPR: 0.9581
# Specificity per class: [0.9612068965517241, 0.8743718592964824, 0.9688888888888889, 1.0]
# Macro-average Specificity: 0.9511
# MCC per class: [0.7755668869127056, 0.8179829307627351, 0.9404249627388198, 0.4852668039004337]
# Macro-average MCC: 0.7548
# F1 Score (micro): 0.8703
# F1 Score (weighted): 0.8549
# ---------------------------------------------------------------------------------------------------
# Epoch 8/100, Loss: 0.3081
# Epoch 8/100, Loss: 0.3237
# Accuracy: 0.8360
# Precision: 0.9174
# Recall: 0.8360
# F1 Score: 0.8528
# AUC: 0.9903
# AUPR: 0.9680
# Specificity per class: [0.853448275862069, 1.0, 0.9822222222222222, 1.0]
# Macro-average Specificity: 0.9589
# MCC per class: [0.7794481705756171, 0.8166118580860928, 0.9699822148245933, 0.751011091824981]
# Macro-average MCC: 0.8293
# F1 Score (micro): 0.8797
# F1 Score (weighted): 0.8788
# ---------------------------------------------------------------------------------------------------
# Epoch 9/100, Loss: 0.2627
# Epoch 9/100, Loss: 0.7340
# Accuracy: 0.7214
# Precision: 0.7694
# Recall: 0.7214
# F1 Score: 0.7094
# AUC: 0.9477
# AUPR: 0.8912
# Specificity per class: [0.9956896551724138, 1.0, 0.6844444444444444, 0.9554794520547946]
# Macro-average Specificity: 0.9089
# MCC per class: [0.77789354007616, 0.6829080360621219, 0.6100171280303214, 0.5411387549904755]
# Macro-average MCC: 0.6530
# F1 Score (micro): 0.7310
# F1 Score (weighted): 0.7373
# ---------------------------------------------------------------------------------------------------
# Epoch 10/100, Loss: 0.5875
# Epoch 10/100, Loss: 0.3692
# Accuracy: 0.7577
# Precision: 0.9089
# Recall: 0.7577
# F1 Score: 0.7636
# AUC: 0.9844
# AUPR: 0.9602
# Specificity per class: [0.8793103448275862, 0.9748743718592965, 0.9733333333333334, 1.0]
# Macro-average Specificity: 0.9569
# MCC per class: [0.7933669658198799, 0.8437095261361519, 0.9555768664876327, 0.4422731886731076]
# Macro-average MCC: 0.7587
# F1 Score (micro): 0.8766
# F1 Score (weighted): 0.8614
# ---------------------------------------------------------------------------------------------------
# Epoch 11/100, Loss: 0.3795
# Epoch 11/100, Loss: 0.4669
# Accuracy: 0.7715
# Precision: 0.8386
# Recall: 0.7715
# F1 Score: 0.7766
# AUC: 0.9806
# AUPR: 0.9374
# Specificity per class: [0.7629310344827587, 1.0, 1.0, 0.9863013698630136]
# Macro-average Specificity: 0.9373
# MCC per class: [0.6790079883010443, 0.7275380601018006, 0.9615145720873706, 0.5876001809076813]
# Macro-average MCC: 0.7389
# F1 Score (micro): 0.8133
# F1 Score (weighted): 0.8149
# ---------------------------------------------------------------------------------------------------
# Epoch 12/100, Loss: 0.3119
# Epoch 12/100, Loss: 0.2380
# Accuracy: 0.9149
# Precision: 0.9339
# Recall: 0.9149
# F1 Score: 0.9212
# AUC: 0.9971
# AUPR: 0.9891
# Specificity per class: [0.9310344827586207, 0.9949748743718593, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9798
# MCC per class: [0.8843466319929314, 0.9325845850929314, 0.9615145720873706, 0.834728011337836]
# Macro-average MCC: 0.9033
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9406
# ---------------------------------------------------------------------------------------------------
# Epoch 13/100, Loss: 0.2702
# Epoch 13/100, Loss: 0.3486
# Accuracy: 0.8834
# Precision: 0.8977
# Recall: 0.8834
# F1 Score: 0.8843
# AUC: 0.9934
# AUPR: 0.9753
# Specificity per class: [0.9525862068965517, 0.9899497487437185, 0.9155555555555556, 0.9931506849315068]
# Macro-average Specificity: 0.9628
# MCC per class: [0.8916088805902701, 0.8134533941445768, 0.870295433409909, 0.834728011337836]
# Macro-average MCC: 0.8525
# F1 Score (micro): 0.8924
# F1 Score (weighted): 0.8905
# ---------------------------------------------------------------------------------------------------
# Epoch 14/100, Loss: 0.3475
# Epoch 14/100, Loss: 0.2630
# Accuracy: 0.9032
# Precision: 0.8944
# Recall: 0.9032
# F1 Score: 0.8985
# AUC: 0.9921
# AUPR: 0.9776
# Specificity per class: [0.9612068965517241, 0.964824120603015, 0.9777777777777777, 0.9828767123287672]
# Macro-average Specificity: 0.9717
# MCC per class: [0.854064039408867, 0.8704295430302097, 0.9547410841058538, 0.801092163523476]
# Macro-average MCC: 0.8701
# F1 Score (micro): 0.9177
# F1 Score (weighted): 0.9176
# ---------------------------------------------------------------------------------------------------
# Epoch 15/100, Loss: 0.2327
# Epoch 15/100, Loss: 0.8090
# Accuracy: 0.7145
# Precision: 0.8692
# Recall: 0.7145
# F1 Score: 0.7195
# AUC: 0.9649
# AUPR: 0.9297
# Specificity per class: [0.6206896551724138, 1.0, 0.9955555555555555, 1.0]
# Macro-average Specificity: 0.9041
# MCC per class: [0.5505701644790014, 0.5383077607937683, 0.9380765906204261, 0.7224971973786625]
# Macro-average MCC: 0.6874
# F1 Score (micro): 0.7184
# F1 Score (weighted): 0.7117
# ---------------------------------------------------------------------------------------------------
# Epoch 16/100, Loss: 0.2816
# Epoch 16/100, Loss: 0.2083
# Accuracy: 0.9129
# Precision: 0.9192
# Recall: 0.9129
# F1 Score: 0.9149
# AUC: 0.9930
# AUPR: 0.9774
# Specificity per class: [0.9396551724137931, 0.9748743718592965, 1.0, 0.9897260273972602]
# Macro-average Specificity: 0.9761
# MCC per class: [0.8620365176180789, 0.9115035288202712, 0.9538367162324234, 0.8393256142128035]
# Macro-average MCC: 0.8917
# F1 Score (micro): 0.9304
# F1 Score (weighted): 0.9312
# ---------------------------------------------------------------------------------------------------
# Epoch 17/100, Loss: 0.2099
# Epoch 17/100, Loss: 0.2226
# Accuracy: 0.9298
# Precision: 0.9253
# Recall: 0.9298
# F1 Score: 0.9255
# AUC: 0.9924
# AUPR: 0.9816
# Specificity per class: [0.9353448275862069, 0.9949748743718593, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9789
# MCC per class: [0.881964418149203, 0.90608495842879, 0.9690466897894506, 0.8647260273972602]
# Macro-average MCC: 0.9055
# F1 Score (micro): 0.9367
# F1 Score (weighted): 0.9374
# ---------------------------------------------------------------------------------------------------
# Epoch 18/100, Loss: 0.1669
# Epoch 18/100, Loss: 0.1439
# Accuracy: 0.9608
# Precision: 0.9498
# Recall: 0.9608
# F1 Score: 0.9549
# AUC: 0.9967
# AUPR: 0.9889
# Specificity per class: [0.9741379310344828, 0.9949748743718593, 0.9822222222222222, 0.9931506849315068]
# Macro-average Specificity: 0.9861
# MCC per class: [0.9281223053474523, 0.939250105582329, 0.9620442890220036, 0.9338605850305136]
# Macro-average MCC: 0.9408
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9589
# ---------------------------------------------------------------------------------------------------
# Epoch 19/100, Loss: 0.1746
# Epoch 19/100, Loss: 0.1534
# Accuracy: 0.9512
# Precision: 0.9471
# Recall: 0.9512
# F1 Score: 0.9486
# AUC: 0.9957
# AUPR: 0.9863
# Specificity per class: [0.9612068965517241, 0.9899497487437185, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9850
# MCC per class: [0.9145246423032853, 0.9254926645253152, 0.9845665445665446, 0.9098173515981736]
# Macro-average MCC: 0.9336
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9559
# ---------------------------------------------------------------------------------------------------
# Epoch 20/100, Loss: 0.1683
# Epoch 20/100, Loss: 0.2322
# Accuracy: 0.9094
# Precision: 0.8704
# Recall: 0.9094
# F1 Score: 0.8838
# AUC: 0.9913
# AUPR: 0.9612
# Specificity per class: [0.9396551724137931, 0.9849246231155779, 1.0, 0.9623287671232876]
# Macro-average Specificity: 0.9717
# MCC per class: [0.8797493707395952, 0.8716036682431851, 0.9461635504451551, 0.7352904060551418]
# Macro-average MCC: 0.8582
# F1 Score (micro): 0.9114
# F1 Score (weighted): 0.9140
# ---------------------------------------------------------------------------------------------------
# Epoch 21/100, Loss: 0.1592
# Epoch 21/100, Loss: 0.1726
# Accuracy: 0.9562
# Precision: 0.9389
# Recall: 0.9562
# F1 Score: 0.9463
# AUC: 0.9951
# AUPR: 0.9860
# Specificity per class: [0.9568965517241379, 0.9949748743718593, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9843
# MCC per class: [0.9073772042004405, 0.9325845850929314, 0.9690466897894506, 0.9140014911483973]
# Macro-average MCC: 0.9308
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9530
# ---------------------------------------------------------------------------------------------------
# Epoch 22/100, Loss: 0.1470
# Epoch 22/100, Loss: 0.1778
# Accuracy: 0.9442
# Precision: 0.9330
# Recall: 0.9442
# F1 Score: 0.9373
# AUC: 0.9960
# AUPR: 0.9848
# Specificity per class: [0.9482758620689655, 0.9949748743718593, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9821
# MCC per class: [0.8933760872875811, 0.9193034230536933, 0.9768030891848316, 0.8896044445281678]
# Macro-average MCC: 0.9198
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9467
# ---------------------------------------------------------------------------------------------------
# Epoch 23/100, Loss: 0.1135
# Epoch 23/100, Loss: 0.1724
# Accuracy: 0.9254
# Precision: 0.9250
# Recall: 0.9254
# F1 Score: 0.9248
# AUC: 0.9955
# AUPR: 0.9848
# Specificity per class: [0.9439655172413793, 0.964824120603015, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9744
# MCC per class: [0.8424143263105991, 0.891121837935321, 0.9535520638570569, 0.9098173515981736]
# Macro-average MCC: 0.8992
# F1 Score (micro): 0.9272
# F1 Score (weighted): 0.9279
# ---------------------------------------------------------------------------------------------------
# Epoch 24/100, Loss: 0.1317
# Epoch 24/100, Loss: 0.1537
# Accuracy: 0.9398
# Precision: 0.9479
# Recall: 0.9398
# F1 Score: 0.9437
# AUC: 0.9959
# AUPR: 0.9871
# Specificity per class: [0.9741379310344828, 0.964824120603015, 0.9866666666666667, 0.9965753424657534]
# Macro-average Specificity: 0.9806
# MCC per class: [0.8857438874074495, 0.9119571276696354, 0.9694477535121453, 0.9312905566854962]
# Macro-average MCC: 0.9246
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9460
# ---------------------------------------------------------------------------------------------------
# Epoch 25/100, Loss: 0.1166
# Epoch 25/100, Loss: 0.1856
# Accuracy: 0.9451
# Precision: 0.9429
# Recall: 0.9451
# F1 Score: 0.9432
# AUC: 0.9932
# AUPR: 0.9810
# Specificity per class: [0.9525862068965517, 0.9849246231155779, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9827
# MCC per class: [0.9003285737788081, 0.9252324391444847, 0.96919786333672, 0.9098173515981736]
# Macro-average MCC: 0.9261
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9499
# ---------------------------------------------------------------------------------------------------
# Epoch 26/100, Loss: 0.0988
# Epoch 26/100, Loss: 0.1650
# Accuracy: 0.9432
# Precision: 0.9440
# Recall: 0.9432
# F1 Score: 0.9435
# AUC: 0.9950
# AUPR: 0.9830
# Specificity per class: [0.9698275862068966, 0.964824120603015, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9820
# MCC per class: [0.9035596663727024, 0.9119571276696354, 0.9768873266890564, 0.9098173515981736]
# Macro-average MCC: 0.9256
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9496
# ---------------------------------------------------------------------------------------------------
# Epoch 27/100, Loss: 0.0863
# Epoch 27/100, Loss: 0.1533
# Accuracy: 0.9557
# Precision: 0.9389
# Recall: 0.9557
# F1 Score: 0.9467
# AUC: 0.9960
# AUPR: 0.9856
# Specificity per class: [0.9741379310344828, 0.9849246231155779, 0.9866666666666667, 0.9897260273972602]
# Macro-average Specificity: 0.9839
# MCC per class: [0.9196546412641213, 0.918475629152568, 0.9694477535121453, 0.9140014911483973]
# Macro-average MCC: 0.9304
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9525
# ---------------------------------------------------------------------------------------------------
# Epoch 28/100, Loss: 0.0893
# Epoch 28/100, Loss: 0.1728
# Accuracy: 0.9232
# Precision: 0.9413
# Recall: 0.9232
# F1 Score: 0.9297
# AUC: 0.9949
# AUPR: 0.9820
# Specificity per class: [0.9353448275862069, 0.9949748743718593, 0.9911111111111112, 0.9965753424657534]
# Macro-average Specificity: 0.9795
# MCC per class: [0.8641733509528565, 0.9193034230536933, 0.9769542224975036, 0.882686929807428]
# Macro-average MCC: 0.9108
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9404
# ---------------------------------------------------------------------------------------------------
# Epoch 29/100, Loss: 0.0726
# Epoch 29/100, Loss: 0.1837
# Accuracy: 0.9385
# Precision: 0.9218
# Recall: 0.9385
# F1 Score: 0.9288
# AUC: 0.9946
# AUPR: 0.9807
# Specificity per class: [0.9482758620689655, 0.9899497487437185, 0.9955555555555555, 0.9863013698630136]
# Macro-average Specificity: 0.9800
# MCC per class: [0.8846101301702942, 0.9121185533761437, 0.9690466897894506, 0.870530017457414]
# Macro-average MCC: 0.9091
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9406
# ---------------------------------------------------------------------------------------------------
# Epoch 30/100, Loss: 0.0693
# Epoch 30/100, Loss: 0.2020
# Accuracy: 0.9215
# Precision: 0.9324
# Recall: 0.9215
# F1 Score: 0.9242
# AUC: 0.9943
# AUPR: 0.9768
# Specificity per class: [0.9267241379310345, 0.9949748743718593, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9787
# MCC per class: [0.8689446514092803, 0.9126866390039042, 0.9768873266890564, 0.8602932215197799]
# Macro-average MCC: 0.9047
# F1 Score (micro): 0.9367
# F1 Score (weighted): 0.9377
# ---------------------------------------------------------------------------------------------------
# Epoch 31/100, Loss: 0.0712
# Epoch 31/100, Loss: 0.1302
# Accuracy: 0.9517
# Precision: 0.9570
# Recall: 0.9517
# F1 Score: 0.9542
# AUC: 0.9969
# AUPR: 0.9882
# Specificity per class: [0.9741379310344828, 0.9849246231155779, 0.9866666666666667, 0.9965753424657534]
# Macro-average Specificity: 0.9856
# MCC per class: [0.9196546412641213, 0.9387976740971787, 0.9694477535121453, 0.9312905566854962]
# Macro-average MCC: 0.9398
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9588
# ---------------------------------------------------------------------------------------------------
# Epoch 32/100, Loss: 0.0872
# Epoch 32/100, Loss: 0.1807
# Accuracy: 0.9325
# Precision: 0.9438
# Recall: 0.9325
# F1 Score: 0.9353
# AUC: 0.9967
# AUPR: 0.9883
# Specificity per class: [0.9267241379310345, 0.9949748743718593, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9796
# MCC per class: [0.8689446514092803, 0.90608495842879, 0.9845836908536074, 0.9072291086054585]
# Macro-average MCC: 0.9167
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9408
# ---------------------------------------------------------------------------------------------------
# Epoch 33/100, Loss: 0.0774
# Epoch 33/100, Loss: 0.1388
# Accuracy: 0.9595
# Precision: 0.9553
# Recall: 0.9595
# F1 Score: 0.9568
# AUC: 0.9975
# AUPR: 0.9916
# Specificity per class: [0.9612068965517241, 0.9849246231155779, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9846
# MCC per class: [0.9145246423032853, 0.9117352234683014, 0.9845665445665446, 0.9549086757990868]
# Macro-average MCC: 0.9414
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9558
# ---------------------------------------------------------------------------------------------------
# Epoch 34/100, Loss: 0.0615
# Epoch 34/100, Loss: 0.1305
# Accuracy: 0.9638
# Precision: 0.9605
# Recall: 0.9638
# F1 Score: 0.9618
# AUC: 0.9973
# AUPR: 0.9918
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9867
# MCC per class: [0.9291271099667554, 0.9252324391444847, 0.9845665445665446, 0.9549086757990868]
# Macro-average MCC: 0.9485
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9621
# ---------------------------------------------------------------------------------------------------
# Epoch 35/100, Loss: 0.0793
# Epoch 35/100, Loss: 0.1765
# Accuracy: 0.9543
# Precision: 0.9387
# Recall: 0.9543
# F1 Score: 0.9460
# AUC: 0.9968
# AUPR: 0.9876
# Specificity per class: [0.9741379310344828, 0.9849246231155779, 0.9866666666666667, 0.9897260273972602]
# Macro-average Specificity: 0.9839
# MCC per class: [0.911184000211381, 0.9320062537742658, 0.9615706499287768, 0.9140014911483973]
# Macro-average MCC: 0.9297
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9527
# ---------------------------------------------------------------------------------------------------
# Epoch 36/100, Loss: 0.0646
# Epoch 36/100, Loss: 0.1236
# Accuracy: 0.9428
# Precision: 0.9504
# Recall: 0.9428
# F1 Score: 0.9464
# AUC: 0.9968
# AUPR: 0.9932
# Specificity per class: [0.978448275862069, 0.9698492462311558, 0.9822222222222222, 0.9965753424657534]
# Macro-average Specificity: 0.9818
# MCC per class: [0.9020852622568629, 0.9185671949491045, 0.9620442890220036, 0.9312905566854962]
# Macro-average MCC: 0.9285
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9492
# ---------------------------------------------------------------------------------------------------
# Epoch 37/100, Loss: 0.0606
# Epoch 37/100, Loss: 0.1291
# Accuracy: 0.9610
# Precision: 0.9576
# Recall: 0.9610
# F1 Score: 0.9588
# AUC: 0.9977
# AUPR: 0.9940
# Specificity per class: [0.9612068965517241, 0.9899497487437185, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9858
# MCC per class: [0.9145246423032853, 0.9322043221572608, 0.9768030891848316, 0.9549086757990868]
# Macro-average MCC: 0.9446
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9591
# ---------------------------------------------------------------------------------------------------
# Epoch 38/100, Loss: 0.0528
# Epoch 38/100, Loss: 0.1308
# Accuracy: 0.9587
# Precision: 0.9549
# Recall: 0.9587
# F1 Score: 0.9564
# AUC: 0.9971
# AUPR: 0.9919
# Specificity per class: [0.9655172413793104, 0.9849246231155779, 0.9911111111111112, 0.9965753424657534]
# Macro-average Specificity: 0.9845
# MCC per class: [0.9132015205357783, 0.918475629152568, 0.9769542224975036, 0.9549086757990868]
# Macro-average MCC: 0.9409
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9557
# ---------------------------------------------------------------------------------------------------
# Epoch 39/100, Loss: 0.0559
# Epoch 39/100, Loss: 0.1376
# Accuracy: 0.9553
# Precision: 0.9530
# Recall: 0.9553
# F1 Score: 0.9535
# AUC: 0.9973
# AUPR: 0.9921
# Specificity per class: [0.9525862068965517, 0.9849246231155779, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9835
# MCC per class: [0.8916088805902701, 0.9252324391444847, 0.9768873266890564, 0.9549086757990868]
# Macro-average MCC: 0.9372
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9531
# ---------------------------------------------------------------------------------------------------
# Epoch 40/100, Loss: 0.0511
# Epoch 40/100, Loss: 0.1233
# Accuracy: 0.9534
# Precision: 0.9575
# Recall: 0.9534
# F1 Score: 0.9549
# AUC: 0.9975
# AUPR: 0.9927
# Specificity per class: [0.9655172413793104, 0.9849246231155779, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9856
# MCC per class: [0.9217736534970257, 0.9252324391444847, 0.9845665445665446, 0.9312905566854962]
# Macro-average MCC: 0.9407
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9589
# ---------------------------------------------------------------------------------------------------
# Epoch 41/100, Loss: 0.0475
# Epoch 41/100, Loss: 0.1595
# Accuracy: 0.9539
# Precision: 0.9349
# Recall: 0.9539
# F1 Score: 0.9422
# AUC: 0.9975
# AUPR: 0.9909
# Specificity per class: [0.9439655172413793, 0.9949748743718593, 1.0, 0.9897260273972602]
# Macro-average Specificity: 0.9822
# MCC per class: [0.895325390526334, 0.8994978103502184, 0.9922876771341849, 0.9140014911483973]
# Macro-average MCC: 0.9253
# F1 Score (micro): 0.9462
# F1 Score (weighted): 0.9465
# ---------------------------------------------------------------------------------------------------
# Epoch 42/100, Loss: 0.0526
# Epoch 42/100, Loss: 0.1147
# Accuracy: 0.9621
# Precision: 0.9516
# Recall: 0.9621
# F1 Score: 0.9561
# AUC: 0.9974
# AUPR: 0.9948
# Specificity per class: [0.9913793103448276, 0.964824120603015, 0.9866666666666667, 0.9931506849315068]
# Macro-average Specificity: 0.9840
# MCC per class: [0.918172555376766, 0.9259354233325153, 0.9615706499287768, 0.9574729648393807]
# Macro-average MCC: 0.9408
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9555
# ---------------------------------------------------------------------------------------------------
# Epoch 43/100, Loss: 0.0541
# Epoch 43/100, Loss: 0.1142
# Accuracy: 0.9712
# Precision: 0.9606
# Recall: 0.9712
# F1 Score: 0.9656
# AUC: 0.9980
# AUPR: 0.9939
# Specificity per class: [0.9741379310344828, 0.9849246231155779, 0.9911111111111112, 0.9965753424657534]
# Macro-average Specificity: 0.9867
# MCC per class: [0.9281223053474523, 0.9252324391444847, 0.9769542224975036, 0.9781167255328594]
# Macro-average MCC: 0.9521
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9620
# ---------------------------------------------------------------------------------------------------
# Epoch 44/100, Loss: 0.0404
# Epoch 44/100, Loss: 0.1225
# Accuracy: 0.9587
# Precision: 0.9475
# Recall: 0.9587
# F1 Score: 0.9526
# AUC: 0.9979
# AUPR: 0.9939
# Specificity per class: [0.9698275862068966, 0.9899497487437185, 0.9866666666666667, 0.9931506849315068]
# Macro-average Specificity: 0.9849
# MCC per class: [0.9206073369943373, 0.9254926645253152, 0.9694477535121453, 0.9338605850305136]
# Macro-average MCC: 0.9374
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9557
# ---------------------------------------------------------------------------------------------------
# Epoch 45/100, Loss: 0.0412
# Epoch 45/100, Loss: 0.1674
# Accuracy: 0.9445
# Precision: 0.9223
# Recall: 0.9445
# F1 Score: 0.9304
# AUC: 0.9974
# AUPR: 0.9902
# Specificity per class: [0.9353448275862069, 0.9949748743718593, 1.0, 0.9863013698630136]
# Macro-average Specificity: 0.9792
# MCC per class: [0.881964418149203, 0.9126866390039042, 0.9538367162324234, 0.8952207487823]
# Macro-average MCC: 0.9109
# F1 Score (micro): 0.9367
# F1 Score (weighted): 0.9378
# ---------------------------------------------------------------------------------------------------
# Epoch 46/100, Loss: 0.0438
# Epoch 46/100, Loss: 0.1531
# Accuracy: 0.9325
# Precision: 0.9431
# Recall: 0.9325
# F1 Score: 0.9351
# AUC: 0.9975
# AUPR: 0.9912
# Specificity per class: [0.9310344827586207, 0.9949748743718593, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9795
# MCC per class: [0.8754129782615152, 0.90608495842879, 0.9768030891848316, 0.9072291086054585]
# Macro-average MCC: 0.9164
# F1 Score (micro): 0.9399
# F1 Score (weighted): 0.9406
# ---------------------------------------------------------------------------------------------------
# Epoch 47/100, Loss: 0.0438
# Epoch 47/100, Loss: 0.1146
# Accuracy: 0.9626
# Precision: 0.9538
# Recall: 0.9626
# F1 Score: 0.9578
# AUC: 0.9977
# AUPR: 0.9928
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9870
# MCC per class: [0.9291271099667554, 0.9387976740971787, 0.9768873266890564, 0.9338605850305136]
# Macro-average MCC: 0.9447
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9623
# ---------------------------------------------------------------------------------------------------
# Epoch 48/100, Loss: 0.0469
# Epoch 48/100, Loss: 0.1197
# Accuracy: 0.9438
# Precision: 0.9545
# Recall: 0.9438
# F1 Score: 0.9479
# AUC: 0.9983
# AUPR: 0.9939
# Specificity per class: [0.9568965517241379, 0.9899497487437185, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9847
# MCC per class: [0.9160470173873222, 0.9254926645253152, 0.9845665445665446, 0.9072291086054585]
# Macro-average MCC: 0.9333
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9558
# ---------------------------------------------------------------------------------------------------
# Epoch 49/100, Loss: 0.0412
# Epoch 49/100, Loss: 0.1277
# Accuracy: 0.9515
# Precision: 0.9548
# Recall: 0.9515
# F1 Score: 0.9520
# AUC: 0.9977
# AUPR: 0.9933
# Specificity per class: [0.9525862068965517, 0.9949748743718593, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9849
# MCC per class: [0.9090458721223321, 0.9325845850929314, 0.9768030891848316, 0.9312905566854962]
# Macro-average MCC: 0.9374
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9561
# ---------------------------------------------------------------------------------------------------
# Epoch 50/100, Loss: 0.0379
# Epoch 50/100, Loss: 0.1081
# Accuracy: 0.9630
# Precision: 0.9603
# Recall: 0.9630
# F1 Score: 0.9615
# AUC: 0.9977
# AUPR: 0.9944
# Specificity per class: [0.9741379310344828, 0.9849246231155779, 0.9911111111111112, 0.9965753424657534]
# Macro-average Specificity: 0.9867
# MCC per class: [0.9281223053474523, 0.9320062537742658, 0.9769542224975036, 0.9549086757990868]
# Macro-average MCC: 0.9480
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9620
# ---------------------------------------------------------------------------------------------------
# Epoch 51/100, Loss: 0.0397
# Epoch 51/100, Loss: 0.1066
# Accuracy: 0.9525
# Precision: 0.9572
# Recall: 0.9525
# F1 Score: 0.9545
# AUC: 0.9980
# AUPR: 0.9953
# Specificity per class: [0.9698275862068966, 0.9849246231155779, 0.9911111111111112, 0.9965753424657534]
# Macro-average Specificity: 0.9856
# MCC per class: [0.9206073369943373, 0.9320062537742658, 0.9769542224975036, 0.9312905566854962]
# Macro-average MCC: 0.9402
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9589
# ---------------------------------------------------------------------------------------------------
# Epoch 52/100, Loss: 0.0502
# Epoch 52/100, Loss: 0.0962
# Accuracy: 0.9576
# Precision: 0.9628
# Recall: 0.9576
# F1 Score: 0.9599
# AUC: 0.9981
# AUPR: 0.9956
# Specificity per class: [0.9741379310344828, 0.9849246231155779, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9878
# MCC per class: [0.9365879961071812, 0.9387976740971787, 0.9845665445665446, 0.9312905566854962]
# Macro-average MCC: 0.9478
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9652
# ---------------------------------------------------------------------------------------------------
# Epoch 53/100, Loss: 0.0307
# Epoch 53/100, Loss: 0.1228
# Accuracy: 0.9555
# Precision: 0.9368
# Recall: 0.9555
# F1 Score: 0.9447
# AUC: 0.9983
# AUPR: 0.9945
# Specificity per class: [0.9568965517241379, 0.9899497487437185, 0.9955555555555555, 0.9897260273972602]
# Macro-average Specificity: 0.9830
# MCC per class: [0.9160470173873222, 0.9054549279550154, 0.9768030891848316, 0.9140014911483973]
# Macro-average MCC: 0.9281
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9495
# ---------------------------------------------------------------------------------------------------
# Epoch 54/100, Loss: 0.0454
# Epoch 54/100, Loss: 0.0960
# Accuracy: 0.9573
# Precision: 0.9741
# Recall: 0.9573
# F1 Score: 0.9652
# AUC: 0.9982
# AUPR: 0.9963
# Specificity per class: [0.9827586206896551, 0.9798994974874372, 0.9911111111111112, 1.0]
# Macro-average Specificity: 0.9884
# MCC per class: [0.9267845820012487, 0.9595142500456046, 0.9769542224975036, 0.9541649956911371]
# Macro-average MCC: 0.9544
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9682
# ---------------------------------------------------------------------------------------------------
# Epoch 55/100, Loss: 0.0307
# Epoch 55/100, Loss: 0.0891
# Accuracy: 0.9651
# Precision: 0.9626
# Recall: 0.9651
# F1 Score: 0.9637
# AUC: 0.9986
# AUPR: 0.9959
# Specificity per class: [0.978448275862069, 0.9899497487437185, 0.9866666666666667, 0.9965753424657534]
# Macro-average Specificity: 0.9879
# MCC per class: [0.9357496161555404, 0.9456797751166062, 0.9694477535121453, 0.9549086757990868]
# Macro-average MCC: 0.9514
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9652
# ---------------------------------------------------------------------------------------------------
# Epoch 56/100, Loss: 0.0407
# Epoch 56/100, Loss: 0.1257
# Accuracy: 0.9721
# Precision: 0.9534
# Recall: 0.9721
# F1 Score: 0.9618
# AUC: 0.9979
# AUPR: 0.9932
# Specificity per class: [0.9698275862068966, 0.9949748743718593, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9873
# MCC per class: [0.9291271099667554, 0.9325845850929314, 0.9769542224975036, 0.9574729648393807]
# Macro-average MCC: 0.9490
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9620
# ---------------------------------------------------------------------------------------------------
# Epoch 57/100, Loss: 0.0291
# Epoch 57/100, Loss: 0.1344
# Accuracy: 0.9512
# Precision: 0.9542
# Recall: 0.9512
# F1 Score: 0.9518
# AUC: 0.9979
# AUPR: 0.9927
# Specificity per class: [0.9568965517241379, 0.9949748743718593, 0.9911111111111112, 0.9965753424657534]
# Macro-average Specificity: 0.9849
# MCC per class: [0.9073772042004405, 0.9325845850929314, 0.9769542224975036, 0.9312905566854962]
# Macro-average MCC: 0.9371
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9559
# ---------------------------------------------------------------------------------------------------
# Epoch 58/100, Loss: 0.0355
# Epoch 58/100, Loss: 0.1696
# Accuracy: 0.9393
# Precision: 0.9336
# Recall: 0.9393
# F1 Score: 0.9338
# AUC: 0.9973
# AUPR: 0.9913
# Specificity per class: [0.9310344827586207, 0.9949748743718593, 0.9955555555555555, 0.9931506849315068]
# Macro-average Specificity: 0.9787
# MCC per class: [0.8754129782615152, 0.886364825126441, 0.9845665445665446, 0.9098173515981736]
# Macro-average MCC: 0.9140
# F1 Score (micro): 0.9367
# F1 Score (weighted): 0.9371
# ---------------------------------------------------------------------------------------------------
# Epoch 59/100, Loss: 0.0372
# Epoch 59/100, Loss: 0.1203
# Accuracy: 0.9683
# Precision: 0.9504
# Recall: 0.9683
# F1 Score: 0.9586
# AUC: 0.9981
# AUPR: 0.9936
# Specificity per class: [0.9741379310344828, 0.9949748743718593, 0.9822222222222222, 0.9931506849315068]
# Macro-average Specificity: 0.9861
# MCC per class: [0.9196546412641213, 0.939250105582329, 0.9620442890220036, 0.9574729648393807]
# Macro-average MCC: 0.9446
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9589
# ---------------------------------------------------------------------------------------------------
# Epoch 60/100, Loss: 0.0446
# Epoch 60/100, Loss: 0.1104
# Accuracy: 0.9466
# Precision: 0.9512
# Recall: 0.9466
# F1 Score: 0.9485
# AUC: 0.9982
# AUPR: 0.9954
# Specificity per class: [0.9698275862068966, 0.9899497487437185, 0.9777777777777777, 0.9965753424657534]
# Macro-average Specificity: 0.9835
# MCC per class: [0.9035596663727024, 0.9389331631730534, 0.9547410841058538, 0.9312905566854962]
# Macro-average MCC: 0.9321
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9525
# ---------------------------------------------------------------------------------------------------
# Epoch 61/100, Loss: 0.0265
# Epoch 61/100, Loss: 0.1540
# Accuracy: 0.9202
# Precision: 0.9375
# Recall: 0.9202
# F1 Score: 0.9268
# AUC: 0.9976
# AUPR: 0.9918
# Specificity per class: [0.9525862068965517, 0.9949748743718593, 0.9688888888888889, 0.9965753424657534]
# Macro-average Specificity: 0.9783
# MCC per class: [0.8828857341614156, 0.9193034230536933, 0.9404249627388198, 0.882686929807428]
# Macro-average MCC: 0.9063
# F1 Score (micro): 0.9367
# F1 Score (weighted): 0.9367
# ---------------------------------------------------------------------------------------------------
# Epoch 62/100, Loss: 0.0234
# Epoch 62/100, Loss: 0.1378
# Accuracy: 0.9491
# Precision: 0.9442
# Recall: 0.9491
# F1 Score: 0.9458
# AUC: 0.9977
# AUPR: 0.9920
# Specificity per class: [0.9568965517241379, 0.9949748743718593, 0.9911111111111112, 0.9931506849315068]
# Macro-average Specificity: 0.9840
# MCC per class: [0.9073772042004405, 0.9259358814138647, 0.9769542224975036, 0.9098173515981736]
# Macro-average MCC: 0.9300
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9527
# ---------------------------------------------------------------------------------------------------
# Epoch 63/100, Loss: 0.0219
# Epoch 63/100, Loss: 0.1353
# Accuracy: 0.9536
# Precision: 0.9572
# Recall: 0.9536
# F1 Score: 0.9545
# AUC: 0.9974
# AUPR: 0.9927
# Specificity per class: [0.9568965517241379, 0.9949748743718593, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9860
# MCC per class: [0.9160470173873222, 0.939250105582329, 0.9768030891848316, 0.9312905566854962]
# Macro-average MCC: 0.9408
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9592
# ---------------------------------------------------------------------------------------------------
# Epoch 64/100, Loss: 0.0468
# Epoch 64/100, Loss: 0.1582
# Accuracy: 0.9521
# Precision: 0.9548
# Recall: 0.9521
# F1 Score: 0.9522
# AUC: 0.9973
# AUPR: 0.9933
# Specificity per class: [0.9525862068965517, 0.9949748743718593, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9849
# MCC per class: [0.9090458721223321, 0.9259358814138647, 0.9845665445665446, 0.9312905566854962]
# Macro-average MCC: 0.9377
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9560
# ---------------------------------------------------------------------------------------------------
# Epoch 65/100, Loss: 0.0339
# Epoch 65/100, Loss: 0.1335
# Accuracy: 0.9525
# Precision: 0.9563
# Recall: 0.9525
# F1 Score: 0.9539
# AUC: 0.9974
# AUPR: 0.9918
# Specificity per class: [0.9655172413793104, 0.9949748743718593, 0.9866666666666667, 0.9965753424657534]
# Macro-average Specificity: 0.9859
# MCC per class: [0.9132015205357783, 0.9459330151619536, 0.9694477535121453, 0.9312905566854962]
# Macro-average MCC: 0.9400
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9590
# ---------------------------------------------------------------------------------------------------
# Epoch 66/100, Loss: 0.0341
# Epoch 66/100, Loss: 0.1242
# Accuracy: 0.9704
# Precision: 0.9532
# Recall: 0.9704
# F1 Score: 0.9612
# AUC: 0.9977
# AUPR: 0.9921
# Specificity per class: [0.978448275862069, 0.9949748743718593, 0.9822222222222222, 0.9931506849315068]
# Macro-average Specificity: 0.9872
# MCC per class: [0.9273382946495989, 0.9459330151619536, 0.9620442890220036, 0.9574729648393807]
# Macro-average MCC: 0.9482
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9620
# ---------------------------------------------------------------------------------------------------
# Epoch 67/100, Loss: 0.0310
# Epoch 67/100, Loss: 0.1631
# Accuracy: 0.9367
# Precision: 0.9243
# Recall: 0.9367
# F1 Score: 0.9293
# AUC: 0.9973
# AUPR: 0.9898
# Specificity per class: [0.9612068965517241, 0.9949748743718593, 0.9688888888888889, 0.9897260273972602]
# Macro-average Specificity: 0.9787
# MCC per class: [0.8972759311048011, 0.90608495842879, 0.9404249627388198, 0.8896044445281678]
# Macro-average MCC: 0.9083
# F1 Score (micro): 0.9367
# F1 Score (weighted): 0.9367
# ---------------------------------------------------------------------------------------------------
# Epoch 68/100, Loss: 0.0217
# Epoch 68/100, Loss: 0.1577
# Accuracy: 0.9417
# Precision: 0.9520
# Recall: 0.9417
# F1 Score: 0.9451
# AUC: 0.9972
# AUPR: 0.9913
# Specificity per class: [0.9482758620689655, 0.9949748743718593, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9838
# MCC per class: [0.9021394970306476, 0.9259358814138647, 0.9845665445665446, 0.9072291086054585]
# Macro-average MCC: 0.9300
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9528
# ---------------------------------------------------------------------------------------------------
# Epoch 69/100, Loss: 0.0210
# Epoch 69/100, Loss: 0.1264
# Accuracy: 0.9557
# Precision: 0.9381
# Recall: 0.9557
# F1 Score: 0.9461
# AUC: 0.9980
# AUPR: 0.9934
# Specificity per class: [0.9698275862068966, 0.9949748743718593, 0.9822222222222222, 0.9897260273972602]
# Macro-average Specificity: 0.9842
# MCC per class: [0.9120851963967855, 0.9325845850929314, 0.9620442890220036, 0.9140014911483973]
# Macro-average MCC: 0.9302
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9527
# ---------------------------------------------------------------------------------------------------
# Epoch 70/100, Loss: 0.0261
# Epoch 70/100, Loss: 0.1066
# Accuracy: 0.9708
# Precision: 0.9646
# Recall: 0.9708
# F1 Score: 0.9674
# AUC: 0.9983
# AUPR: 0.9960
# Specificity per class: [0.9913793103448276, 0.9798994974874372, 0.9822222222222222, 0.9965753424657534]
# Macro-average Specificity: 0.9875
# MCC per class: [0.9346461321459099, 0.945711463299403, 0.9620442890220036, 0.9781167255328594]
# Macro-average MCC: 0.9551
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9650
# ---------------------------------------------------------------------------------------------------
# Epoch 71/100, Loss: 0.0297
# Epoch 71/100, Loss: 0.1168
# Accuracy: 0.9491
# Precision: 0.9375
# Recall: 0.9491
# F1 Score: 0.9425
# AUC: 0.9979
# AUPR: 0.9924
# Specificity per class: [0.9612068965517241, 0.9949748743718593, 0.9911111111111112, 0.9897260273972602]
# Macro-average Specificity: 0.9843
# MCC per class: [0.9145246423032853, 0.9259358814138647, 0.9769542224975036, 0.8896044445281678]
# Macro-average MCC: 0.9268
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9527
# ---------------------------------------------------------------------------------------------------
# Epoch 72/100, Loss: 0.0314
# Epoch 72/100, Loss: 0.1399
# Accuracy: 0.9461
# Precision: 0.9346
# Recall: 0.9461
# F1 Score: 0.9396
# AUC: 0.9980
# AUPR: 0.9938
# Specificity per class: [0.9655172413793104, 0.9949748743718593, 0.9822222222222222, 0.9897260273972602]
# Macro-average Specificity: 0.9831
# MCC per class: [0.9132015205357783, 0.9259358814138647, 0.9620442890220036, 0.8896044445281678]
# Macro-average MCC: 0.9227
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9495
# ---------------------------------------------------------------------------------------------------
# Epoch 73/100, Loss: 0.0221
# Epoch 73/100, Loss: 0.0978
# Accuracy: 0.9606
# Precision: 0.9730
# Recall: 0.9606
# F1 Score: 0.9659
# AUC: 0.9983
# AUPR: 0.9961
# Specificity per class: [0.9655172413793104, 0.9949748743718593, 0.9955555555555555, 1.0]
# Macro-average Specificity: 0.9890
# MCC per class: [0.9303440963742202, 0.9526338872016222, 0.9845665445665446, 0.9541649956911371]
# Macro-average MCC: 0.9554
# F1 Score (micro): 0.9684
# F1 Score (weighted): 0.9685
# ---------------------------------------------------------------------------------------------------
# Epoch 74/100, Loss: 0.0230
# Epoch 74/100, Loss: 0.1299
# Accuracy: 0.9521
# Precision: 0.9476
# Recall: 0.9521
# F1 Score: 0.9487
# AUC: 0.9981
# AUPR: 0.9937
# Specificity per class: [0.9525862068965517, 0.9949748743718593, 1.0, 0.9931506849315068]
# Macro-average Specificity: 0.9852
# MCC per class: [0.9090458721223321, 0.9259358814138647, 0.9922876771341849, 0.9098173515981736]
# Macro-average MCC: 0.9343
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9561
# ---------------------------------------------------------------------------------------------------
# Epoch 75/100, Loss: 0.0258
# Epoch 75/100, Loss: 0.1005
# Accuracy: 0.9721
# Precision: 0.9647
# Recall: 0.9721
# F1 Score: 0.9683
# AUC: 0.9983
# AUPR: 0.9966
# Specificity per class: [0.9827586206896551, 0.9748743718592965, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9874
# MCC per class: [0.9434925890878169, 0.9321393291242538, 0.9690466897894506, 0.9781167255328594]
# Macro-average MCC: 0.9557
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9652
# ---------------------------------------------------------------------------------------------------
# Epoch 76/100, Loss: 0.0287
# Epoch 76/100, Loss: 0.1115
# Accuracy: 0.9555
# Precision: 0.9675
# Recall: 0.9555
# F1 Score: 0.9606
# AUC: 0.9984
# AUPR: 0.9959
# Specificity per class: [0.9655172413793104, 0.9949748743718593, 0.9866666666666667, 1.0]
# Macro-average Specificity: 0.9868
# MCC per class: [0.9217736534970257, 0.9459330151619536, 0.9694477535121453, 0.9541649956911371]
# Macro-average MCC: 0.9478
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9622
# ---------------------------------------------------------------------------------------------------
# Epoch 77/100, Loss: 0.0232
# Epoch 77/100, Loss: 0.1064
# Accuracy: 0.9712
# Precision: 0.9603
# Recall: 0.9712
# F1 Score: 0.9654
# AUC: 0.9988
# AUPR: 0.9970
# Specificity per class: [0.978448275862069, 0.9899497487437185, 0.9822222222222222, 0.9965753424657534]
# Macro-average Specificity: 0.9868
# MCC per class: [0.9357496161555404, 0.9322043221572608, 0.9620442890220036, 0.9781167255328594]
# Macro-average MCC: 0.9520
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9619
# ---------------------------------------------------------------------------------------------------
# Epoch 78/100, Loss: 0.0290
# Epoch 78/100, Loss: 0.1137
# Accuracy: 0.9630
# Precision: 0.9594
# Recall: 0.9630
# F1 Score: 0.9608
# AUC: 0.9983
# AUPR: 0.9952
# Specificity per class: [0.9698275862068966, 0.9949748743718593, 0.9866666666666667, 0.9965753424657534]
# Macro-average Specificity: 0.9870
# MCC per class: [0.9206073369943373, 0.9459330151619536, 0.9694477535121453, 0.9549086757990868]
# Macro-average MCC: 0.9477
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9621
# ---------------------------------------------------------------------------------------------------
# Epoch 79/100, Loss: 0.0192
# Epoch 79/100, Loss: 0.1530
# Accuracy: 0.9493
# Precision: 0.9530
# Recall: 0.9493
# F1 Score: 0.9496
# AUC: 0.9969
# AUPR: 0.9935
# Specificity per class: [0.9439655172413793, 0.9949748743718593, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9839
# MCC per class: [0.895325390526334, 0.9259358814138647, 0.9845836908536074, 0.9312905566854962]
# Macro-average MCC: 0.9343
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9532
# ---------------------------------------------------------------------------------------------------
# Epoch 80/100, Loss: 0.0195
# Epoch 80/100, Loss: 0.0993
# Accuracy: 0.9570
# Precision: 0.9549
# Recall: 0.9570
# F1 Score: 0.9558
# AUC: 0.9986
# AUPR: 0.9965
# Specificity per class: [0.978448275862069, 0.9849246231155779, 0.9777777777777777, 0.9965753424657534]
# Macro-average Specificity: 0.9844
# MCC per class: [0.9189244663382594, 0.9320062537742658, 0.9547410841058538, 0.9549086757990868]
# Macro-average MCC: 0.9401
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9556
# ---------------------------------------------------------------------------------------------------
# Epoch 81/100, Loss: 0.0225
# Epoch 81/100, Loss: 0.1260
# Accuracy: 0.9536
# Precision: 0.9569
# Recall: 0.9536
# F1 Score: 0.9544
# AUC: 0.9975
# AUPR: 0.9926
# Specificity per class: [0.9612068965517241, 0.9949748743718593, 0.9911111111111112, 0.9965753424657534]
# Macro-average Specificity: 0.9860
# MCC per class: [0.923145527810611, 0.939250105582329, 0.9691330891330892, 0.9312905566854962]
# Macro-average MCC: 0.9407
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9590
# ---------------------------------------------------------------------------------------------------
# Epoch 82/100, Loss: 0.0223
# Epoch 82/100, Loss: 0.1455
# Accuracy: 0.9542
# Precision: 0.9569
# Recall: 0.9542
# F1 Score: 0.9547
# AUC: 0.9978
# AUPR: 0.9933
# Specificity per class: [0.9612068965517241, 0.9949748743718593, 0.9911111111111112, 0.9965753424657534]
# Macro-average Specificity: 0.9860
# MCC per class: [0.923145527810611, 0.9325845850929314, 0.9769542224975036, 0.9312905566854962]
# Macro-average MCC: 0.9410
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9589
# ---------------------------------------------------------------------------------------------------
# Epoch 83/100, Loss: 0.0235
# Epoch 83/100, Loss: 0.0969
# Accuracy: 0.9651
# Precision: 0.9620
# Recall: 0.9651
# F1 Score: 0.9633
# AUC: 0.9986
# AUPR: 0.9959
# Specificity per class: [0.9741379310344828, 0.9949748743718593, 0.9866666666666667, 0.9965753424657534]
# Macro-average Specificity: 0.9881
# MCC per class: [0.9281223053474523, 0.9526338872016222, 0.9694477535121453, 0.9549086757990868]
# Macro-average MCC: 0.9513
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9653
# ---------------------------------------------------------------------------------------------------
# Epoch 84/100, Loss: 0.0323
# Epoch 84/100, Loss: 0.1007
# Accuracy: 0.9642
# Precision: 0.9703
# Recall: 0.9642
# F1 Score: 0.9670
# AUC: 0.9984
# AUPR: 0.9963
# Specificity per class: [0.978448275862069, 0.9899497487437185, 0.9822222222222222, 1.0]
# Macro-average Specificity: 0.9877
# MCC per class: [0.9273382946495989, 0.9524447467356325, 0.9620442890220036, 0.9772730279218427]
# Macro-average MCC: 0.9548
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9652
# ---------------------------------------------------------------------------------------------------
# Epoch 85/100, Loss: 0.0272
# Epoch 85/100, Loss: 0.1345
# Accuracy: 0.9400
# Precision: 0.9507
# Recall: 0.9400
# F1 Score: 0.9444
# AUC: 0.9977
# AUPR: 0.9922
# Specificity per class: [0.9612068965517241, 0.9949748743718593, 0.9822222222222222, 0.9965753424657534]
# Macro-average Specificity: 0.9837
# MCC per class: [0.9059017880597403, 0.939250105582329, 0.9620442890220036, 0.9072291086054585]
# Macro-average MCC: 0.9286
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9526
# ---------------------------------------------------------------------------------------------------
# Epoch 86/100, Loss: 0.0270
# Epoch 86/100, Loss: 0.1295
# Accuracy: 0.9534
# Precision: 0.9567
# Recall: 0.9534
# F1 Score: 0.9543
# AUC: 0.9980
# AUPR: 0.9954
# Specificity per class: [0.9612068965517241, 0.9949748743718593, 0.9911111111111112, 0.9965753424657534]
# Macro-average Specificity: 0.9860
# MCC per class: [0.9145246423032853, 0.939250105582329, 0.9769542224975036, 0.9312905566854962]
# Macro-average MCC: 0.9405
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9590
# ---------------------------------------------------------------------------------------------------
# Epoch 87/100, Loss: 0.0235
# Epoch 87/100, Loss: 0.1129
# Accuracy: 0.9704
# Precision: 0.9599
# Recall: 0.9704
# F1 Score: 0.9647
# AUC: 0.9981
# AUPR: 0.9949
# Specificity per class: [0.978448275862069, 0.9949748743718593, 0.9777777777777777, 0.9965753424657534]
# Macro-average Specificity: 0.9869
# MCC per class: [0.9273382946495989, 0.9459330151619536, 0.9547410841058538, 0.9781167255328594]
# Macro-average MCC: 0.9515
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9620
# ---------------------------------------------------------------------------------------------------
# Epoch 88/100, Loss: 0.0137
# Epoch 88/100, Loss: 0.1197
# Accuracy: 0.9587
# Precision: 0.9545
# Recall: 0.9587
# F1 Score: 0.9562
# AUC: 0.9981
# AUPR: 0.9957
# Specificity per class: [0.9698275862068966, 0.9899497487437185, 0.9822222222222222, 0.9965753424657534]
# Macro-average Specificity: 0.9846
# MCC per class: [0.9206073369943373, 0.9254926645253152, 0.9620442890220036, 0.9549086757990868]
# Macro-average MCC: 0.9408
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9557
# ---------------------------------------------------------------------------------------------------
# Epoch 89/100, Loss: 0.0183
# Epoch 89/100, Loss: 0.1634
# Accuracy: 0.9470
# Precision: 0.9492
# Recall: 0.9470
# F1 Score: 0.9469
# AUC: 0.9973
# AUPR: 0.9910
# Specificity per class: [0.9525862068965517, 0.9949748743718593, 0.9866666666666667, 0.9965753424657534]
# Macro-average Specificity: 0.9827
# MCC per class: [0.9003285737788081, 0.9193034230536933, 0.9694477535121453, 0.9312905566854962]
# Macro-average MCC: 0.9301
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9495
# ---------------------------------------------------------------------------------------------------
# Epoch 90/100, Loss: 0.0206
# Epoch 90/100, Loss: 0.1259
# Accuracy: 0.9579
# Precision: 0.9627
# Recall: 0.9579
# F1 Score: 0.9597
# AUC: 0.9979
# AUPR: 0.9938
# Specificity per class: [0.9655172413793104, 0.9899497487437185, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9880
# MCC per class: [0.9303440963742202, 0.9456797751166062, 0.9845836908536074, 0.9312905566854962]
# Macro-average MCC: 0.9480
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9654
# ---------------------------------------------------------------------------------------------------
# Epoch 91/100, Loss: 0.0134
# Epoch 91/100, Loss: 0.1358
# Accuracy: 0.9565
# Precision: 0.9519
# Recall: 0.9565
# F1 Score: 0.9537
# AUC: 0.9977
# AUPR: 0.9925
# Specificity per class: [0.9655172413793104, 0.9899497487437185, 0.9822222222222222, 0.9965753424657534]
# Macro-average Specificity: 0.9836
# MCC per class: [0.9132015205357783, 0.918797603624423, 0.9620442890220036, 0.9549086757990868]
# Macro-average MCC: 0.9372
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9525
# ---------------------------------------------------------------------------------------------------
# Epoch 92/100, Loss: 0.0178
# Epoch 92/100, Loss: 0.1065
# Accuracy: 0.9651
# Precision: 0.9626
# Recall: 0.9651
# F1 Score: 0.9637
# AUC: 0.9981
# AUPR: 0.9948
# Specificity per class: [0.978448275862069, 0.9899497487437185, 0.9866666666666667, 0.9965753424657534]
# Macro-average Specificity: 0.9879
# MCC per class: [0.9357496161555404, 0.9456797751166062, 0.9694477535121453, 0.9549086757990868]
# Macro-average MCC: 0.9514
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9652
# ---------------------------------------------------------------------------------------------------
# Epoch 93/100, Loss: 0.0176
# Epoch 93/100, Loss: 0.1028
# Accuracy: 0.9696
# Precision: 0.9607
# Recall: 0.9696
# F1 Score: 0.9649
# AUC: 0.9982
# AUPR: 0.9946
# Specificity per class: [0.9827586206896551, 0.9849246231155779, 0.9822222222222222, 0.9965753424657534]
# Macro-average Specificity: 0.9866
# MCC per class: [0.9267845820012487, 0.9387976740971787, 0.9620442890220036, 0.9781167255328594]
# Macro-average MCC: 0.9514
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9619
# ---------------------------------------------------------------------------------------------------
# Epoch 94/100, Loss: 0.0287
# Epoch 94/100, Loss: 0.1108
# Accuracy: 0.9472
# Precision: 0.9598
# Recall: 0.9472
# F1 Score: 0.9528
# AUC: 0.9979
# AUPR: 0.9946
# Specificity per class: [0.9655172413793104, 0.9849246231155779, 1.0, 0.9965753424657534]
# Macro-average Specificity: 0.9868
# MCC per class: [0.9217736534970257, 0.9387976740971787, 0.9922876771341849, 0.9072291086054585]
# Macro-average MCC: 0.9400
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9621
# ---------------------------------------------------------------------------------------------------
# Epoch 95/100, Loss: 0.0171
# Epoch 95/100, Loss: 0.1300
# Accuracy: 0.9461
# Precision: 0.9412
# Recall: 0.9461
# F1 Score: 0.9429
# AUC: 0.9981
# AUPR: 0.9936
# Specificity per class: [0.9612068965517241, 0.9949748743718593, 0.9822222222222222, 0.9931506849315068]
# Macro-average Specificity: 0.9829
# MCC per class: [0.9059017880597403, 0.9259358814138647, 0.9620442890220036, 0.9098173515981736]
# Macro-average MCC: 0.9259
# F1 Score (micro): 0.9494
# F1 Score (weighted): 0.9495
# ---------------------------------------------------------------------------------------------------
# Epoch 96/100, Loss: 0.0241
# Epoch 96/100, Loss: 0.1409
# Accuracy: 0.9417
# Precision: 0.9516
# Recall: 0.9417
# F1 Score: 0.9451
# AUC: 0.9975
# AUPR: 0.9919
# Specificity per class: [0.9525862068965517, 0.9949748743718593, 0.9911111111111112, 0.9965753424657534]
# Macro-average Specificity: 0.9838
# MCC per class: [0.9090458721223321, 0.9259358814138647, 0.9769542224975036, 0.9072291086054585]
# Macro-average MCC: 0.9298
# F1 Score (micro): 0.9525
# F1 Score (weighted): 0.9527
# ---------------------------------------------------------------------------------------------------
# Epoch 97/100, Loss: 0.0172
# Epoch 97/100, Loss: 0.1178
# Accuracy: 0.9587
# Precision: 0.9476
# Recall: 0.9587
# F1 Score: 0.9527
# AUC: 0.9984
# AUPR: 0.9952
# Specificity per class: [0.9741379310344828, 0.9899497487437185, 0.9822222222222222, 0.9931506849315068]
# Macro-average Specificity: 0.9849
# MCC per class: [0.9281223053474523, 0.9254926645253152, 0.9620442890220036, 0.9338605850305136]
# Macro-average MCC: 0.9374
# F1 Score (micro): 0.9557
# F1 Score (weighted): 0.9556
# ---------------------------------------------------------------------------------------------------
# Epoch 98/100, Loss: 0.0192
# Epoch 98/100, Loss: 0.0970
# Accuracy: 0.9651
# Precision: 0.9626
# Recall: 0.9651
# F1 Score: 0.9637
# AUC: 0.9983
# AUPR: 0.9957
# Specificity per class: [0.978448275862069, 0.9899497487437185, 0.9866666666666667, 0.9965753424657534]
# Macro-average Specificity: 0.9879
# MCC per class: [0.9357496161555404, 0.9456797751166062, 0.9694477535121453, 0.9549086757990868]
# Macro-average MCC: 0.9514
# F1 Score (micro): 0.9652
# F1 Score (weighted): 0.9652
# ---------------------------------------------------------------------------------------------------
# Epoch 99/100, Loss: 0.0162
# Epoch 99/100, Loss: 0.1383
# Accuracy: 0.9542
# Precision: 0.9574
# Recall: 0.9542
# F1 Score: 0.9550
# AUC: 0.9970
# AUPR: 0.9923
# Specificity per class: [0.9612068965517241, 0.9899497487437185, 0.9955555555555555, 0.9965753424657534]
# Macro-average Specificity: 0.9858
# MCC per class: [0.923145527810611, 0.9254926645253152, 0.9845665445665446, 0.9312905566854962]
# Macro-average MCC: 0.9411
# F1 Score (micro): 0.9589
# F1 Score (weighted): 0.9589
# ---------------------------------------------------------------------------------------------------
# Epoch 100/100, Loss: 0.0240
# Epoch 100/100, Loss: 0.1255
# Accuracy: 0.9696
# Precision: 0.9607
# Recall: 0.9696
# F1 Score: 0.9649
# AUC: 0.9977
# AUPR: 0.9941
# Specificity per class: [0.9827586206896551, 0.9849246231155779, 0.9822222222222222, 0.9965753424657534]
# Macro-average Specificity: 0.9866
# MCC per class: [0.9267845820012487, 0.9387976740971787, 0.9620442890220036, 0.9781167255328594]
# Macro-average MCC: 0.9514
# F1 Score (micro): 0.9620
# F1 Score (weighted): 0.9619
# ---------------------------------------------------------------------------------------------------
# Training and validating complete
